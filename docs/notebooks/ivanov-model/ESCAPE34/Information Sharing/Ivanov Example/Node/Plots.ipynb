# %%
import pandas
import matplotlib.pyplot as plt
from matplotlib import rc


loc6_varying_factor_ex = pandas.DataFrame(data={'com1_process': [1]*12})

loc6_varying_factor_ac = pandas.DataFrame(data={'com1_process': [1]*6 + [0]*6})

# %%
# rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
# rc('text', usetex=False)
# 
# fig, ax = plt.subplots()
# 
# # Plot data from the first dataset
# ax.plot(range(len(loc1_varying_factor_ex['com1_pur'])), loc1_varying_factor_ex['com1_pur'], label='Expected',
#         color='blue', marker='o')
# 
# ax.plot(range(len(loc1_varying_factor_ac['com1_pur'])), loc1_varying_factor_ac['com1_pur'], label='Actual',
#         color='red', marker='x')
# # Customize the plot
# ax.set_xlabel('Time Horizon')
# ax.set_ylabel('Normalized Availability Factor')
# ax.set_title('Resource Availability factor at Location 1')
# ax.legend()
# ax.plot(linewidth=0.5)
# plt.grid(alpha=0.3)
# plt.rcdefaults()
# # Show the plot
# plt.show()

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(1, len(loc6_varying_factor_ex['com1_process'])+1), loc6_varying_factor_ex['com1_process'], label='Expected',
        color='blue', marker='o')

ax.plot(range(1, len(loc6_varying_factor_ac['com1_process'])+1), loc6_varying_factor_ac['com1_process'], label='Actual',
        color='red', marker='x')
# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Normalized Capacity Factor')
ax.set_title('Processing Capacity Factor at Location 6')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
varying_list_ex = [1.00, 0.53, 0.58, 0.53, 0.65, 0.73] + [1.75, 1.74, 1.72, 1.72, 1.79, 1.80]
varying_list_ac = [1.00, 0.53, 0.58, 0.53, 0.65, 0.73] + [0.78, 0.91, 0.89, 1.2, 1.14, 0.83]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(varying_list_ex)), varying_list_ex, label='Expected',
        color='blue', marker='o')

ax.plot(range(len(varying_list_ac)), varying_list_ac, label='Actual',
        color='red', marker='x')
# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Normalized Demand Factor')
ax.set_title('Demand factor at Location 5')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

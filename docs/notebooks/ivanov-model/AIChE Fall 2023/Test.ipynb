# %%
import sys

sys.path.append('../../src')
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set

# %%
_time_intervals = 30  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 12  # Number of execution scenarios                     (chi)

init = [1]

loc1_varying_factor = pandas.DataFrame(
    data={'com1_pur': [1.0, 0.6, 0.25, 0.13, 0.17, 0.57, 0.72, 0.49, 0.21, 0.3, 0.59, 0.69]})

loc6_varying_factor = pandas.DataFrame(
    data={'com1_pur': [1.0, 0.36, 0.68, 0.28, 0.41, 0.15, 0.15, 0.68, 0.73, 0.54, 0.19, 0.13]})

# loc1_varying_factor = pandas.DataFrame(
#     data={'com1_pur': init + [math.ceil(random.uniform(0, 0.75)*100)/100.0 for _ in range(_exec_scenarios-1)]})
# 
# loc6_varying_factor = pandas.DataFrame(
#     data={'com1_pur': init + [math.ceil(random.uniform(0, 0.75)*100)/100.0 for _ in range(_exec_scenarios-1)]})

M = 1e6  # Big M

# Define temporal scales
scales = TemporalScale(discretization_list=[1, _exec_scenarios, _time_intervals])

demand_factor = [1] * _exec_scenarios

# %%
list(loc1_varying_factor['com1_pur'])
# Out:
# [1.0, 0.6, 0.25, 0.13, 0.17, 0.57, 0.72, 0.49, 0.21, 0.3, 0.59, 0.69]

# %%
list(loc6_varying_factor['com1_pur'])
# Out:
# [1.0, 0.36, 0.68, 0.28, 0.41, 0.15, 0.15, 0.68, 0.73, 0.54, 0.19, 0.13]

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================

com1_pur = Resource(name='com1_pur', cons_max=200, block={'imp': 1, 'urg': 1}, price=0.00,
                    label='Commodity 1 consumed from outside the system',
                    varying=[VaryingResource.DETERMINISTIC_AVAILABILITY])

com1_in = Resource(name='com1_in', label='Commodity 1 received')

com1_stored10 = Resource(name='com1_stored10', store_max=10, label='Commodity 1 in storage10')
com1_stored20 = Resource(name='com1_stored20', store_max=20, label='Commodity 1 in storage20')
com1_stored50 = Resource(name='com1_stored50', store_max=50, label='Commodity 1 in storage50')

com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True,
                     label='Commodity 1 sold to outside the system')

# com2_pur = Resource(name='com2_pur', cons_max=200, block={'imp': 1, 'urg': 1}, price=50,
#                     label='Commodity 2 consumed from outside the system', varying=[VaryingResource.DETERMINISTIC_AVAILABILITY])
# 
# com2 = Resource(name='com2', block={'imp': 1, 'urg': 1}, label='Commodity 2')
# 
# com2_sold = Resource(name='com2_sold', revenue=80.00, demand=True, sell=True, label='Commodity 2 sold to outside the system')

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_procure = Process(name='procure com1', prod_max=M, conversion={com1_pur: -1, com1_in: 1}, capex=0, vopex=0,
                       fopex=0,
                       label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=M, conversion={com1_out: -1, com1_sold: 1}, capex=0, vopex=0, fopex=0,
                    label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=M, conversion={com1_loc1_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=M, conversion={com1_loc2_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=M, conversion={com1_loc3_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=M, conversion={com1_loc4_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 4')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=M, conversion={com1_loc6_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=M, conversion={com1_loc7_out: -1, com1_in: 1}, capex=0,
                            vopex=0, fopex=0,
                            label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=M, conversion={com1_in: -1, com1_out: 1}, capex=750, vopex=50,
                       fopex=0,
                       label='Process the commodity through the location')

com1_store10 = Process(name='com1_store10', conversion={com1_in: -1, com1_stored10: 1}, store_max=10 / _coms,
                       prod_max=M, capex=1000, vopex=20,
                       label="Storage capacity of 10 units")
com1_discharge10 = Process(name='com1_discharge10', conversion={com1_stored10: -1, com1_out: 1},
                           label='Discharge process from storage')

com1_store20 = Process(name='com1_store20', conversion={com1_in: -1, com1_stored20: 1}, store_max=20 / _coms,
                       prod_max=M, capex=2000, vopex=15,
                       label="Storage capacity of 20 units")
com1_discharge20 = Process(name='com1_discharge20', conversion={com1_stored20: -1, com1_out: 1},
                           label='Discharge process from storage')

com1_store50 = Process(name='com1_store50', conversion={com1_in: -1, com1_stored50: 1}, store_max=50 / _coms,
                       prod_max=M, capex=5000, vopex=10,
                       label="Storage capacity of 50 units")
com1_discharge50 = Process(name='com1_discharge50', conversion={com1_stored50: -1, com1_out: 1},
                           label='Discharge process from storage')

com1_loc1_send = Process(name='com1_loc1_send', prod_max=M, conversion={com1_out: -1, com1_loc1_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=M, conversion={com1_out: -1, com1_loc2_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=M, conversion={com1_out: -1, com1_loc3_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=M, conversion={com1_out: -1, com1_loc4_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')
# com1_loc5_send = Process(name='com1_loc5_send', prod_max=M, conversion={com1_out:-1, com1_loc5_out:1}, capex=0, vopex=0, fopex=0,
#                             label='Send commodity one from location 1')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=M, conversion={com1_out: -1, com1_loc6_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=M, conversion={com1_out: -1, com1_loc7_out: 1}, capex=0,
                         vopex=0, fopex=0,
                         label='Send commodity one from location 1')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_process, com1_store20, com1_discharge20, com1_loc1_send},
                label="Location 1", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1,
                availability_factor={com1_pur: loc1_varying_factor[['com1_pur']]})

loc2 = Location(name='loc2',
                processes={com1_receive_loc1, com1_process, com1_store20, com1_discharge20, com1_loc2_send},
                label="Location 2", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1)

loc3 = Location(name='loc3',
                processes={com1_receive_loc1, com1_process, com1_store20, com1_discharge20, com1_loc3_send},
                label="Location 3", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1)

loc4 = Location(name='loc4',
                processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_process, com1_store50,
                           com1_discharge50, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1)

loc5 = Location(name='loc5',
                processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store50,
                           com1_sell, com1_discharge50}, label="Location 5", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1)

loc6 = Location(name='loc6', processes={com1_procure, com1_process, com1_store10, com1_discharge10, com1_loc6_send},
                label="Location 6", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1,
                availability_factor={com1_pur: loc6_varying_factor[['com1_pur']]})

loc7 = Location(name='loc7',
                processes={com1_receive_loc4, com1_process, com1_store20, com1_discharge20, com1_loc7_send},
                label="Location 7", scales=scales, demand_scale_level=2,
                capacity_scale_level=1, availability_scale_level=1)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================
truck20 = Transport(name='truck20', resources=[com1_loc3_out], trans_max=20,
                    label='Truck with maximum capacity of 20 units', capex=200, vopex=15)
truck30 = Transport(name='truck30', resources=[com1_loc1_out, com1_loc2_out], trans_max=30,
                    label='Truck with maximum capacity of 30 units', capex=300, vopex=12)
truck40 = Transport(name='truck40', resources=[com1_loc4_out, com1_loc7_out], trans_max=40,
                    label='Truck with maximum capacity of 40 units', capex=400, vopex=10)
truck50 = Transport(name='truck50', resources=[com1_loc1_out, com1_loc2_out, com1_loc6_out], trans_max=50,
                    label='Truck with maximum capacity of 50 units', capex=500, vopex=7)
truck100 = Transport(name='truck100', resources=[com1_loc4_out], trans_max=100,
                     label='Truck with maximum capacity of 100 units', capex=1000, vopex=5)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================
transport_matrix = [
    [[], [truck50], [truck30], [], [], [], []],  # sink: location 1
    [[truck50], [], [], [truck50], [truck30], [], []],  # sink: location 2
    [[truck30], [], [], [truck20], [], [], []],  # sink: location 3
    [[], [truck50], [truck20], [], [truck100], [truck50], [truck40]],  # sink: location 4
    [[], [truck30], [], [truck100], [], [], [truck40]],  # sink: location 5
    [[], [], [], [truck50], [], [], []],  # sink: location 6
    [[], [], [], [truck40], [truck40], [], []]  # sink: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = list(locset)
sinks = list(locset)

network = Network(name='Network', scales=scales, source_locations=sources, sink_locations=sinks,
                  transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
demand_dict = {i: {com1_sold: 100} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: 5000} if i == loc5 else {com1_sold: 0} for i in locset}

scenario_disruption = Scenario(name='scenario_disruption', scales=scales, scheduling_scale_level=2,
                               network_scale_level=0, purchase_scale_level=2, availability_scale_level=1,
                               demand_scale_level=2, capacity_scale_level=1,
                               network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                               label='scenario_disruption')

# %%
min_demand_satisfaction76 = 0.76
min_demand_dict76 = {i: {com1_sold: min_demand_satisfaction76 * 100} if i == loc5 else {com1_sold: 0} for i in locset}

scenario_disruption76 = Scenario(name='scenario_disruption76', scales=scales, scheduling_scale_level=2,
                               network_scale_level=0, purchase_scale_level=2, availability_scale_level=1,
                               demand_scale_level=2, capacity_scale_level=1,
                               network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                               label='scenario_disruption76')

# %%
min_demand_satisfaction80 = 0.80
min_demand_dict80 = {i: {com1_sold: min_demand_satisfaction80 * 100} if i == loc5 else {com1_sold: 0} for i in locset}

scenario_disruption80 = Scenario(name='scenario_disruption80', scales=scales, scheduling_scale_level=2,
                               network_scale_level=0, purchase_scale_level=2, availability_scale_level=1,
                               demand_scale_level=2, capacity_scale_level=1,
                               network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                               label='scenario_disruption80')

# %%
min_demand_satisfaction82 = 0.82
min_demand_dict82 = {i: {com1_sold: min_demand_satisfaction82 * 100} if i == loc5 else {com1_sold: 0} for i in locset}

scenario_disruption82 = Scenario(name='scenario_disruption82', scales=scales, scheduling_scale_level=2,
                               network_scale_level=0, purchase_scale_level=2, availability_scale_level=1,
                               demand_scale_level=2, capacity_scale_level=1,
                               network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                               label='scenario_disruption82')

# %%
plot_scenario.availability_factor(scenario=scenario_disruption76, resource=com1_pur, location=loc1, color='green')
plot_scenario.availability_factor(scenario=scenario_disruption76, resource=com1_pur, location=loc6, color='green')

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(scenario_disruption76.availability_factor['loc1']['com1_pur'])), list(scenario_disruption76.availability_factor['loc1']['com1_pur'].values()), label='Location 1', color='blue', marker='o')

# Plot data from the second dataset
ax.plot(range(len(scenario_disruption76.availability_factor['loc6']['com1_pur'])), list(scenario_disruption76.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Normalized Availability Factor')
ax.set_title('Availability factor for Commodity 1')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
problem_mincost = formulate(scenario=scenario_disruption, constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.PRODUCTION, Constraints.INVENTORY, Constraints.DEMAND}, demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint production mode
# constraint inventory balance
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capacity UB
# constraint transport capacity LB
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint demand penalty
# objective cost w demand penalty

# %%
problem_mincost76 = formulate(scenario=scenario_disruption76, constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.PRODUCTION, Constraints.INVENTORY, Constraints.DEMAND}, demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

min_demand76 = min_demand_dict76
if isinstance(min_demand76, dict):
    if isinstance(list(min_demand76.keys())[0], Location):
        try:
            min_demand = {i.name: {
                j.name: min_demand76[i][j] for j in min_demand76[i].keys()} for i in min_demand76.keys()}
        except:
            pass

problem_mincost76.del_component(constraint_demand2)
problem_mincost76.constraint_demand2 = constraint_demand2(instance=problem_mincost76, demand=min_demand, demand_factor=scenario_disruption76.demand_factor, demand_scale_level=scenario_disruption76.demand_scale_level, scheduling_scale_level=scenario_disruption76.scheduling_scale_level, cluster_wt=None, loc_res_dict= None, sign='geq')
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint production mode
# constraint inventory balance
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capacity UB
# constraint transport capacity LB
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint demand penalty
# objective cost w demand penalty
# constraint demand2

# %%
problem_mincost80 = formulate(scenario=scenario_disruption80, constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.PRODUCTION, Constraints.INVENTORY, Constraints.DEMAND}, demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

min_demand80 = min_demand_dict80
if isinstance(min_demand80, dict):
    if isinstance(list(min_demand80.keys())[0], Location):
        try:
            min_demand = {i.name: {
                j.name: min_demand80[i][j] for j in min_demand80[i].keys()} for i in min_demand80.keys()}
        except:
            pass

problem_mincost80.del_component(constraint_demand2)
problem_mincost80.constraint_demand2 = constraint_demand2(instance=problem_mincost80, demand=min_demand, demand_factor=scenario_disruption80.demand_factor, demand_scale_level=scenario_disruption80.demand_scale_level, scheduling_scale_level=scenario_disruption80.scheduling_scale_level, cluster_wt=None, loc_res_dict= None, sign='geq')
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint production mode
# constraint inventory balance
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capacity UB
# constraint transport capacity LB
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint demand penalty
# objective cost w demand penalty
# constraint demand2

# %%
problem_mincost82 = formulate(scenario=scenario_disruption82, constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.PRODUCTION, Constraints.INVENTORY, Constraints.DEMAND}, demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

min_demand82 = min_demand_dict82
if isinstance(min_demand82, dict):
    if isinstance(list(min_demand82.keys())[0], Location):
        try:
            min_demand = {i.name: {
                j.name: min_demand82[i][j] for j in min_demand82[i].keys()} for i in min_demand82.keys()}
        except:
            pass

problem_mincost82.del_component(constraint_demand2)
problem_mincost82.constraint_demand2 = constraint_demand2(instance=problem_mincost82, demand=min_demand, demand_factor=scenario_disruption82.demand_factor, demand_scale_level=scenario_disruption82.demand_scale_level, scheduling_scale_level=scenario_disruption82.scheduling_scale_level, cluster_wt=None, loc_res_dict= None, sign='geq')
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint production mode
# constraint inventory balance
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capacity UB
# constraint transport capacity LB
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint demand penalty
# objective cost w demand penalty
# constraint demand2

# %%
results_mincost = solve(scenario=scenario_disruption, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 346781 rows, 851707 columns and 748709 nonzeros
# Model fingerprint: 0x87bdea84
# Variable types: 851462 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+06]
# Found heuristic solution: objective 1.800000e+08
# Presolve removed 331458 rows and 838368 columns
# Presolve time: 0.68s
# Presolved: 15323 rows, 13339 columns, 47206 nonzeros
# Variable types: 13339 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 8.364745e+07, 24179 iterations, 2.54 seconds (3.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8.364745e+07 8.3647e+07  0.00%     -    3s
#
# Explored 1 nodes (24179 simplex iterations) in 3.50 seconds (4.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.36475e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.364745277778e+07, best bound 8.364745277778e+07, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
results_mincost76 = solve(scenario=scenario_disruption76, instance=problem_mincost76, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 349301 rows, 851707 columns and 751229 nonzeros
# Model fingerprint: 0xa4f4c3be
# Variable types: 851462 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+06]
# Presolve removed 333978 rows and 838008 columns
# Presolve time: 0.64s
# Presolved: 15323 rows, 13699 columns, 47566 nonzeros
# Variable types: 13699 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 8.364745e+07, 22097 iterations, 2.38 seconds (2.91 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8.364745e+07 8.3647e+07  0.00%     -    3s
#
# Explored 1 nodes (22097 simplex iterations) in 3.26 seconds (3.99 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.36475e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.364745277778e+07, best bound 8.364745277778e+07, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
results_mincost80 = solve(scenario=scenario_disruption80, instance=problem_mincost80, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 349301 rows, 851707 columns and 751229 nonzeros
# Model fingerprint: 0x5ea14532
# Variable types: 851462 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+06]
# Presolve removed 333978 rows and 838008 columns
# Presolve time: 0.65s
# Presolved: 15323 rows, 13699 columns, 47566 nonzeros
# Variable types: 13699 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 8.364745e+07, 21552 iterations, 2.15 seconds (2.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8.364745e+07 8.3647e+07  0.00%     -    3s
#
# Explored 1 nodes (21552 simplex iterations) in 3.05 seconds (3.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.36475e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.364745277778e+07, best bound 8.364745277778e+07, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
results_mincost82 = solve(scenario=scenario_disruption82, instance=problem_mincost82, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 349301 rows, 851707 columns and 751229 nonzeros
# Model fingerprint: 0xbe0b1ba0
# Variable types: 851462 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+06]
# Presolve removed 333978 rows and 838008 columns
# Presolve time: 0.67s
# Presolved: 15323 rows, 13699 columns, 47566 nonzeros
# Variable types: 13699 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 8.370803e+07, 20857 iterations, 2.19 seconds (2.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8.370803e+07 8.3708e+07  0.00%     -    3s
#
# Explored 1 nodes (20857 simplex iterations) in 3.12 seconds (3.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.3708e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.370802611111e+07, best bound 8.370802611111e+07, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
sum(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold' and value!=0)/(100*_exec_scenarios*_time_intervals)
min(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# Out:
# 0.0

# %%
sum(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')/(100*_exec_scenarios*_time_intervals)
min(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# Out:
# 76.0

# %%
sum(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')/(100*_exec_scenarios*_time_intervals)
min(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# Out:
# 80.0

# %%
sum(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')/(100*_exec_scenarios*_time_intervals)
min(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# Out:
# 82.0

# %%
print([(key, value) for key, value in results_mincost.output['S'].items()])
# Out:
# {('loc1', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 29): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 7): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 8): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 9): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 10): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 11): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 12): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 13): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 14): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 15): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 16): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 17): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 18): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 19): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 20): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 21): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 22): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 23): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 24): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 25): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 26): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 27): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 28): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 29): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 7): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 8): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 9): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 10): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 11): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 12): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 13): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 14): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 15): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 16): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 17): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 18): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 19): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 20): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 21): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 22): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 23): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 24): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 25): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 26): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 27): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 28): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 9): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 10): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 11): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 12): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 13): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 14): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 15): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 16): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 17): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 18): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 19): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 20): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 21): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 22): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 23): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 24): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 25): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 26): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 27): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 28): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 29): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 7): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 8): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 9): 0.0,
#  ...}

# %%
plot_results.schedule(results=results_mincost, y_axis='S', component='com1_sold', location='loc5', color='green')
plot_results.schedule(results=results_mincost76, y_axis='S', component='com1_sold', location='loc5', color='green')
plot_results.schedule(results=results_mincost80, y_axis='S', component='com1_sold', location='loc5', color='green')
plot_results.schedule(results=results_mincost82, y_axis='S', component='com1_sold', location='loc5', color='green')

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
# ax.plot(range(len(list(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))), list(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'), label='Location 5', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))), list(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'), label='Location 5_min76', color='blue')

ax.plot(range(len(list(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))), list(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'), label='Location 5_min80', color='green')

ax.plot(range(len(list(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))), list(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'), label='Location 5_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Commodity sold')
ax.set_title('Commodity 1 sold from location 5')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
# ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'), label='Location 1', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'), label='Location 1_min76', color='blue')

ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'), label='Location 1_min80', color='green')

# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_stored20'), label='Location 1_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 1')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
# ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'), label='location 2', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'), label='location 2_min76', color='blue')

ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'), label='location 2_min80', color='green')

# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_stored20'), label='location 2_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 2')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
# ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'), label='location 3', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'), label='location 3_min76', color='blue')

ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'), label='location 3_min80', color='green')

# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_stored20'), label='location 3_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 3')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'), label='location 4', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'), label='location 4_min76', color='blue')

# ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'), label='location 4_min80', color='green')

# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_stored50'), label='location 4_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 4')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'), label='location 5', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'), label='location 5_min76', color='blue')

# ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'), label='location 5_min80', color='green')

# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_stored50'), label='location 5_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 5')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'), label='location 6', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'), label='location 6_min76', color='blue')

# ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'), label='location 6_min80', color='green')
# 
# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_stored10'), label='location 6_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 6')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)

fig, ax = plt.subplots()

# Plot data from the first dataset
ax.plot(range(len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'), label='location 7', color='yellow')

ax.plot(range(len(list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost76.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'), label='location 7_min76', color='blue')

# ax.plot(range(len(list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost80.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'), label='location 7_min80', color='green')
# 
# ax.plot(range(len(list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'))), list(value for key, value in results_mincost82.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_stored20'), label='location 7_min82', color='red')

# Plot data from the second dataset
# ax.plot(range(len(scenario_disruption.availability_factor['loc6']['com1_pur'])), list(scenario_disruption.availability_factor['loc6']['com1_pur'].values()), label='Location 6', color='red', marker='x')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels at Location 7')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
sum(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold' and value!=0)/(100*_exec_scenarios*_time_intervals)
# Out:
# 0.9681944444444445

# %%
sum(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold' and value!=0)/(100*_exec_scenarios*_time_intervals)
# Out:
# 0.9681944444444445

# %%
sum(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold' and value!=0)/(100*_exec_scenarios*_time_intervals)
# Out:
# 0.9681944444444445

# %%
sum(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold' and value!=0)/(100*_exec_scenarios*_time_intervals)
# Out:
# 0.96875

# %%
plot_results.transport(results=results_mincost, source='loc2', sink='loc5', transport='truck30', resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc5', transport='truck100', resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc7', sink='loc5', transport='truck40', resource='com1_loc7_out')

# %%
results_mincost.output['objective']
# Out:
# 83647452.77777778

# %%
import matplotlib.pyplot as plt

x = [ min(value for key, value in results_mincost76.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'),
     min(value for key, value in results_mincost80.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'),
     min(value for key, value in results_mincost82.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')]
y = [results_mincost76.output['objective'], results_mincost80.output['objective'], results_mincost82.output['objective']]

plt.plot(x, y, label='Data Points', color='blue', marker='o')

plt.xlabel('Units of commodity 1')
plt.ylabel('Total cost')
plt.title('Cost vs Minimum Service Level')
plt.grid(True)

plt.show()
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
min_demand_satisfactionmax = 0.85
min_demand_dictmax = {i: {com1_sold: min_demand_satisfactionmax * 100} if i == loc5 else {com1_sold: 0} for i in locset}

scenario_disruptionmax = Scenario(name='scenario_disruptionmax', scales=scales, scheduling_scale_level=2,
                               network_scale_level=0, purchase_scale_level=2, availability_scale_level=1,
                               demand_scale_level=2, capacity_scale_level=1,
                               network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                               label='scenario_disruptionmax')

# %%
problem_mincostmax = formulate(scenario=scenario_disruptionmax, constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.PRODUCTION, Constraints.INVENTORY, Constraints.DEMAND}, demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

min_demandmax = min_demand_dictmax
if isinstance(min_demandmax, dict):
    if isinstance(list(min_demandmax.keys())[0], Location):
        try:
            min_demand = {i.name: {
                j.name: min_demandmax[i][j] for j in min_demandmax[i].keys()} for i in min_demandmax.keys()}
        except:
            pass

problem_mincostmax.del_component(constraint_demand2)
problem_mincostmax.constraint_demand2 = constraint_demand2(instance=problem_mincostmax, demand=min_demand, demand_factor=scenario_disruptionmax.demand_factor, demand_scale_level=scenario_disruptionmax.demand_scale_level, scheduling_scale_level=scenario_disruptionmax.scheduling_scale_level, cluster_wt=None, loc_res_dict= None, sign='geq')
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint production mode
# constraint inventory balance
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capacity UB
# constraint transport capacity LB
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint demand penalty
# objective cost w demand penalty
# constraint demand2

# %%
results_mincostmax = solve(scenario=scenario_disruptionmax, instance=problem_mincostmax, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6700 CPU @ 3.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 349301 rows, 851707 columns and 751229 nonzeros
# Model fingerprint: 0x41cba3da
# Variable types: 851462 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+06]
# Presolve removed 333978 rows and 838008 columns
# Presolve time: 0.64s
# Presolved: 15323 rows, 13699 columns, 47566 nonzeros
# Variable types: 13699 continuous, 0 integer (0 binary)
#
# Root relaxation: infeasible, 14251 iterations, 1.42 seconds (1.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    2s
#
# Explored 1 nodes (14251 simplex iterations) in 2.23 seconds (2.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>

# %%
plot_results.schedule(results=results_mincostmax, y_axis='S', component='com1_sold', location='loc5', color='green')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[274], line 1
# ----> 1 plot_results.schedule(results=results_mincostmax, y_axis='S', component='com1_sold', location='loc5', color='green')
#
# File ~\PycharmProjects\energiapy\src\energiapy\plot\plot_results.py:83, in schedule(results, y_axis, component, location, fig_size, font_size, color, usetex)
#      80 fig, ax = plt.subplots(figsize=fig_size)
#      81 results.__dict__['components'].keys()
#      82 y_ = [results.output[y_axis][i]
# ---> 83       for i in results.output[y_axis].keys() if location in i if component in i]
#      85 for i in results.__dict__['components'].keys():
#      86     if component in results.__dict__['components'][i]:
#
# KeyError: 'S'
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

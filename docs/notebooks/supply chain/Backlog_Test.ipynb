# %%
import sys
sys.path.append('../../../src')
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
_time_intervals = 30  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 12  # Number of execution scenarios                     (chi)

M = 1e3  # Big M

# Define temporal scales
scales = TemporalScale(discretization_list=[1, _exec_scenarios, _time_intervals])

loc5_backlog_penalty_factor = pandas.DataFrame(data={'com1_sold':[1]*4 + [0]*8})

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================
com1_pur = Resource(name='com1_pur', cons_max=125, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')

com1_in = Resource(name='com1_in', label='Commodity 1 received')
com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_process_capacity = 150

com1_procure = Process(name='procure com1', prod_max=125, conversion={com1_pur: -1, com1_in: 1}, capex=0.01, vopex=0.01, prod_min=125, label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity, conversion={com1_loc3_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity, conversion={com1_loc4_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 4')
com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity, conversion={com1_loc5_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 5')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity, conversion={com1_loc6_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity, conversion={com1_loc7_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},  capex=0.01, vopex=0.01, prod_min=com1_process_capacity, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

com1_store10 = Process(name='com1_store10', prod_max=com1_process_capacity, capex=100, vopex=1, store_min=0.01, store_max= 20, prod_min=com1_process_capacity, label="Storage capacity of 10 units", storage=com1_in, storage_cost=0.02)
com1_store20 = Process(name='com1_store20', prod_max=com1_process_capacity, capex=200, vopex=2, store_min=0.01,store_max= 40, prod_min=com1_process_capacity, label="Storage capacity of 20 units", storage=com1_in, storage_cost=0.02)
com1_store50 = Process(name='com1_store50', prod_max=com1_process_capacity, capex=500, vopex=5, store_min=0.01, store_max= 100, prod_min=com1_process_capacity, label="Storage capacity of 50 units", storage=com1_in, storage_cost=0.02)

com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 2')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc3_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 3')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc4_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 4')
com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc5_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 5')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc6_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 6')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc7_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 7')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store20, com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc2 = Location(name='loc2', processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc3 = Location(name='loc3', processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store20, com1_loc3_send}, label="Location 3", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5, com1_receive_loc7, com1_process, com1_store50, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc5 = Location(name='loc5', processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store50, com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1, backlog_penalty_factor={com1_sold: loc5_backlog_penalty_factor[['com1_sold']]}, backlog_penalty_scale_level=1)

loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store10, com1_loc6_send}, label="Location 6", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc7 = Location(name='loc7', processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc7_send}, label="Location 7", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================

truck_cap12 = 70
truck_cap13 = 50
truck_cap24 = 50
truck_cap25 = 30
truck_cap34 = 20
truck_cap45 = 100
truck_cap47 = 40
truck_cap64 = 50
truck_cap75 = 40

truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12, label='Truck from location 1 to 2', capex=0.5, vopex=0.05, trans_min=truck_cap12, speed=20)
truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_cap12, speed=20)

truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13, label='Truck from location 1 to 3', capex=0.3, vopex=0.03, trans_min=truck_cap13, speed=20)
truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_cap13, speed=20)

truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24, label='Truck from location 2 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap24, speed=20)
truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_cap24, speed=20)

truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25, label='Truck from location 2 to 5', capex=0.3, vopex=0.03, trans_min=truck_cap25, speed=20)
truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_cap25, speed=20)

truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34, label='Truck from location 3 to 4', capex=0.2, vopex=0.02, trans_min=truck_cap34, speed=20)
truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_cap34, speed=20)

truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45, label='Truck from location 4 to 5', capex=1, vopex=0.1, trans_min=truck_cap45, speed=20)
truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_cap45, speed=20)

truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47, label='Truck from location 4 to 7', capex=0.4, vopex=0.04, trans_min=truck_cap47, speed=20)
truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_cap47, speed=20)

truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64, label='Truck from location 6 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap64, speed=20)
truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_cap64, speed=20)

truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75, label='Truck from location 7 to 5', capex=0.4, vopex=0.04, trans_min=truck_cap75, speed=20)
truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_cap75, speed=20)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================

# transport_matrix = [
#     [[], [truck50_12], [truck30_13], [], [], [], []],  # source: location 1
#     [[truck50_21], [], [], [truck50_24], [truck30_25], [], []],  # source: location 2
#     [[truck30_31], [], [], [truck20_34], [], [], []],  # source: location 3
#     [[], [truck50_42], [truck20_43], [], [truck100_45], [truck50_46], [truck40_47]],  # source: location 4
#     [[], [truck30_52], [], [truck100_54], [], [], [truck40_57]],  # source: location 5
#     [[], [], [], [truck50_64], [], [], []],  # source: location 6
#     [[], [], [], [truck40_74], [truck40_75], [], []]  # source: location 7
# ]

# transport_matrix = [
#     [[], [truck12], [truck13], [], [], [], []],  # source: location 1
#     [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
#     [[truck31], [], [], [truck34], [], [], []],  # source: location 3
#     [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
#     [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
#     [[], [], [], [truck64], [], [], []],  # source: location 6
#     [[], [], [], [truck74], [truck75], [], []]  # source: location 7
# ]

transport_matrix = [
    [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    [[], [], [], [truck24], [truck25], [], []],  # source: location 2
    [[], [], [], [truck34], [], [], []],  # source: location 3
    [[], [], [], [], [truck45], [], [truck47]],  # source: location 4
    [[], [], [], [], [], [], []],  # source: location 5
    [[], [], [], [truck64], [], [], []],  # source: location 6
    [[], [], [], [], [truck75], [], []]  # source: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = locset
sinks = locset

network = Network(name='Network', scales= scales, source_locations=sources, sink_locations=sinks, transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
daily_demand = 100
demand_penalty = 75
backlog_penalty = 50

demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}
backlog_penalty_dict = {i:{com1_sold: backlog_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

backlog_zero = {loc5:{com1_sold: 34}}

scenario = Scenario(name='scenario_baseline', scales=scales, scheduling_scale_level=2, network_scale_level=0, purchase_scale_level=2, availability_scale_level=1, demand_scale_level=2, capacity_scale_level=1, backlog_penalty_scale_level=1, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict, backlog_penalty=backlog_penalty_dict, label='Scenario with perfect information')

# %%
problem_mincost = formulate(scenario=scenario,
                            constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.BACKLOG},
                            # constraints = {Constraints.BACKLOG},
                            demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY, backlog_zero=backlog_zero)

# %%
results_mincost = solve(scenario=scenario, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 563424 rows, 1369676 columns and 763312 nonzeros
# Model fingerprint: 0xa054a4ad
# Variable types: 1369235 continuous, 441 integer (441 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 2e+02]
# Presolve removed 549800 rows and 1331213 columns
# Presolve time: 0.12s
# Presolved: 13624 rows, 38463 columns, 76143 nonzeros
# Variable types: 38463 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.792660e+06, 11764 iterations, 0.05 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2792660.1400 2792660.14  0.00%     -    0s
#
# Explored 1 nodes (11764 simplex iterations) in 0.45 seconds (0.57 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.79266e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.792660140000e+06, best bound 2.792660140000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
plot_results.schedule(results=results_mincost, y_axis='S', component='com1_sold', location='loc5', color='green')

# %%
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc2', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc3', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc4', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc5', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store10_com1_in_stored', location='loc6', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc7', color='green')

# %%
plot_results.transport(results=results_mincost, source='loc1', sink='loc2', transport='truck12',
                       resource='com1_loc1_out')
plot_results.transport(results=results_mincost, source='loc1', sink='loc3', transport='truck13',
                       resource='com1_loc1_out')
plot_results.transport(results=results_mincost, source='loc2', sink='loc4', transport='truck24',
                       resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc2', sink='loc5', transport='truck25',
                       resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc3', sink='loc4', transport='truck34',
                       resource='com1_loc3_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc5', transport='truck45',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc7', transport='truck47',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc6', sink='loc4', transport='truck64',
                       resource='com1_loc6_out')
plot_results.transport(results=results_mincost, source='loc7', sink='loc5', transport='truck75',
                       resource='com1_loc7_out')

# %%
# plot_results.transport(results=results_mincost, source='loc2', sink='loc1', transport='truck50_21',
#                        resource='com1_loc2_out')
# plot_results.transport(results=results_mincost, source='loc3', sink='loc1', transport='truck30_31',
#                        resource='com1_loc3_out')
# plot_results.transport(results=results_mincost, source='loc4', sink='loc2', transport='truck50_42',
#                        resource='com1_loc4_out')
# plot_results.transport(results=results_mincost, source='loc5', sink='loc2', transport='truck30_52',
#                        resource='com1_loc5_out')
# plot_results.transport(results=results_mincost, source='loc4', sink='loc3', transport='truck20_43',
#                        resource='com1_loc4_out')
# plot_results.transport(results=results_mincost, source='loc5', sink='loc4', transport='truck100_54',
#                        resource='com1_loc5_out')
# plot_results.transport(results=results_mincost, source='loc7', sink='loc4', transport='truck40_74',
#                        resource='com1_loc7_out')
# plot_results.transport(results=results_mincost, source='loc4', sink='loc6', transport='truck50_46',
#                        resource='com1_loc4_out')
# plot_results.transport(results=results_mincost, source='loc5', sink='loc7', transport='truck40_57',
#                        resource='com1_loc5_out')

# %%
plot_results.schedule(results=results_mincost, y_axis='C', component='com1_pur', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='C', component='com1_pur', location='loc6', color='green')

# %%
print(*[(key, value) for key, value in results_mincost.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'], sep='\n')
# Out:
# (('loc1', 'procure com1', 0, 0, 0), 90.0)
# (('loc1', 'procure com1', 0, 0, 1), 90.0)
# (('loc1', 'procure com1', 0, 0, 2), 90.0)
# (('loc1', 'procure com1', 0, 0, 3), 90.0)
# (('loc1', 'procure com1', 0, 0, 4), 90.0)
# (('loc1', 'procure com1', 0, 0, 5), 90.0)
# (('loc1', 'procure com1', 0, 0, 6), 90.0)
# (('loc1', 'procure com1', 0, 0, 7), 90.0)
# (('loc1', 'procure com1', 0, 0, 8), 90.0)
# (('loc1', 'procure com1', 0, 0, 9), 90.0)
# (('loc1', 'procure com1', 0, 0, 10), 90.0)
# (('loc1', 'procure com1', 0, 0, 11), 90.0)
# (('loc1', 'procure com1', 0, 0, 12), 90.0)
# (('loc1', 'procure com1', 0, 0, 13), 90.0)
# (('loc1', 'procure com1', 0, 0, 14), 90.0)
# (('loc1', 'procure com1', 0, 0, 15), 90.0)
# (('loc1', 'procure com1', 0, 0, 16), 90.0)
# (('loc1', 'procure com1', 0, 0, 17), 90.0)
# (('loc1', 'procure com1', 0, 0, 18), 90.0)
# (('loc1', 'procure com1', 0, 0, 19), 90.0)
# (('loc1', 'procure com1', 0, 0, 20), 90.0)
# (('loc1', 'procure com1', 0, 0, 21), 90.0)
# (('loc1', 'procure com1', 0, 0, 22), 90.0)
# (('loc1', 'procure com1', 0, 0, 23), 90.0)
# (('loc1', 'procure com1', 0, 0, 24), 90.0)
# (('loc1', 'procure com1', 0, 0, 25), 90.0)
# (('loc1', 'procure com1', 0, 0, 26), 90.0)
# (('loc1', 'procure com1', 0, 0, 27), 90.0)
# (('loc1', 'procure com1', 0, 0, 28), 90.0)
# (('loc1', 'procure com1', 0, 0, 29), 90.0)
# (('loc1', 'procure com1', 0, 1, 0), 90.0)
# (('loc1', 'procure com1', 0, 1, 1), 90.0)
# (('loc1', 'procure com1', 0, 1, 2), 90.0)
# (('loc1', 'procure com1', 0, 1, 3), 80.0)
# (('loc1', 'procure com1', 0, 1, 4), 80.0)
# (('loc1', 'procure com1', 0, 1, 5), 80.0)
# (('loc1', 'procure com1', 0, 1, 6), 80.0)
# (('loc1', 'procure com1', 0, 1, 7), 80.0)
# (('loc1', 'procure com1', 0, 1, 8), 80.0)
# (('loc1', 'procure com1', 0, 1, 9), 64.0)
# (('loc1', 'procure com1', 0, 1, 10), 50.0)
# (('loc1', 'procure com1', 0, 1, 11), 50.0)
# (('loc1', 'procure com1', 0, 1, 12), 50.0)
# (('loc1', 'procure com1', 0, 1, 13), 50.0)
# (('loc1', 'procure com1', 0, 1, 14), 50.0)
# (('loc1', 'procure com1', 0, 1, 15), 50.0)
# (('loc1', 'procure com1', 0, 1, 16), 50.0)
# (('loc1', 'procure com1', 0, 1, 17), 50.0)
# (('loc1', 'procure com1', 0, 1, 18), 50.0)
# (('loc1', 'procure com1', 0, 1, 19), 50.0)
# (('loc1', 'procure com1', 0, 1, 20), 50.0)
# (('loc1', 'procure com1', 0, 1, 21), 50.0)
# (('loc1', 'procure com1', 0, 1, 22), 50.0)
# (('loc1', 'procure com1', 0, 1, 23), 50.0)
# (('loc1', 'procure com1', 0, 1, 24), 50.0)
# (('loc1', 'procure com1', 0, 1, 25), 50.0)
# (('loc1', 'procure com1', 0, 1, 26), 50.0)
# (('loc1', 'procure com1', 0, 1, 27), 50.0)
# (('loc1', 'procure com1', 0, 1, 28), 50.0)
# (('loc1', 'procure com1', 0, 1, 29), 50.0)
# (('loc1', 'procure com1', 0, 2, 0), 50.0)
# (('loc1', 'procure com1', 0, 2, 1), 50.0)
# (('loc1', 'procure com1', 0, 2, 2), 50.0)
# (('loc1', 'procure com1', 0, 2, 3), 50.0)
# (('loc1', 'procure com1', 0, 2, 4), 50.0)
# (('loc1', 'procure com1', 0, 2, 5), 50.0)
# (('loc1', 'procure com1', 0, 2, 6), 50.0)
# (('loc1', 'procure com1', 0, 2, 7), 50.0)
# (('loc1', 'procure com1', 0, 2, 8), 50.0)
# (('loc1', 'procure com1', 0, 2, 9), 50.0)
# (('loc1', 'procure com1', 0, 2, 10), 50.0)
# (('loc1', 'procure com1', 0, 2, 11), 50.0)
# (('loc1', 'procure com1', 0, 2, 12), 50.0)
# (('loc1', 'procure com1', 0, 2, 13), 50.0)
# (('loc1', 'procure com1', 0, 2, 14), 50.0)
# (('loc1', 'procure com1', 0, 2, 15), 50.0)
# (('loc1', 'procure com1', 0, 2, 16), 50.0)
# (('loc1', 'procure com1', 0, 2, 17), 50.0)
# (('loc1', 'procure com1', 0, 2, 18), 50.0)
# (('loc1', 'procure com1', 0, 2, 19), 50.0)
# (('loc1', 'procure com1', 0, 2, 20), 50.0)
# (('loc1', 'procure com1', 0, 2, 21), 50.0)
# (('loc1', 'procure com1', 0, 2, 22), 50.0)
# (('loc1', 'procure com1', 0, 2, 23), 50.0)
# (('loc1', 'procure com1', 0, 2, 24), 50.0)
# (('loc1', 'procure com1', 0, 2, 25), 50.0)
# (('loc1', 'procure com1', 0, 2, 26), 50.0)
# (('loc1', 'procure com1', 0, 2, 27), 50.0)
# (('loc1', 'procure com1', 0, 2, 28), 50.0)
# (('loc1', 'procure com1', 0, 2, 29), 50.0)
# (('loc1', 'procure com1', 0, 3, 0), 50.0)
# (('loc1', 'procure com1', 0, 3, 1), 50.0)
# (('loc1', 'procure com1', 0, 3, 2), 50.0)
# (('loc1', 'procure com1', 0, 3, 3), 50.0)
# (('loc1', 'procure com1', 0, 3, 4), 50.0)
# (('loc1', 'procure com1', 0, 3, 5), 50.0)
# (('loc1', 'procure com1', 0, 3, 6), 50.0)
# (('loc1', 'procure com1', 0, 3, 7), 50.0)
# (('loc1', 'procure com1', 0, 3, 8), 50.0)
# (('loc1', 'procure com1', 0, 3, 9), 50.0)
# (('loc1', 'procure com1', 0, 3, 10), 50.0)
# (('loc1', 'procure com1', 0, 3, 11), 50.0)
# (('loc1', 'procure com1', 0, 3, 12), 50.0)
# (('loc1', 'procure com1', 0, 3, 13), 50.0)
# (('loc1', 'procure com1', 0, 3, 14), 50.0)
# (('loc1', 'procure com1', 0, 3, 15), 50.0)
# (('loc1', 'procure com1', 0, 3, 16), 50.0)
# (('loc1', 'procure com1', 0, 3, 17), 50.0)
# (('loc1', 'procure com1', 0, 3, 18), 50.0)
# (('loc1', 'procure com1', 0, 3, 19), 50.0)
# (('loc1', 'procure com1', 0, 3, 20), 50.0)
# (('loc1', 'procure com1', 0, 3, 21), 50.0)
# (('loc1', 'procure com1', 0, 3, 22), 50.0)
# (('loc1', 'procure com1', 0, 3, 23), 50.0)
# (('loc1', 'procure com1', 0, 3, 24), 50.0)
# (('loc1', 'procure com1', 0, 3, 25), 50.0)
# (('loc1', 'procure com1', 0, 3, 26), 50.0)
# (('loc1', 'procure com1', 0, 3, 27), 50.0)
# (('loc1', 'procure com1', 0, 3, 28), 50.0)
# (('loc1', 'procure com1', 0, 3, 29), 50.0)
# (('loc1', 'procure com1', 0, 4, 0), 50.0)
# (('loc1', 'procure com1', 0, 4, 1), 50.0)
# (('loc1', 'procure com1', 0, 4, 2), 50.0)
# (('loc1', 'procure com1', 0, 4, 3), 50.0)
# (('loc1', 'procure com1', 0, 4, 4), 50.0)
# (('loc1', 'procure com1', 0, 4, 5), 50.0)
# (('loc1', 'procure com1', 0, 4, 6), 50.0)
# (('loc1', 'procure com1', 0, 4, 7), 50.0)
# (('loc1', 'procure com1', 0, 4, 8), 50.0)
# (('loc1', 'procure com1', 0, 4, 9), 50.0)
# (('loc1', 'procure com1', 0, 4, 10), 50.0)
# (('loc1', 'procure com1', 0, 4, 11), 50.0)
# (('loc1', 'procure com1', 0, 4, 12), 50.0)
# (('loc1', 'procure com1', 0, 4, 13), 50.0)
# (('loc1', 'procure com1', 0, 4, 14), 50.0)
# (('loc1', 'procure com1', 0, 4, 15), 50.0)
# (('loc1', 'procure com1', 0, 4, 16), 50.0)
# (('loc1', 'procure com1', 0, 4, 17), 50.0)
# (('loc1', 'procure com1', 0, 4, 18), 50.0)
# (('loc1', 'procure com1', 0, 4, 19), 50.0)
# (('loc1', 'procure com1', 0, 4, 20), 50.0)
# (('loc1', 'procure com1', 0, 4, 21), 50.0)
# (('loc1', 'procure com1', 0, 4, 22), 50.0)
# (('loc1', 'procure com1', 0, 4, 23), 50.0)
# (('loc1', 'procure com1', 0, 4, 24), 50.0)
# (('loc1', 'procure com1', 0, 4, 25), 50.0)
# (('loc1', 'procure com1', 0, 4, 26), 50.0)
# (('loc1', 'procure com1', 0, 4, 27), 50.0)
# (('loc1', 'procure com1', 0, 4, 28), 50.0)
# (('loc1', 'procure com1', 0, 4, 29), 50.0)
# (('loc1', 'procure com1', 0, 5, 0), 50.0)
# (('loc1', 'procure com1', 0, 5, 1), 50.0)
# (('loc1', 'procure com1', 0, 5, 2), 50.0)
# (('loc1', 'procure com1', 0, 5, 3), 50.0)
# (('loc1', 'procure com1', 0, 5, 4), 50.0)
# (('loc1', 'procure com1', 0, 5, 5), 50.0)
# (('loc1', 'procure com1', 0, 5, 6), 50.0)
# (('loc1', 'procure com1', 0, 5, 7), 50.0)
# (('loc1', 'procure com1', 0, 5, 8), 50.0)
# (('loc1', 'procure com1', 0, 5, 9), 50.0)
# (('loc1', 'procure com1', 0, 5, 10), 50.0)
# (('loc1', 'procure com1', 0, 5, 11), 50.0)
# (('loc1', 'procure com1', 0, 5, 12), 50.0)
# (('loc1', 'procure com1', 0, 5, 13), 50.0)
# (('loc1', 'procure com1', 0, 5, 14), 50.0)
# (('loc1', 'procure com1', 0, 5, 15), 50.0)
# (('loc1', 'procure com1', 0, 5, 16), 50.0)
# (('loc1', 'procure com1', 0, 5, 17), 50.0)
# (('loc1', 'procure com1', 0, 5, 18), 50.0)
# (('loc1', 'procure com1', 0, 5, 19), 50.0)
# (('loc1', 'procure com1', 0, 5, 20), 50.0)
# (('loc1', 'procure com1', 0, 5, 21), 50.0)
# (('loc1', 'procure com1', 0, 5, 22), 50.0)
# (('loc1', 'procure com1', 0, 5, 23), 50.0)
# (('loc1', 'procure com1', 0, 5, 24), 50.0)
# (('loc1', 'procure com1', 0, 5, 25), 50.0)
# (('loc1', 'procure com1', 0, 5, 26), 50.0)
# (('loc1', 'procure com1', 0, 5, 27), 50.0)
# (('loc1', 'procure com1', 0, 5, 28), 50.0)
# (('loc1', 'procure com1', 0, 5, 29), 50.0)
# (('loc1', 'procure com1', 0, 6, 0), 50.0)
# (('loc1', 'procure com1', 0, 6, 1), 50.0)
# (('loc1', 'procure com1', 0, 6, 2), 50.0)
# (('loc1', 'procure com1', 0, 6, 3), 50.0)
# (('loc1', 'procure com1', 0, 6, 4), 50.0)
# (('loc1', 'procure com1', 0, 6, 5), 50.0)
# (('loc1', 'procure com1', 0, 6, 6), 50.0)
# (('loc1', 'procure com1', 0, 6, 7), 50.0)
# (('loc1', 'procure com1', 0, 6, 8), 50.0)
# (('loc1', 'procure com1', 0, 6, 9), 50.0)
# (('loc1', 'procure com1', 0, 6, 10), 50.0)
# (('loc1', 'procure com1', 0, 6, 11), 50.0)
# (('loc1', 'procure com1', 0, 6, 12), 50.0)
# (('loc1', 'procure com1', 0, 6, 13), 50.0)
# (('loc1', 'procure com1', 0, 6, 14), 50.0)
# (('loc1', 'procure com1', 0, 6, 15), 50.0)
# (('loc1', 'procure com1', 0, 6, 16), 50.0)
# (('loc1', 'procure com1', 0, 6, 17), 50.0)
# (('loc1', 'procure com1', 0, 6, 18), 50.0)
# (('loc1', 'procure com1', 0, 6, 19), 50.0)
# (('loc1', 'procure com1', 0, 6, 20), 50.0)
# (('loc1', 'procure com1', 0, 6, 21), 50.0)
# (('loc1', 'procure com1', 0, 6, 22), 50.0)
# (('loc1', 'procure com1', 0, 6, 23), 50.0)
# (('loc1', 'procure com1', 0, 6, 24), 50.0)
# (('loc1', 'procure com1', 0, 6, 25), 50.0)
# (('loc1', 'procure com1', 0, 6, 26), 50.0)
# (('loc1', 'procure com1', 0, 6, 27), 50.0)
# (('loc1', 'procure com1', 0, 6, 28), 50.0)
# (('loc1', 'procure com1', 0, 6, 29), 50.0)
# (('loc1', 'procure com1', 0, 7, 0), 50.0)
# (('loc1', 'procure com1', 0, 7, 1), 50.0)
# (('loc1', 'procure com1', 0, 7, 2), 50.0)
# (('loc1', 'procure com1', 0, 7, 3), 50.0)
# (('loc1', 'procure com1', 0, 7, 4), 50.0)
# (('loc1', 'procure com1', 0, 7, 5), 50.0)
# (('loc1', 'procure com1', 0, 7, 6), 50.0)
# (('loc1', 'procure com1', 0, 7, 7), 50.0)
# (('loc1', 'procure com1', 0, 7, 8), 50.0)
# (('loc1', 'procure com1', 0, 7, 9), 50.0)
# (('loc1', 'procure com1', 0, 7, 10), 50.0)
# (('loc1', 'procure com1', 0, 7, 11), 50.0)
# (('loc1', 'procure com1', 0, 7, 12), 50.0)
# (('loc1', 'procure com1', 0, 7, 13), 50.0)
# (('loc1', 'procure com1', 0, 7, 14), 50.0)
# (('loc1', 'procure com1', 0, 7, 15), 50.0)
# (('loc1', 'procure com1', 0, 7, 16), 50.0)
# (('loc1', 'procure com1', 0, 7, 17), 50.0)
# (('loc1', 'procure com1', 0, 7, 18), 50.0)
# (('loc1', 'procure com1', 0, 7, 19), 50.0)
# (('loc1', 'procure com1', 0, 7, 20), 50.0)
# (('loc1', 'procure com1', 0, 7, 21), 50.0)
# (('loc1', 'procure com1', 0, 7, 22), 50.0)
# (('loc1', 'procure com1', 0, 7, 23), 50.0)
# (('loc1', 'procure com1', 0, 7, 24), 50.0)
# (('loc1', 'procure com1', 0, 7, 25), 50.0)
# (('loc1', 'procure com1', 0, 7, 26), 50.0)
# (('loc1', 'procure com1', 0, 7, 27), 50.0)
# (('loc1', 'procure com1', 0, 7, 28), 50.0)
# (('loc1', 'procure com1', 0, 7, 29), 50.0)
# (('loc1', 'procure com1', 0, 8, 0), 50.0)
# (('loc1', 'procure com1', 0, 8, 1), 50.0)
# (('loc1', 'procure com1', 0, 8, 2), 50.0)
# (('loc1', 'procure com1', 0, 8, 3), 50.0)
# (('loc1', 'procure com1', 0, 8, 4), 50.0)
# (('loc1', 'procure com1', 0, 8, 5), 50.0)
# (('loc1', 'procure com1', 0, 8, 6), 50.0)
# (('loc1', 'procure com1', 0, 8, 7), 50.0)
# (('loc1', 'procure com1', 0, 8, 8), 50.0)
# (('loc1', 'procure com1', 0, 8, 9), 50.0)
# (('loc1', 'procure com1', 0, 8, 10), 50.0)
# (('loc1', 'procure com1', 0, 8, 11), 50.0)
# (('loc1', 'procure com1', 0, 8, 12), 50.0)
# (('loc1', 'procure com1', 0, 8, 13), 50.0)
# (('loc1', 'procure com1', 0, 8, 14), 50.0)
# (('loc1', 'procure com1', 0, 8, 15), 50.0)
# (('loc1', 'procure com1', 0, 8, 16), 50.0)
# (('loc1', 'procure com1', 0, 8, 17), 50.0)
# (('loc1', 'procure com1', 0, 8, 18), 50.0)
# (('loc1', 'procure com1', 0, 8, 19), 50.0)
# (('loc1', 'procure com1', 0, 8, 20), 50.0)
# (('loc1', 'procure com1', 0, 8, 21), 50.0)
# (('loc1', 'procure com1', 0, 8, 22), 50.0)
# (('loc1', 'procure com1', 0, 8, 23), 50.0)
# (('loc1', 'procure com1', 0, 8, 24), 50.0)
# (('loc1', 'procure com1', 0, 8, 25), 50.0)
# (('loc1', 'procure com1', 0, 8, 26), 50.0)
# (('loc1', 'procure com1', 0, 8, 27), 50.0)
# (('loc1', 'procure com1', 0, 8, 28), 50.0)
# (('loc1', 'procure com1', 0, 8, 29), 50.0)
# (('loc1', 'procure com1', 0, 9, 0), 50.0)
# (('loc1', 'procure com1', 0, 9, 1), 50.0)
# (('loc1', 'procure com1', 0, 9, 2), 50.0)
# (('loc1', 'procure com1', 0, 9, 3), 50.0)
# (('loc1', 'procure com1', 0, 9, 4), 50.0)
# (('loc1', 'procure com1', 0, 9, 5), 50.0)
# (('loc1', 'procure com1', 0, 9, 6), 50.0)
# (('loc1', 'procure com1', 0, 9, 7), 50.0)
# (('loc1', 'procure com1', 0, 9, 8), 50.0)
# (('loc1', 'procure com1', 0, 9, 9), 50.0)
# (('loc1', 'procure com1', 0, 9, 10), 50.0)
# (('loc1', 'procure com1', 0, 9, 11), 50.0)
# (('loc1', 'procure com1', 0, 9, 12), 50.0)
# (('loc1', 'procure com1', 0, 9, 13), 50.0)
# (('loc1', 'procure com1', 0, 9, 14), 50.0)
# (('loc1', 'procure com1', 0, 9, 15), 50.0)
# (('loc1', 'procure com1', 0, 9, 16), 50.0)
# (('loc1', 'procure com1', 0, 9, 17), 50.0)
# (('loc1', 'procure com1', 0, 9, 18), 50.0)
# (('loc1', 'procure com1', 0, 9, 19), 50.0)
# (('loc1', 'procure com1', 0, 9, 20), 50.0)
# (('loc1', 'procure com1', 0, 9, 21), 50.0)
# (('loc1', 'procure com1', 0, 9, 22), 50.0)
# (('loc1', 'procure com1', 0, 9, 23), 50.0)
# (('loc1', 'procure com1', 0, 9, 24), 50.0)
# (('loc1', 'procure com1', 0, 9, 25), 50.0)
# (('loc1', 'procure com1', 0, 9, 26), 50.0)
# (('loc1', 'procure com1', 0, 9, 27), 50.0)
# (('loc1', 'procure com1', 0, 9, 28), 50.0)
# (('loc1', 'procure com1', 0, 9, 29), 50.0)
# (('loc1', 'procure com1', 0, 10, 0), 50.0)
# (('loc1', 'procure com1', 0, 10, 1), 50.0)
# (('loc1', 'procure com1', 0, 10, 2), 50.0)
# (('loc1', 'procure com1', 0, 10, 3), 50.0)
# (('loc1', 'procure com1', 0, 10, 4), 50.0)
# (('loc1', 'procure com1', 0, 10, 5), 50.0)
# (('loc1', 'procure com1', 0, 10, 6), 50.0)
# (('loc1', 'procure com1', 0, 10, 7), 50.0)
# (('loc1', 'procure com1', 0, 10, 8), 50.0)
# (('loc1', 'procure com1', 0, 10, 9), 50.0)
# (('loc1', 'procure com1', 0, 10, 10), 50.0)
# (('loc1', 'procure com1', 0, 10, 11), 50.0)
# (('loc1', 'procure com1', 0, 10, 12), 50.0)
# (('loc1', 'procure com1', 0, 10, 13), 50.0)
# (('loc1', 'procure com1', 0, 10, 14), 50.0)
# (('loc1', 'procure com1', 0, 10, 15), 50.0)
# (('loc1', 'procure com1', 0, 10, 16), 50.0)
# (('loc1', 'procure com1', 0, 10, 17), 50.0)
# (('loc1', 'procure com1', 0, 10, 18), 50.0)
# (('loc1', 'procure com1', 0, 10, 19), 50.0)
# (('loc1', 'procure com1', 0, 10, 20), 50.0)
# (('loc1', 'procure com1', 0, 10, 21), 50.0)
# (('loc1', 'procure com1', 0, 10, 22), 50.0)
# (('loc1', 'procure com1', 0, 10, 23), 50.0)
# (('loc1', 'procure com1', 0, 10, 24), 50.0)
# (('loc1', 'procure com1', 0, 10, 25), 50.0)
# (('loc1', 'procure com1', 0, 10, 26), 50.0)
# (('loc1', 'procure com1', 0, 10, 27), 30.0)
# (('loc1', 'procure com1', 0, 10, 28), 30.0)
# (('loc1', 'procure com1', 0, 10, 29), 30.0)
# (('loc1', 'procure com1', 0, 11, 0), 30.0)
# (('loc1', 'procure com1', 0, 11, 1), 30.0)
# (('loc1', 'procure com1', 0, 11, 2), 30.0)
# (('loc1', 'procure com1', 0, 11, 3), 30.0)
# (('loc1', 'procure com1', 0, 11, 4), 30.0)
# (('loc1', 'procure com1', 0, 11, 5), 30.0)
# (('loc1', 'procure com1', 0, 11, 6), 30.0)
# (('loc1', 'procure com1', 0, 11, 7), 30.0)
# (('loc1', 'procure com1', 0, 11, 8), 30.0)
# (('loc1', 'procure com1', 0, 11, 9), 30.0)
# (('loc1', 'procure com1', 0, 11, 10), 30.0)
# (('loc1', 'procure com1', 0, 11, 11), 30.0)
# (('loc1', 'procure com1', 0, 11, 12), 30.0)
# (('loc1', 'procure com1', 0, 11, 13), 30.0)
# (('loc1', 'procure com1', 0, 11, 14), 30.0)
# (('loc1', 'procure com1', 0, 11, 15), 30.0)
# (('loc1', 'procure com1', 0, 11, 16), 30.0)
# (('loc1', 'procure com1', 0, 11, 17), 30.0)
# (('loc1', 'procure com1', 0, 11, 18), 30.0)
# (('loc1', 'procure com1', 0, 11, 19), 30.0)
# (('loc1', 'procure com1', 0, 11, 20), 30.0)
# (('loc1', 'procure com1', 0, 11, 21), 0.0)
# (('loc1', 'procure com1', 0, 11, 22), 0.0)
# (('loc1', 'procure com1', 0, 11, 23), 0.0)
# (('loc1', 'procure com1', 0, 11, 24), 0.0)
# (('loc1', 'procure com1', 0, 11, 25), 0.0)
# (('loc1', 'procure com1', 0, 11, 26), 0.0)
# (('loc1', 'procure com1', 0, 11, 27), 0.0)
# (('loc1', 'procure com1', 0, 11, 28), 0.0)
# (('loc1', 'procure com1', 0, 11, 29), 0.0)

# %%
print(*[(key, value) for key, value in results_mincost.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'], sep='\n')
# Out:
# (('loc6', 'procure com1', 0, 0, 0), 50.0)
# (('loc6', 'procure com1', 0, 0, 1), 50.0)
# (('loc6', 'procure com1', 0, 0, 2), 50.0)
# (('loc6', 'procure com1', 0, 0, 3), 50.0)
# (('loc6', 'procure com1', 0, 0, 4), 50.0)
# (('loc6', 'procure com1', 0, 0, 5), 50.0)
# (('loc6', 'procure com1', 0, 0, 6), 50.0)
# (('loc6', 'procure com1', 0, 0, 7), 50.0)
# (('loc6', 'procure com1', 0, 0, 8), 50.0)
# (('loc6', 'procure com1', 0, 0, 9), 50.0)
# (('loc6', 'procure com1', 0, 0, 10), 50.0)
# (('loc6', 'procure com1', 0, 0, 11), 50.0)
# (('loc6', 'procure com1', 0, 0, 12), 50.0)
# (('loc6', 'procure com1', 0, 0, 13), 50.0)
# (('loc6', 'procure com1', 0, 0, 14), 50.0)
# (('loc6', 'procure com1', 0, 0, 15), 50.0)
# (('loc6', 'procure com1', 0, 0, 16), 50.0)
# (('loc6', 'procure com1', 0, 0, 17), 50.0)
# (('loc6', 'procure com1', 0, 0, 18), 50.0)
# (('loc6', 'procure com1', 0, 0, 19), 50.0)
# (('loc6', 'procure com1', 0, 0, 20), 50.0)
# (('loc6', 'procure com1', 0, 0, 21), 50.0)
# (('loc6', 'procure com1', 0, 0, 22), 50.0)
# (('loc6', 'procure com1', 0, 0, 23), 50.0)
# (('loc6', 'procure com1', 0, 0, 24), 50.0)
# (('loc6', 'procure com1', 0, 0, 25), 50.0)
# (('loc6', 'procure com1', 0, 0, 26), 50.0)
# (('loc6', 'procure com1', 0, 0, 27), 50.0)
# (('loc6', 'procure com1', 0, 0, 28), 50.0)
# (('loc6', 'procure com1', 0, 0, 29), 50.0)
# (('loc6', 'procure com1', 0, 1, 0), 50.0)
# (('loc6', 'procure com1', 0, 1, 1), 50.0)
# (('loc6', 'procure com1', 0, 1, 2), 50.0)
# (('loc6', 'procure com1', 0, 1, 3), 50.0)
# (('loc6', 'procure com1', 0, 1, 4), 50.0)
# (('loc6', 'procure com1', 0, 1, 5), 50.0)
# (('loc6', 'procure com1', 0, 1, 6), 50.0)
# (('loc6', 'procure com1', 0, 1, 7), 50.0)
# (('loc6', 'procure com1', 0, 1, 8), 50.0)
# (('loc6', 'procure com1', 0, 1, 9), 50.0)
# (('loc6', 'procure com1', 0, 1, 10), 50.0)
# (('loc6', 'procure com1', 0, 1, 11), 50.0)
# (('loc6', 'procure com1', 0, 1, 12), 50.0)
# (('loc6', 'procure com1', 0, 1, 13), 50.0)
# (('loc6', 'procure com1', 0, 1, 14), 50.0)
# (('loc6', 'procure com1', 0, 1, 15), 50.0)
# (('loc6', 'procure com1', 0, 1, 16), 50.0)
# (('loc6', 'procure com1', 0, 1, 17), 50.0)
# (('loc6', 'procure com1', 0, 1, 18), 50.0)
# (('loc6', 'procure com1', 0, 1, 19), 50.0)
# (('loc6', 'procure com1', 0, 1, 20), 50.0)
# (('loc6', 'procure com1', 0, 1, 21), 50.0)
# (('loc6', 'procure com1', 0, 1, 22), 50.0)
# (('loc6', 'procure com1', 0, 1, 23), 50.0)
# (('loc6', 'procure com1', 0, 1, 24), 50.0)
# (('loc6', 'procure com1', 0, 1, 25), 50.0)
# (('loc6', 'procure com1', 0, 1, 26), 50.0)
# (('loc6', 'procure com1', 0, 1, 27), 50.0)
# (('loc6', 'procure com1', 0, 1, 28), 50.0)
# (('loc6', 'procure com1', 0, 1, 29), 50.0)
# (('loc6', 'procure com1', 0, 2, 0), 50.0)
# (('loc6', 'procure com1', 0, 2, 1), 50.0)
# (('loc6', 'procure com1', 0, 2, 2), 50.0)
# (('loc6', 'procure com1', 0, 2, 3), 50.0)
# (('loc6', 'procure com1', 0, 2, 4), 50.0)
# (('loc6', 'procure com1', 0, 2, 5), 50.0)
# (('loc6', 'procure com1', 0, 2, 6), 50.0)
# (('loc6', 'procure com1', 0, 2, 7), 50.0)
# (('loc6', 'procure com1', 0, 2, 8), 50.0)
# (('loc6', 'procure com1', 0, 2, 9), 50.0)
# (('loc6', 'procure com1', 0, 2, 10), 50.0)
# (('loc6', 'procure com1', 0, 2, 11), 50.0)
# (('loc6', 'procure com1', 0, 2, 12), 50.0)
# (('loc6', 'procure com1', 0, 2, 13), 50.0)
# (('loc6', 'procure com1', 0, 2, 14), 50.0)
# (('loc6', 'procure com1', 0, 2, 15), 50.0)
# (('loc6', 'procure com1', 0, 2, 16), 50.0)
# (('loc6', 'procure com1', 0, 2, 17), 50.0)
# (('loc6', 'procure com1', 0, 2, 18), 50.0)
# (('loc6', 'procure com1', 0, 2, 19), 50.0)
# (('loc6', 'procure com1', 0, 2, 20), 50.0)
# (('loc6', 'procure com1', 0, 2, 21), 50.0)
# (('loc6', 'procure com1', 0, 2, 22), 50.0)
# (('loc6', 'procure com1', 0, 2, 23), 50.0)
# (('loc6', 'procure com1', 0, 2, 24), 50.0)
# (('loc6', 'procure com1', 0, 2, 25), 50.0)
# (('loc6', 'procure com1', 0, 2, 26), 50.0)
# (('loc6', 'procure com1', 0, 2, 27), 50.0)
# (('loc6', 'procure com1', 0, 2, 28), 50.0)
# (('loc6', 'procure com1', 0, 2, 29), 50.0)
# (('loc6', 'procure com1', 0, 3, 0), 50.0)
# (('loc6', 'procure com1', 0, 3, 1), 50.0)
# (('loc6', 'procure com1', 0, 3, 2), 50.0)
# (('loc6', 'procure com1', 0, 3, 3), 50.0)
# (('loc6', 'procure com1', 0, 3, 4), 50.0)
# (('loc6', 'procure com1', 0, 3, 5), 50.0)
# (('loc6', 'procure com1', 0, 3, 6), 50.0)
# (('loc6', 'procure com1', 0, 3, 7), 50.0)
# (('loc6', 'procure com1', 0, 3, 8), 50.0)
# (('loc6', 'procure com1', 0, 3, 9), 50.0)
# (('loc6', 'procure com1', 0, 3, 10), 50.0)
# (('loc6', 'procure com1', 0, 3, 11), 50.0)
# (('loc6', 'procure com1', 0, 3, 12), 50.0)
# (('loc6', 'procure com1', 0, 3, 13), 50.0)
# (('loc6', 'procure com1', 0, 3, 14), 50.0)
# (('loc6', 'procure com1', 0, 3, 15), 50.0)
# (('loc6', 'procure com1', 0, 3, 16), 50.0)
# (('loc6', 'procure com1', 0, 3, 17), 50.0)
# (('loc6', 'procure com1', 0, 3, 18), 50.0)
# (('loc6', 'procure com1', 0, 3, 19), 50.0)
# (('loc6', 'procure com1', 0, 3, 20), 50.0)
# (('loc6', 'procure com1', 0, 3, 21), 50.0)
# (('loc6', 'procure com1', 0, 3, 22), 50.0)
# (('loc6', 'procure com1', 0, 3, 23), 50.0)
# (('loc6', 'procure com1', 0, 3, 24), 50.0)
# (('loc6', 'procure com1', 0, 3, 25), 50.0)
# (('loc6', 'procure com1', 0, 3, 26), 50.0)
# (('loc6', 'procure com1', 0, 3, 27), 50.0)
# (('loc6', 'procure com1', 0, 3, 28), 50.0)
# (('loc6', 'procure com1', 0, 3, 29), 50.0)
# (('loc6', 'procure com1', 0, 4, 0), 50.0)
# (('loc6', 'procure com1', 0, 4, 1), 50.0)
# (('loc6', 'procure com1', 0, 4, 2), 50.0)
# (('loc6', 'procure com1', 0, 4, 3), 50.0)
# (('loc6', 'procure com1', 0, 4, 4), 50.0)
# (('loc6', 'procure com1', 0, 4, 5), 50.0)
# (('loc6', 'procure com1', 0, 4, 6), 50.0)
# (('loc6', 'procure com1', 0, 4, 7), 50.0)
# (('loc6', 'procure com1', 0, 4, 8), 50.0)
# (('loc6', 'procure com1', 0, 4, 9), 50.0)
# (('loc6', 'procure com1', 0, 4, 10), 50.0)
# (('loc6', 'procure com1', 0, 4, 11), 50.0)
# (('loc6', 'procure com1', 0, 4, 12), 50.0)
# (('loc6', 'procure com1', 0, 4, 13), 50.0)
# (('loc6', 'procure com1', 0, 4, 14), 50.0)
# (('loc6', 'procure com1', 0, 4, 15), 50.0)
# (('loc6', 'procure com1', 0, 4, 16), 50.0)
# (('loc6', 'procure com1', 0, 4, 17), 50.0)
# (('loc6', 'procure com1', 0, 4, 18), 50.0)
# (('loc6', 'procure com1', 0, 4, 19), 50.0)
# (('loc6', 'procure com1', 0, 4, 20), 50.0)
# (('loc6', 'procure com1', 0, 4, 21), 50.0)
# (('loc6', 'procure com1', 0, 4, 22), 50.0)
# (('loc6', 'procure com1', 0, 4, 23), 50.0)
# (('loc6', 'procure com1', 0, 4, 24), 50.0)
# (('loc6', 'procure com1', 0, 4, 25), 50.0)
# (('loc6', 'procure com1', 0, 4, 26), 50.0)
# (('loc6', 'procure com1', 0, 4, 27), 50.0)
# (('loc6', 'procure com1', 0, 4, 28), 50.0)
# (('loc6', 'procure com1', 0, 4, 29), 50.0)
# (('loc6', 'procure com1', 0, 5, 0), 50.0)
# (('loc6', 'procure com1', 0, 5, 1), 50.0)
# (('loc6', 'procure com1', 0, 5, 2), 50.0)
# (('loc6', 'procure com1', 0, 5, 3), 50.0)
# (('loc6', 'procure com1', 0, 5, 4), 50.0)
# (('loc6', 'procure com1', 0, 5, 5), 50.0)
# (('loc6', 'procure com1', 0, 5, 6), 50.0)
# (('loc6', 'procure com1', 0, 5, 7), 50.0)
# (('loc6', 'procure com1', 0, 5, 8), 50.0)
# (('loc6', 'procure com1', 0, 5, 9), 50.0)
# (('loc6', 'procure com1', 0, 5, 10), 50.0)
# (('loc6', 'procure com1', 0, 5, 11), 50.0)
# (('loc6', 'procure com1', 0, 5, 12), 50.0)
# (('loc6', 'procure com1', 0, 5, 13), 50.0)
# (('loc6', 'procure com1', 0, 5, 14), 50.0)
# (('loc6', 'procure com1', 0, 5, 15), 50.0)
# (('loc6', 'procure com1', 0, 5, 16), 50.0)
# (('loc6', 'procure com1', 0, 5, 17), 50.0)
# (('loc6', 'procure com1', 0, 5, 18), 50.0)
# (('loc6', 'procure com1', 0, 5, 19), 50.0)
# (('loc6', 'procure com1', 0, 5, 20), 50.0)
# (('loc6', 'procure com1', 0, 5, 21), 50.0)
# (('loc6', 'procure com1', 0, 5, 22), 50.0)
# (('loc6', 'procure com1', 0, 5, 23), 50.0)
# (('loc6', 'procure com1', 0, 5, 24), 50.0)
# (('loc6', 'procure com1', 0, 5, 25), 50.0)
# (('loc6', 'procure com1', 0, 5, 26), 50.0)
# (('loc6', 'procure com1', 0, 5, 27), 50.0)
# (('loc6', 'procure com1', 0, 5, 28), 50.0)
# (('loc6', 'procure com1', 0, 5, 29), 50.0)
# (('loc6', 'procure com1', 0, 6, 0), 50.0)
# (('loc6', 'procure com1', 0, 6, 1), 50.0)
# (('loc6', 'procure com1', 0, 6, 2), 50.0)
# (('loc6', 'procure com1', 0, 6, 3), 50.0)
# (('loc6', 'procure com1', 0, 6, 4), 50.0)
# (('loc6', 'procure com1', 0, 6, 5), 50.0)
# (('loc6', 'procure com1', 0, 6, 6), 50.0)
# (('loc6', 'procure com1', 0, 6, 7), 50.0)
# (('loc6', 'procure com1', 0, 6, 8), 50.0)
# (('loc6', 'procure com1', 0, 6, 9), 50.0)
# (('loc6', 'procure com1', 0, 6, 10), 50.0)
# (('loc6', 'procure com1', 0, 6, 11), 50.0)
# (('loc6', 'procure com1', 0, 6, 12), 50.0)
# (('loc6', 'procure com1', 0, 6, 13), 50.0)
# (('loc6', 'procure com1', 0, 6, 14), 50.0)
# (('loc6', 'procure com1', 0, 6, 15), 50.0)
# (('loc6', 'procure com1', 0, 6, 16), 50.0)
# (('loc6', 'procure com1', 0, 6, 17), 50.0)
# (('loc6', 'procure com1', 0, 6, 18), 50.0)
# (('loc6', 'procure com1', 0, 6, 19), 50.0)
# (('loc6', 'procure com1', 0, 6, 20), 50.0)
# (('loc6', 'procure com1', 0, 6, 21), 50.0)
# (('loc6', 'procure com1', 0, 6, 22), 50.0)
# (('loc6', 'procure com1', 0, 6, 23), 50.0)
# (('loc6', 'procure com1', 0, 6, 24), 50.0)
# (('loc6', 'procure com1', 0, 6, 25), 50.0)
# (('loc6', 'procure com1', 0, 6, 26), 50.0)
# (('loc6', 'procure com1', 0, 6, 27), 50.0)
# (('loc6', 'procure com1', 0, 6, 28), 50.0)
# (('loc6', 'procure com1', 0, 6, 29), 50.0)
# (('loc6', 'procure com1', 0, 7, 0), 50.0)
# (('loc6', 'procure com1', 0, 7, 1), 50.0)
# (('loc6', 'procure com1', 0, 7, 2), 50.0)
# (('loc6', 'procure com1', 0, 7, 3), 50.0)
# (('loc6', 'procure com1', 0, 7, 4), 50.0)
# (('loc6', 'procure com1', 0, 7, 5), 50.0)
# (('loc6', 'procure com1', 0, 7, 6), 50.0)
# (('loc6', 'procure com1', 0, 7, 7), 50.0)
# (('loc6', 'procure com1', 0, 7, 8), 50.0)
# (('loc6', 'procure com1', 0, 7, 9), 50.0)
# (('loc6', 'procure com1', 0, 7, 10), 50.0)
# (('loc6', 'procure com1', 0, 7, 11), 50.0)
# (('loc6', 'procure com1', 0, 7, 12), 50.0)
# (('loc6', 'procure com1', 0, 7, 13), 50.0)
# (('loc6', 'procure com1', 0, 7, 14), 50.0)
# (('loc6', 'procure com1', 0, 7, 15), 50.0)
# (('loc6', 'procure com1', 0, 7, 16), 50.0)
# (('loc6', 'procure com1', 0, 7, 17), 50.0)
# (('loc6', 'procure com1', 0, 7, 18), 50.0)
# (('loc6', 'procure com1', 0, 7, 19), 50.0)
# (('loc6', 'procure com1', 0, 7, 20), 50.0)
# (('loc6', 'procure com1', 0, 7, 21), 50.0)
# (('loc6', 'procure com1', 0, 7, 22), 50.0)
# (('loc6', 'procure com1', 0, 7, 23), 50.0)
# (('loc6', 'procure com1', 0, 7, 24), 50.0)
# (('loc6', 'procure com1', 0, 7, 25), 50.0)
# (('loc6', 'procure com1', 0, 7, 26), 50.0)
# (('loc6', 'procure com1', 0, 7, 27), 50.0)
# (('loc6', 'procure com1', 0, 7, 28), 50.0)
# (('loc6', 'procure com1', 0, 7, 29), 50.0)
# (('loc6', 'procure com1', 0, 8, 0), 50.0)
# (('loc6', 'procure com1', 0, 8, 1), 50.0)
# (('loc6', 'procure com1', 0, 8, 2), 50.0)
# (('loc6', 'procure com1', 0, 8, 3), 50.0)
# (('loc6', 'procure com1', 0, 8, 4), 50.0)
# (('loc6', 'procure com1', 0, 8, 5), 50.0)
# (('loc6', 'procure com1', 0, 8, 6), 50.0)
# (('loc6', 'procure com1', 0, 8, 7), 50.0)
# (('loc6', 'procure com1', 0, 8, 8), 50.0)
# (('loc6', 'procure com1', 0, 8, 9), 50.0)
# (('loc6', 'procure com1', 0, 8, 10), 50.0)
# (('loc6', 'procure com1', 0, 8, 11), 50.0)
# (('loc6', 'procure com1', 0, 8, 12), 50.0)
# (('loc6', 'procure com1', 0, 8, 13), 50.0)
# (('loc6', 'procure com1', 0, 8, 14), 50.0)
# (('loc6', 'procure com1', 0, 8, 15), 50.0)
# (('loc6', 'procure com1', 0, 8, 16), 50.0)
# (('loc6', 'procure com1', 0, 8, 17), 50.0)
# (('loc6', 'procure com1', 0, 8, 18), 50.0)
# (('loc6', 'procure com1', 0, 8, 19), 50.0)
# (('loc6', 'procure com1', 0, 8, 20), 50.0)
# (('loc6', 'procure com1', 0, 8, 21), 50.0)
# (('loc6', 'procure com1', 0, 8, 22), 50.0)
# (('loc6', 'procure com1', 0, 8, 23), 50.0)
# (('loc6', 'procure com1', 0, 8, 24), 50.0)
# (('loc6', 'procure com1', 0, 8, 25), 50.0)
# (('loc6', 'procure com1', 0, 8, 26), 50.0)
# (('loc6', 'procure com1', 0, 8, 27), 50.0)
# (('loc6', 'procure com1', 0, 8, 28), 50.0)
# (('loc6', 'procure com1', 0, 8, 29), 50.0)
# (('loc6', 'procure com1', 0, 9, 0), 50.0)
# (('loc6', 'procure com1', 0, 9, 1), 50.0)
# (('loc6', 'procure com1', 0, 9, 2), 50.0)
# (('loc6', 'procure com1', 0, 9, 3), 50.0)
# (('loc6', 'procure com1', 0, 9, 4), 50.0)
# (('loc6', 'procure com1', 0, 9, 5), 50.0)
# (('loc6', 'procure com1', 0, 9, 6), 50.0)
# (('loc6', 'procure com1', 0, 9, 7), 50.0)
# (('loc6', 'procure com1', 0, 9, 8), 50.0)
# (('loc6', 'procure com1', 0, 9, 9), 50.0)
# (('loc6', 'procure com1', 0, 9, 10), 50.0)
# (('loc6', 'procure com1', 0, 9, 11), 50.0)
# (('loc6', 'procure com1', 0, 9, 12), 50.0)
# (('loc6', 'procure com1', 0, 9, 13), 50.0)
# (('loc6', 'procure com1', 0, 9, 14), 50.0)
# (('loc6', 'procure com1', 0, 9, 15), 50.0)
# (('loc6', 'procure com1', 0, 9, 16), 50.0)
# (('loc6', 'procure com1', 0, 9, 17), 50.0)
# (('loc6', 'procure com1', 0, 9, 18), 50.0)
# (('loc6', 'procure com1', 0, 9, 19), 50.0)
# (('loc6', 'procure com1', 0, 9, 20), 50.0)
# (('loc6', 'procure com1', 0, 9, 21), 50.0)
# (('loc6', 'procure com1', 0, 9, 22), 50.0)
# (('loc6', 'procure com1', 0, 9, 23), 50.0)
# (('loc6', 'procure com1', 0, 9, 24), 50.0)
# (('loc6', 'procure com1', 0, 9, 25), 50.0)
# (('loc6', 'procure com1', 0, 9, 26), 50.0)
# (('loc6', 'procure com1', 0, 9, 27), 50.0)
# (('loc6', 'procure com1', 0, 9, 28), 50.0)
# (('loc6', 'procure com1', 0, 9, 29), 50.0)
# (('loc6', 'procure com1', 0, 10, 0), 50.0)
# (('loc6', 'procure com1', 0, 10, 1), 50.0)
# (('loc6', 'procure com1', 0, 10, 2), 50.0)
# (('loc6', 'procure com1', 0, 10, 3), 50.0)
# (('loc6', 'procure com1', 0, 10, 4), 50.0)
# (('loc6', 'procure com1', 0, 10, 5), 50.0)
# (('loc6', 'procure com1', 0, 10, 6), 50.0)
# (('loc6', 'procure com1', 0, 10, 7), 50.0)
# (('loc6', 'procure com1', 0, 10, 8), 50.0)
# (('loc6', 'procure com1', 0, 10, 9), 50.0)
# (('loc6', 'procure com1', 0, 10, 10), 50.0)
# (('loc6', 'procure com1', 0, 10, 11), 50.0)
# (('loc6', 'procure com1', 0, 10, 12), 50.0)
# (('loc6', 'procure com1', 0, 10, 13), 50.0)
# (('loc6', 'procure com1', 0, 10, 14), 50.0)
# (('loc6', 'procure com1', 0, 10, 15), 50.0)
# (('loc6', 'procure com1', 0, 10, 16), 50.0)
# (('loc6', 'procure com1', 0, 10, 17), 50.0)
# (('loc6', 'procure com1', 0, 10, 18), 50.0)
# (('loc6', 'procure com1', 0, 10, 19), 50.0)
# (('loc6', 'procure com1', 0, 10, 20), 50.0)
# (('loc6', 'procure com1', 0, 10, 21), 50.0)
# (('loc6', 'procure com1', 0, 10, 22), 50.0)
# (('loc6', 'procure com1', 0, 10, 23), 50.0)
# (('loc6', 'procure com1', 0, 10, 24), 50.0)
# (('loc6', 'procure com1', 0, 10, 25), 50.0)
# (('loc6', 'procure com1', 0, 10, 26), 50.0)
# (('loc6', 'procure com1', 0, 10, 27), 50.0)
# (('loc6', 'procure com1', 0, 10, 28), 50.0)
# (('loc6', 'procure com1', 0, 10, 29), 50.0)
# (('loc6', 'procure com1', 0, 11, 0), 50.0)
# (('loc6', 'procure com1', 0, 11, 1), 50.0)
# (('loc6', 'procure com1', 0, 11, 2), 50.0)
# (('loc6', 'procure com1', 0, 11, 3), 50.0)
# (('loc6', 'procure com1', 0, 11, 4), 50.0)
# (('loc6', 'procure com1', 0, 11, 5), 50.0)
# (('loc6', 'procure com1', 0, 11, 6), 50.0)
# (('loc6', 'procure com1', 0, 11, 7), 50.0)
# (('loc6', 'procure com1', 0, 11, 8), 50.0)
# (('loc6', 'procure com1', 0, 11, 9), 50.0)
# (('loc6', 'procure com1', 0, 11, 10), 50.0)
# (('loc6', 'procure com1', 0, 11, 11), 50.0)
# (('loc6', 'procure com1', 0, 11, 12), 50.0)
# (('loc6', 'procure com1', 0, 11, 13), 50.0)
# (('loc6', 'procure com1', 0, 11, 14), 50.0)
# (('loc6', 'procure com1', 0, 11, 15), 50.0)
# (('loc6', 'procure com1', 0, 11, 16), 50.0)
# (('loc6', 'procure com1', 0, 11, 17), 50.0)
# (('loc6', 'procure com1', 0, 11, 18), 50.0)
# (('loc6', 'procure com1', 0, 11, 19), 0.0)
# (('loc6', 'procure com1', 0, 11, 20), 0.0)
# (('loc6', 'procure com1', 0, 11, 21), 0.0)
# (('loc6', 'procure com1', 0, 11, 22), 0.0)
# (('loc6', 'procure com1', 0, 11, 23), 0.0)
# (('loc6', 'procure com1', 0, 11, 24), 0.0)
# (('loc6', 'procure com1', 0, 11, 25), 0.0)
# (('loc6', 'procure com1', 0, 11, 26), 0.0)
# (('loc6', 'procure com1', 0, 11, 27), 0.0)
# (('loc6', 'procure com1', 0, 11, 28), 0.0)
# (('loc6', 'procure com1', 0, 11, 29), 0.0)

# %%
print(*[(key, value) for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'], sep='\n')
# Out:
# (('loc5', 'com1_sold', 0, 0, 0), 0.0)
# (('loc5', 'com1_sold', 0, 0, 1), 0.0)
# (('loc5', 'com1_sold', 0, 0, 2), 0.0)
# (('loc5', 'com1_sold', 0, 0, 3), 0.0)
# (('loc5', 'com1_sold', 0, 0, 4), 0.0)
# (('loc5', 'com1_sold', 0, 0, 5), 0.0)
# (('loc5', 'com1_sold', 0, 0, 6), 0.0)
# (('loc5', 'com1_sold', 0, 0, 7), 0.0)
# (('loc5', 'com1_sold', 0, 0, 8), 0.0)
# (('loc5', 'com1_sold', 0, 0, 9), 30.0)
# (('loc5', 'com1_sold', 0, 0, 10), 30.0)
# (('loc5', 'com1_sold', 0, 0, 11), 80.0)
# (('loc5', 'com1_sold', 0, 0, 12), 80.0)
# (('loc5', 'com1_sold', 0, 0, 13), 80.0)
# (('loc5', 'com1_sold', 0, 0, 14), 80.0)
# (('loc5', 'com1_sold', 0, 0, 15), 80.0)
# (('loc5', 'com1_sold', 0, 0, 16), 80.0)
# (('loc5', 'com1_sold', 0, 0, 17), 120.0)
# (('loc5', 'com1_sold', 0, 0, 18), 120.0)
# (('loc5', 'com1_sold', 0, 0, 19), 130.0)
# (('loc5', 'com1_sold', 0, 0, 20), 130.0)
# (('loc5', 'com1_sold', 0, 0, 21), 130.0)
# (('loc5', 'com1_sold', 0, 0, 22), 130.0)
# (('loc5', 'com1_sold', 0, 0, 23), 130.0)
# (('loc5', 'com1_sold', 0, 0, 24), 130.0)
# (('loc5', 'com1_sold', 0, 0, 25), 130.0)
# (('loc5', 'com1_sold', 0, 0, 26), 140.0)
# (('loc5', 'com1_sold', 0, 0, 27), 140.0)
# (('loc5', 'com1_sold', 0, 0, 28), 140.0)
# (('loc5', 'com1_sold', 0, 0, 29), 140.0)
# (('loc5', 'com1_sold', 0, 1, 0), 140.0)
# (('loc5', 'com1_sold', 0, 1, 1), 140.0)
# (('loc5', 'com1_sold', 0, 1, 2), 140.0)
# (('loc5', 'com1_sold', 0, 1, 3), 140.0)
# (('loc5', 'com1_sold', 0, 1, 4), 140.0)
# (('loc5', 'com1_sold', 0, 1, 5), 140.0)
# (('loc5', 'com1_sold', 0, 1, 6), 140.0)
# (('loc5', 'com1_sold', 0, 1, 7), 140.0)
# (('loc5', 'com1_sold', 0, 1, 8), 140.0)
# (('loc5', 'com1_sold', 0, 1, 9), 140.0)
# (('loc5', 'com1_sold', 0, 1, 10), 140.0)
# (('loc5', 'com1_sold', 0, 1, 11), 140.0)
# (('loc5', 'com1_sold', 0, 1, 12), 140.0)
# (('loc5', 'com1_sold', 0, 1, 13), 140.0)
# (('loc5', 'com1_sold', 0, 1, 14), 140.0)
# (('loc5', 'com1_sold', 0, 1, 15), 140.0)
# (('loc5', 'com1_sold', 0, 1, 16), 140.0)
# (('loc5', 'com1_sold', 0, 1, 17), 140.0)
# (('loc5', 'com1_sold', 0, 1, 18), 140.0)
# (('loc5', 'com1_sold', 0, 1, 19), 124.0)
# (('loc5', 'com1_sold', 0, 1, 20), 100.0)
# (('loc5', 'com1_sold', 0, 1, 21), 100.0)
# (('loc5', 'com1_sold', 0, 1, 22), 100.0)
# (('loc5', 'com1_sold', 0, 1, 23), 100.0)
# (('loc5', 'com1_sold', 0, 1, 24), 100.0)
# (('loc5', 'com1_sold', 0, 1, 25), 100.0)
# (('loc5', 'com1_sold', 0, 1, 26), 100.0)
# (('loc5', 'com1_sold', 0, 1, 27), 100.0)
# (('loc5', 'com1_sold', 0, 1, 28), 100.0)
# (('loc5', 'com1_sold', 0, 1, 29), 100.0)
# (('loc5', 'com1_sold', 0, 2, 0), 100.0)
# (('loc5', 'com1_sold', 0, 2, 1), 100.0)
# (('loc5', 'com1_sold', 0, 2, 2), 100.0)
# (('loc5', 'com1_sold', 0, 2, 3), 100.0)
# (('loc5', 'com1_sold', 0, 2, 4), 100.0)
# (('loc5', 'com1_sold', 0, 2, 5), 100.0)
# (('loc5', 'com1_sold', 0, 2, 6), 100.0)
# (('loc5', 'com1_sold', 0, 2, 7), 100.0)
# (('loc5', 'com1_sold', 0, 2, 8), 100.0)
# (('loc5', 'com1_sold', 0, 2, 9), 100.0)
# (('loc5', 'com1_sold', 0, 2, 10), 100.0)
# (('loc5', 'com1_sold', 0, 2, 11), 100.0)
# (('loc5', 'com1_sold', 0, 2, 12), 100.0)
# (('loc5', 'com1_sold', 0, 2, 13), 100.0)
# (('loc5', 'com1_sold', 0, 2, 14), 100.0)
# (('loc5', 'com1_sold', 0, 2, 15), 100.0)
# (('loc5', 'com1_sold', 0, 2, 16), 100.0)
# (('loc5', 'com1_sold', 0, 2, 17), 100.0)
# (('loc5', 'com1_sold', 0, 2, 18), 100.0)
# (('loc5', 'com1_sold', 0, 2, 19), 100.0)
# (('loc5', 'com1_sold', 0, 2, 20), 100.0)
# (('loc5', 'com1_sold', 0, 2, 21), 100.0)
# (('loc5', 'com1_sold', 0, 2, 22), 100.0)
# (('loc5', 'com1_sold', 0, 2, 23), 100.0)
# (('loc5', 'com1_sold', 0, 2, 24), 100.0)
# (('loc5', 'com1_sold', 0, 2, 25), 100.0)
# (('loc5', 'com1_sold', 0, 2, 26), 100.0)
# (('loc5', 'com1_sold', 0, 2, 27), 100.0)
# (('loc5', 'com1_sold', 0, 2, 28), 100.0)
# (('loc5', 'com1_sold', 0, 2, 29), 100.0)
# (('loc5', 'com1_sold', 0, 3, 0), 100.0)
# (('loc5', 'com1_sold', 0, 3, 1), 100.0)
# (('loc5', 'com1_sold', 0, 3, 2), 100.0)
# (('loc5', 'com1_sold', 0, 3, 3), 100.0)
# (('loc5', 'com1_sold', 0, 3, 4), 100.0)
# (('loc5', 'com1_sold', 0, 3, 5), 100.0)
# (('loc5', 'com1_sold', 0, 3, 6), 100.0)
# (('loc5', 'com1_sold', 0, 3, 7), 100.0)
# (('loc5', 'com1_sold', 0, 3, 8), 100.0)
# (('loc5', 'com1_sold', 0, 3, 9), 100.0)
# (('loc5', 'com1_sold', 0, 3, 10), 100.0)
# (('loc5', 'com1_sold', 0, 3, 11), 100.0)
# (('loc5', 'com1_sold', 0, 3, 12), 100.0)
# (('loc5', 'com1_sold', 0, 3, 13), 100.0)
# (('loc5', 'com1_sold', 0, 3, 14), 100.0)
# (('loc5', 'com1_sold', 0, 3, 15), 100.0)
# (('loc5', 'com1_sold', 0, 3, 16), 100.0)
# (('loc5', 'com1_sold', 0, 3, 17), 100.0)
# (('loc5', 'com1_sold', 0, 3, 18), 100.0)
# (('loc5', 'com1_sold', 0, 3, 19), 100.0)
# (('loc5', 'com1_sold', 0, 3, 20), 100.0)
# (('loc5', 'com1_sold', 0, 3, 21), 100.0)
# (('loc5', 'com1_sold', 0, 3, 22), 100.0)
# (('loc5', 'com1_sold', 0, 3, 23), 100.0)
# (('loc5', 'com1_sold', 0, 3, 24), 100.0)
# (('loc5', 'com1_sold', 0, 3, 25), 100.0)
# (('loc5', 'com1_sold', 0, 3, 26), 100.0)
# (('loc5', 'com1_sold', 0, 3, 27), 100.0)
# (('loc5', 'com1_sold', 0, 3, 28), 100.0)
# (('loc5', 'com1_sold', 0, 3, 29), 100.0)
# (('loc5', 'com1_sold', 0, 4, 0), 100.0)
# (('loc5', 'com1_sold', 0, 4, 1), 100.0)
# (('loc5', 'com1_sold', 0, 4, 2), 100.0)
# (('loc5', 'com1_sold', 0, 4, 3), 100.0)
# (('loc5', 'com1_sold', 0, 4, 4), 100.0)
# (('loc5', 'com1_sold', 0, 4, 5), 100.0)
# (('loc5', 'com1_sold', 0, 4, 6), 100.0)
# (('loc5', 'com1_sold', 0, 4, 7), 100.0)
# (('loc5', 'com1_sold', 0, 4, 8), 100.0)
# (('loc5', 'com1_sold', 0, 4, 9), 100.0)
# (('loc5', 'com1_sold', 0, 4, 10), 100.0)
# (('loc5', 'com1_sold', 0, 4, 11), 100.0)
# (('loc5', 'com1_sold', 0, 4, 12), 100.0)
# (('loc5', 'com1_sold', 0, 4, 13), 100.0)
# (('loc5', 'com1_sold', 0, 4, 14), 100.0)
# (('loc5', 'com1_sold', 0, 4, 15), 100.0)
# (('loc5', 'com1_sold', 0, 4, 16), 100.0)
# (('loc5', 'com1_sold', 0, 4, 17), 100.0)
# (('loc5', 'com1_sold', 0, 4, 18), 100.0)
# (('loc5', 'com1_sold', 0, 4, 19), 100.0)
# (('loc5', 'com1_sold', 0, 4, 20), 100.0)
# (('loc5', 'com1_sold', 0, 4, 21), 100.0)
# (('loc5', 'com1_sold', 0, 4, 22), 100.0)
# (('loc5', 'com1_sold', 0, 4, 23), 100.0)
# (('loc5', 'com1_sold', 0, 4, 24), 100.0)
# (('loc5', 'com1_sold', 0, 4, 25), 100.0)
# (('loc5', 'com1_sold', 0, 4, 26), 100.0)
# (('loc5', 'com1_sold', 0, 4, 27), 100.0)
# (('loc5', 'com1_sold', 0, 4, 28), 100.0)
# (('loc5', 'com1_sold', 0, 4, 29), 100.0)
# (('loc5', 'com1_sold', 0, 5, 0), 100.0)
# (('loc5', 'com1_sold', 0, 5, 1), 100.0)
# (('loc5', 'com1_sold', 0, 5, 2), 100.0)
# (('loc5', 'com1_sold', 0, 5, 3), 100.0)
# (('loc5', 'com1_sold', 0, 5, 4), 100.0)
# (('loc5', 'com1_sold', 0, 5, 5), 100.0)
# (('loc5', 'com1_sold', 0, 5, 6), 100.0)
# (('loc5', 'com1_sold', 0, 5, 7), 100.0)
# (('loc5', 'com1_sold', 0, 5, 8), 100.0)
# (('loc5', 'com1_sold', 0, 5, 9), 100.0)
# (('loc5', 'com1_sold', 0, 5, 10), 100.0)
# (('loc5', 'com1_sold', 0, 5, 11), 100.0)
# (('loc5', 'com1_sold', 0, 5, 12), 100.0)
# (('loc5', 'com1_sold', 0, 5, 13), 100.0)
# (('loc5', 'com1_sold', 0, 5, 14), 100.0)
# (('loc5', 'com1_sold', 0, 5, 15), 100.0)
# (('loc5', 'com1_sold', 0, 5, 16), 100.0)
# (('loc5', 'com1_sold', 0, 5, 17), 100.0)
# (('loc5', 'com1_sold', 0, 5, 18), 100.0)
# (('loc5', 'com1_sold', 0, 5, 19), 100.0)
# (('loc5', 'com1_sold', 0, 5, 20), 100.0)
# (('loc5', 'com1_sold', 0, 5, 21), 100.0)
# (('loc5', 'com1_sold', 0, 5, 22), 100.0)
# (('loc5', 'com1_sold', 0, 5, 23), 100.0)
# (('loc5', 'com1_sold', 0, 5, 24), 100.0)
# (('loc5', 'com1_sold', 0, 5, 25), 100.0)
# (('loc5', 'com1_sold', 0, 5, 26), 100.0)
# (('loc5', 'com1_sold', 0, 5, 27), 100.0)
# (('loc5', 'com1_sold', 0, 5, 28), 100.0)
# (('loc5', 'com1_sold', 0, 5, 29), 100.0)
# (('loc5', 'com1_sold', 0, 6, 0), 100.0)
# (('loc5', 'com1_sold', 0, 6, 1), 100.0)
# (('loc5', 'com1_sold', 0, 6, 2), 100.0)
# (('loc5', 'com1_sold', 0, 6, 3), 100.0)
# (('loc5', 'com1_sold', 0, 6, 4), 100.0)
# (('loc5', 'com1_sold', 0, 6, 5), 100.0)
# (('loc5', 'com1_sold', 0, 6, 6), 100.0)
# (('loc5', 'com1_sold', 0, 6, 7), 100.0)
# (('loc5', 'com1_sold', 0, 6, 8), 100.0)
# (('loc5', 'com1_sold', 0, 6, 9), 100.0)
# (('loc5', 'com1_sold', 0, 6, 10), 100.0)
# (('loc5', 'com1_sold', 0, 6, 11), 100.0)
# (('loc5', 'com1_sold', 0, 6, 12), 100.0)
# (('loc5', 'com1_sold', 0, 6, 13), 100.0)
# (('loc5', 'com1_sold', 0, 6, 14), 100.0)
# (('loc5', 'com1_sold', 0, 6, 15), 100.0)
# (('loc5', 'com1_sold', 0, 6, 16), 100.0)
# (('loc5', 'com1_sold', 0, 6, 17), 100.0)
# (('loc5', 'com1_sold', 0, 6, 18), 100.0)
# (('loc5', 'com1_sold', 0, 6, 19), 100.0)
# (('loc5', 'com1_sold', 0, 6, 20), 100.0)
# (('loc5', 'com1_sold', 0, 6, 21), 100.0)
# (('loc5', 'com1_sold', 0, 6, 22), 100.0)
# (('loc5', 'com1_sold', 0, 6, 23), 100.0)
# (('loc5', 'com1_sold', 0, 6, 24), 100.0)
# (('loc5', 'com1_sold', 0, 6, 25), 100.0)
# (('loc5', 'com1_sold', 0, 6, 26), 100.0)
# (('loc5', 'com1_sold', 0, 6, 27), 100.0)
# (('loc5', 'com1_sold', 0, 6, 28), 100.0)
# (('loc5', 'com1_sold', 0, 6, 29), 100.0)
# (('loc5', 'com1_sold', 0, 7, 0), 100.0)
# (('loc5', 'com1_sold', 0, 7, 1), 100.0)
# (('loc5', 'com1_sold', 0, 7, 2), 100.0)
# (('loc5', 'com1_sold', 0, 7, 3), 100.0)
# (('loc5', 'com1_sold', 0, 7, 4), 100.0)
# (('loc5', 'com1_sold', 0, 7, 5), 100.0)
# (('loc5', 'com1_sold', 0, 7, 6), 100.0)
# (('loc5', 'com1_sold', 0, 7, 7), 100.0)
# (('loc5', 'com1_sold', 0, 7, 8), 100.0)
# (('loc5', 'com1_sold', 0, 7, 9), 100.0)
# (('loc5', 'com1_sold', 0, 7, 10), 100.0)
# (('loc5', 'com1_sold', 0, 7, 11), 100.0)
# (('loc5', 'com1_sold', 0, 7, 12), 100.0)
# (('loc5', 'com1_sold', 0, 7, 13), 100.0)
# (('loc5', 'com1_sold', 0, 7, 14), 100.0)
# (('loc5', 'com1_sold', 0, 7, 15), 100.0)
# (('loc5', 'com1_sold', 0, 7, 16), 100.0)
# (('loc5', 'com1_sold', 0, 7, 17), 100.0)
# (('loc5', 'com1_sold', 0, 7, 18), 100.0)
# (('loc5', 'com1_sold', 0, 7, 19), 100.0)
# (('loc5', 'com1_sold', 0, 7, 20), 100.0)
# (('loc5', 'com1_sold', 0, 7, 21), 100.0)
# (('loc5', 'com1_sold', 0, 7, 22), 100.0)
# (('loc5', 'com1_sold', 0, 7, 23), 100.0)
# (('loc5', 'com1_sold', 0, 7, 24), 100.0)
# (('loc5', 'com1_sold', 0, 7, 25), 100.0)
# (('loc5', 'com1_sold', 0, 7, 26), 100.0)
# (('loc5', 'com1_sold', 0, 7, 27), 100.0)
# (('loc5', 'com1_sold', 0, 7, 28), 100.0)
# (('loc5', 'com1_sold', 0, 7, 29), 100.0)
# (('loc5', 'com1_sold', 0, 8, 0), 100.0)
# (('loc5', 'com1_sold', 0, 8, 1), 100.0)
# (('loc5', 'com1_sold', 0, 8, 2), 100.0)
# (('loc5', 'com1_sold', 0, 8, 3), 100.0)
# (('loc5', 'com1_sold', 0, 8, 4), 100.0)
# (('loc5', 'com1_sold', 0, 8, 5), 100.0)
# (('loc5', 'com1_sold', 0, 8, 6), 100.0)
# (('loc5', 'com1_sold', 0, 8, 7), 100.0)
# (('loc5', 'com1_sold', 0, 8, 8), 100.0)
# (('loc5', 'com1_sold', 0, 8, 9), 100.0)
# (('loc5', 'com1_sold', 0, 8, 10), 100.0)
# (('loc5', 'com1_sold', 0, 8, 11), 100.0)
# (('loc5', 'com1_sold', 0, 8, 12), 100.0)
# (('loc5', 'com1_sold', 0, 8, 13), 100.0)
# (('loc5', 'com1_sold', 0, 8, 14), 100.0)
# (('loc5', 'com1_sold', 0, 8, 15), 100.0)
# (('loc5', 'com1_sold', 0, 8, 16), 100.0)
# (('loc5', 'com1_sold', 0, 8, 17), 100.0)
# (('loc5', 'com1_sold', 0, 8, 18), 100.0)
# (('loc5', 'com1_sold', 0, 8, 19), 100.0)
# (('loc5', 'com1_sold', 0, 8, 20), 100.0)
# (('loc5', 'com1_sold', 0, 8, 21), 100.0)
# (('loc5', 'com1_sold', 0, 8, 22), 100.0)
# (('loc5', 'com1_sold', 0, 8, 23), 100.0)
# (('loc5', 'com1_sold', 0, 8, 24), 100.0)
# (('loc5', 'com1_sold', 0, 8, 25), 100.0)
# (('loc5', 'com1_sold', 0, 8, 26), 100.0)
# (('loc5', 'com1_sold', 0, 8, 27), 100.0)
# (('loc5', 'com1_sold', 0, 8, 28), 100.0)
# (('loc5', 'com1_sold', 0, 8, 29), 100.0)
# (('loc5', 'com1_sold', 0, 9, 0), 100.0)
# (('loc5', 'com1_sold', 0, 9, 1), 100.0)
# (('loc5', 'com1_sold', 0, 9, 2), 100.0)
# (('loc5', 'com1_sold', 0, 9, 3), 100.0)
# (('loc5', 'com1_sold', 0, 9, 4), 100.0)
# (('loc5', 'com1_sold', 0, 9, 5), 100.0)
# (('loc5', 'com1_sold', 0, 9, 6), 100.0)
# (('loc5', 'com1_sold', 0, 9, 7), 100.0)
# (('loc5', 'com1_sold', 0, 9, 8), 100.0)
# (('loc5', 'com1_sold', 0, 9, 9), 100.0)
# (('loc5', 'com1_sold', 0, 9, 10), 100.0)
# (('loc5', 'com1_sold', 0, 9, 11), 100.0)
# (('loc5', 'com1_sold', 0, 9, 12), 100.0)
# (('loc5', 'com1_sold', 0, 9, 13), 100.0)
# (('loc5', 'com1_sold', 0, 9, 14), 100.0)
# (('loc5', 'com1_sold', 0, 9, 15), 100.0)
# (('loc5', 'com1_sold', 0, 9, 16), 100.0)
# (('loc5', 'com1_sold', 0, 9, 17), 100.0)
# (('loc5', 'com1_sold', 0, 9, 18), 100.0)
# (('loc5', 'com1_sold', 0, 9, 19), 100.0)
# (('loc5', 'com1_sold', 0, 9, 20), 100.0)
# (('loc5', 'com1_sold', 0, 9, 21), 100.0)
# (('loc5', 'com1_sold', 0, 9, 22), 100.0)
# (('loc5', 'com1_sold', 0, 9, 23), 100.0)
# (('loc5', 'com1_sold', 0, 9, 24), 100.0)
# (('loc5', 'com1_sold', 0, 9, 25), 100.0)
# (('loc5', 'com1_sold', 0, 9, 26), 100.0)
# (('loc5', 'com1_sold', 0, 9, 27), 100.0)
# (('loc5', 'com1_sold', 0, 9, 28), 100.0)
# (('loc5', 'com1_sold', 0, 9, 29), 100.0)
# (('loc5', 'com1_sold', 0, 10, 0), 100.0)
# (('loc5', 'com1_sold', 0, 10, 1), 100.0)
# (('loc5', 'com1_sold', 0, 10, 2), 100.0)
# (('loc5', 'com1_sold', 0, 10, 3), 100.0)
# (('loc5', 'com1_sold', 0, 10, 4), 100.0)
# (('loc5', 'com1_sold', 0, 10, 5), 100.0)
# (('loc5', 'com1_sold', 0, 10, 6), 100.0)
# (('loc5', 'com1_sold', 0, 10, 7), 100.0)
# (('loc5', 'com1_sold', 0, 10, 8), 100.0)
# (('loc5', 'com1_sold', 0, 10, 9), 100.0)
# (('loc5', 'com1_sold', 0, 10, 10), 100.0)
# (('loc5', 'com1_sold', 0, 10, 11), 100.0)
# (('loc5', 'com1_sold', 0, 10, 12), 100.0)
# (('loc5', 'com1_sold', 0, 10, 13), 100.0)
# (('loc5', 'com1_sold', 0, 10, 14), 100.0)
# (('loc5', 'com1_sold', 0, 10, 15), 100.0)
# (('loc5', 'com1_sold', 0, 10, 16), 100.0)
# (('loc5', 'com1_sold', 0, 10, 17), 100.0)
# (('loc5', 'com1_sold', 0, 10, 18), 100.0)
# (('loc5', 'com1_sold', 0, 10, 19), 100.0)
# (('loc5', 'com1_sold', 0, 10, 20), 100.0)
# (('loc5', 'com1_sold', 0, 10, 21), 100.0)
# (('loc5', 'com1_sold', 0, 10, 22), 100.0)
# (('loc5', 'com1_sold', 0, 10, 23), 100.0)
# (('loc5', 'com1_sold', 0, 10, 24), 100.0)
# (('loc5', 'com1_sold', 0, 10, 25), 100.0)
# (('loc5', 'com1_sold', 0, 10, 26), 100.0)
# (('loc5', 'com1_sold', 0, 10, 27), 100.0)
# (('loc5', 'com1_sold', 0, 10, 28), 100.0)
# (('loc5', 'com1_sold', 0, 10, 29), 100.0)
# (('loc5', 'com1_sold', 0, 11, 0), 100.0)
# (('loc5', 'com1_sold', 0, 11, 1), 100.0)
# (('loc5', 'com1_sold', 0, 11, 2), 100.0)
# (('loc5', 'com1_sold', 0, 11, 3), 100.0)
# (('loc5', 'com1_sold', 0, 11, 4), 100.0)
# (('loc5', 'com1_sold', 0, 11, 5), 100.0)
# (('loc5', 'com1_sold', 0, 11, 6), 100.0)
# (('loc5', 'com1_sold', 0, 11, 7), 100.0)
# (('loc5', 'com1_sold', 0, 11, 8), 100.0)
# (('loc5', 'com1_sold', 0, 11, 9), 100.0)
# (('loc5', 'com1_sold', 0, 11, 10), 100.0)
# (('loc5', 'com1_sold', 0, 11, 11), 100.0)
# (('loc5', 'com1_sold', 0, 11, 12), 100.0)
# (('loc5', 'com1_sold', 0, 11, 13), 100.0)
# (('loc5', 'com1_sold', 0, 11, 14), 100.0)
# (('loc5', 'com1_sold', 0, 11, 15), 100.0)
# (('loc5', 'com1_sold', 0, 11, 16), 100.0)
# (('loc5', 'com1_sold', 0, 11, 17), 100.0)
# (('loc5', 'com1_sold', 0, 11, 18), 100.0)
# (('loc5', 'com1_sold', 0, 11, 19), 100.0)
# (('loc5', 'com1_sold', 0, 11, 20), 100.0)
# (('loc5', 'com1_sold', 0, 11, 21), 100.0)
# (('loc5', 'com1_sold', 0, 11, 22), 100.0)
# (('loc5', 'com1_sold', 0, 11, 23), 100.0)
# (('loc5', 'com1_sold', 0, 11, 24), 100.0)
# (('loc5', 'com1_sold', 0, 11, 25), 100.0)
# (('loc5', 'com1_sold', 0, 11, 26), 100.0)
# (('loc5', 'com1_sold', 0, 11, 27), 100.0)
# (('loc5', 'com1_sold', 0, 11, 28), 100.0)
# (('loc5', 'com1_sold', 0, 11, 29), 100.0)

# %%
scenario.travel_time_dict
# Out:
# {('loc1', 'loc1'): {},
#  ('loc1', 'loc2'): {'truck12': 3},
#  ('loc1', 'loc3'): {'truck13': 10},
#  ('loc1', 'loc4'): {},
#  ('loc1', 'loc5'): {},
#  ('loc1', 'loc6'): {},
#  ('loc1', 'loc7'): {},
#  ('loc2', 'loc1'): {},
#  ('loc2', 'loc2'): {},
#  ('loc2', 'loc3'): {},
#  ('loc2', 'loc4'): {'truck24': 9},
#  ('loc2', 'loc5'): {'truck25': 6},
#  ('loc2', 'loc6'): {},
#  ('loc2', 'loc7'): {},
#  ('loc3', 'loc1'): {},
#  ('loc3', 'loc2'): {},
#  ('loc3', 'loc3'): {},
#  ('loc3', 'loc4'): {'truck34': 4},
#  ('loc3', 'loc5'): {},
#  ('loc3', 'loc6'): {},
#  ('loc3', 'loc7'): {},
#  ('loc4', 'loc1'): {},
#  ('loc4', 'loc2'): {},
#  ('loc4', 'loc3'): {},
#  ('loc4', 'loc4'): {},
#  ('loc4', 'loc5'): {'truck45': 5},
#  ('loc4', 'loc6'): {},
#  ('loc4', 'loc7'): {'truck47': 5},
#  ('loc5', 'loc1'): {},
#  ('loc5', 'loc2'): {},
#  ('loc5', 'loc3'): {},
#  ('loc5', 'loc4'): {},
#  ('loc5', 'loc5'): {},
#  ('loc5', 'loc6'): {},
#  ('loc5', 'loc7'): {},
#  ('loc6', 'loc1'): {},
#  ('loc6', 'loc2'): {},
#  ('loc6', 'loc3'): {},
#  ('loc6', 'loc4'): {'truck64': 6},
#  ('loc6', 'loc5'): {},
#  ('loc6', 'loc6'): {},
#  ('loc6', 'loc7'): {},
#  ('loc7', 'loc1'): {},
#  ('loc7', 'loc2'): {},
#  ('loc7', 'loc3'): {},
#  ('loc7', 'loc4'): {},
#  ('loc7', 'loc5'): {'truck75': 7},
#  ('loc7', 'loc6'): {},
#  ('loc7', 'loc7'): {}}

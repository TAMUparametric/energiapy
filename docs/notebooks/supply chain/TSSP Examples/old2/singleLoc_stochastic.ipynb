# %%
from pyomo.environ import *
from pyomo.environ import Binary, NonNegativeReals, value
import mpisppy.utils.sputils as sputils
import matplotlib.pyplot as plt
from matplotlib import rc
import sys
sys.path.append('../../../../src')
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
from energiapy.utils.scale_utils import scale_list, scale_tuple

# %%
_time_intervals = 7  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 52  # Number of execution scenarios                     (chi)

# M = 1e3  # Big M

all_scenario_names = ["good", "average", "bad"]
ns_dict = {'good': 52, "average": 26, "bad":0}
scenario_probabilities = {'good': 0.4, 'average': 0.3, 'bad': 0.3}

# %%
def build_model(cap_factor):
    
    # Define temporal scales
    scales = TemporalScale(discretization_list=[1, _exec_scenarios, _time_intervals])
    
    # ======================================================================================================================
    # Declare resources/commodities
    # ======================================================================================================================
    com1_pur = Resource(name='com1_pur', cons_max=500, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')
    
    com1_in = Resource(name='com1_in', label='Commodity 1 received')
    com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')
    
    com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
    # com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
    
    com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')
    
    # ======================================================================================================================
    # Declare processes/storage capacities
    # ======================================================================================================================
    com1_process_capacity = 250
    
    # prod_max = {0: 0.25*com1_process_capacity, 1: 0.5*com1_process_capacity, 2: 0.75*com1_process_capacity, 3: 0.95*com1_process_capacity, 4: com1_process_capacity}
    # prod_min = {0: 0, 1: 0.25*75, 2: 0.5*75, 3: 0.75*75, 4: 0.95*75}
    # rate_max = {0:1.25/2, 1: 1/2, 2: 0.75/2, 3: 0.5/2, 4: 0.25/2}
    # mode_ramp = {(0,1): 5, (1,2): 5}
    
    com1_procure = Process(name='procure com1', prod_max=com1_process_capacity, conversion={com1_pur: -1, com1_in: 1}, capex=1, vopex=0.1, prod_min=0.01, label='Procure com1', varying=[VaryingProcess.DETERMINISTIC_CAPACITY])
    
    com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.1, vopex=0.1, prod_min=0.01, label='Sell com1')
    com1_opt_procure = Process(name='procure optional com1', prod_max=150, conversion={com1_pur: -1, com1_in:1}, capex=50, vopex=0.1, prod_min=0.01, label='Procure optional com1')
    
    com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.1, vopex=0.01, prod_min=0.01, label='Commodity 1 received from location 1')
    # com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 2')
    
    # com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},  capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Process the commodity through the location')
    
    com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},  capex=0.1, vopex=0.01, prod_min=com1_process_capacity, label='Process the commodity through the location')
    
    # com1_process = Process(name='com1_process', prod_max=prod_max, conversion={0: {com1_in: -1, com1_out: 1}, 1: {com1_in: -1, com1_out: 1}, 2: {com1_in: -1, com1_out: 1}, 3: {com1_in: -1, com1_out: 1}, 4: {com1_in: -1, com1_out: 1}},  capex=0.1, vopex=0.01, prod_min=prod_min, label='Process the commodity through the location', rate_max=rate_max)
    
    com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=0.1, vopex=0.05, storage_capex=0.5, store_min=0.01, store_max= 200, prod_min=0.01, label="Storage capacity of 200 units", storage=com1_in, storage_cost=0.02)
    
    # com1_store10 = Process(name='com1_store10', prod_max=com1_process_capacity, capex=0.1, vopex=0.01, storage_capex=0.1, store_min=0.01, store_max= 40, prod_min=0.01, label="Storage capacity of 10 units", storage=com1_in, storage_cost=0.02)
    # com1_store20 = Process(name='com1_store20', prod_max=com1_process_capacity, capex=0.1, vopex=0.02, storage_capex=0.2, store_min=0.01, store_max= 80, prod_min=0.01, label="Storage capacity of 20 units", storage=com1_in, storage_cost=0.02)
    # com1_store50 = Process(name='com1_store50', prod_max=com1_process_capacity, capex=0.1, vopex=0.05, storage_capex=0.5, store_min=0.01, store_max= 200, prod_min=0.01, label="Storage capacity of 50 units", storage=com1_in, storage_cost=0.02)
    
    
    com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.1, vopex=0.1, prod_min=0.01, label='Send commodity one from location 1')
    # com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 2')
    
    # ======================================================================================================================
    # Declare locations/warehouses
    # ======================================================================================================================
    loc1 = Location(name='loc1', processes={com1_procure, com1_process, com1_store, com1_loc1_send, com1_sell, com1_opt_procure}, label="Location 1", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1, capacity_factor={com1_procure: cap_factor[['com1_procure']]})
    
   
    locset = [loc1]


    # ======================================================================================================================
    # Declare scenario
    # ======================================================================================================================
    
    daily_demand = 100
    demand_penalty = 20
    
    demand_dict = {i: {com1_sold: daily_demand} if i == loc1 else {com1_sold: 0} for i in locset}
    demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc1 else {com1_sold: 0} for i in locset}
    
    scenario = Scenario(name='scenario_baseline', network= loc1, scales=scales, scheduling_scale_level=2, network_scale_level=0, purchase_scale_level=2, availability_scale_level=1, demand_scale_level=2, capacity_scale_level=1, demand=demand_dict, demand_penalty=demand_penalty_dict, label='Scenario with perfect information')
    
    # ======================================================================================================================
    # Declare problem
    # ======================================================================================================================
    
    problem_mincost = formulate(scenario=scenario,
                            constraints={Constraints.COST, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND, Constraints.NETWORK},
                            demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)


    scale_iter = scale_tuple(instance=problem_mincost, scale_levels=scenario.network_scale_level+1)
    capex_process= sum(problem_mincost.Capex_network[scale_] for scale_ in scale_iter)

    problem_mincost.first_stage_cost  = capex_process
    
    return scenario, problem_mincost

# %% [markdown]
# # Perfect Information

# %%
exCost_PI = 0
results_PI =  dict()
model_PI = dict()
solver_options = {
    'MIPGap': 0.01,
    'TimeLimit': 60 * 15,
    'Heuristics': 0.20
}

for scenario_name in all_scenario_names:
    cap_factor = pandas.DataFrame(data={'com1_procure': [1]*ns_dict[scenario_name] + [0]*(_exec_scenarios-ns_dict[scenario_name])})
    scen_PI, model_PI[scenario_name]  = build_model(cap_factor=cap_factor)
    results_PI[scenario_name] = solve(scenario=scen_PI, instance=model_PI[scenario_name], solver='gurobi', name=scenario_name, solver_options=solver_options)
    
    # print(f"################## OBJECTIVE VALUE: {value(model_PI.objective_cost_w_demand_penalty)} ##################")
    # print(f"################## NETWORK CAPEX: {value(model_PI.Capex_network[0])} ##################")
    # print(f"################## NETWORK VOPEX: {value(model_PI.Vopex_network[0])} ##################")
    # print(f"################## NETWORK InvHold: {value(model_PI.Inv_cost_network[0])} ##################")
    # print(f"################## DEMAND PENALTY: {value(model_PI.Demand_penalty_cost_network['com1_sold',0])} ##################")
    # 
    # model_PI.write('model_PI_'+scenario_name+'.lp')
    # 
    # with open('model_PI_'+scenario_name+'.lp', 'w') as f:
    #     for v in model_PI.component_objects(Var, active=True):
    #         varobject = getattr(model_PI, str(v))
    #         for index in varobject:
    #             f.write(f'{varobject[index].name}: {varobject[index].value}\n')
    
    exCost_PI += value(model_PI[scenario_name].objective_cost_w_demand_penalty)*scenario_probabilities[scenario_name]
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# Set parameter MIPGap to value 0.01
# Set parameter TimeLimit to value 900
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9189 rows, 7728 columns and 24554 nonzeros
# Model fingerprint: 0x8864cf3e
# Variable types: 7720 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+02]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 5e+02]
# Presolve removed 5903 rows and 5533 columns
# Presolve time: 0.00s
# Presolved: 3286 rows, 2195 columns, 8389 nonzeros
# Variable types: 2188 continuous, 7 integer (7 binary)
# Found heuristic solution: objective 728000.00000
# Found heuristic solution: objective 12679.000000
#
# Root relaxation: objective 7.779000e+03, 582 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7779.0000000 7779.00000  0.00%     -    0s
#
# Explored 1 nodes (582 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 7779 12679 728000
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 7.779000000000e+03, best bound 7.779000000000e+03, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# Set parameter MIPGap to value 0.01
# Set parameter TimeLimit to value 900
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9189 rows, 7728 columns and 24372 nonzeros
# Model fingerprint: 0xf0e01e50
# Variable types: 7720 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+02]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 5e+02]
# Presolve removed 6085 rows and 5715 columns
# Presolve time: 0.01s
# Presolved: 3104 rows, 2013 columns, 7843 nonzeros
# Variable types: 2006 continuous, 7 integer (7 binary)
# Found heuristic solution: objective 728000.00000
# Found heuristic solution: objective 12679.000000
#
# Root relaxation: interrupted, 766 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      12679.0000 12597.0000  0.65%     -    0s
#
# Explored 1 nodes (766 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 12679 728000
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.267900000000e+04, best bound 1.259700000000e+04, gap 0.6467%
# WARNING: Cannot get duals for MIP.
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# Set parameter MIPGap to value 0.01
# Set parameter TimeLimit to value 900
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9189 rows, 7728 columns and 24190 nonzeros
# Model fingerprint: 0x8bbf3712
# Variable types: 7720 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+02]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 5e+02]
# Presolve removed 6270 rows and 5900 columns
# Presolve time: 0.01s
# Presolved: 2919 rows, 1828 columns, 7291 nonzeros
# Variable types: 1822 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 728000.00000
# Found heuristic solution: objective 12679.000000
#
# Root relaxation: interrupted, 379 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      12679.0000 12567.1250  0.88%     -    0s
#
# Explored 1 nodes (379 simplex iterations) in 0.02 seconds (0.03 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 12679 728000
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.267900000000e+04, best bound 1.256712500000e+04, gap 0.8824%
# WARNING: Cannot get duals for MIP.

# %%
model_PI['good'].P.pprint()
# Out:
# P : Production
#     Size=2548, Index=locations*processes_full*scales_scheduling
#     Key                                         : Lower : Value : Upper : Fixed : Stale : Domain
#             ('loc1', 'com1_loc1_send', 0, 0, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 0, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 1, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 2, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 3, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 4, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 5, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 6, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 7, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 8, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#             ('loc1', 'com1_loc1_send', 0, 9, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 10, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 11, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 12, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 13, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 14, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 15, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 16, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 17, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 18, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 19, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 20, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 21, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 22, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 23, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 24, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 25, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 26, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 27, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 28, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 29, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 30, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 31, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 32, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 33, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 34, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 35, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 36, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 37, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 38, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 39, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 40, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 41, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 42, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 43, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 44, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 45, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 46, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 47, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 48, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 49, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 50, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 1) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 2) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 3) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 4) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 5) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#            ('loc1', 'com1_loc1_send', 0, 51, 6) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 0, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 1, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 2, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 3, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 4, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 5, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 6, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 7, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 8, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#               ('loc1', 'com1_process', 0, 9, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 10, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 11, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 11, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 11, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 11, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0, 11, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
# ...
#                 ('loc1', 'sell com1', 0, 30, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 30, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 31, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 32, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 33, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 34, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 35, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 36, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 37, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 38, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 39, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 40, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 41, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 42, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 43, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 44, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 45, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 46, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 47, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 48, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 49, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 50, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 1) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 2) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 3) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 4) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 5) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0, 51, 6) :     0 : 100.0 :  None : False :  True : NonNegativeReals

# %%
model_PI[('average')].Cap_P.pprint()
# Out:
# Cap_P : Process Capacity
#     Size=7, Index=locations*processes*scales_network
#     Key                                  : Lower : Value : Upper : Fixed : Stale : Domain
#            ('loc1', 'com1_loc1_send', 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'com1_process', 0) :     0 : 250.0 :  None : False :  True : NonNegativeReals
#                ('loc1', 'com1_store', 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#      ('loc1', 'com1_store_discharge', 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#              ('loc1', 'procure com1', 0) :     0 :   0.0 :  None : False :  True : NonNegativeReals
#     ('loc1', 'procure optional com1', 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals
#                 ('loc1', 'sell com1', 0) :     0 : 100.0 :  None : False :  True : NonNegativeReals

# %%
# model_PI['average'].X_O.pprint()

# %%
# model_PI['bad'].constraint_production_max_order_fopex.pprint()

# %%
# model_PI['bad'].constraint_process_order_fopex.pprint()

# %%
# model_PI['bad'].Fopex_order_process.pprint()

# %%
# model_PI['bad'].constraint_location_fopex.pprint()

# %%
print(f"Expected cost under perfect information: {exCost_PI:.3f}")
# Out:
# Expected cost under perfect information: 10719.000

# %% [markdown]
# # Expected Value of Perfect Information

# %%
def scenario_creator(scenario_name):    
    cap_factor_scen = pandas.DataFrame(data={'com1_procure': [1] * ns_dict[scenario_name] + [0] * (_exec_scenarios - ns_dict[scenario_name])})
    scen, model = build_model(cap_factor=cap_factor_scen)
    sputils.attach_root_node(model, model.first_stage_cost, [model.X_P, model.Cap_P, model.X_S, model.Cap_S])
    model._mpisppy_probability = scenario_probabilities[scenario_name]
    return model

# %%
from mpisppy.opt.ef import ExtensiveForm

options = {"solver": "gurobi"}
ef_UI = ExtensiveForm(options, all_scenario_names, scenario_creator, model_name='model_UI')
results = ef_UI.solve_extensive_form(solver_options=solver_options)
# Out:
# [  247.22] Initializing SPBase
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# Set parameter TokenServer to value "coe-vtls1.engr.tamu.edu"
# Read LP format model from file C:\Users\SHIVAM~1.VED\AppData\Local\Temp\tmpt6mvl8_e.pyomo.lp
# Reading time = 0.03 seconds
# x1: 27599 rows, 22083 columns, 73180 nonzeros
# Set parameter MIPGap to value 0.01
# Set parameter TimeLimit to value 900
# Set parameter Heuristics to value 0.2
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 27599 rows, 22083 columns and 73180 nonzeros
# Model fingerprint: 0xf621d47c
# Variable types: 22059 continuous, 24 integer (24 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+02]
#   Objective range  [3e-01, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 5e+02]
# Presolve removed 18312 rows and 16071 columns
# Presolve time: 0.03s
# Presolved: 9287 rows, 6012 columns, 23479 nonzeros
# Variable types: 6005 continuous, 7 integer (7 binary)
# Found heuristic solution: objective 728000.00000
# Found heuristic solution: objective 12679.000000
#
# Root relaxation: interrupted, 2145 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      12679.0000 12589.7579  0.70%     -    0s
#
# Explored 1 nodes (2145 simplex iterations) in 0.07 seconds (0.11 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 12679 728000
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.267900000000e+04, best bound 1.258975789474e+04, gap 0.7039%

# %%
exCost_UI = ef_UI.get_objective_value()
print(f"Expected cost under uncertainty: {exCost_UI:.3f}")
# Out:
# Expected cost under uncertainty: 12679.000

# %%
EVPI = exCost_UI - exCost_PI
EVPI
# Out:
# 1960.0

# %%
from pyomo.environ import Var

# %%
# instance = ef_UI.ef

# %%
# getattr(instance, 'average')

# %%
# type(instance)

# %%
# output_dict = {}
# for scenario in all_scenario_names:
#     model_vars = getattr(instance,scenario).component_map(ctype=Var)
#     vars_dict = {i: model_vars[i].extract_values()
#                  for i in model_vars.keys()}
#     
#     model_obj = getattr(instance,scenario).component_map(ctype=Objective)
#     obj_dict = {'objective': model_obj[i]() for i in model_obj.keys()}
#     
#     output_dict[scenario] = {**vars_dict, **obj_dict}

# %%
# import pickle
# with open('uttarpradesh_ka_pimp.pkl', "wb") as f:
#     pickle.dump(output_dict, f)
#     f.close()

# %%
# file_ = 
# results_dict = pickle.load(open('uttarpradesh_ka_pimp.pkl', 'rb'))

# %%
# results_dict['average']

# %%
# output_dict['average']

# %%
# ef_UI.ef.pprint()

# %% [markdown]
# # Value of Stochastic Solution

# %%
n_avg = int(sum(ns_dict[i] for i in ns_dict.keys())/3)
cap_factor_avg = pandas.DataFrame(data={'com1_procure': [1]*n_avg + [0]*(_exec_scenarios-n_avg)})
scen_avg, model_avg = build_model(cap_factor=cap_factor_avg)

solver_avg = SolverFactory("gurobi")
solver_avg.solve(model_avg, options=solver_options)

# %%
def fix_variables(model1: ConcreteModel, model2:ConcreteModel):
    
    def fix(var1, var2):
        for i in list(var1.keys()):
            var2[i].fixed = True
            var2[i] = value(var1[i])
    
    # def fix(var1, var2):
    #     for i in var1:
    #         if var1[i].value is not None:
    #             var2[i].fix(value(var1[i]))
            
    fix(model1.X_P, model2.X_P)
    fix(model1.Cap_P, model2.Cap_P)
    fix(model1.X_S, model2.X_S)
    fix(model1.Cap_S, model2.Cap_S)

# %%
exCost_FD = 0

for scenario_name in all_scenario_names:
    cap_factor_VSS = pandas.DataFrame(data={'com1_procure': [1]*ns_dict[scenario_name] + [0]*(_exec_scenarios-ns_dict[scenario_name])})
    scen_VSS, model_VSS = build_model(cap_factor=cap_factor_VSS)

    fix_variables(model1=model_avg, model2=model_VSS)

    solver = SolverFactory("gurobi")
    solver.solve(model_VSS, options = solver_options)

    # print(f"################## OBJECTIVE VALUE: {value(model_VSS.objective_cost_w_demand_penalty)} ##################")
    # print(f"################## NETWORK CAPEX: {value(model_VSS.Capex_network[0])} ##################")
    # print(f"################## NETWORK VOPEX: {value(model_VSS.Vopex_network[0])} ##################")
    # print(f"################## NETWORK InvHold: {value(model_VSS.Inv_cost_network[0])} ##################")
    # print(f"################## UNMET DEMAND: {value(model_VSS.Demand_penalty_network['com1_sold',0])} ##################")
    # print(f"################## DEMAND PENALTY COST: {value(model_VSS.Demand_penalty_cost_network['com1_sold',0])} ##################")

    exCost_FD += value(model_VSS.objective_cost_w_demand_penalty)*scenario_probabilities[scenario_name]

# %%
exCost_FD

# %% [markdown]
# # Results Summary

# %%
exCost_PI

# %%
exCost_UI

# %%
exCost_FD

# %%
EVPI

# %%
VSS = exCost_FD - exCost_UI
VSS

# %%
import pickle
from energiapy.plot import plot_results, plot_scenario, plot_location
from matplotlib import pyplot as plt
from matplotlib import rc

# %%
with open(f'Round Robin Tests/ControlResults_ef_07.pkl', 'rb') as file:
    load_results = pickle.load(file)

# %%
plot_results.schedule(results=load_results, y_axis='S', component='com1_sold', location='loc5')

# %%
print(*[(k, v) for k,v in load_results.output['Demand_penalty'].items() if v], sep='\n')
# Out:
# (('loc5', 'com1_sold', 0, 0, 0), 100.0)
# (('loc5', 'com1_sold', 0, 0, 1), 100.61)
# (('loc5', 'com1_sold', 0, 0, 2), 75.53)
# (('loc5', 'com1_sold', 0, 0, 3), 87.57)
# (('loc5', 'com1_sold', 0, 0, 4), 69.45)
# (('loc5', 'com1_sold', 0, 0, 6), 13.519999999999996)
# (('loc5', 'com1_sold', 0, 1, 0), 5.930000000000007)
# (('loc5', 'com1_sold', 0, 1, 2), 17.090000000000003)
# (('loc5', 'com1_sold', 0, 1, 5), 21.83)
# (('loc5', 'com1_sold', 0, 2, 1), 9.489999999999995)
# (('loc5', 'com1_sold', 0, 2, 5), 6.060000000000002)
# (('loc5', 'com1_sold', 0, 3, 3), 10.870000000000005)
# (('loc5', 'com1_sold', 0, 3, 4), 7.609999999999999)
# (('loc5', 'com1_sold', 0, 3, 5), 21.470000000000027)
# (('loc5', 'com1_sold', 0, 3, 6), 28.810000000000002)
# (('loc5', 'com1_sold', 0, 4, 0), 17.53)
# (('loc5', 'com1_sold', 0, 4, 1), 5.430000000000007)
# (('loc5', 'com1_sold', 0, 4, 2), 10.019999999999996)
# (('loc5', 'com1_sold', 0, 4, 5), 20.83)
# (('loc5', 'com1_sold', 0, 5, 0), 7.099999999999994)
# (('loc5', 'com1_sold', 0, 5, 1), 9.419999999999987)
# (('loc5', 'com1_sold', 0, 5, 2), 0.18999999999999773)
# (('loc5', 'com1_sold', 0, 5, 4), 12.18999999999997)
# (('loc5', 'com1_sold', 0, 5, 5), 24.379999999999995)
# (('loc5', 'com1_sold', 0, 5, 6), 0.2400000000000091)
# (('loc5', 'com1_sold', 0, 6, 1), 7.409999999999997)
# (('loc5', 'com1_sold', 0, 6, 3), 1.67999999999995)
# (('loc5', 'com1_sold', 0, 6, 5), 1.299999999999983)
# (('loc5', 'com1_sold', 0, 7, 0), 27.450000000000003)
# (('loc5', 'com1_sold', 0, 7, 2), 20.870000000000005)
# (('loc5', 'com1_sold', 0, 7, 3), 32.17999999999998)
# (('loc5', 'com1_sold', 0, 7, 5), 3.160000000000011)
# (('loc5', 'com1_sold', 0, 7, 6), 11.86)
# (('loc5', 'com1_sold', 0, 8, 1), 12.060000000000002)
# (('loc5', 'com1_sold', 0, 8, 2), 11.990000000000009)
# (('loc5', 'com1_sold', 0, 8, 3), 14.950000000000003)
# (('loc5', 'com1_sold', 0, 8, 4), 10.120000000000005)
# (('loc5', 'com1_sold', 0, 8, 5), 33.599999999999994)
# (('loc5', 'com1_sold', 0, 9, 0), 4.189999999999998)
# (('loc5', 'com1_sold', 0, 9, 1), 25.960000000000008)
# (('loc5', 'com1_sold', 0, 9, 2), 3.8899999999999864)
# (('loc5', 'com1_sold', 0, 9, 5), 17.640000000000015)
# (('loc5', 'com1_sold', 0, 10, 0), 3.2900000000000205)
# (('loc5', 'com1_sold', 0, 10, 1), 1.8099999999999454)
# (('loc5', 'com1_sold', 0, 10, 2), 23.550000000000026)
# (('loc5', 'com1_sold', 0, 10, 3), 13.289999999999992)
# (('loc5', 'com1_sold', 0, 10, 4), 2.039999999999992)
# (('loc5', 'com1_sold', 0, 10, 5), 19.989999999999995)
# (('loc5', 'com1_sold', 0, 11, 1), 27.83)
# (('loc5', 'com1_sold', 0, 11, 2), 6.269999999999953)
# (('loc5', 'com1_sold', 0, 11, 4), 4.060000000000002)
# (('loc5', 'com1_sold', 0, 12, 0), 1.0699999999999932)
# (('loc5', 'com1_sold', 0, 12, 3), 15.84999999999998)
# (('loc5', 'com1_sold', 0, 12, 5), 7.269999999999996)
# (('loc5', 'com1_sold', 0, 13, 1), 20.269999999999996)
# (('loc5', 'com1_sold', 0, 13, 3), 13.050000000000011)
# (('loc5', 'com1_sold', 0, 13, 4), 25.980000000000004)
# (('loc5', 'com1_sold', 0, 13, 5), 17.340000000000003)
# (('loc5', 'com1_sold', 0, 13, 6), 14.999999999999986)
# (('loc5', 'com1_sold', 0, 14, 0), 6.6200000000000045)
# (('loc5', 'com1_sold', 0, 14, 1), 2.089999999999989)
# (('loc5', 'com1_sold', 0, 15, 2), 16.19999999999999)
# (('loc5', 'com1_sold', 0, 15, 5), 18.629999999999995)
# (('loc5', 'com1_sold', 0, 15, 6), 22.049999999999997)
# (('loc5', 'com1_sold', 0, 16, 0), 3.1700000000000017)
# (('loc5', 'com1_sold', 0, 16, 2), 14.480000000000004)
# (('loc5', 'com1_sold', 0, 16, 3), 40.54999999999998)
# (('loc5', 'com1_sold', 0, 16, 5), 5.780000000000015)
# (('loc5', 'com1_sold', 0, 17, 0), 35.69000000000001)
# (('loc5', 'com1_sold', 0, 17, 1), 2.4200000000000017)
# (('loc5', 'com1_sold', 0, 17, 2), 4.7099999999999795)
# (('loc5', 'com1_sold', 0, 17, 3), 35.41)
# (('loc5', 'com1_sold', 0, 17, 4), 2.9399999999999835)
# (('loc5', 'com1_sold', 0, 17, 5), 27.319999999999993)
# (('loc5', 'com1_sold', 0, 17, 6), 21.559999999999974)
# (('loc5', 'com1_sold', 0, 18, 0), 0.9500000000000028)
# (('loc5', 'com1_sold', 0, 18, 1), 22.610000000000014)
# (('loc5', 'com1_sold', 0, 18, 2), 28.549999999999997)
# (('loc5', 'com1_sold', 0, 18, 4), 3.6499999999999773)
# (('loc5', 'com1_sold', 0, 18, 5), 16.01000000000002)
# (('loc5', 'com1_sold', 0, 18, 6), 7.469999999999985)
# (('loc5', 'com1_sold', 0, 19, 0), 27.16000000000001)
# (('loc5', 'com1_sold', 0, 19, 2), 10.129999999999995)
# (('loc5', 'com1_sold', 0, 20, 0), 28.430000000000007)
# (('loc5', 'com1_sold', 0, 20, 1), 17.799999999999997)
# (('loc5', 'com1_sold', 0, 20, 3), 7.589999999999989)
# (('loc5', 'com1_sold', 0, 21, 1), 21.120000000000005)
# (('loc5', 'com1_sold', 0, 21, 3), 17.769999999999996)
# (('loc5', 'com1_sold', 0, 22, 1), 24.239999999999995)
# (('loc5', 'com1_sold', 0, 22, 2), 2.049999999999997)
# (('loc5', 'com1_sold', 0, 22, 3), 19.629999999999995)
# (('loc5', 'com1_sold', 0, 22, 4), 19.340000000000018)
# (('loc5', 'com1_sold', 0, 22, 5), 13.33999999999999)
# (('loc5', 'com1_sold', 0, 22, 6), 29.839999999999975)
# (('loc5', 'com1_sold', 0, 23, 2), 25.12999999999998)
# (('loc5', 'com1_sold', 0, 23, 3), 21.960000000000008)
# (('loc5', 'com1_sold', 0, 23, 4), 20.03)
# (('loc5', 'com1_sold', 0, 23, 5), 19.319999999999993)
# (('loc5', 'com1_sold', 0, 23, 6), 5.450000000000003)
# (('loc5', 'com1_sold', 0, 24, 6), 0.9699999999999989)
# (('loc5', 'com1_sold', 0, 25, 0), 34.629999999999995)
# (('loc5', 'com1_sold', 0, 25, 3), 15.620000000000019)
# (('loc5', 'com1_sold', 0, 25, 4), 3.67999999999995)
# (('loc5', 'com1_sold', 0, 25, 5), 10.910000000000053)
# (('loc5', 'com1_sold', 0, 25, 6), 4.439999999999998)
# (('loc5', 'com1_sold', 0, 26, 3), 37.269999999999996)
# (('loc5', 'com1_sold', 0, 26, 4), 4.230000000000004)
# (('loc5', 'com1_sold', 0, 26, 5), 6.709999999999994)
# (('loc5', 'com1_sold', 0, 27, 0), 28.47)
# (('loc5', 'com1_sold', 0, 27, 2), 15.230000000000004)
# (('loc5', 'com1_sold', 0, 27, 3), 26.03)
# (('loc5', 'com1_sold', 0, 27, 5), 18.280000000000015)
# (('loc5', 'com1_sold', 0, 27, 6), 8.899999999999977)
# (('loc5', 'com1_sold', 0, 28, 0), 13.219999999999942)
# (('loc5', 'com1_sold', 0, 28, 1), 37.970000000000084)
# (('loc5', 'com1_sold', 0, 28, 2), 14.349999999999994)
# (('loc5', 'com1_sold', 0, 28, 4), 1.8199999999999932)
# (('loc5', 'com1_sold', 0, 28, 5), 6.650000000000006)
# (('loc5', 'com1_sold', 0, 29, 1), 14.819999999999993)
# (('loc5', 'com1_sold', 0, 29, 4), 6.3700000000000045)
# (('loc5', 'com1_sold', 0, 29, 5), 32.639999999999986)
# (('loc5', 'com1_sold', 0, 29, 6), 0.8700000000000188)
# (('loc5', 'com1_sold', 0, 30, 0), 3.9000000000000057)
# (('loc5', 'com1_sold', 0, 30, 1), 22.10999999999997)
# (('loc5', 'com1_sold', 0, 30, 3), 4.6200000000000045)
# (('loc5', 'com1_sold', 0, 30, 4), 0.6699999999999875)
# (('loc5', 'com1_sold', 0, 31, 0), 11.319999999999993)
# (('loc5', 'com1_sold', 0, 31, 2), 7.170000000000016)
# (('loc5', 'com1_sold', 0, 31, 4), 21.429999999999993)
# (('loc5', 'com1_sold', 0, 32, 0), 14.530000000000001)
# (('loc5', 'com1_sold', 0, 32, 1), 19.760000000000005)
# (('loc5', 'com1_sold', 0, 32, 3), 20.269999999999996)
# (('loc5', 'com1_sold', 0, 32, 4), 44.519999999999996)
# (('loc5', 'com1_sold', 0, 32, 5), 32.120000000000005)
# (('loc5', 'com1_sold', 0, 33, 1), 32.359999999999985)
# (('loc5', 'com1_sold', 0, 33, 2), 15.66000000000001)
# (('loc5', 'com1_sold', 0, 33, 4), 22.700000000000003)
# (('loc5', 'com1_sold', 0, 33, 6), 7.230000000000004)
# (('loc5', 'com1_sold', 0, 34, 0), 29.05000000000001)
# (('loc5', 'com1_sold', 0, 34, 1), 37.69999999999999)
# (('loc5', 'com1_sold', 0, 34, 2), 3.8100000000000023)
# (('loc5', 'com1_sold', 0, 34, 5), 12.89)
# (('loc5', 'com1_sold', 0, 34, 6), 27.979999999999976)
# (('loc5', 'com1_sold', 0, 35, 1), 9.54000000000002)
# (('loc5', 'com1_sold', 0, 35, 2), 8.269999999999996)
# (('loc5', 'com1_sold', 0, 35, 3), 22.480000000000004)
# (('loc5', 'com1_sold', 0, 35, 4), 8.590000000000003)
# (('loc5', 'com1_sold', 0, 35, 5), 15.079999999999984)
# (('loc5', 'com1_sold', 0, 36, 1), 6.030000000000001)
# (('loc5', 'com1_sold', 0, 36, 2), 4.280000000000001)
# (('loc5', 'com1_sold', 0, 36, 3), 17.53)
# (('loc5', 'com1_sold', 0, 36, 4), 2.1899999999999977)
# (('loc5', 'com1_sold', 0, 36, 5), 38.91000000000001)
# (('loc5', 'com1_sold', 0, 37, 0), 20.260000000000005)
# (('loc5', 'com1_sold', 0, 37, 2), 21.599999999999994)
# (('loc5', 'com1_sold', 0, 37, 3), 4.459999999999994)
# (('loc5', 'com1_sold', 0, 37, 4), 33.83000000000001)
# (('loc5', 'com1_sold', 0, 37, 5), 20.64999999999995)
# (('loc5', 'com1_sold', 0, 37, 6), 15.519999999999996)
# (('loc5', 'com1_sold', 0, 38, 0), 5.980000000000004)
# (('loc5', 'com1_sold', 0, 38, 1), 4.560000000000002)
# (('loc5', 'com1_sold', 0, 38, 2), 24.250000000000014)
# (('loc5', 'com1_sold', 0, 39, 1), 12.989999999999995)
# (('loc5', 'com1_sold', 0, 39, 3), 15.829999999999984)
# (('loc5', 'com1_sold', 0, 39, 4), 42.15000000000002)
# (('loc5', 'com1_sold', 0, 39, 5), 7.289999999999992)
# (('loc5', 'com1_sold', 0, 39, 6), 28.519999999999996)
# (('loc5', 'com1_sold', 0, 40, 0), 4.389999999999986)
# (('loc5', 'com1_sold', 0, 40, 1), 40.8)
# (('loc5', 'com1_sold', 0, 40, 3), 21.269999999999982)
# (('loc5', 'com1_sold', 0, 40, 4), 5.640000000000001)
# (('loc5', 'com1_sold', 0, 40, 6), 29.789999999999992)
# (('loc5', 'com1_sold', 0, 41, 0), 27.95999999999998)
# (('loc5', 'com1_sold', 0, 41, 1), 41.859999999999985)
# (('loc5', 'com1_sold', 0, 41, 3), 15.700000000000003)
# (('loc5', 'com1_sold', 0, 41, 4), 16.14)
# (('loc5', 'com1_sold', 0, 41, 5), 28.72)
# (('loc5', 'com1_sold', 0, 41, 6), 26.950000000000003)
# (('loc5', 'com1_sold', 0, 42, 2), 10.559999999999974)
# (('loc5', 'com1_sold', 0, 42, 3), 18.440000000000026)
# (('loc5', 'com1_sold', 0, 42, 4), 34.91)
# (('loc5', 'com1_sold', 0, 42, 6), 15.11999999999999)
# (('loc5', 'com1_sold', 0, 43, 0), 20.620000000000005)
# (('loc5', 'com1_sold', 0, 43, 1), 10.849999999999994)
# (('loc5', 'com1_sold', 0, 43, 2), 10.349999999999994)
# (('loc5', 'com1_sold', 0, 43, 3), 6.579999999999998)
# (('loc5', 'com1_sold', 0, 43, 4), 32.83000000000001)
# (('loc5', 'com1_sold', 0, 43, 6), 1.8299999999999983)
# (('loc5', 'com1_sold', 0, 44, 2), 24.180000000000007)
# (('loc5', 'com1_sold', 0, 44, 3), 11.230000000000004)
# (('loc5', 'com1_sold', 0, 44, 4), 10.879999999999995)
# (('loc5', 'com1_sold', 0, 45, 1), 5.299999999999997)
# (('loc5', 'com1_sold', 0, 45, 2), 6.859999999999999)
# (('loc5', 'com1_sold', 0, 45, 3), 12.719999999999999)
# (('loc5', 'com1_sold', 0, 45, 4), 6.079999999999998)
# (('loc5', 'com1_sold', 0, 45, 5), 6.990000000000009)
# (('loc5', 'com1_sold', 0, 45, 6), 0.0799999999999983)
# (('loc5', 'com1_sold', 0, 46, 0), 13.969999999999999)
# (('loc5', 'com1_sold', 0, 46, 1), 1.4000000000000057)
# (('loc5', 'com1_sold', 0, 46, 2), 15.14)
# (('loc5', 'com1_sold', 0, 46, 3), 18.80000000000001)
# (('loc5', 'com1_sold', 0, 46, 4), 8.090000000000018)
# (('loc5', 'com1_sold', 0, 46, 5), 15.960000000000008)
# (('loc5', 'com1_sold', 0, 46, 6), 22.29000000000002)
# (('loc5', 'com1_sold', 0, 47, 0), 44.209999999999994)
# (('loc5', 'com1_sold', 0, 47, 1), 3.239999999999995)
# (('loc5', 'com1_sold', 0, 47, 2), 26.480000000000018)
# (('loc5', 'com1_sold', 0, 47, 3), 6.269999999999953)
# (('loc5', 'com1_sold', 0, 47, 4), 19.610000000000042)
# (('loc5', 'com1_sold', 0, 47, 5), 19.74000000000001)
# (('loc5', 'com1_sold', 0, 48, 1), 16.959999999999994)
# (('loc5', 'com1_sold', 0, 48, 5), 2.499999999999986)
# (('loc5', 'com1_sold', 0, 49, 2), 5.140000000000001)
# (('loc5', 'com1_sold', 0, 49, 3), 15.159999999999997)
# (('loc5', 'com1_sold', 0, 49, 4), 20.090000000000018)
# (('loc5', 'com1_sold', 0, 49, 5), 12.670000000000002)
# (('loc5', 'com1_sold', 0, 49, 6), 20.900000000000006)
# (('loc5', 'com1_sold', 0, 50, 0), 9.52000000000001)
# (('loc5', 'com1_sold', 0, 50, 1), 26.67)
# (('loc5', 'com1_sold', 0, 50, 2), 23.079999999999984)
# (('loc5', 'com1_sold', 0, 50, 4), 10.240000000000009)
# (('loc5', 'com1_sold', 0, 50, 5), 0.07999999999994145)
# (('loc5', 'com1_sold', 0, 50, 6), 1.5300000000000296)
# (('loc5', 'com1_sold', 0, 51, 0), 3.4200000000000017)
# (('loc5', 'com1_sold', 0, 51, 6), 45.52999999999999)

# %%
load_results.output.keys()
# Out:
# dict_keys(['termination', 'LB', 'UB', 'n_cons', 'n_vars', 'n_binvars', 'n_intvars', 'n_convars', 'n_nonzero', 'P', 'B', 'C', 'S', 'R', 'Inv', 'P_m', 'P_material_m', 'Cap_P', 'Cap_S', 'P_location', 'P_location_material_m', 'S_location', 'R_location', 'C_location', 'B_location', 'P_network', 'S_network', 'R_network', 'C_network', 'B_network', 'Trans_cost_network', 'Fopex_process', 'Vopex_process', 'Capex_process', 'Incidental_process', 'Capex_storage', 'Fopex_location', 'Vopex_location', 'Capex_location', 'Incidental_location', 'Fopex_network', 'Vopex_network', 'Capex_network', 'Incidental_network', 'Inv_network', 'Cost', 'Inv_cost', 'Inv_cost_location', 'Inv_cost_network', 'X_F', 'Cap_F', 'Exp_R', 'Exp_F', 'Exp_F_network', 'Exp', 'Capex_transport', 'Vopex_transport', 'Fopex_transport', 'Capex_transport_network', 'Vopex_transport_network', 'Fopex_transport_network', 'X_P', 'X_S', 'Demand_penalty', 'Demand_penalty_location', 'Demand_penalty_network', 'Demand_penalty_cost', 'Demand_penalty_cost_location', 'Demand_penalty_cost_network', 'objective'])

# %%
load_results.output['P'][('loc1', 'procure com1', 0,0,0)]
# Out:
# 75.0

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset
start=0

ax.plot(range(start, len(list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')[:15])), list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')[:15], label='Location 5', color='blue', linestyle='-')

# ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Delivery')
ax.set_title('Amount delivered at customer node')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
x = list(range(start, len(list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))))
y = list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# y2 = [556280.48, 383540.86, 373214.82, 645751.8, 437765.47]
# Plotting
plt.plot(x, y, marker='', label='Location 5')  # 'o' adds circular markers at data points
# plt.plot(x, y2, marker='x', label='approx_obj')
plt.title('Delivery under demand variability')
plt.xlabel('Time Horizon')
plt.ylabel('Delivery')
plt.grid(True)
plt.legend()
plt.show()

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset

key1 = 0
key2 = 3
start=0

ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'), label='Location 1', color='red', linestyle='-.')

ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Procurement')
ax.set_title('Procurement levels under demand variability')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
x = list(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'))))
y = list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1')
y2 = list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1')
# Plotting
plt.plot(x, y, marker='', label='Location 1')  # 'o' adds circular markers at data points
plt.plot(x, y2, marker='', label='Location 6', linestyle='--')
plt.title('Procurement levels under demand variability')
plt.xlabel('Time Horizon')
plt.ylabel('Procurement')
plt.grid(True)
plt.legend()
plt.show()

# %%
load_results.output['Exp']
# Out:
# {('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 0, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 1, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 2, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 3, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 4, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 5, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 6, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 7, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 8, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 9, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 10, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 11, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 12, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 13, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 14, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 15, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 16, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 17, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 18, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 19, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 20, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 21, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 22, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 23, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 24, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 25, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 26, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 27, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 28, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 29, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 30, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 31, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 32, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 33, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 34, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 35, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 36, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 37, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 38, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 39, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 40, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 41, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 42, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 43, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 44, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 45, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 46, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 47, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 48, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 49, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 50, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc1_out', 0, 51, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 0, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 1, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 2, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 3, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 4, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 5, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 6, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 7, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 8, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 9, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 10, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 11, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 12, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 13, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 14, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 15, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 16, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 17, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 18, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 19, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 20, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 21, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 22, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 23, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 24, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 25, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 26, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 27, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 28, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 29, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 30, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 31, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 32, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 33, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 34, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 35, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 36, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 37, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 38, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 39, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 40, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 41, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 42, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 43, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 44, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 45, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 46, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 47, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 48, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 49, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 50, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc2_out', 0, 51, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 0, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 1, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 2, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 3, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 4, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 5, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 6, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 7, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 8, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 9, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 10, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 11, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 12, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 13, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 14, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 15, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 16, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 17, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 18, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 19, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 20, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 21, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 22, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 23, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 24, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 25, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 26, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 27, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 28, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 29, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 30, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 31, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 32, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 33, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 34, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 35, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 36, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 5): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 37, 6): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 0): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 1): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 2): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 3): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 4): None,
#  ('loc1', 'loc1', 'plane15', 'com1_loc3_out', 0, 38, 5): None,
#  ...}

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset
start=0

a=1
b=2
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='red', linestyle='-.')

a=6
b=4
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='green', linestyle='-')

a=4
b=5
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='blue', linestyle='-')

a=4
b=7
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='red', linestyle='--')

# ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Transport')
ax.set_title('Product transport under demand variability')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
load_results.output['objective']
# Out:
# 1098628.4734999998

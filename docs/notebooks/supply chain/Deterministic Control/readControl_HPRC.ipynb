# %%
import pickle
from energiapy.plot import plot_results, plot_scenario, plot_location
from matplotlib import pyplot as plt
from matplotlib import rc

# %%
with open(f'HPRC Results/ControlResults_ef_10.pkl', 'rb') as file:
    load_results = pickle.load(file)

# %%
plot_results.schedule(results=load_results, y_axis='S', component='com1_sold', location='loc5')

# %%
print(*[(k, v) for k,v in load_results.output['Demand_penalty'].items() if v], sep='\n')
# Out:
# (('loc5', 'com1_sold', 0, 0, 0), 100.0)
# (('loc5', 'com1_sold', 0, 0, 1), 135.07)
# (('loc5', 'com1_sold', 0, 0, 2), 76.48)
# (('loc5', 'com1_sold', 0, 0, 3), 110.28)
# (('loc5', 'com1_sold', 0, 0, 4), 125.76)
# (('loc5', 'com1_sold', 0, 0, 5), 6.849999999999994)
# (('loc5', 'com1_sold', 0, 0, 6), 34.84000000000002)
# (('loc5', 'com1_sold', 0, 1, 0), 33.93999999999998)
# (('loc5', 'com1_sold', 0, 1, 1), 9.08999999999999)
# (('loc5', 'com1_sold', 0, 1, 3), 13.47999999999999)
# (('loc5', 'com1_sold', 0, 1, 4), 23.560000000000002)
# (('loc5', 'com1_sold', 0, 2, 3), 13.129999999999995)
# (('loc5', 'com1_sold', 0, 3, 0), 0.18999999999999773)
# (('loc5', 'com1_sold', 0, 3, 1), 32.400000000000006)
# (('loc5', 'com1_sold', 0, 3, 2), 3.0700000000000074)
# (('loc5', 'com1_sold', 0, 3, 3), 27.599999999999994)
# (('loc5', 'com1_sold', 0, 3, 5), 3.019999999999996)
# (('loc5', 'com1_sold', 0, 3, 6), 11.670000000000002)
# (('loc5', 'com1_sold', 0, 4, 0), 29.090000000000003)
# ...

# %%
print(*[(k, v) for k,v in load_results.output['S'].items() if k[0]=='loc5'], sep='\n')
# Out:
# (('loc5', 'com1_sold', 0, 0, 0), 0.0)
# (('loc5', 'com1_sold', 0, 0, 1), 0.0)
# (('loc5', 'com1_sold', 0, 0, 2), 0.0)
# (('loc5', 'com1_sold', 0, 0, 3), 0.0)
# (('loc5', 'com1_sold', 0, 0, 4), 0.0)
# (('loc5', 'com1_sold', 0, 0, 5), 100.0)
# (('loc5', 'com1_sold', 0, 0, 6), 78.97)
# (('loc5', 'com1_sold', 0, 1, 0), 87.77)
# (('loc5', 'com1_sold', 0, 1, 1), 78.12)
# (('loc5', 'com1_sold', 0, 1, 2), 77.25)
# (('loc5', 'com1_sold', 0, 1, 3), 93.81)
# (('loc5', 'com1_sold', 0, 1, 4), 87.74)
# (('loc5', 'com1_sold', 0, 1, 5), 91.21)
# (('loc5', 'com1_sold', 0, 1, 6), 89.63)
# (('loc5', 'com1_sold', 0, 2, 0), 91.9)
# (('loc5', 'com1_sold', 0, 2, 1), 93.79)
# (('loc5', 'com1_sold', 0, 2, 2), 91.78)
# (('loc5', 'com1_sold', 0, 2, 3), 67.29)
# (('loc5', 'com1_sold', 0, 2, 4), 73.72)
# (('loc5', 'com1_sold', 0, 2, 5), 92.96)
# (('loc5', 'com1_sold', 0, 2, 6), 93.01)
# (('loc5', 'com1_sold', 0, 3, 0), 100.0)
# (('loc5', 'com1_sold', 0, 3, 1), 73.03)
# (('loc5', 'com1_sold', 0, 3, 2), 91.11)
# ...

# %%
load_results.output.keys()
# Out:
# dict_keys(['termination', 'LB', 'UB', 'n_cons', 'n_vars', 'n_binvars', 'n_intvars', 'n_convars', 'n_nonzero', 'P', 'B', 'C', 'S', 'R', 'Inv', 'P_m', 'P_material_m', 'Cap_P', 'Cap_S', 'P_location', 'P_location_material_m', 'S_location', 'R_location', 'C_location', 'B_location', 'P_network', 'S_network', 'R_network', 'C_network', 'B_network', 'Trans_cost_network', 'Fopex_process', 'Vopex_process', 'Capex_process', 'Incidental_process', 'Capex_storage', 'Fopex_location', 'Vopex_location', 'Capex_location', 'Incidental_location', 'Fopex_network', 'Vopex_network', 'Capex_network', 'Incidental_network', 'Inv_network', 'Cost', 'Inv_cost', 'Inv_cost_location', 'Inv_cost_network', 'X_F', 'Cap_F', 'Exp_R', 'Exp_F', 'Exp_F_network', 'Exp', 'Capex_transport', 'Vopex_transport', 'Fopex_transport', 'Capex_transport_network', 'Vopex_transport_network', 'Fopex_transport_network', 'X_P', 'X_S', 'Demand_penalty', 'Demand_penalty_location', 'Demand_penalty_network', 'Demand_penalty_cost', 'Demand_penal
# ...

# %%
load_results.output['Cap_F']
# Out:
# {('loc1', 'loc1', 'plane15', 0): 0.0,
#  ('loc1', 'loc1', 'truck12', 0): 0.0,
#  ('loc1', 'loc1', 'truck13', 0): 0.0,
#  ('loc1', 'loc1', 'truck24', 0): 0.0,
#  ('loc1', 'loc1', 'truck25', 0): 0.0,
#  ('loc1', 'loc1', 'truck34', 0): 0.0,
#  ('loc1', 'loc1', 'truck45', 0): 0.0,
#  ('loc1', 'loc1', 'truck47', 0): 0.0,
#  ('loc1', 'loc1', 'truck64', 0): 0.0,
#  ('loc1', 'loc1', 'truck75', 0): 0.0,
#  ('loc1', 'loc2', 'plane15', 0): 0.0,
#  ('loc1', 'loc2', 'truck12', 0): 123.53448275862071,
#  ('loc1', 'loc2', 'truck13', 0): 0.0,
#  ('loc1', 'loc2', 'truck24', 0): 0.0,
#  ('loc1', 'loc2', 'truck25', 0): 0.0,
#  ('loc1', 'loc2', 'truck34', 0): 0.0,
#  ('loc1', 'loc2', 'truck45', 0): 0.0,
#  ('loc1', 'loc2', 'truck47', 0): 0.0,
#  ('loc1', 'loc2', 'truck64', 0): 0.0,
#  ('loc1', 'loc2', 'truck75', 0): 0.0,
#  ('loc1', 'loc3', 'plane15', 0): 0.0,
#  ('loc1', 'loc3', 'truck12', 0): 0.0,
#  ('loc1', 'loc3', 'truck13', 0): 60.0,
#  ('loc1', 'loc3', 'truck24', 0): 0.0,
# ...

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset
start=0

ax.plot(range(start, len(list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')[:15])), list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')[:15], label='Location 5', color='blue', linestyle='-')

# ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Delivery')
ax.set_title('Amount delivered at customer node')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
x = list(range(start, len(list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold'))))
y = list(value for key, value in load_results.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# y2 = [556280.48, 383540.86, 373214.82, 645751.8, 437765.47]
# Plotting
plt.plot(x, y, marker='', label='Location 5')  # 'o' adds circular markers at data points
# plt.plot(x, y2, marker='x', label='approx_obj')
plt.title('Delivery under demand variability')
plt.xlabel('Time Horizon')
plt.ylabel('Delivery Level')
plt.grid(True)
plt.legend()
plt.savefig(fname = 'MPC_demand', dpi = 300)
plt.show()

# %%
x = list(range(start, len(list(value for key, value in load_results.output['Demand_penalty'].items() if key[0]=='loc5' and key[1]=='com1_sold'))))
y = list(value for key, value in load_results.output['Demand_penalty'].items() if key[0]=='loc5' and key[1]=='com1_sold')
# y2 = [556280.48, 383540.86, 373214.82, 645751.8, 437765.47]
# Plotting
plt.plot(x, y, marker='', label='Location 5')  # 'o' adds circular markers at data points
# plt.plot(x, y2, marker='x', label='approx_obj')
plt.title('Unmet demand under demand variability')
plt.xlabel('Time Horizon')
plt.ylabel('Unmet Demand Level')
plt.grid(True)
plt.legend()
plt.savefig(fname = 'MPC_demand_penalty', dpi = 300)
plt.show()

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset

key1 = 0
key2 = 3
start=0

ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'), label='Location 1', color='red', linestyle='-.')

ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Procurement Level')
ax.set_title('Procurement levels under demand variability')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
plt.savefig(fname = 'MPC_supply', dpi = 300)
# Show the plot
plt.show()

# %%
x = list(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1'))))
y = list(value for key, value in load_results.output['P'].items() if key[0]=='loc1' and key[1]=='procure com1')
y2 = list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1')
# Plotting
plt.plot(x, y, marker='', label='Location 1')  # 'o' adds circular markers at data points
plt.plot(x, y2, marker='', label='Location 6', linestyle='--')
plt.title('Procurement levels under demand variability')
plt.xlabel('Time Horizon')
plt.ylabel('Procurement')
plt.grid(True)
plt.legend()
plt.show()

# %%
load_results.output['Capex_network']
# Out:
# {0: 143438.6206896552}

# %%
load_results.output['Vopex_network']
# Out:
# {0: 8762.616700000002}

# %%
load_results.output['Demand_penalty_network']
# Out:
# {('com1_sold', 0): 4985.100000000002}

# %%
load_results.output['Demand_penalty']
# Out:
# {('loc1', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 3): 0.0,
# ...

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset
start=0

a=1
b=2
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='red', linestyle='-.')

a=6
b=4
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='green', linestyle='-')

a=4
b=5
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='blue', linestyle='-')

a=4
b=7
ax.plot(range(start, len(list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'))), list(value for key, value in load_results.output['Exp'].items() if key[0]==f'loc{a}' and key[1]==f'loc{b}' and key[2]==f'truck{a}{b}' and key[3]==f'com1_loc{a}_out'), label=f'Truck {a}{b}', color='red', linestyle='--')

# ax.plot(range(start, len(list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'))), list(value for key, value in load_results.output['P'].items() if key[0]=='loc6' and key[1]=='procure com1'), label='Location 6', color='green', linestyle='-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Transport Level')
ax.set_title('Product transport under demand variability')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
plt.savefig(fname = 'MPC_logistics', dpi = 300)
# Show the plot
plt.show()

# %%
load_results.output['objective']
# Out:
# 479807.96598620695

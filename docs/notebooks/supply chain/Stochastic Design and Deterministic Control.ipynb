# %%
import sys
sys.path.append("../../../src")
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set, scale_tuple, scale_list, scale_changer
import matplotlib.pyplot as plt
from matplotlib import rc
from typing import Union, Tuple, List
from pyomo.environ import ConcreteModel, Var
from pyomo.contrib.iis import write_iis

# %%
def create_list(n_total: int, n: int):
    return [1] * n + [0] * (n_total - n)

# %%
def sum_probabilities(d:dict):
    total_prob = 0

    def recursive_sum(current_dict:dict):
        nonlocal total_prob
        for key, value in current_dict.items():
            if isinstance(value, dict):
                # Recursively traverse if it's still a dictionary
                recursive_sum(value)
            elif key == 'prob':
                # Add the probability value
                total_prob += value

    recursive_sum(d)
    return total_prob

# %%
def create_sceario_dict(n_total: int):
    default_list = [1] * n_total
    scenario_dict = {
        'cap2_1': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 1)})},
        'cap2_2': {'prob': 0.06, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 2)})},
        'cap2_3': {'prob': 0.085, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 3)})},

        'cap4_1': {'prob': 0.025, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 1)})},
        'cap4_2': {'prob': 0.075, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 2)})},
        'cap4_3': {'prob': 0.09, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 3)})},

        'res6_1': {'prob': 0.015, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 1)})},
        'res6_2': {'prob': 0.08, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 2)})},
        'res6_3': {'prob': 0.085, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 3)})},

        'trans25_1': {'prob': 0.02, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): create_list(n_total, 1)})},
        'trans25_2': {'prob': 0.035, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): create_list(n_total, 2)})},
        'trans25_3': {'prob': 0.09, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): create_list(n_total, 3)})},
        
        'trans47_1': {'prob': 0.04, 'factor': pandas.DataFrame(data={('trans47', 'com1_loc4_out'): create_list(n_total, 1)})},
        'trans47_2': {'prob': 0.085, 'factor': pandas.DataFrame(data={('trans47', 'com1_loc4_out'): create_list(n_total, 2)})},
        'trans47_3': {'prob': 0.075, 'factor': pandas.DataFrame(data={('trans47', 'com1_loc4_out'): create_list(n_total, 3)})},
        
        'no_disruption': {'prob': 0.11, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): default_list})}
    }
    return scenario_dict

# %%
_time_intervals = 30  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 12  # Number of execution scenarios                     (chi)

M = 1e3  # Big M
loc6_varying_factor = pandas.DataFrame(data={'com1_process': [1]*_exec_scenarios})
# Define temporal scales
scales = TemporalScale(discretization_list=[_exec_scenarios, _time_intervals])
annualization_factor = 1/_exec_scenarios

# %%
def build_model(scen_df=pandas.DataFrame()):
    default_df = pandas.DataFrame(data=[1] * _exec_scenarios)
    scale_factor = 90
    
    # Define temporal scales
    scales = TemporalScale(discretization_list=[1, _exec_scenarios])

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================
com1_pur = Resource(name='com1_pur', cons_max=75, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')

com1_in = Resource(name='com1_in', label='Commodity 1 received')
com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_process_capacity = 125
min_process_capacity = 0.01

com1_procure = Process(name='procure com1', prod_max=125, conversion={com1_pur: -1, com1_in: 1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity, conversion={com1_loc3_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity, conversion={com1_loc4_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 4')
com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity, conversion={com1_loc5_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 5')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity, conversion={com1_loc6_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity, conversion={com1_loc7_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},  capex=0.01, vopex=0.01, prod_min=min_process_capacity, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

# com1_process = Process(name='com1_process', prod_max=prod_max, conversion={0:{com1_in: -1, com1_out: 1}, 1:{com1_in: -1, com1_out: 1}, 2:{com1_in: -1, com1_out: 1}},  capex=0.01, vopex=0.01, prod_min=prod_min, rate_max=rate_max, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=500, vopex=5, store_min=0.01, store_max= 100, prod_min=min_process_capacity, label="Storage capacity of upto 100 units", storage=com1_in, storage_cost=0.02, storage_capex=50)

com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 2')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc3_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 3')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc4_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 4')
com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc5_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 5')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc6_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 6')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc7_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 7')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store, com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc2 = Location(name='loc2', processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc3 = Location(name='loc3', processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store, com1_loc3_send}, label="Location 3", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5, com1_receive_loc7, com1_process, com1_store, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc5 = Location(name='loc5', processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store, com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store, com1_loc6_send}, label="Location 6", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0, capacity_factor={com1_process: loc6_varying_factor[['com1_process']]})

loc7 = Location(name='loc7', processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc7_send}, label="Location 7", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================

truck_cap12 = 70
truck_cap13 = 30
truck_cap24 = 50
truck_cap25 = 30
truck_cap34 = 30
truck_cap45 = 100
truck_cap47 = 40
truck_cap64 = 50
truck_cap75 = 40

truck_capmin = 0.01

truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12, label='Truck from location 1 to 2', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13, label='Truck from location 1 to 3', capex=0.3, vopex=0.03, trans_min=truck_capmin, speed=50)
truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=50)

truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24, label='Truck from location 2 to 4', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25, label='Truck from location 2 to 5', capex=0.3, vopex=0.03, trans_min=truck_capmin, speed=50)
truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=50)

truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34, label='Truck from location 3 to 4', capex=0.2, vopex=0.02, trans_min=truck_capmin, speed=50)
truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_capmin, speed=50)

truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45, label='Truck from location 4 to 5', capex=1, vopex=0.1, trans_min=truck_capmin, speed=50)
truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_capmin, speed=50)

truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47, label='Truck from location 4 to 7', capex=0.4, vopex=0.04, trans_min=truck_capmin, speed=50)
truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=50)

truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64, label='Truck from location 6 to 4', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75, label='Truck from location 7 to 5', capex=0.4, vopex=0.04, trans_min=truck_capmin, speed=50)
truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=50)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================

# transport_matrix = [
#     [[], [truck50_12], [truck30_13], [], [], [], []],  # source: location 1
#     [[truck50_21], [], [], [truck50_24], [truck30_25], [], []],  # source: location 2
#     [[truck30_31], [], [], [truck20_34], [], [], []],  # source: location 3
#     [[], [truck50_42], [truck20_43], [], [truck100_45], [truck50_46], [truck40_47]],  # source: location 4
#     [[], [truck30_52], [], [truck100_54], [], [], [truck40_57]],  # source: location 5
#     [[], [], [], [truck50_64], [], [], []],  # source: location 6
#     [[], [], [], [truck40_74], [truck40_75], [], []]  # source: location 7
# ]

transport_matrix = [
    [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    [[], [], [], [truck64], [], [], []],  # source: location 6
    [[], [], [], [truck74], [truck75], [], []]  # source: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = locset
sinks = locset

network = Network(name='Network', scales= scales, source_locations=sources, sink_locations=sinks, transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
# ======================================================================================================================
# Declare scenario
# ======================================================================================================================

daily_demand = 100
demand_penalty = 50

demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

scenario = Scenario(name=f'scenario', scales=scales, scheduling_scale_level=1, network_scale_level=0, purchase_scale_level=1, availability_scale_level=0, demand_scale_level=1, capacity_scale_level=0, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict, label='Baseline Scenario', annualization_factor=annualization_factor)

# %%
# ======================================================================================================================
# Declare model
# ======================================================================================================================

problem_mincost = formulate(scenario=scenario,
                        constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND, Constraints.NETWORK, Constraints.MODE},
                        demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint fixed nameplate min production mode
# constraint fixed nameplate max production mode
# constraint production mode binary
# constraint production rate1
# constraint production rate2
# constraint production mode switch
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
result = solve(scenario=scenario, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 992760 rows, 2997313 columns and 1268967 nonzeros
# Model fingerprint: 0xbe2e74c0
# Variable types: 2889289 continuous, 108024 integer (108024 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 1e+02]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e+01, 1e+02]
# Presolve removed 947834 rows and 2951307 columns
# Presolve time: 0.25s
# Presolved: 44926 rows, 46006 columns, 144155 nonzeros
# Variable types: 45118 continuous, 888 integer (888 binary)
# Found heuristic solution: objective 1800000.0000
# Performing another presolve...
# Presolve removed 10714 rows and 28174 columns
# Presolve time: 0.13s
#
# Root relaxation: objective 4.910045e+05, 8979 iterations, 0.17 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    491004.47500 491004.475  0.00%     -    0s
#
# Explored 1 nodes (8979 simplex iterations) in 1.00 seconds (1.47 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 491004 1.8e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.910044750000e+05, best bound 4.910044750000e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
print(*[(key, value) for key, value in result.output['X_F'].items() if value], sep='\n')
# Out:
# (('loc1', 'loc2', 'truck12', 0), 1.0)
# (('loc1', 'loc2', 'truck12', 1), 1.0)
# (('loc1', 'loc2', 'truck12', 2), 1.0)
# (('loc1', 'loc2', 'truck12', 3), 1.0)
# (('loc1', 'loc2', 'truck12', 4), 1.0)
# (('loc1', 'loc2', 'truck12', 5), 1.0)
# (('loc1', 'loc2', 'truck12', 6), 1.0)
# (('loc1', 'loc2', 'truck12', 7), 1.0)
# (('loc1', 'loc2', 'truck12', 8), 1.0)
# (('loc1', 'loc2', 'truck12', 9), 1.0)
# (('loc1', 'loc2', 'truck12', 10), 1.0)
# (('loc1', 'loc2', 'truck12', 11), 1.0)
# (('loc1', 'loc3', 'truck13', 0), 1.0)
# (('loc1', 'loc3', 'truck13', 1), 1.0)
# (('loc1', 'loc3', 'truck13', 2), 1.0)
# (('loc1', 'loc3', 'truck13', 3), 1.0)
# (('loc1', 'loc3', 'truck13', 4), 1.0)
# (('loc1', 'loc3', 'truck13', 5), 1.0)
# (('loc1', 'loc3', 'truck13', 6), 1.0)
# (('loc1', 'loc3', 'truck13', 7), 1.0)
# (('loc1', 'loc3', 'truck13', 8), 1.0)
# (('loc1', 'loc3', 'truck13', 9), 1.0)
# (('loc1', 'loc3', 'truck13', 10), 1.0)
# (('loc1', 'loc3', 'truck13', 11), 1.0)
# (('loc2', 'loc5', 'truck25', 0), 1.0)
# (('loc2', 'loc5', 'truck25', 1), 1.0)
# (('loc2', 'loc5', 'truck25', 2), 1.0)
# (('loc2', 'loc5', 'truck25', 3), 1.0)
# (('loc2', 'loc5', 'truck25', 4), 1.0)
# (('loc2', 'loc5', 'truck25', 5), 1.0)
# (('loc2', 'loc5', 'truck25', 6), 1.0)
# (('loc2', 'loc5', 'truck25', 7), 1.0)
# (('loc2', 'loc5', 'truck25', 8), 1.0)
# (('loc2', 'loc5', 'truck25', 9), 1.0)
# (('loc2', 'loc5', 'truck25', 10), 1.0)
# (('loc2', 'loc5', 'truck25', 11), 1.0)
# (('loc3', 'loc4', 'truck34', 0), 1.0)
# (('loc3', 'loc4', 'truck34', 1), 1.0)
# (('loc3', 'loc4', 'truck34', 2), 1.0)
# (('loc3', 'loc4', 'truck34', 3), 1.0)
# (('loc3', 'loc4', 'truck34', 4), 1.0)
# (('loc3', 'loc4', 'truck34', 5), 1.0)
# (('loc3', 'loc4', 'truck34', 6), 1.0)
# (('loc3', 'loc4', 'truck34', 7), 1.0)
# (('loc3', 'loc4', 'truck34', 8), 1.0)
# (('loc3', 'loc4', 'truck34', 9), 1.0)
# (('loc3', 'loc4', 'truck34', 10), 1.0)
# (('loc3', 'loc4', 'truck34', 11), 1.0)
# (('loc4', 'loc5', 'truck45', 0), 1.0)
# (('loc4', 'loc5', 'truck45', 1), 1.0)
# (('loc4', 'loc5', 'truck45', 2), 1.0)
# (('loc4', 'loc5', 'truck45', 3), 1.0)
# (('loc4', 'loc5', 'truck45', 4), 1.0)
# (('loc4', 'loc5', 'truck45', 5), 1.0)
# (('loc4', 'loc5', 'truck45', 6), 1.0)
# (('loc4', 'loc5', 'truck45', 7), 1.0)
# (('loc4', 'loc5', 'truck45', 8), 1.0)
# (('loc4', 'loc5', 'truck45', 9), 1.0)
# (('loc4', 'loc5', 'truck45', 10), 1.0)
# (('loc4', 'loc5', 'truck45', 11), 1.0)
# (('loc4', 'loc7', 'truck47', 0), 1.0)
# (('loc4', 'loc7', 'truck47', 1), 1.0)
# (('loc4', 'loc7', 'truck47', 2), 1.0)
# (('loc4', 'loc7', 'truck47', 3), 1.0)
# (('loc4', 'loc7', 'truck47', 4), 1.0)
# (('loc4', 'loc7', 'truck47', 5), 1.0)
# (('loc4', 'loc7', 'truck47', 6), 1.0)
# (('loc4', 'loc7', 'truck47', 7), 1.0)
# (('loc4', 'loc7', 'truck47', 8), 1.0)
# (('loc4', 'loc7', 'truck47', 9), 1.0)
# (('loc4', 'loc7', 'truck47', 10), 1.0)
# (('loc4', 'loc7', 'truck47', 11), 1.0)
# (('loc6', 'loc4', 'truck64', 0), 1.0)
# (('loc6', 'loc4', 'truck64', 1), 1.0)
# (('loc6', 'loc4', 'truck64', 2), 1.0)
# (('loc6', 'loc4', 'truck64', 3), 1.0)
# (('loc6', 'loc4', 'truck64', 4), 1.0)
# (('loc6', 'loc4', 'truck64', 5), 1.0)
# (('loc6', 'loc4', 'truck64', 6), 1.0)
# (('loc6', 'loc4', 'truck64', 7), 1.0)
# (('loc6', 'loc4', 'truck64', 8), 1.0)
# (('loc6', 'loc4', 'truck64', 9), 1.0)
# (('loc6', 'loc4', 'truck64', 10), 1.0)
# (('loc6', 'loc4', 'truck64', 11), 1.0)
# (('loc7', 'loc5', 'truck75', 0), 1.0)
# (('loc7', 'loc5', 'truck75', 1), 1.0)
# (('loc7', 'loc5', 'truck75', 2), 1.0)
# (('loc7', 'loc5', 'truck75', 3), 1.0)
# (('loc7', 'loc5', 'truck75', 4), 1.0)
# (('loc7', 'loc5', 'truck75', 5), 1.0)
# (('loc7', 'loc5', 'truck75', 6), 1.0)
# (('loc7', 'loc5', 'truck75', 7), 1.0)
# (('loc7', 'loc5', 'truck75', 8), 1.0)
# (('loc7', 'loc5', 'truck75', 9), 1.0)
# (('loc7', 'loc5', 'truck75', 10), 1.0)
# (('loc7', 'loc5', 'truck75', 11), 1.0)

# %%
print(*[(key, value) for key, value in result.output['Exp'].items() if value], sep='\n')
# Out:
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 0, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 1, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 2, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 3, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 4, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 5, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 6, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 7, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 8, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 9, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 24), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 25), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 26), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 27), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 28), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 10, 29), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 0), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 1), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 2), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 3), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 4), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 5), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 6), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 7), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 8), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 9), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 10), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 11), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 12), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 13), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 14), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 15), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 16), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 17), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 18), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 19), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 20), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 21), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 22), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 23), 30.0)
# (('loc1', 'loc2', 'truck12', 'com1_loc1_out', 11, 24), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 0), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 1), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 2), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 3), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 4), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 5), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 6), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 7), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 8), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 9), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 10), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 11), 30.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 0, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 1, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 2, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 3, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 4, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 5, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 6, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 7, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 8, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 9, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 18), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 19), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 20), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 21), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 22), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 23), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 24), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 25), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 26), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 27), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 28), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 10, 29), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 0), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 1), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 2), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 3), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 4), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 5), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 6), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 7), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 8), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 9), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 10), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 11), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 12), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 13), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 14), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 15), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 16), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 17), 20.0)
# (('loc1', 'loc3', 'truck13', 'com1_loc1_out', 11, 18), 20.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 2), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 3), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 4), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 5), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 6), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 7), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 8), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 9), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 10), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 11), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 12), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 13), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 14), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 15), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 16), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 17), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 18), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 19), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 20), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 21), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 22), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 23), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 24), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 25), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 26), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 27), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 28), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 0, 29), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 0), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 1), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 2), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 3), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 4), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 5), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 6), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 7), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 8), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 9), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 10), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 11), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 12), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 13), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 14), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 15), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 16), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 17), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 18), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 19), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 20), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 21), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 22), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 23), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 24), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 25), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 26), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 27), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 28), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 1, 29), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 0), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 1), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 2), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 3), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 4), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 5), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 6), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 7), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 8), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 9), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 10), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 11), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 12), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 13), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 14), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 15), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 16), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 17), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 18), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 19), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 20), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 21), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 22), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 23), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 24), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 25), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 26), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 27), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 28), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 2, 29), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 0), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 1), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 2), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 3), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 4), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 5), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 6), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 7), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 8), 30.0)
# (('loc2', 'loc5', 'truck25', 'com1_loc2_out', 3, 9), 30.0)
# ...
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 3, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 4, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 5, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 6, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 7, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 8, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 9, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 26), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 27), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 28), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 10, 29), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 0), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 1), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 2), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 3), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 4), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 5), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 6), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 7), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 8), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 9), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 10), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 11), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 12), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 13), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 14), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 15), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 16), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 17), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 18), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 19), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 20), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 21), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 22), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 23), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 24), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 25), 40.0)
# (('loc7', 'loc5', 'truck75', 'com1_loc7_out', 11, 26), 40.0)

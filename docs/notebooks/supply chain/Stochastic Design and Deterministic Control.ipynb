# %%
import sys
sys.path.append("../../../src")
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set, scale_tuple, scale_list, scale_changer
import matplotlib.pyplot as plt
from matplotlib import rc
from typing import Union, Tuple, List
from pyomo.environ import ConcreteModel, Var
from pyomo.contrib.iis import write_iis

# %%
_time_intervals = 30  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 12  # Number of execution scenarios                     (chi)

M = 1e3  # Big M
loc6_varying_factor = pandas.DataFrame(data={'com1_process': [1]*_exec_scenarios})
# Define temporal scales
scales = TemporalScale(discretization_list=[_exec_scenarios, _time_intervals])
annualization_factor = 1/_exec_scenarios

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================
com1_pur = Resource(name='com1_pur', cons_max=75, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')

com1_in = Resource(name='com1_in', label='Commodity 1 received')
com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_process_capacity = 125
min_process_capacity = 0.01

com1_procure = Process(name='procure com1', prod_max=125, conversion={com1_pur: -1, com1_in: 1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity, conversion={com1_loc3_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity, conversion={com1_loc4_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 4')
com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity, conversion={com1_loc5_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 5')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity, conversion={com1_loc6_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity, conversion={com1_loc7_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},  capex=0.01, vopex=0.01, prod_min=min_process_capacity, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

# com1_process = Process(name='com1_process', prod_max=prod_max, conversion={0:{com1_in: -1, com1_out: 1}, 1:{com1_in: -1, com1_out: 1}, 2:{com1_in: -1, com1_out: 1}},  capex=0.01, vopex=0.01, prod_min=prod_min, rate_max=rate_max, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=500, vopex=5, store_min=0.01, store_max= 100, prod_min=min_process_capacity, label="Storage capacity of upto 100 units", storage=com1_in, storage_cost=0.02, storage_capex=50)

com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 2')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc3_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 3')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc4_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 4')
com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc5_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 5')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc6_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 6')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc7_out:1}, capex=0.01, vopex=0.01, prod_min=min_process_capacity, label='Send commodity one from location 7')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store, com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc2 = Location(name='loc2', processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc3 = Location(name='loc3', processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store, com1_loc3_send}, label="Location 3", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5, com1_receive_loc7, com1_process, com1_store, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc5 = Location(name='loc5', processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store, com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store, com1_loc6_send}, label="Location 6", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0, capacity_factor={com1_process: loc6_varying_factor[['com1_process']]})

loc7 = Location(name='loc7', processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc7_send}, label="Location 7", scales=scales, demand_scale_level=1, capacity_scale_level=0, availability_scale_level=0)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================

truck_cap12 = 70
truck_cap13 = 30
truck_cap24 = 50
truck_cap25 = 30
truck_cap34 = 30
truck_cap45 = 100
truck_cap47 = 40
truck_cap64 = 50
truck_cap75 = 40

truck_capmin = 0.01

truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12, label='Truck from location 1 to 2', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13, label='Truck from location 1 to 3', capex=0.3, vopex=0.03, trans_min=truck_capmin, speed=50)
truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=50)

truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24, label='Truck from location 2 to 4', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25, label='Truck from location 2 to 5', capex=0.3, vopex=0.03, trans_min=truck_capmin, speed=50)
truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=50)

truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34, label='Truck from location 3 to 4', capex=0.2, vopex=0.02, trans_min=truck_capmin, speed=50)
truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_capmin, speed=50)

truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45, label='Truck from location 4 to 5', capex=1, vopex=0.1, trans_min=truck_capmin, speed=50)
truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_capmin, speed=50)

truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47, label='Truck from location 4 to 7', capex=0.4, vopex=0.04, trans_min=truck_capmin, speed=50)
truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=50)

truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64, label='Truck from location 6 to 4', capex=0.5, vopex=0.05, trans_min=truck_capmin, speed=50)
truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=50)

truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75, label='Truck from location 7 to 5', capex=0.4, vopex=0.04, trans_min=truck_capmin, speed=50)
truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=50)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================

# transport_matrix = [
#     [[], [truck50_12], [truck30_13], [], [], [], []],  # source: location 1
#     [[truck50_21], [], [], [truck50_24], [truck30_25], [], []],  # source: location 2
#     [[truck30_31], [], [], [truck20_34], [], [], []],  # source: location 3
#     [[], [truck50_42], [truck20_43], [], [truck100_45], [truck50_46], [truck40_47]],  # source: location 4
#     [[], [truck30_52], [], [truck100_54], [], [], [truck40_57]],  # source: location 5
#     [[], [], [], [truck50_64], [], [], []],  # source: location 6
#     [[], [], [], [truck40_74], [truck40_75], [], []]  # source: location 7
# ]

transport_matrix = [
    [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    [[], [], [], [truck64], [], [], []],  # source: location 6
    [[], [], [], [truck74], [truck75], [], []]  # source: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = locset
sinks = locset

network = Network(name='Network', scales= scales, source_locations=sources, sink_locations=sinks, transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
# ======================================================================================================================
# Declare scenario
# ======================================================================================================================

daily_demand = 100
demand_penalty = 50

demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

scenario = Scenario(name=f'scenario', scales=scales, scheduling_scale_level=1, network_scale_level=0, purchase_scale_level=1, availability_scale_level=0, demand_scale_level=1, capacity_scale_level=0, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict, label='Baseline Scenario', annualization_factor=annualization_factor)

# %%
# ======================================================================================================================
# Declare model
# ======================================================================================================================

problem_mincost = formulate(scenario=scenario,
                        constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND, Constraints.NETWORK, Constraints.MODE},
                        demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint fixed nameplate min production mode
# constraint fixed nameplate max production mode
# constraint production mode binary
# constraint production rate1
# constraint production rate2
# constraint production mode switch
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
result = solve(scenario=scenario, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 992760 rows, 2997313 columns and 1268967 nonzeros
# Model fingerprint: 0xbe2e74c0
# Variable types: 2889289 continuous, 108024 integer (108024 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 1e+02]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e+01, 1e+02]
# Presolve removed 947834 rows and 2951307 columns
# Presolve time: 0.29s
# Presolved: 44926 rows, 46006 columns, 144155 nonzeros
# Variable types: 45118 continuous, 888 integer (888 binary)
# Found heuristic solution: objective 1800000.0000
# Performing another presolve...
# Presolve removed 10714 rows and 28174 columns
# Presolve time: 0.13s
#
# Root relaxation: objective 4.910045e+05, 9052 iterations, 0.19 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    491004.47500 491004.475  0.00%     -    1s
#
# Explored 1 nodes (9052 simplex iterations) in 1.21 seconds (1.47 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 491004 1.8e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.910044750000e+05, best bound 4.910044750000e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
problem_mincost.X_P.pprint()
# Out:
# X_P : Process Binary
#     Size=1596, Index=locations*processes*scales_network_binary
#     Key                                  : Lower : Value : Upper : Fixed : Stale : Domain
#            ('loc1', 'com1_loc1_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc1_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc1_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc1_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc2_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc2_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc2_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc3_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc3_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc3_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc4_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc4_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc4_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc5_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc5_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc5_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc6_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc6_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc6_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc1', 'com1_loc7_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc7_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc1', 'com1_loc7_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'com1_process', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc1', 'com1_process', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc1', 'com1_process', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc1', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc1', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc1', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 0) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 1) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 2) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 3) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 4) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 5) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 6) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 7) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 8) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc2', 9) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc2', 10) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc2', 11) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 0) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 1) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 2) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 3) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 4) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 5) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 6) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 7) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 8) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc3', 9) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc3', 10) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc3', 11) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc4', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc4', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc4', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc5', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc5', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc5', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc6', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc6', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc6', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc1', 'com1_receive_loc7', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc7', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc1', 'com1_receive_loc7', 11) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 0) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 1) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 2) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 3) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 4) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 5) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 6) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 7) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 8) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc1', 'com1_store', 9) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc1', 'com1_store', 10) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc1', 'com1_store', 11) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 0) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 1) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 2) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 3) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 4) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 5) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 6) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 7) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 8) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc1', 'com1_store_discharge', 9) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc1', 'com1_store_discharge', 10) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc1', 'com1_store_discharge', 11) :     0 :  -0.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc1', 'procure com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc1', 'procure com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc1', 'procure com1', 11) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc1', 'sell com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc1', 'sell com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc1', 'sell com1', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc1_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc1_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc1_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc2_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc2_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc2_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc3_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc3_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc3_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc4_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc4_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc4_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc5_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc5_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc5_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc6_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc6_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc6_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc2', 'com1_loc7_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc7_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc2', 'com1_loc7_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'com1_process', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc2', 'com1_process', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc2', 'com1_process', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc1', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc1', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc1', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc2', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc2', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc2', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc3', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc3', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc3', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 0) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 1) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 2) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 3) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 4) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 5) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 6) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 7) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 8) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc4', 9) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc4', 10) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc4', 11) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 0) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 1) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 2) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 3) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 4) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 5) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 6) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 7) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 8) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc5', 9) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc5', 10) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc5', 11) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc6', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc6', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc6', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc2', 'com1_receive_loc7', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc7', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc2', 'com1_receive_loc7', 11) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 0) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 1) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 2) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 3) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 4) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 5) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 6) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 7) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 8) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc2', 'com1_store', 9) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc2', 'com1_store', 10) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc2', 'com1_store', 11) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 0) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 1) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 2) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 3) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 4) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 5) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 6) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 7) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 8) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc2', 'com1_store_discharge', 9) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc2', 'com1_store_discharge', 10) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc2', 'com1_store_discharge', 11) :     0 :  -0.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc2', 'procure com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc2', 'procure com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc2', 'procure com1', 11) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc2', 'sell com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc2', 'sell com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc2', 'sell com1', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc1_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc1_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc1_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc2_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc2_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc2_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc3_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc3_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc3_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc4_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc4_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc4_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc5_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc5_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc5_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc6_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc6_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc3', 'com1_loc6_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc7_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc7_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc3', 'com1_loc7_send', 2) :     0 :   1.0 :     1 : False : False : Binary
# ...
#            ('loc7', 'com1_loc5_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc5_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc5_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc5_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc6_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc6_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc6_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 0) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 1) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 2) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 3) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 4) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 5) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 6) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 7) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 8) :     0 :   1.0 :     1 : False : False : Binary
#            ('loc7', 'com1_loc7_send', 9) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc7_send', 10) :     0 :   1.0 :     1 : False : False : Binary
#           ('loc7', 'com1_loc7_send', 11) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'com1_process', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc7', 'com1_process', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc7', 'com1_process', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc1', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc1', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc1', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc2', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc2', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc2', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc3', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc3', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc3', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc4', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc4', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc4', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 0) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 1) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 2) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 3) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 4) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 5) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 6) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 7) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 8) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc5', 9) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc5', 10) :     0 :  -0.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc5', 11) :     0 :  -0.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc6', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc6', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc6', 11) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 5) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 6) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 7) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 8) :     0 :   1.0 :     1 : False : False : Binary
#         ('loc7', 'com1_receive_loc7', 9) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc7', 10) :     0 :   1.0 :     1 : False : False : Binary
#        ('loc7', 'com1_receive_loc7', 11) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 0) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 1) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 2) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 3) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 4) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 5) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 6) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 7) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 8) :     0 :  -0.0 :     1 : False : False : Binary
#                ('loc7', 'com1_store', 9) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc7', 'com1_store', 10) :     0 :  -0.0 :     1 : False : False : Binary
#               ('loc7', 'com1_store', 11) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 0) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 1) :     0 :   0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 2) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 3) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 4) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 5) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 6) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 7) :     0 :  -0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 8) :     0 :   0.0 :     1 : False : False : Binary
#      ('loc7', 'com1_store_discharge', 9) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc7', 'com1_store_discharge', 10) :     0 :  -0.0 :     1 : False : False : Binary
#     ('loc7', 'com1_store_discharge', 11) :     0 :   0.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#              ('loc7', 'procure com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc7', 'procure com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#             ('loc7', 'procure com1', 11) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 0) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 1) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 2) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 3) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 4) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 5) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 6) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 7) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 8) :     0 :   1.0 :     1 : False : False : Binary
#                 ('loc7', 'sell com1', 9) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc7', 'sell com1', 10) :     0 :   1.0 :     1 : False : False : Binary
#                ('loc7', 'sell com1', 11) :     0 :   1.0 :     1 : False : False : Binary

# %%
print(*[(key, value) for key, value in result.output['X_F'].items() if value], sep='\n')
# Out:
# (('loc1', 'loc2', 'truck12', 0), 1.0)
# (('loc1', 'loc2', 'truck12', 1), 1.0)
# (('loc1', 'loc2', 'truck12', 2), 1.0)
# (('loc1', 'loc2', 'truck12', 3), 1.0)
# (('loc1', 'loc2', 'truck12', 4), 1.0)
# (('loc1', 'loc2', 'truck12', 5), 1.0)
# (('loc1', 'loc2', 'truck12', 6), 1.0)
# (('loc1', 'loc2', 'truck12', 7), 1.0)
# (('loc1', 'loc2', 'truck12', 8), 1.0)
# (('loc1', 'loc2', 'truck12', 9), 1.0)
# (('loc1', 'loc2', 'truck12', 10), 1.0)
# (('loc1', 'loc2', 'truck12', 11), 1.0)
# (('loc1', 'loc3', 'truck13', 0), 1.0)
# (('loc1', 'loc3', 'truck13', 1), 1.0)
# (('loc1', 'loc3', 'truck13', 2), 1.0)
# (('loc1', 'loc3', 'truck13', 3), 1.0)
# (('loc1', 'loc3', 'truck13', 4), 1.0)
# (('loc1', 'loc3', 'truck13', 5), 1.0)
# (('loc1', 'loc3', 'truck13', 6), 1.0)
# (('loc1', 'loc3', 'truck13', 7), 1.0)
# (('loc1', 'loc3', 'truck13', 8), 1.0)
# (('loc1', 'loc3', 'truck13', 9), 1.0)
# (('loc1', 'loc3', 'truck13', 10), 1.0)
# (('loc1', 'loc3', 'truck13', 11), 1.0)
# (('loc2', 'loc5', 'truck25', 0), 1.0)
# (('loc2', 'loc5', 'truck25', 1), 1.0)
# (('loc2', 'loc5', 'truck25', 2), 1.0)
# (('loc2', 'loc5', 'truck25', 3), 1.0)
# (('loc2', 'loc5', 'truck25', 4), 1.0)
# (('loc2', 'loc5', 'truck25', 5), 1.0)
# (('loc2', 'loc5', 'truck25', 6), 1.0)
# (('loc2', 'loc5', 'truck25', 7), 1.0)
# (('loc2', 'loc5', 'truck25', 8), 1.0)
# (('loc2', 'loc5', 'truck25', 9), 1.0)
# (('loc2', 'loc5', 'truck25', 10), 1.0)
# (('loc2', 'loc5', 'truck25', 11), 1.0)
# (('loc3', 'loc4', 'truck34', 0), 1.0)
# (('loc3', 'loc4', 'truck34', 1), 1.0)
# (('loc3', 'loc4', 'truck34', 2), 1.0)
# (('loc3', 'loc4', 'truck34', 3), 1.0)
# (('loc3', 'loc4', 'truck34', 4), 1.0)
# (('loc3', 'loc4', 'truck34', 5), 1.0)
# (('loc3', 'loc4', 'truck34', 6), 1.0)
# (('loc3', 'loc4', 'truck34', 7), 1.0)
# (('loc3', 'loc4', 'truck34', 8), 1.0)
# (('loc3', 'loc4', 'truck34', 9), 1.0)
# (('loc3', 'loc4', 'truck34', 10), 1.0)
# (('loc3', 'loc4', 'truck34', 11), 1.0)
# (('loc4', 'loc5', 'truck45', 0), 1.0)
# (('loc4', 'loc5', 'truck45', 1), 1.0)
# (('loc4', 'loc5', 'truck45', 2), 1.0)
# (('loc4', 'loc5', 'truck45', 3), 1.0)
# (('loc4', 'loc5', 'truck45', 4), 1.0)
# (('loc4', 'loc5', 'truck45', 5), 1.0)
# (('loc4', 'loc5', 'truck45', 6), 1.0)
# (('loc4', 'loc5', 'truck45', 7), 1.0)
# (('loc4', 'loc5', 'truck45', 8), 1.0)
# (('loc4', 'loc5', 'truck45', 9), 1.0)
# (('loc4', 'loc5', 'truck45', 10), 1.0)
# (('loc4', 'loc5', 'truck45', 11), 1.0)
# (('loc4', 'loc7', 'truck47', 0), 1.0)
# (('loc4', 'loc7', 'truck47', 1), 1.0)
# (('loc4', 'loc7', 'truck47', 2), 1.0)
# (('loc4', 'loc7', 'truck47', 3), 1.0)
# (('loc4', 'loc7', 'truck47', 4), 1.0)
# (('loc4', 'loc7', 'truck47', 5), 1.0)
# (('loc4', 'loc7', 'truck47', 6), 1.0)
# (('loc4', 'loc7', 'truck47', 7), 1.0)
# (('loc4', 'loc7', 'truck47', 8), 1.0)
# (('loc4', 'loc7', 'truck47', 9), 1.0)
# (('loc4', 'loc7', 'truck47', 10), 1.0)
# (('loc4', 'loc7', 'truck47', 11), 1.0)
# (('loc6', 'loc4', 'truck64', 0), 1.0)
# (('loc6', 'loc4', 'truck64', 1), 1.0)
# (('loc6', 'loc4', 'truck64', 2), 1.0)
# (('loc6', 'loc4', 'truck64', 3), 1.0)
# (('loc6', 'loc4', 'truck64', 4), 1.0)
# (('loc6', 'loc4', 'truck64', 5), 1.0)
# (('loc6', 'loc4', 'truck64', 6), 1.0)
# (('loc6', 'loc4', 'truck64', 7), 1.0)
# (('loc6', 'loc4', 'truck64', 8), 1.0)
# (('loc6', 'loc4', 'truck64', 9), 1.0)
# (('loc6', 'loc4', 'truck64', 10), 1.0)
# (('loc6', 'loc4', 'truck64', 11), 1.0)
# (('loc7', 'loc5', 'truck75', 0), 1.0)
# (('loc7', 'loc5', 'truck75', 1), 1.0)
# (('loc7', 'loc5', 'truck75', 2), 1.0)
# (('loc7', 'loc5', 'truck75', 3), 1.0)
# (('loc7', 'loc5', 'truck75', 4), 1.0)
# (('loc7', 'loc5', 'truck75', 5), 1.0)
# (('loc7', 'loc5', 'truck75', 6), 1.0)
# (('loc7', 'loc5', 'truck75', 7), 1.0)
# (('loc7', 'loc5', 'truck75', 8), 1.0)
# (('loc7', 'loc5', 'truck75', 9), 1.0)
# (('loc7', 'loc5', 'truck75', 10), 1.0)
# (('loc7', 'loc5', 'truck75', 11), 1.0)

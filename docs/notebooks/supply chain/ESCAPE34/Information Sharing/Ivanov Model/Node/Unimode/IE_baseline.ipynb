# %%
import sys
sys.path.append('../../../../../src')
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
_time_intervals = 30  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 12  # Number of execution scenarios                     (chi)

M = 1e3  # Big M

# Define temporal scales
scales = TemporalScale(discretization_list=[1, _exec_scenarios, _time_intervals])

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================
com1_pur = Resource(name='com1_pur', cons_max=125, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')

com1_in = Resource(name='com1_in', label='Commodity 1 received')
com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_process_capacity = 150

com1_procure = Process(name='procure com1', prod_max=125, conversion={com1_pur: -1, com1_in: 1}, capex=0.01, vopex=0.01, prod_min=125, label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity, conversion={com1_loc3_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity, conversion={com1_loc4_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 4')
com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity, conversion={com1_loc5_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 5')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity, conversion={com1_loc6_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity, conversion={com1_loc7_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={0:{com1_in: -1, com1_out: 1}, 1:{com1_in: -1, com1_out: 1}, 2:{com1_in: -1, com1_out: 1}, 3:{com1_in: -1, com1_out: 1}, 4:{com1_in: -1, com1_out: 1}},  capex=0.01, vopex=0.01, prod_min=com1_process_capacity, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

com1_store10 = Process(name='com1_store10', prod_max=150, capex=100, vopex=1, store_min=0.01, store_max= 20, prod_min=150, label="Storage capacity of 10 units", storage=com1_in, storage_cost=0.02)
com1_store20 = Process(name='com1_store20', prod_max=150, capex=200, vopex=2, store_min=0.01,store_max= 40, prod_min=150, label="Storage capacity of 20 units", storage=com1_in, storage_cost=0.02)
com1_store50 = Process(name='com1_store50', prod_max=150, capex=500, vopex=5, store_min=0.01, store_max= 100, prod_min=150, label="Storage capacity of 50 units", storage=com1_in, storage_cost=0.02)

com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 2')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc3_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 3')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc4_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 4')
com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc5_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 5')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc6_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 6')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc7_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 7')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store20, com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc2 = Location(name='loc2', processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc3 = Location(name='loc3', processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store20, com1_loc3_send}, label="Location 3", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5, com1_receive_loc7, com1_process, com1_store50, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc5 = Location(name='loc5', processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store50, com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store10, com1_loc6_send}, label="Location 6", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc7 = Location(name='loc7', processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc7_send}, label="Location 7", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================

truck_cap12 = 70
truck_cap13 = 50
truck_cap24 = 50
truck_cap25 = 30
truck_cap34 = 20
truck_cap45 = 100
truck_cap47 = 40
truck_cap64 = 50
truck_cap75 = 40

truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12, label='Truck from location 1 to 2', capex=0.5, vopex=0.05, trans_min=truck_cap12)
truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_cap12)

truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13, label='Truck from location 1 to 3', capex=0.3, vopex=0.03, trans_min=truck_cap13)
truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_cap13)

truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24, label='Truck from location 2 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap24)
truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_cap24)

truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25, label='Truck from location 2 to 5', capex=0.3, vopex=0.03, trans_min=truck_cap25)
truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_cap25)

truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34, label='Truck from location 3 to 4', capex=0.2, vopex=0.02, trans_min=truck_cap34)
truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_cap34)

truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45, label='Truck from location 4 to 5', capex=1, vopex=0.1, trans_min=truck_cap45)
truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_cap45)

truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47, label='Truck from location 4 to 7', capex=0.4, vopex=0.04, trans_min=truck_cap47)
truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_cap47)

truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64, label='Truck from location 6 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap64)
truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_cap64)

truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75, label='Truck from location 7 to 5', capex=0.4, vopex=0.04, trans_min=truck_cap75)
truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_cap75)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================

# transport_matrix = [
#     [[], [truck50_12], [truck30_13], [], [], [], []],  # source: location 1
#     [[truck50_21], [], [], [truck50_24], [truck30_25], [], []],  # source: location 2
#     [[truck30_31], [], [], [truck20_34], [], [], []],  # source: location 3
#     [[], [truck50_42], [truck20_43], [], [truck100_45], [truck50_46], [truck40_47]],  # source: location 4
#     [[], [truck30_52], [], [truck100_54], [], [], [truck40_57]],  # source: location 5
#     [[], [], [], [truck50_64], [], [], []],  # source: location 6
#     [[], [], [], [truck40_74], [truck40_75], [], []]  # source: location 7
# ]

transport_matrix = [
    [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    [[], [], [], [truck64], [], [], []],  # source: location 6
    [[], [], [], [truck74], [truck75], [], []]  # source: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = locset
sinks = locset

network = Network(name='Network', scales= scales, source_locations=sources, sink_locations=sinks, transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
daily_demand = 100
demand_penalty = 50

demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

scenario = Scenario(name='scenario_baseline', scales=scales, scheduling_scale_level=2, network_scale_level=0, purchase_scale_level=2, availability_scale_level=1, demand_scale_level=2, capacity_scale_level=1, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict, label='Scenario with perfect information')

# %%
problem_mincost = formulate(scenario=scenario,
                            constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND},
                            demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
results_mincost = solve(scenario=scenario, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 893670 rows, 2818795 columns and 1140196 nonzeros
# Model fingerprint: 0xb8ada247
# Variable types: 2817913 continuous, 882 integer (882 binary)
# Coefficient statistics:
#   Matrix range     [6e-03, 5e+02]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 2e+02]
# Presolve removed 874590 rows and 2764435 columns
# Presolve time: 0.24s
# Presolved: 19080 rows, 54360 columns, 120233 nonzeros
# Variable types: 54360 continuous, 0 integer (0 binary)
# Performing another presolve...
# Presolve removed 5767 rows and 24855 columns
# Presolve time: 0.09s
#
# Root relaxation: objective 1.053290e+06, 10557 iterations, 0.05 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1053290.0650 1053290.06  0.00%     -    0s
#
# Explored 1 nodes (10557 simplex iterations) in 0.70 seconds (1.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.05329e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.053290065000e+06, best bound 1.053290065000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.

# %%
sum(value for key, value in results_mincost.output['S'].items() if key[0] == 'loc5' and key[1] == 'com1_sold') / 36000
# Out:
# 1.0

# %%
min(value for key, value in results_mincost.output['S'].items() if key[0] == 'loc5' and key[1] == 'com1_sold')
# Out:
# 100.0

# %%
# print([(key, value) for key, value in results_mincost.output['X_P'].items() if value == 1 and key[0] == 'loc1'])

# %%
# print([(key, value) for key, value in results_mincost.output['X_F'].items() if value == 1])

# %%
plot_results.schedule(results=results_mincost, y_axis='S', component='com1_sold', location='loc5', color='green')

# %%
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc2', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc3', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc4', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc5', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store10_com1_in_stored', location='loc6', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc7', color='green')

# %%
plot_results.transport(results=results_mincost, source='loc1', sink='loc2', transport='truck50_12',
                       resource='com1_loc1_out')
plot_results.transport(results=results_mincost, source='loc1', sink='loc3', transport='truck30_13',
                       resource='com1_loc1_out')
plot_results.transport(results=results_mincost, source='loc2', sink='loc4', transport='truck50_24',
                       resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc2', sink='loc5', transport='truck30_25',
                       resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc3', sink='loc4', transport='truck20_34',
                       resource='com1_loc3_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc5', transport='truck100_45',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc7', transport='truck40_47',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc6', sink='loc4', transport='truck50_64',
                       resource='com1_loc6_out')
plot_results.transport(results=results_mincost, source='loc7', sink='loc5', transport='truck40_75',
                       resource='com1_loc7_out')

# %%
plot_results.transport(results=results_mincost, source='loc2', sink='loc1', transport='truck50_21',
                       resource='com1_loc2_out')
plot_results.transport(results=results_mincost, source='loc3', sink='loc1', transport='truck30_31',
                       resource='com1_loc3_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc2', transport='truck50_42',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc5', sink='loc2', transport='truck30_52',
                       resource='com1_loc5_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc3', transport='truck20_43',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc5', sink='loc4', transport='truck100_54',
                       resource='com1_loc5_out')
plot_results.transport(results=results_mincost, source='loc7', sink='loc4', transport='truck40_74',
                       resource='com1_loc7_out')
plot_results.transport(results=results_mincost, source='loc4', sink='loc6', transport='truck50_46',
                       resource='com1_loc4_out')
plot_results.transport(results=results_mincost, source='loc5', sink='loc7', transport='truck40_57',
                       resource='com1_loc5_out')

# %%
plot_results.schedule(results=results_mincost, y_axis='C', component='com1_pur', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='C', component='com1_pur', location='loc6', color='green')

# %%
results_mincost.output['objective']
# Out:
# 1053290.065

# %%
demand_penalty*sum(value for key, value in results_mincost.output['Demand_penalty'].items()) + problem_mincost.Capex_network[0].value + problem_mincost.Vopex_network[0].value + problem_mincost.Capex_transport_network[0].value + problem_mincost.Vopex_transport_network[0].value + problem_mincost.Inv_cost_network[0].value
# Out:
# 1053290.065

# %%
problem_mincost.Capex_network.pprint()
problem_mincost.Fopex_network.pprint()
problem_mincost.Vopex_network.pprint()
problem_mincost.Capex_transport_network.pprint()
problem_mincost.Fopex_transport_network.pprint()
problem_mincost.Vopex_transport_network.pprint()
# Out:
# Capex_network : Capex at network scale
#     Size=1, Index=scales_network
#     Key : Lower : Value    : Upper : Fixed : Stale : Domain
#       0 :     0 : 570052.0 :  None : False : False : NonNegativeReals
# Fopex_network : Fixed Opex at network scale
#     Size=1, Index=scales_network
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#       0 :     0 :   0.0 :  None : False : False : NonNegativeReals
# Vopex_network : Variable Opex at network scale
#     Size=1, Index=scales_network
#     Key : Lower : Value  : Upper : Fixed : Stale : Domain
#       0 :     0 : 3888.0 :  None : False : False : NonNegativeReals
# Capex_transport_network : overall capex for transport at the network level
#     Size=1, Index=scales_network
#     Key : Lower : Value     : Upper : Fixed : Stale : Domain
#       0 :     0 : 26182.065 :  None : False : False : NonNegativeReals
# Fopex_transport_network : overall fopex for transport at the network level
#     Size=1, Index=scales_network
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#       0 :     0 :   0.0 :  None : False : False : NonNegativeReals
# Vopex_transport_network : overall vopex for transport at the network level
#     Size=1, Index=scales_network
#     Key : Lower : Value    : Upper : Fixed : Stale : Domain
#       0 :     0 : 453168.0 :  None : False : False : NonNegativeReals

# %%
sum(value for key, value in results_mincost.output['P'].items() if value!=0 and value!=None)
# Out:
# 388800.0

# %%
problem_mincost.constraint_transport_capacity_UB_no_bin.pprint()
# Out:
# constraint_transport_capacity_UB_no_bin : UB_no_bin for transport capacity
#     Size=882, Index=sources*sinks*transports*{0}, Active=True
#     Key                            : Lower : Body                       : Upper : Active
#     ('loc1', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc1,loc1,truck12,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc1,loc1,truck13,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck21', 0) :   0.0 : Cap_F[loc1,loc1,truck21,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc1,loc1,truck24,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc1,loc1,truck25,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck31', 0) :   0.0 : Cap_F[loc1,loc1,truck31,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc1,loc1,truck34,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc1,loc1,truck42,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc1,loc1,truck43,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc1,loc1,truck45,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc1,loc1,truck46,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc1,loc1,truck47,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc1,loc1,truck52,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc1,loc1,truck54,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc1,loc1,truck57,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc1,loc1,truck64,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc1,loc1,truck74,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc1,loc1,truck75,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck12', 0) :  -Inf : Cap_F[loc1,loc2,truck12,0] :  70.0 :   True
#     ('loc1', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc1,loc2,truck13,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc1,loc2,truck21,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc1,loc2,truck24,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc1,loc2,truck25,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc1,loc2,truck31,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc1,loc2,truck34,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck42', 0) :   0.0 : Cap_F[loc1,loc2,truck42,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc1,loc2,truck43,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc1,loc2,truck45,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc1,loc2,truck46,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc1,loc2,truck47,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck52', 0) :   0.0 : Cap_F[loc1,loc2,truck52,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc1,loc2,truck54,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck57', 0) :   0.0 : Cap_F[loc1,loc2,truck57,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck64', 0) :   0.0 : Cap_F[loc1,loc2,truck64,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck74', 0) :   0.0 : Cap_F[loc1,loc2,truck74,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck75', 0) :   0.0 : Cap_F[loc1,loc2,truck75,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck12', 0) :   0.0 : Cap_F[loc1,loc3,truck12,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck13', 0) :  -Inf : Cap_F[loc1,loc3,truck13,0] :  50.0 :   True
#     ('loc1', 'loc3', 'truck21', 0) :   0.0 : Cap_F[loc1,loc3,truck21,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck24', 0) :   0.0 : Cap_F[loc1,loc3,truck24,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck25', 0) :   0.0 : Cap_F[loc1,loc3,truck25,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck31', 0) :   0.0 : Cap_F[loc1,loc3,truck31,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck34', 0) :   0.0 : Cap_F[loc1,loc3,truck34,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck42', 0) :   0.0 : Cap_F[loc1,loc3,truck42,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck43', 0) :   0.0 : Cap_F[loc1,loc3,truck43,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck45', 0) :   0.0 : Cap_F[loc1,loc3,truck45,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck46', 0) :   0.0 : Cap_F[loc1,loc3,truck46,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck47', 0) :   0.0 : Cap_F[loc1,loc3,truck47,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck52', 0) :   0.0 : Cap_F[loc1,loc3,truck52,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck54', 0) :   0.0 : Cap_F[loc1,loc3,truck54,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck57', 0) :   0.0 : Cap_F[loc1,loc3,truck57,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck64', 0) :   0.0 : Cap_F[loc1,loc3,truck64,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck74', 0) :   0.0 : Cap_F[loc1,loc3,truck74,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck75', 0) :   0.0 : Cap_F[loc1,loc3,truck75,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck12', 0) :   0.0 : Cap_F[loc1,loc4,truck12,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck13', 0) :   0.0 : Cap_F[loc1,loc4,truck13,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck21', 0) :   0.0 : Cap_F[loc1,loc4,truck21,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck24', 0) :   0.0 : Cap_F[loc1,loc4,truck24,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck25', 0) :   0.0 : Cap_F[loc1,loc4,truck25,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck31', 0) :   0.0 : Cap_F[loc1,loc4,truck31,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck34', 0) :   0.0 : Cap_F[loc1,loc4,truck34,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck42', 0) :   0.0 : Cap_F[loc1,loc4,truck42,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck43', 0) :   0.0 : Cap_F[loc1,loc4,truck43,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck45', 0) :   0.0 : Cap_F[loc1,loc4,truck45,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck46', 0) :   0.0 : Cap_F[loc1,loc4,truck46,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck47', 0) :   0.0 : Cap_F[loc1,loc4,truck47,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck52', 0) :   0.0 : Cap_F[loc1,loc4,truck52,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck54', 0) :   0.0 : Cap_F[loc1,loc4,truck54,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck57', 0) :   0.0 : Cap_F[loc1,loc4,truck57,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck64', 0) :   0.0 : Cap_F[loc1,loc4,truck64,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck74', 0) :   0.0 : Cap_F[loc1,loc4,truck74,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck75', 0) :   0.0 : Cap_F[loc1,loc4,truck75,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck12', 0) :   0.0 : Cap_F[loc1,loc5,truck12,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc1,loc5,truck13,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc1,loc5,truck21,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc1,loc5,truck24,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck25', 0) :   0.0 : Cap_F[loc1,loc5,truck25,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc1,loc5,truck31,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc1,loc5,truck34,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc1,loc5,truck42,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc1,loc5,truck43,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck45', 0) :   0.0 : Cap_F[loc1,loc5,truck45,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc1,loc5,truck46,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc1,loc5,truck47,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc1,loc5,truck52,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc1,loc5,truck54,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc1,loc5,truck57,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc1,loc5,truck64,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc1,loc5,truck74,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck75', 0) :   0.0 : Cap_F[loc1,loc5,truck75,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc1,loc6,truck12,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc1,loc6,truck13,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc1,loc6,truck21,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc1,loc6,truck24,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc1,loc6,truck25,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc1,loc6,truck31,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc1,loc6,truck34,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc1,loc6,truck42,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc1,loc6,truck43,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc1,loc6,truck45,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck46', 0) :   0.0 : Cap_F[loc1,loc6,truck46,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc1,loc6,truck47,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc1,loc6,truck52,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc1,loc6,truck54,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc1,loc6,truck57,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc1,loc6,truck64,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc1,loc6,truck74,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc1,loc6,truck75,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc1,loc7,truck12,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc1,loc7,truck13,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc1,loc7,truck21,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc1,loc7,truck24,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc1,loc7,truck25,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc1,loc7,truck31,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc1,loc7,truck34,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc1,loc7,truck42,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc1,loc7,truck43,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc1,loc7,truck45,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc1,loc7,truck46,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck47', 0) :   0.0 : Cap_F[loc1,loc7,truck47,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc1,loc7,truck52,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc1,loc7,truck54,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc1,loc7,truck57,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc1,loc7,truck64,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc1,loc7,truck74,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc1,loc7,truck75,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc2,loc1,truck12,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc2,loc1,truck13,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck21', 0) :  -Inf : Cap_F[loc2,loc1,truck21,0] :  70.0 :   True
#     ('loc2', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc2,loc1,truck24,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc2,loc1,truck25,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck31', 0) :   0.0 : Cap_F[loc2,loc1,truck31,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc2,loc1,truck34,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc2,loc1,truck42,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc2,loc1,truck43,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc2,loc1,truck45,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc2,loc1,truck46,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc2,loc1,truck47,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc2,loc1,truck52,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc2,loc1,truck54,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc2,loc1,truck57,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc2,loc1,truck64,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc2,loc1,truck74,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc2,loc1,truck75,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck12', 0) :   0.0 : Cap_F[loc2,loc2,truck12,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc2,loc2,truck13,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc2,loc2,truck21,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc2,loc2,truck24,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc2,loc2,truck25,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc2,loc2,truck31,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc2,loc2,truck34,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck42', 0) :   0.0 : Cap_F[loc2,loc2,truck42,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc2,loc2,truck43,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc2,loc2,truck45,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc2,loc2,truck46,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc2,loc2,truck47,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck52', 0) :   0.0 : Cap_F[loc2,loc2,truck52,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc2,loc2,truck54,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck57', 0) :   0.0 : Cap_F[loc2,loc2,truck57,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck64', 0) :   0.0 : Cap_F[loc2,loc2,truck64,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck74', 0) :   0.0 : Cap_F[loc2,loc2,truck74,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck75', 0) :   0.0 : Cap_F[loc2,loc2,truck75,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck12', 0) :   0.0 : Cap_F[loc2,loc3,truck12,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck13', 0) :   0.0 : Cap_F[loc2,loc3,truck13,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck21', 0) :   0.0 : Cap_F[loc2,loc3,truck21,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck24', 0) :   0.0 : Cap_F[loc2,loc3,truck24,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck25', 0) :   0.0 : Cap_F[loc2,loc3,truck25,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck31', 0) :   0.0 : Cap_F[loc2,loc3,truck31,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck34', 0) :   0.0 : Cap_F[loc2,loc3,truck34,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck42', 0) :   0.0 : Cap_F[loc2,loc3,truck42,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck43', 0) :   0.0 : Cap_F[loc2,loc3,truck43,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck45', 0) :   0.0 : Cap_F[loc2,loc3,truck45,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck46', 0) :   0.0 : Cap_F[loc2,loc3,truck46,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck47', 0) :   0.0 : Cap_F[loc2,loc3,truck47,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck52', 0) :   0.0 : Cap_F[loc2,loc3,truck52,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck54', 0) :   0.0 : Cap_F[loc2,loc3,truck54,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck57', 0) :   0.0 : Cap_F[loc2,loc3,truck57,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck64', 0) :   0.0 : Cap_F[loc2,loc3,truck64,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck74', 0) :   0.0 : Cap_F[loc2,loc3,truck74,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck75', 0) :   0.0 : Cap_F[loc2,loc3,truck75,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck12', 0) :   0.0 : Cap_F[loc2,loc4,truck12,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck13', 0) :   0.0 : Cap_F[loc2,loc4,truck13,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck21', 0) :   0.0 : Cap_F[loc2,loc4,truck21,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck24', 0) :  -Inf : Cap_F[loc2,loc4,truck24,0] :  50.0 :   True
#     ('loc2', 'loc4', 'truck25', 0) :   0.0 : Cap_F[loc2,loc4,truck25,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck31', 0) :   0.0 : Cap_F[loc2,loc4,truck31,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck34', 0) :   0.0 : Cap_F[loc2,loc4,truck34,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck42', 0) :   0.0 : Cap_F[loc2,loc4,truck42,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck43', 0) :   0.0 : Cap_F[loc2,loc4,truck43,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck45', 0) :   0.0 : Cap_F[loc2,loc4,truck45,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck46', 0) :   0.0 : Cap_F[loc2,loc4,truck46,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck47', 0) :   0.0 : Cap_F[loc2,loc4,truck47,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck52', 0) :   0.0 : Cap_F[loc2,loc4,truck52,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck54', 0) :   0.0 : Cap_F[loc2,loc4,truck54,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck57', 0) :   0.0 : Cap_F[loc2,loc4,truck57,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck64', 0) :   0.0 : Cap_F[loc2,loc4,truck64,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck74', 0) :   0.0 : Cap_F[loc2,loc4,truck74,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck75', 0) :   0.0 : Cap_F[loc2,loc4,truck75,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck12', 0) :   0.0 : Cap_F[loc2,loc5,truck12,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc2,loc5,truck13,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc2,loc5,truck21,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc2,loc5,truck24,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck25', 0) :  -Inf : Cap_F[loc2,loc5,truck25,0] :  30.0 :   True
#     ('loc2', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc2,loc5,truck31,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc2,loc5,truck34,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc2,loc5,truck42,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc2,loc5,truck43,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck45', 0) :   0.0 : Cap_F[loc2,loc5,truck45,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc2,loc5,truck46,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc2,loc5,truck47,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc2,loc5,truck52,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc2,loc5,truck54,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc2,loc5,truck57,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc2,loc5,truck64,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc2,loc5,truck74,0] :   0.0 :   True
#     ('loc2', 'loc5', 'truck75', 0) :   0.0 : Cap_F[loc2,loc5,truck75,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc2,loc6,truck12,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc2,loc6,truck13,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc2,loc6,truck21,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc2,loc6,truck24,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc2,loc6,truck25,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc2,loc6,truck31,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc2,loc6,truck34,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc2,loc6,truck42,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc2,loc6,truck43,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc2,loc6,truck45,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck46', 0) :   0.0 : Cap_F[loc2,loc6,truck46,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc2,loc6,truck47,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc2,loc6,truck52,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc2,loc6,truck54,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc2,loc6,truck57,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc2,loc6,truck64,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc2,loc6,truck74,0] :   0.0 :   True
#     ('loc2', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc2,loc6,truck75,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc2,loc7,truck12,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc2,loc7,truck13,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc2,loc7,truck21,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc2,loc7,truck24,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc2,loc7,truck25,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc2,loc7,truck31,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc2,loc7,truck34,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc2,loc7,truck42,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc2,loc7,truck43,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc2,loc7,truck45,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc2,loc7,truck46,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck47', 0) :   0.0 : Cap_F[loc2,loc7,truck47,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc2,loc7,truck52,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc2,loc7,truck54,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc2,loc7,truck57,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc2,loc7,truck64,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc2,loc7,truck74,0] :   0.0 :   True
#     ('loc2', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc2,loc7,truck75,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc3,loc1,truck12,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc3,loc1,truck13,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck21', 0) :   0.0 : Cap_F[loc3,loc1,truck21,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc3,loc1,truck24,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc3,loc1,truck25,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck31', 0) :  -Inf : Cap_F[loc3,loc1,truck31,0] :  50.0 :   True
#     ('loc3', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc3,loc1,truck34,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc3,loc1,truck42,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc3,loc1,truck43,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc3,loc1,truck45,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc3,loc1,truck46,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc3,loc1,truck47,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc3,loc1,truck52,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc3,loc1,truck54,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc3,loc1,truck57,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc3,loc1,truck64,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc3,loc1,truck74,0] :   0.0 :   True
#     ('loc3', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc3,loc1,truck75,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck12', 0) :   0.0 : Cap_F[loc3,loc2,truck12,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc3,loc2,truck13,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc3,loc2,truck21,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc3,loc2,truck24,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc3,loc2,truck25,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc3,loc2,truck31,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc3,loc2,truck34,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck42', 0) :   0.0 : Cap_F[loc3,loc2,truck42,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc3,loc2,truck43,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc3,loc2,truck45,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc3,loc2,truck46,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc3,loc2,truck47,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck52', 0) :   0.0 : Cap_F[loc3,loc2,truck52,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc3,loc2,truck54,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck57', 0) :   0.0 : Cap_F[loc3,loc2,truck57,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck64', 0) :   0.0 : Cap_F[loc3,loc2,truck64,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck74', 0) :   0.0 : Cap_F[loc3,loc2,truck74,0] :   0.0 :   True
#     ('loc3', 'loc2', 'truck75', 0) :   0.0 : Cap_F[loc3,loc2,truck75,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck12', 0) :   0.0 : Cap_F[loc3,loc3,truck12,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck13', 0) :   0.0 : Cap_F[loc3,loc3,truck13,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck21', 0) :   0.0 : Cap_F[loc3,loc3,truck21,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck24', 0) :   0.0 : Cap_F[loc3,loc3,truck24,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck25', 0) :   0.0 : Cap_F[loc3,loc3,truck25,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck31', 0) :   0.0 : Cap_F[loc3,loc3,truck31,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck34', 0) :   0.0 : Cap_F[loc3,loc3,truck34,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck42', 0) :   0.0 : Cap_F[loc3,loc3,truck42,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck43', 0) :   0.0 : Cap_F[loc3,loc3,truck43,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck45', 0) :   0.0 : Cap_F[loc3,loc3,truck45,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck46', 0) :   0.0 : Cap_F[loc3,loc3,truck46,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck47', 0) :   0.0 : Cap_F[loc3,loc3,truck47,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck52', 0) :   0.0 : Cap_F[loc3,loc3,truck52,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck54', 0) :   0.0 : Cap_F[loc3,loc3,truck54,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck57', 0) :   0.0 : Cap_F[loc3,loc3,truck57,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck64', 0) :   0.0 : Cap_F[loc3,loc3,truck64,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck74', 0) :   0.0 : Cap_F[loc3,loc3,truck74,0] :   0.0 :   True
#     ('loc3', 'loc3', 'truck75', 0) :   0.0 : Cap_F[loc3,loc3,truck75,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck12', 0) :   0.0 : Cap_F[loc3,loc4,truck12,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck13', 0) :   0.0 : Cap_F[loc3,loc4,truck13,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck21', 0) :   0.0 : Cap_F[loc3,loc4,truck21,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck24', 0) :   0.0 : Cap_F[loc3,loc4,truck24,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck25', 0) :   0.0 : Cap_F[loc3,loc4,truck25,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck31', 0) :   0.0 : Cap_F[loc3,loc4,truck31,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck34', 0) :  -Inf : Cap_F[loc3,loc4,truck34,0] :  20.0 :   True
#     ('loc3', 'loc4', 'truck42', 0) :   0.0 : Cap_F[loc3,loc4,truck42,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck43', 0) :   0.0 : Cap_F[loc3,loc4,truck43,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck45', 0) :   0.0 : Cap_F[loc3,loc4,truck45,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck46', 0) :   0.0 : Cap_F[loc3,loc4,truck46,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck47', 0) :   0.0 : Cap_F[loc3,loc4,truck47,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck52', 0) :   0.0 : Cap_F[loc3,loc4,truck52,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck54', 0) :   0.0 : Cap_F[loc3,loc4,truck54,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck57', 0) :   0.0 : Cap_F[loc3,loc4,truck57,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck64', 0) :   0.0 : Cap_F[loc3,loc4,truck64,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck74', 0) :   0.0 : Cap_F[loc3,loc4,truck74,0] :   0.0 :   True
#     ('loc3', 'loc4', 'truck75', 0) :   0.0 : Cap_F[loc3,loc4,truck75,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck12', 0) :   0.0 : Cap_F[loc3,loc5,truck12,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc3,loc5,truck13,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc3,loc5,truck21,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc3,loc5,truck24,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck25', 0) :   0.0 : Cap_F[loc3,loc5,truck25,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc3,loc5,truck31,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc3,loc5,truck34,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc3,loc5,truck42,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc3,loc5,truck43,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck45', 0) :   0.0 : Cap_F[loc3,loc5,truck45,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc3,loc5,truck46,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc3,loc5,truck47,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc3,loc5,truck52,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc3,loc5,truck54,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc3,loc5,truck57,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc3,loc5,truck64,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc3,loc5,truck74,0] :   0.0 :   True
#     ('loc3', 'loc5', 'truck75', 0) :   0.0 : Cap_F[loc3,loc5,truck75,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc3,loc6,truck12,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc3,loc6,truck13,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc3,loc6,truck21,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc3,loc6,truck24,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc3,loc6,truck25,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc3,loc6,truck31,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc3,loc6,truck34,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc3,loc6,truck42,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc3,loc6,truck43,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc3,loc6,truck45,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck46', 0) :   0.0 : Cap_F[loc3,loc6,truck46,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc3,loc6,truck47,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc3,loc6,truck52,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc3,loc6,truck54,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc3,loc6,truck57,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc3,loc6,truck64,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc3,loc6,truck74,0] :   0.0 :   True
#     ('loc3', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc3,loc6,truck75,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc3,loc7,truck12,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc3,loc7,truck13,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc3,loc7,truck21,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc3,loc7,truck24,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc3,loc7,truck25,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc3,loc7,truck31,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc3,loc7,truck34,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc3,loc7,truck42,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc3,loc7,truck43,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc3,loc7,truck45,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc3,loc7,truck46,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck47', 0) :   0.0 : Cap_F[loc3,loc7,truck47,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc3,loc7,truck52,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc3,loc7,truck54,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc3,loc7,truck57,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc3,loc7,truck64,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc3,loc7,truck74,0] :   0.0 :   True
#     ('loc3', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc3,loc7,truck75,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc4,loc1,truck12,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc4,loc1,truck13,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck21', 0) :   0.0 : Cap_F[loc4,loc1,truck21,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc4,loc1,truck24,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc4,loc1,truck25,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck31', 0) :   0.0 : Cap_F[loc4,loc1,truck31,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc4,loc1,truck34,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc4,loc1,truck42,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc4,loc1,truck43,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc4,loc1,truck45,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc4,loc1,truck46,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc4,loc1,truck47,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc4,loc1,truck52,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc4,loc1,truck54,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc4,loc1,truck57,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc4,loc1,truck64,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc4,loc1,truck74,0] :   0.0 :   True
#     ('loc4', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc4,loc1,truck75,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck12', 0) :   0.0 : Cap_F[loc4,loc2,truck12,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc4,loc2,truck13,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc4,loc2,truck21,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc4,loc2,truck24,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc4,loc2,truck25,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc4,loc2,truck31,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc4,loc2,truck34,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck42', 0) :  -Inf : Cap_F[loc4,loc2,truck42,0] :  50.0 :   True
#     ('loc4', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc4,loc2,truck43,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc4,loc2,truck45,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc4,loc2,truck46,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc4,loc2,truck47,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck52', 0) :   0.0 : Cap_F[loc4,loc2,truck52,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc4,loc2,truck54,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck57', 0) :   0.0 : Cap_F[loc4,loc2,truck57,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck64', 0) :   0.0 : Cap_F[loc4,loc2,truck64,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck74', 0) :   0.0 : Cap_F[loc4,loc2,truck74,0] :   0.0 :   True
#     ('loc4', 'loc2', 'truck75', 0) :   0.0 : Cap_F[loc4,loc2,truck75,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck12', 0) :   0.0 : Cap_F[loc4,loc3,truck12,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck13', 0) :   0.0 : Cap_F[loc4,loc3,truck13,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck21', 0) :   0.0 : Cap_F[loc4,loc3,truck21,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck24', 0) :   0.0 : Cap_F[loc4,loc3,truck24,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck25', 0) :   0.0 : Cap_F[loc4,loc3,truck25,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck31', 0) :   0.0 : Cap_F[loc4,loc3,truck31,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck34', 0) :   0.0 : Cap_F[loc4,loc3,truck34,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck42', 0) :   0.0 : Cap_F[loc4,loc3,truck42,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck43', 0) :  -Inf : Cap_F[loc4,loc3,truck43,0] :  20.0 :   True
#     ('loc4', 'loc3', 'truck45', 0) :   0.0 : Cap_F[loc4,loc3,truck45,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck46', 0) :   0.0 : Cap_F[loc4,loc3,truck46,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck47', 0) :   0.0 : Cap_F[loc4,loc3,truck47,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck52', 0) :   0.0 : Cap_F[loc4,loc3,truck52,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck54', 0) :   0.0 : Cap_F[loc4,loc3,truck54,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck57', 0) :   0.0 : Cap_F[loc4,loc3,truck57,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck64', 0) :   0.0 : Cap_F[loc4,loc3,truck64,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck74', 0) :   0.0 : Cap_F[loc4,loc3,truck74,0] :   0.0 :   True
#     ('loc4', 'loc3', 'truck75', 0) :   0.0 : Cap_F[loc4,loc3,truck75,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck12', 0) :   0.0 : Cap_F[loc4,loc4,truck12,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck13', 0) :   0.0 : Cap_F[loc4,loc4,truck13,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck21', 0) :   0.0 : Cap_F[loc4,loc4,truck21,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck24', 0) :   0.0 : Cap_F[loc4,loc4,truck24,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck25', 0) :   0.0 : Cap_F[loc4,loc4,truck25,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck31', 0) :   0.0 : Cap_F[loc4,loc4,truck31,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck34', 0) :   0.0 : Cap_F[loc4,loc4,truck34,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck42', 0) :   0.0 : Cap_F[loc4,loc4,truck42,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck43', 0) :   0.0 : Cap_F[loc4,loc4,truck43,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck45', 0) :   0.0 : Cap_F[loc4,loc4,truck45,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck46', 0) :   0.0 : Cap_F[loc4,loc4,truck46,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck47', 0) :   0.0 : Cap_F[loc4,loc4,truck47,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck52', 0) :   0.0 : Cap_F[loc4,loc4,truck52,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck54', 0) :   0.0 : Cap_F[loc4,loc4,truck54,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck57', 0) :   0.0 : Cap_F[loc4,loc4,truck57,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck64', 0) :   0.0 : Cap_F[loc4,loc4,truck64,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck74', 0) :   0.0 : Cap_F[loc4,loc4,truck74,0] :   0.0 :   True
#     ('loc4', 'loc4', 'truck75', 0) :   0.0 : Cap_F[loc4,loc4,truck75,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck12', 0) :   0.0 : Cap_F[loc4,loc5,truck12,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc4,loc5,truck13,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc4,loc5,truck21,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc4,loc5,truck24,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck25', 0) :   0.0 : Cap_F[loc4,loc5,truck25,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc4,loc5,truck31,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc4,loc5,truck34,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc4,loc5,truck42,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc4,loc5,truck43,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck45', 0) :  -Inf : Cap_F[loc4,loc5,truck45,0] : 100.0 :   True
#     ('loc4', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc4,loc5,truck46,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc4,loc5,truck47,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc4,loc5,truck52,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc4,loc5,truck54,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc4,loc5,truck57,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc4,loc5,truck64,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc4,loc5,truck74,0] :   0.0 :   True
#     ('loc4', 'loc5', 'truck75', 0) :   0.0 : Cap_F[loc4,loc5,truck75,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc4,loc6,truck12,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc4,loc6,truck13,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc4,loc6,truck21,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc4,loc6,truck24,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc4,loc6,truck25,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc4,loc6,truck31,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc4,loc6,truck34,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc4,loc6,truck42,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc4,loc6,truck43,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc4,loc6,truck45,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck46', 0) :  -Inf : Cap_F[loc4,loc6,truck46,0] :  50.0 :   True
#     ('loc4', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc4,loc6,truck47,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc4,loc6,truck52,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc4,loc6,truck54,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc4,loc6,truck57,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc4,loc6,truck64,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc4,loc6,truck74,0] :   0.0 :   True
#     ('loc4', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc4,loc6,truck75,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc4,loc7,truck12,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc4,loc7,truck13,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc4,loc7,truck21,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc4,loc7,truck24,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc4,loc7,truck25,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc4,loc7,truck31,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc4,loc7,truck34,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc4,loc7,truck42,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc4,loc7,truck43,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc4,loc7,truck45,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc4,loc7,truck46,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck47', 0) :  -Inf : Cap_F[loc4,loc7,truck47,0] :  40.0 :   True
#     ('loc4', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc4,loc7,truck52,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc4,loc7,truck54,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc4,loc7,truck57,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc4,loc7,truck64,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc4,loc7,truck74,0] :   0.0 :   True
#     ('loc4', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc4,loc7,truck75,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc5,loc1,truck12,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc5,loc1,truck13,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck21', 0) :   0.0 : Cap_F[loc5,loc1,truck21,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc5,loc1,truck24,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc5,loc1,truck25,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck31', 0) :   0.0 : Cap_F[loc5,loc1,truck31,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc5,loc1,truck34,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc5,loc1,truck42,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc5,loc1,truck43,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc5,loc1,truck45,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc5,loc1,truck46,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc5,loc1,truck47,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc5,loc1,truck52,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc5,loc1,truck54,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc5,loc1,truck57,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc5,loc1,truck64,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc5,loc1,truck74,0] :   0.0 :   True
#     ('loc5', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc5,loc1,truck75,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck12', 0) :   0.0 : Cap_F[loc5,loc2,truck12,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc5,loc2,truck13,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc5,loc2,truck21,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc5,loc2,truck24,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc5,loc2,truck25,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc5,loc2,truck31,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc5,loc2,truck34,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck42', 0) :   0.0 : Cap_F[loc5,loc2,truck42,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc5,loc2,truck43,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc5,loc2,truck45,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc5,loc2,truck46,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc5,loc2,truck47,0] :   0.0 :   True
#     ('loc5', 'loc2', 'truck52', 0) :  -Inf : Cap_F[loc5,loc2,truck52,0] :  30.0 :   True
#     ('loc5', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc5,loc2,truck54,0] :   0.0 :   True
# ...
#     ('loc6', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc6,loc5,truck13,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc6,loc5,truck21,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc6,loc5,truck24,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck25', 0) :   0.0 : Cap_F[loc6,loc5,truck25,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc6,loc5,truck31,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc6,loc5,truck34,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc6,loc5,truck42,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc6,loc5,truck43,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck45', 0) :   0.0 : Cap_F[loc6,loc5,truck45,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc6,loc5,truck46,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc6,loc5,truck47,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc6,loc5,truck52,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc6,loc5,truck54,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc6,loc5,truck57,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc6,loc5,truck64,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc6,loc5,truck74,0] :   0.0 :   True
#     ('loc6', 'loc5', 'truck75', 0) :   0.0 : Cap_F[loc6,loc5,truck75,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc6,loc6,truck12,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc6,loc6,truck13,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc6,loc6,truck21,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc6,loc6,truck24,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc6,loc6,truck25,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc6,loc6,truck31,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc6,loc6,truck34,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc6,loc6,truck42,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc6,loc6,truck43,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc6,loc6,truck45,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck46', 0) :   0.0 : Cap_F[loc6,loc6,truck46,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc6,loc6,truck47,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc6,loc6,truck52,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc6,loc6,truck54,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc6,loc6,truck57,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc6,loc6,truck64,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc6,loc6,truck74,0] :   0.0 :   True
#     ('loc6', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc6,loc6,truck75,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc6,loc7,truck12,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc6,loc7,truck13,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc6,loc7,truck21,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc6,loc7,truck24,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc6,loc7,truck25,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc6,loc7,truck31,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc6,loc7,truck34,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc6,loc7,truck42,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc6,loc7,truck43,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc6,loc7,truck45,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc6,loc7,truck46,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck47', 0) :   0.0 : Cap_F[loc6,loc7,truck47,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc6,loc7,truck52,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc6,loc7,truck54,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc6,loc7,truck57,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc6,loc7,truck64,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc6,loc7,truck74,0] :   0.0 :   True
#     ('loc6', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc6,loc7,truck75,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck12', 0) :   0.0 : Cap_F[loc7,loc1,truck12,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck13', 0) :   0.0 : Cap_F[loc7,loc1,truck13,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck21', 0) :   0.0 : Cap_F[loc7,loc1,truck21,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck24', 0) :   0.0 : Cap_F[loc7,loc1,truck24,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck25', 0) :   0.0 : Cap_F[loc7,loc1,truck25,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck31', 0) :   0.0 : Cap_F[loc7,loc1,truck31,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck34', 0) :   0.0 : Cap_F[loc7,loc1,truck34,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck42', 0) :   0.0 : Cap_F[loc7,loc1,truck42,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck43', 0) :   0.0 : Cap_F[loc7,loc1,truck43,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck45', 0) :   0.0 : Cap_F[loc7,loc1,truck45,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck46', 0) :   0.0 : Cap_F[loc7,loc1,truck46,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck47', 0) :   0.0 : Cap_F[loc7,loc1,truck47,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck52', 0) :   0.0 : Cap_F[loc7,loc1,truck52,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck54', 0) :   0.0 : Cap_F[loc7,loc1,truck54,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck57', 0) :   0.0 : Cap_F[loc7,loc1,truck57,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck64', 0) :   0.0 : Cap_F[loc7,loc1,truck64,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck74', 0) :   0.0 : Cap_F[loc7,loc1,truck74,0] :   0.0 :   True
#     ('loc7', 'loc1', 'truck75', 0) :   0.0 : Cap_F[loc7,loc1,truck75,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck12', 0) :   0.0 : Cap_F[loc7,loc2,truck12,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck13', 0) :   0.0 : Cap_F[loc7,loc2,truck13,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck21', 0) :   0.0 : Cap_F[loc7,loc2,truck21,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck24', 0) :   0.0 : Cap_F[loc7,loc2,truck24,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck25', 0) :   0.0 : Cap_F[loc7,loc2,truck25,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck31', 0) :   0.0 : Cap_F[loc7,loc2,truck31,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck34', 0) :   0.0 : Cap_F[loc7,loc2,truck34,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck42', 0) :   0.0 : Cap_F[loc7,loc2,truck42,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck43', 0) :   0.0 : Cap_F[loc7,loc2,truck43,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck45', 0) :   0.0 : Cap_F[loc7,loc2,truck45,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck46', 0) :   0.0 : Cap_F[loc7,loc2,truck46,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck47', 0) :   0.0 : Cap_F[loc7,loc2,truck47,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck52', 0) :   0.0 : Cap_F[loc7,loc2,truck52,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck54', 0) :   0.0 : Cap_F[loc7,loc2,truck54,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck57', 0) :   0.0 : Cap_F[loc7,loc2,truck57,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck64', 0) :   0.0 : Cap_F[loc7,loc2,truck64,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck74', 0) :   0.0 : Cap_F[loc7,loc2,truck74,0] :   0.0 :   True
#     ('loc7', 'loc2', 'truck75', 0) :   0.0 : Cap_F[loc7,loc2,truck75,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck12', 0) :   0.0 : Cap_F[loc7,loc3,truck12,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck13', 0) :   0.0 : Cap_F[loc7,loc3,truck13,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck21', 0) :   0.0 : Cap_F[loc7,loc3,truck21,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck24', 0) :   0.0 : Cap_F[loc7,loc3,truck24,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck25', 0) :   0.0 : Cap_F[loc7,loc3,truck25,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck31', 0) :   0.0 : Cap_F[loc7,loc3,truck31,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck34', 0) :   0.0 : Cap_F[loc7,loc3,truck34,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck42', 0) :   0.0 : Cap_F[loc7,loc3,truck42,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck43', 0) :   0.0 : Cap_F[loc7,loc3,truck43,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck45', 0) :   0.0 : Cap_F[loc7,loc3,truck45,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck46', 0) :   0.0 : Cap_F[loc7,loc3,truck46,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck47', 0) :   0.0 : Cap_F[loc7,loc3,truck47,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck52', 0) :   0.0 : Cap_F[loc7,loc3,truck52,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck54', 0) :   0.0 : Cap_F[loc7,loc3,truck54,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck57', 0) :   0.0 : Cap_F[loc7,loc3,truck57,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck64', 0) :   0.0 : Cap_F[loc7,loc3,truck64,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck74', 0) :   0.0 : Cap_F[loc7,loc3,truck74,0] :   0.0 :   True
#     ('loc7', 'loc3', 'truck75', 0) :   0.0 : Cap_F[loc7,loc3,truck75,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck12', 0) :   0.0 : Cap_F[loc7,loc4,truck12,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck13', 0) :   0.0 : Cap_F[loc7,loc4,truck13,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck21', 0) :   0.0 : Cap_F[loc7,loc4,truck21,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck24', 0) :   0.0 : Cap_F[loc7,loc4,truck24,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck25', 0) :   0.0 : Cap_F[loc7,loc4,truck25,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck31', 0) :   0.0 : Cap_F[loc7,loc4,truck31,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck34', 0) :   0.0 : Cap_F[loc7,loc4,truck34,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck42', 0) :   0.0 : Cap_F[loc7,loc4,truck42,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck43', 0) :   0.0 : Cap_F[loc7,loc4,truck43,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck45', 0) :   0.0 : Cap_F[loc7,loc4,truck45,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck46', 0) :   0.0 : Cap_F[loc7,loc4,truck46,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck47', 0) :   0.0 : Cap_F[loc7,loc4,truck47,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck52', 0) :   0.0 : Cap_F[loc7,loc4,truck52,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck54', 0) :   0.0 : Cap_F[loc7,loc4,truck54,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck57', 0) :   0.0 : Cap_F[loc7,loc4,truck57,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck64', 0) :   0.0 : Cap_F[loc7,loc4,truck64,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck74', 0) :  -Inf : Cap_F[loc7,loc4,truck74,0] :  40.0 :   True
#     ('loc7', 'loc4', 'truck75', 0) :   0.0 : Cap_F[loc7,loc4,truck75,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck12', 0) :   0.0 : Cap_F[loc7,loc5,truck12,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck13', 0) :   0.0 : Cap_F[loc7,loc5,truck13,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck21', 0) :   0.0 : Cap_F[loc7,loc5,truck21,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck24', 0) :   0.0 : Cap_F[loc7,loc5,truck24,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck25', 0) :   0.0 : Cap_F[loc7,loc5,truck25,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck31', 0) :   0.0 : Cap_F[loc7,loc5,truck31,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck34', 0) :   0.0 : Cap_F[loc7,loc5,truck34,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck42', 0) :   0.0 : Cap_F[loc7,loc5,truck42,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck43', 0) :   0.0 : Cap_F[loc7,loc5,truck43,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck45', 0) :   0.0 : Cap_F[loc7,loc5,truck45,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck46', 0) :   0.0 : Cap_F[loc7,loc5,truck46,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck47', 0) :   0.0 : Cap_F[loc7,loc5,truck47,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck52', 0) :   0.0 : Cap_F[loc7,loc5,truck52,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck54', 0) :   0.0 : Cap_F[loc7,loc5,truck54,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck57', 0) :   0.0 : Cap_F[loc7,loc5,truck57,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck64', 0) :   0.0 : Cap_F[loc7,loc5,truck64,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck74', 0) :   0.0 : Cap_F[loc7,loc5,truck74,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck75', 0) :  -Inf : Cap_F[loc7,loc5,truck75,0] :  40.0 :   True
#     ('loc7', 'loc6', 'truck12', 0) :   0.0 : Cap_F[loc7,loc6,truck12,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck13', 0) :   0.0 : Cap_F[loc7,loc6,truck13,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck21', 0) :   0.0 : Cap_F[loc7,loc6,truck21,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck24', 0) :   0.0 : Cap_F[loc7,loc6,truck24,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck25', 0) :   0.0 : Cap_F[loc7,loc6,truck25,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck31', 0) :   0.0 : Cap_F[loc7,loc6,truck31,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck34', 0) :   0.0 : Cap_F[loc7,loc6,truck34,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck42', 0) :   0.0 : Cap_F[loc7,loc6,truck42,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck43', 0) :   0.0 : Cap_F[loc7,loc6,truck43,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck45', 0) :   0.0 : Cap_F[loc7,loc6,truck45,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck46', 0) :   0.0 : Cap_F[loc7,loc6,truck46,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck47', 0) :   0.0 : Cap_F[loc7,loc6,truck47,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck52', 0) :   0.0 : Cap_F[loc7,loc6,truck52,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck54', 0) :   0.0 : Cap_F[loc7,loc6,truck54,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck57', 0) :   0.0 : Cap_F[loc7,loc6,truck57,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck64', 0) :   0.0 : Cap_F[loc7,loc6,truck64,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck74', 0) :   0.0 : Cap_F[loc7,loc6,truck74,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck75', 0) :   0.0 : Cap_F[loc7,loc6,truck75,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck12', 0) :   0.0 : Cap_F[loc7,loc7,truck12,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck13', 0) :   0.0 : Cap_F[loc7,loc7,truck13,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck21', 0) :   0.0 : Cap_F[loc7,loc7,truck21,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck24', 0) :   0.0 : Cap_F[loc7,loc7,truck24,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck25', 0) :   0.0 : Cap_F[loc7,loc7,truck25,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck31', 0) :   0.0 : Cap_F[loc7,loc7,truck31,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck34', 0) :   0.0 : Cap_F[loc7,loc7,truck34,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck42', 0) :   0.0 : Cap_F[loc7,loc7,truck42,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck43', 0) :   0.0 : Cap_F[loc7,loc7,truck43,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck45', 0) :   0.0 : Cap_F[loc7,loc7,truck45,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck46', 0) :   0.0 : Cap_F[loc7,loc7,truck46,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck47', 0) :   0.0 : Cap_F[loc7,loc7,truck47,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck52', 0) :   0.0 : Cap_F[loc7,loc7,truck52,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck54', 0) :   0.0 : Cap_F[loc7,loc7,truck54,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck57', 0) :   0.0 : Cap_F[loc7,loc7,truck57,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck64', 0) :   0.0 : Cap_F[loc7,loc7,truck64,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck74', 0) :   0.0 : Cap_F[loc7,loc7,truck74,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck75', 0) :   0.0 : Cap_F[loc7,loc7,truck75,0] :   0.0 :   True

# %%
problem_mincost.X_F.pprint()
# Out:
# X_F : binaries for transports being set up
#     Size=882, Index=sources*sinks*transports*scales_network
#     Key                            : Lower : Value : Upper : Fixed : Stale : Domain
#     ('loc1', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc1', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc2', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc3', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc4', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc5', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
# ...
#     ('loc6', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc6', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc1', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc2', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc3', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc4', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc5', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc6', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck12', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck13', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck21', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck24', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck25', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck31', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck34', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck42', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck43', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck45', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck46', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck47', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck52', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck54', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck57', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck64', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck74', 0) :     0 :  None :     1 : False :  True : Binary
#     ('loc7', 'loc7', 'truck75', 0) :     0 :  None :     1 : False :  True : Binary

# %%
import sys
sys.path.append('../../../../../../src')
import pandas
import random
import math
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
_time_intervals = 7  # Number of time intervals in a planning horizon    (L_chi)
_coms = 1
_exec_scenarios = 28  # Number of execution scenarios                     (chi)
M = 1e3  # Big M

loc6_varying_factor = pandas.DataFrame(data={'com1_process': [1]*4 + [0]*24})

# Define temporal scales
scales = TemporalScale(discretization_list=[1, _exec_scenarios, _time_intervals])

# %%
# ======================================================================================================================
# Declare resources/commodities
# ======================================================================================================================
com1_pur = Resource(name='com1_pur', cons_max=75, block={'imp': 1, 'urg': 1}, price=0.00, label='Commodity 1 consumed from outside the system')

com1_in = Resource(name='com1_in', label='Commodity 1 received')
com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True, label='Commodity 1 sold to outside the system')

# %%
# prod_max = {0:60, 1: 120, 2: 150}
# prod_min = {0:0, 1: 60, 2: 120}
# rate_max = {0:4, 1:2, 2:1}

prod_max = {0:30, 1: 60, 2: 90, 3: 120, 4: 150}
prod_min = {0:0, 1: 30, 2: 60, 3: 90, 4: 120}
rate_max = {0:1.25/2, 1: 1/2, 2: 0.75/2, 3: 0.5/2, 4: 0.25/2}
mode_ramp = {(0,1): 5, (1,2): 5}

# %%
# ======================================================================================================================
# Declare processes/storage capacities
# ======================================================================================================================
com1_process_capacity = 125

com1_procure = Process(name='procure com1', prod_max=125, conversion={com1_pur: -1, com1_in: 1}, capex=0.01, vopex=0.01, prod_min=125, label='Procure com1')
com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Sell com1')

com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity, conversion={com1_loc1_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 1')
com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity, conversion={com1_loc2_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 2')
com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity, conversion={com1_loc3_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 3')
com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity, conversion={com1_loc4_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 4')
com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity, conversion={com1_loc5_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 5')
com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity, conversion={com1_loc6_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 6')
com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity, conversion={com1_loc7_out:-1, com1_in:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Commodity 1 received from location 7')

com1_process = Process(name='com1_process', prod_max=prod_max, conversion={0:{com1_in: -1, com1_out: 1}, 1:{com1_in: -1, com1_out: 1}, 2:{com1_in: -1, com1_out: 1}, 3:{com1_in: -1, com1_out: 1}, 4:{com1_in: -1, com1_out: 1}},  capex=0.01, vopex=0.01, prod_min=prod_min, rate_max=rate_max, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

# com1_process = Process(name='com1_process', prod_max=prod_max, conversion={0:{com1_in: -1, com1_out: 1}, 1:{com1_in: -1, com1_out: 1}, 2:{com1_in: -1, com1_out: 1}},  capex=0.01, vopex=0.01, prod_min=prod_min, rate_max=rate_max, varying=[VaryingProcess.DETERMINISTIC_CAPACITY], label='Process the commodity through the location')

com1_store10 = Process(name='com1_store10', prod_max=com1_process_capacity, capex=100, vopex=1, store_min=0.01, store_max= 20, prod_min=com1_process_capacity, label="Storage capacity of 10 units", storage=com1_in, storage_cost=0.02)
com1_store20 = Process(name='com1_store20', prod_max=com1_process_capacity, capex=200, vopex=2, store_min=0.01,store_max= 40, prod_min=com1_process_capacity, label="Storage capacity of 20 units", storage=com1_in, storage_cost=0.02)
com1_store50 = Process(name='com1_store50', prod_max=com1_process_capacity, capex=500, vopex=5, store_min=0.01, store_max= 100, prod_min=com1_process_capacity, label="Storage capacity of 50 units", storage=com1_in, storage_cost=0.02)

com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc1_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 1')
com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc2_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 2')
com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc3_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 3')
com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc4_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 4')
com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc5_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 5')
com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc6_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 6')
com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity, conversion={com1_out:-1, com1_loc7_out:1}, capex=0.01, vopex=0.01, prod_min=com1_process_capacity, label='Send commodity one from location 7')

# %%
# ======================================================================================================================
# Declare locations/warehouses
# ======================================================================================================================
loc1 = Location(name='loc1', processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store20, com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc2 = Location(name='loc2', processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc3 = Location(name='loc3', processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store20, com1_loc3_send}, label="Location 3", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5, com1_receive_loc7, com1_process, com1_store50, com1_loc4_send}, label="Location 4", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc5 = Location(name='loc5', processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store50, com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store10, com1_loc6_send}, label="Location 6", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1, capacity_factor={com1_process: loc6_varying_factor[['com1_process']]})

loc7 = Location(name='loc7', processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store20, com1_loc7_send}, label="Location 7", scales=scales, demand_scale_level=2, capacity_scale_level=1, availability_scale_level=1)

# %%
# ======================================================================================================================
# Declare transport/trucks
# ======================================================================================================================

truck_cap12 = 70
truck_cap13 = 30
truck_cap24 = 50
truck_cap25 = 30
truck_cap34 = 30
truck_cap45 = 100
truck_cap47 = 40
truck_cap64 = 50
truck_cap75 = 40

truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12, label='Truck from location 1 to 2', capex=0.5, vopex=0.05, trans_min=truck_cap12)
truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_cap12)

truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13, label='Truck from location 1 to 3', capex=0.3, vopex=0.03, trans_min=truck_cap13)
truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_cap13)

truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24, label='Truck from location 2 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap24)
truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_cap24)

truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25, label='Truck from location 2 to 5', capex=0.3, vopex=0.03, trans_min=truck_cap25)
truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_cap25)

truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34, label='Truck from location 3 to 4', capex=0.2, vopex=0.02, trans_min=truck_cap34)
truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_cap34)

truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45, label='Truck from location 4 to 5', capex=1, vopex=0.1, trans_min=truck_cap45)
truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_cap45)

truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47, label='Truck from location 4 to 7', capex=0.4, vopex=0.04, trans_min=truck_cap47)
truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_cap47)

truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64, label='Truck from location 6 to 4', capex=0.5, vopex=0.05, trans_min=truck_cap64)
truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_cap64)

truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75, label='Truck from location 7 to 5', capex=0.4, vopex=0.04, trans_min=truck_cap75)
truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_cap75)

# %%
# ======================================================================================================================
# Declare network
# ======================================================================================================================

# transport_matrix = [
#     [[], [truck50_12], [truck30_13], [], [], [], []],  # source: location 1
#     [[truck50_21], [], [], [truck50_24], [truck30_25], [], []],  # source: location 2
#     [[truck30_31], [], [], [truck20_34], [], [], []],  # source: location 3
#     [[], [truck50_42], [truck20_43], [], [truck100_45], [truck50_46], [truck40_47]],  # source: location 4
#     [[], [truck30_52], [], [truck100_54], [], [], [truck40_57]],  # source: location 5
#     [[], [], [], [truck50_64], [], [], []],  # source: location 6
#     [[], [], [], [truck40_74], [truck40_75], [], []]  # source: location 7
# ]

transport_matrix = [
    [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    [[], [], [], [truck64], [], [], []],  # source: location 6
    [[], [], [], [truck74], [truck75], [], []]  # source: location 7
]

distance_matrix = [
    [0, 55, 196, M, M, M, M],
    [55, 0, M, 163, 112, M, 134],
    [196, M, 0, 63, M, M, M],
    [M, 163, 63, 0, 95, 117, 88],
    [M, 112, M, 95, 0, M, 134],
    [M, M, M, 117, M, 0, M],
    [M, 134, M, 88, 134, M, 0]
]

locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

sources = locset
sinks = locset

network = Network(name='Network', scales= scales, source_locations=sources, sink_locations=sinks, transport_matrix=transport_matrix, distance_matrix=distance_matrix)

# %%
daily_demand = 100
demand_penalty = 50

demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

scenario = Scenario(name='scenario_IS140', scales=scales, scheduling_scale_level=2, network_scale_level=0, purchase_scale_level=2, availability_scale_level=1, demand_scale_level=2, capacity_scale_level=1, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict, label='Scenario with information updated after 19 weeks')

# %%
plot_scenario.capacity_factor(scenario=scenario, process=com1_process, location=loc6, color='green')

# %%
problem_mincost = formulate(scenario=scenario,
                            constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE, Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND, Constraints.MODE},
                            demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint fixed nameplate min production mode
# constraint fixed nameplate max production mode
# constraint production mode wo binary
# constraint production rate1
# constraint production rate2
# constraint production mode switch
# constraint demand penalty
# objective cost w demand penalty

# %%
results_mincost = solve(scenario=scenario, instance=problem_mincost, solver='gurobi', name='MILP')
# Out:
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 553941 rows, 1674790 columns and 899927 nonzeros
# Model fingerprint: 0xa78de8f0
# Variable types: 1572380 continuous, 102410 integer (102410 binary)
# Coefficient statistics:
#   Matrix range     [6e-03, 5e+02]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 2e+02]
# Found heuristic solution: objective 1242677.2360
# Presolve removed 524271 rows and 1632117 columns
# Presolve time: 1.11s
# Presolved: 29670 rows, 42673 columns, 131792 nonzeros
# Variable types: 24603 continuous, 18070 integer (6020 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.616699e+05, 25117 iterations, 0.54 seconds (0.82 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 661669.873    0 2648 1242677.24 661669.873  46.8%     -    4s
# H    0     0                    835831.59850 661669.873  20.8%     -    4s
#      0     0 661669.956    0 3427 835831.598 661669.956  20.8%     -    6s
# H    0     0                    831612.85600 661669.956  20.4%     -    7s
# H    0     0                    776117.72225 661669.958  14.7%     -    7s
#      0     0 661669.958    0 3404 776117.722 661669.958  14.7%     -    7s
#      0     0 661669.998    0 3541 776117.722 661669.998  14.7%     -    9s
# H    0     0                    748368.08850 661669.998  11.6%     -   10s
# H    0     0                    748262.00975 661669.998  11.6%     -   10s
#      0     0 661670.139    0 2755 748262.010 661670.139  11.6%     -   10s
# H    0     0                    746385.25892 661670.139  11.4%     -   11s
# H    0     0                    745819.51725 661670.139  11.3%     -   11s
# H    0     0                    743513.83850 661670.139  11.0%     -   11s
#      0     0 661670.288    0 1901 743513.838 661670.288  11.0%     -   11s
# H    0     0                    743015.75350 661670.288  10.9%     -   12s
#      0     0 661671.550    0 1309 743015.753 661671.550  10.9%     -   12s
#      0     0 661671.560    0 1211 743015.753 661671.560  10.9%     -   12s
#      0     0 661671.733    0 1074 743015.753 661671.733  10.9%     -   13s
# H    0     0                    687092.53006 661671.733  3.70%     -   13s
#      0     0 661671.751    0 1146 687092.530 661671.751  3.70%     -   13s
#      0     0 661671.793    0 1104 687092.530 661671.793  3.70%     -   14s
#      0     0 661671.793    0  696 687092.530 661671.793  3.70%     -   14s
#      0     2 661671.793    0  696 687092.530 661671.793  3.70%     -   15s
# H   31    40                    686745.48583 661671.827  3.65%   916   17s
# H   33    40                    684503.38225 661671.827  3.34%   862   17s
# H   37    40                    678128.62100 661671.827  2.43%   856   17s
# H   77    86                    675624.96225 661671.827  2.07%   494   18s
# H  123   131                    674279.29850 661671.827  1.87%   332   19s
#    169   216 661672.000   25  585 674279.298 661671.827  1.87%   286   20s
# H  233   252                    673300.33725 661671.827  1.73%   284   21s
# H  547   532                    672962.20517 661671.827  1.68%   314   24s
#    575   615 661675.861   45  506 672962.205 661671.827  1.68%   299   25s
# H  767   433                    662379.81283 661671.827  0.11%   265   26s
# H  839   424                    662379.78408 661671.827  0.11%   275   27s
#   1086   574 661721.046   99  693 662379.784 661671.827  0.11%   259   30s
# * 1223   574             139    662378.46006 661671.827  0.11%   241   30s
# * 1501   593             142    662377.99944 661671.827  0.11%   222   31s
# H 1562    86                    661674.59267 661671.827  0.00%   223   32s
#   1563    56 661672.093   25  696 661674.593 661671.827  0.00%   223   41s
#
# Explored 1563 nodes (414562 simplex iterations) in 41.67 seconds (55.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 661675 662378 662378 ... 678129
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.616745926667e+05, best bound 6.616718270224e+05, gap 0.0004%
# WARNING: Cannot get duals for MIP.

# %%
sum(value for key, value in results_mincost.output['S'].items() if key[0] == 'loc5' and key[1] == 'com1_sold') /(daily_demand*_time_intervals*_exec_scenarios)
# Out:
# 0.8040816326530612

# %%
min(value for key, value in results_mincost.output['S'].items() if key[0] == 'loc5' and key[1] == 'com1_sold')
# Out:
# 74.99999999999892

# %%
plot_results.schedule(results=results_mincost, y_axis='S', component='com1_sold', location='loc5', color='green')

# %%
results_mincost.output['S']
# Out:
# {('loc1', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 12, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 13, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 14, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 15, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 16, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 17, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 18, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 19, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 20, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 21, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 22, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 23, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 24, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 25, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 26, 6): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 0): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 1): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 2): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 3): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 4): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 5): 0.0,
#  ('loc1', 'com1_sold', 0, 27, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 12, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 13, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 14, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 15, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 16, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 17, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 18, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 19, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 20, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 21, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 22, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 23, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 24, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 25, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 26, 6): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 0): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 1): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 2): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 3): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 4): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 5): 0.0,
#  ('loc2', 'com1_sold', 0, 27, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 12, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 13, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 14, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 15, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 16, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 17, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 18, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 19, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 20, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 21, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 22, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 23, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 24, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 25, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 26, 6): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 0): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 1): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 2): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 3): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 4): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 5): 0.0,
#  ('loc3', 'com1_sold', 0, 27, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 2, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 3, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 4, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 5, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 6, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 7, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 8, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 9, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 10, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 11, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 12, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 13, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 14, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 15, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 16, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 17, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 18, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 19, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 20, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 21, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 22, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 23, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 24, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 25, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 26, 6): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 0): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 1): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 2): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 3): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 4): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 5): 0.0,
#  ('loc4', 'com1_sold', 0, 27, 6): 0.0,
#  ('loc5', 'com1_sold', 0, 0, 0): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 1): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 2): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 3): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 4): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 5): 100.0,
#  ('loc5', 'com1_sold', 0, 0, 6): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 0): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 1): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 2): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 3): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 4): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 5): 100.0,
#  ('loc5', 'com1_sold', 0, 1, 6): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 0): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 1): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 2): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 3): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 4): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 5): 100.0,
#  ('loc5', 'com1_sold', 0, 2, 6): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 0): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 1): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 2): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 3): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 4): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 5): 100.0,
#  ('loc5', 'com1_sold', 0, 3, 6): 100.0,
#  ('loc5', 'com1_sold', 0, 4, 0): 99.87500000000442,
#  ('loc5', 'com1_sold', 0, 4, 1): 99.62500000000414,
#  ('loc5', 'com1_sold', 0, 4, 2): 99.3750000000042,
#  ('loc5', 'com1_sold', 0, 4, 3): 99.12500000000414,
#  ('loc5', 'com1_sold', 0, 4, 4): 98.87499999999999,
#  ('loc5', 'com1_sold', 0, 4, 5): 98.62499999999999,
#  ('loc5', 'com1_sold', 0, 4, 6): 98.37499999999999,
#  ('loc5', 'com1_sold', 0, 5, 0): 98.12499999999999,
#  ('loc5', 'com1_sold', 0, 5, 1): 97.87499999999999,
#  ('loc5', 'com1_sold', 0, 5, 2): 97.62499999999999,
#  ('loc5', 'com1_sold', 0, 5, 3): 97.37499999999999,
#  ('loc5', 'com1_sold', 0, 5, 4): 97.12499999999999,
#  ('loc5', 'com1_sold', 0, 5, 5): 96.87499999999999,
#  ('loc5', 'com1_sold', 0, 5, 6): 96.62499999999999,
#  ('loc5', 'com1_sold', 0, 6, 0): 96.3750000000032,
#  ('loc5', 'com1_sold', 0, 6, 1): 81.79166666666862,
#  ('loc5', 'com1_sold', 0, 6, 2): 81.0833333333104,
#  ('loc5', 'com1_sold', 0, 6, 3): 75.25000000000034,
#  ('loc5', 'com1_sold', 0, 6, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 6, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 6, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 2): 75.00000000000061,
#  ('loc5', 'com1_sold', 0, 7, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 7, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 8, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 9, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 9, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 9, 2): 75.00000000000001,
#  ('loc5', 'com1_sold', 0, 9, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 9, 4): 75.00000000000001,
#  ('loc5', 'com1_sold', 0, 9, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 9, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 10, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 11, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 12, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 13, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 14, 5): 74.99999999999999,
#  ('loc5', 'com1_sold', 0, 14, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 2): 74.99999999999999,
#  ('loc5', 'com1_sold', 0, 15, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 15, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 16, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 16, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 16, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 16, 3): 74.99999999999892,
#  ('loc5', 'com1_sold', 0, 16, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 16, 5): 75.00000000000108,
#  ('loc5', 'com1_sold', 0, 16, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 17, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 4): 74.99999999999997,
#  ('loc5', 'com1_sold', 0, 18, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 18, 6): 75.00000000000003,
#  ('loc5', 'com1_sold', 0, 19, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 19, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 0): 75.00000000000068,
#  ('loc5', 'com1_sold', 0, 20, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 20, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 21, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 21, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 21, 2): 74.99999999999997,
#  ('loc5', 'com1_sold', 0, 21, 3): 75.00000000000003,
#  ('loc5', 'com1_sold', 0, 21, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 21, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 21, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 22, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 1): 75.00000000000051,
#  ('loc5', 'com1_sold', 0, 23, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 23, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 24, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 25, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 26, 6): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 0): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 1): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 2): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 3): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 4): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 5): 75.0,
#  ('loc5', 'com1_sold', 0, 27, 6): 75.0,
#  ('loc6', 'com1_sold', 0, 0, 0): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 1): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 2): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 3): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 4): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 5): 0.0,
#  ('loc6', 'com1_sold', 0, 0, 6): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 0): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 1): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 2): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 3): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 4): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 5): 0.0,
#  ('loc6', 'com1_sold', 0, 1, 6): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 0): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 1): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 2): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 3): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 4): 0.0,
#  ('loc6', 'com1_sold', 0, 2, 5): 0.0,
#  ...}

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset

key1 = 0
key2 = 7
start=key1*_time_intervals

output = [100]*7*20 + list(value for key, value in results_mincost.output['S'].items() if key[0]=='loc5' and key[1]=='com1_sold')

ax.plot(range(start, len(output)+start), output, color='green', linestyle='-')

plt.axvline(x = 167, color = 'cyan', label = 'Disruption', linestyle = '-')

# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Units')
ax.set_title('Commodity Sold at Location 5')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc2', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc3', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc4', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store50_com1_in_stored', location='loc5', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store10_com1_in_stored', location='loc6', color='green')
plot_results.schedule(results=results_mincost, y_axis='Inv', component='com1_store20_com1_in_stored', location='loc7', color='green')

# %%
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc1', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc2', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc3', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc4', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc5', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc6', color='green')
plot_results.schedule(results=results_mincost, y_axis='P', component='com1_process', location='loc7', color='green')

# %%
results_mincost.output['objective']
# Out:
# 661674.5926666661

# %%
demand_penalty*sum(value for key, value in results_mincost.output['Demand_penalty'].items()) + problem_mincost.Capex_network[0].value + problem_mincost.Vopex_network[0].value + problem_mincost.Capex_transport_network[0].value + problem_mincost.Vopex_transport_network[0].value + problem_mincost.Inv_cost_network[0].value
# Out:
# 661674.5926666661

# %%
demand_penalty*sum(value for key, value in results_mincost.output['Demand_penalty'].items()) + problem_mincost.Vopex_network[0].value + problem_mincost.Vopex_transport_network[0].value + problem_mincost.Inv_cost_network[0].value
# Out:
# 398997.3566666663

# %%
demand_penalty*sum(value for key, value in results_mincost.output['Demand_penalty'].items())
# Out:
# 191999.99999999994

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# Plot data from the first dataset

key1 = 0
key2 = 7
start=key1*_time_intervals

inv1 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_store20_com1_in_stored' and key[3]>=key1 and key[3]<=key2)
inv2 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2)
inv3 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2)
inv4 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2)
inv5 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2)
inv6 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_store10_com1_in_stored'and key[3]>=key1 and key[3]<=key2)
inv7 = [0]*7 + list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2)

# ax.plot(range(start+133, len(inv1)+start+133), inv1, label='Location 1', color='red', linestyle='-.')
# ax.plot(range(start+133, len(inv2)+start+133), inv2, label='Location 2', color='green', linestyle='-.')
# ax.plot(range(start+133, len(inv3)+start+133), inv3, label='Location 3', color='red', linestyle=':')
# ax.plot(range(start+133, len(inv4)+start+133), inv4, label='Location 4', color='blue', linestyle='-.')
# ax.plot(range(start+133, len(inv5)+start+133), inv5, label='Location 5', color='red', linestyle='--')
# ax.plot(range(start+133, len(inv6)+start+133), inv6, label='Location 6', color='blue', linestyle='-')
# ax.plot(range(start+133, len(inv7)+start+133), inv7, label='Location 7', color='green', linestyle='--')

ax.plot(range(start+133, len(inv1)+start+133), inv1, color='red', linestyle='-.')
ax.plot(range(start+133, len(inv2)+start+133), inv2, color='green', linestyle='-.')
ax.plot(range(start+133, len(inv3)+start+133), inv3, color='red', linestyle=':')
ax.plot(range(start+133, len(inv4)+start+133), inv4, color='blue', linestyle='-.')
ax.plot(range(start+133, len(inv5)+start+133), inv5, color='red', linestyle='--')
ax.plot(range(start+133, len(inv6)+start+133), inv6, color='blue', linestyle='-')
ax.plot(range(start+133, len(inv7)+start+133), inv7, color='green', linestyle='--')

# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_store20_com1_in_stored' and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc1' and key[1]=='com1_store20_com1_in_stored' and key[3]>=key1 and key[3]<=key2), label='Location 1', color='red', linestyle='-.')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc2' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 2', color='green', linestyle='-.')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc3' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 3', color='red', linestyle=':')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc4' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 4', color='blue', linestyle='-.')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc5' and key[1]=='com1_store50_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 5', color='red', linestyle='--')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_store10_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc6' and key[1]=='com1_store10_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 6', color='blue', linestyle='-')
# 
# ax.plot(range(start+140, len(list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2))+start+140), list(value for key, value in results_mincost.output['Inv'].items() if key[0]=='loc7' and key[1]=='com1_store20_com1_in_stored'and key[3]>=key1 and key[3]<=key2), label='Location 7', color='green', linestyle='--')

plt.axvline(x = 167, color = 'cyan', label = 'Disruption', linestyle = '-')
plt.axvline(x = 139, color = 'red', label = 'Information shared', linestyle = '-')


# Customize the plot
ax.set_xlabel('Time Horizon')
ax.set_ylabel('Inventory level')
ax.set_title('Inventory levels for Scenario 2')
ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
partial_vopex_cost = demand_penalty*sum(value for key, value in results_mincost.output['Demand_penalty'].items()) + problem_mincost.Vopex_network[0].value + problem_mincost.Vopex_transport_network[0].value + problem_mincost.Inv_cost_network[0].value

print(f'Partial Vopex Cost: {partial_vopex_cost}')
# Out:
# Partial Vopex Cost: 398997.3566666663

# %%
total_vopex_cost = partial_vopex_cost + 177744.00000000006
print(f'Total Vopex Cost: {total_vopex_cost}')
# Out:
# Total Vopex Cost: 576741.3566666663

# %%
partial_demand_met = sum(value for key, value in results_mincost.output['S'].items() if key[0] == 'loc5' and key[1] == 'com1_sold')

# %%
total_demand_met = partial_demand_met + 14000.0

service_level = total_demand_met/33600
print(f'Service Level: {service_level}')
# Out:
# Service Level: 0.8857142857142857

# %%
partial_demand_met
# Out:
# 15760.0

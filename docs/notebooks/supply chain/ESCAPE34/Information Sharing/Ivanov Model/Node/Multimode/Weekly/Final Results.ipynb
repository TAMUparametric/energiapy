# %%
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 12})
rc('text', usetex=False)
fig, ax = plt.subplots()

# x_values = [89.6, 89.5, 89.06, 88.5, 88.02, 87.5]
# y_values = [566974.67, 568365.43, 572688.7, 577109.78, 581785.69, 586756.8]

x_values = [89.64, 89.64, 89.58, 89.06, 88.54, 88.02, 87.5]
y_values = [566955.568, 567625.745, 568334.126, 572662.899, 577087.599, 581750.399, 586757.794]


# ax.plot(x_values, y_values, label='Location 1', color='red')
plt.scatter(x_values, y_values)

# Customize the plot
ax.set_xlabel('Service Level')
ax.set_ylabel('Total Cost')
ax.set_title('Resilience vs Cost for Information Sharing')
# ax.legend()
ax.plot(linewidth=0.5)
plt.grid(alpha=0.6)
plt.rcdefaults()
# Show the plot
plt.show()

# %%
import os

from pyomo.environ import *
import mpisppy.utils.sputils as sputils
from mpisppy.opt.ef import ExtensiveForm
import matplotlib.pyplot as plt
from matplotlib import rc
import sys
sys.path.append('../../../../src')
import pandas
import random
import math
from itertools import product
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport, VaryingTransport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
from energiapy.utils.scale_utils import scale_list, scale_tuple
from energiapy.model.constraints.constraints import make_constraint, Cons
from energiapy.model.formulate import constraint_export
from functools import reduce
import pickle
from pyomo.environ import value as pyoval
import time
from pyomo.util.infeasible import log_infeasible_constraints
from pyomo.contrib.iis import write_iis
from pyomo.contrib.iis import compute_infeasibility_explanation

# %%
# _time_intervals = 7  # Number of time intervals in a planning horizon    (L_chi)
_exec_scenarios = 4  # Number of execution scenarios                     (chi)

M = 1e5  # Big M

# %%
def create_list(n_total: int, n: int):
    return [1] * n + [0] * (n_total - n)

# %%
def create_event_dict(n_total: int):
    default_list = [1] * n_total

    # If event names are same before '_'; they are considered mutually exclusive else the events are treated as independent
    event_dict = {
        'cap2_1': {'prob': 0.06, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 1)})},
        'cap2_2': {'prob': 0.12, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 2)})},
        'cap2_3': {'prob': 0.17, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 3)})},
        'cap2_nd': {'prob': 0.65, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): default_list})},

        'cap4_1': {'prob': 0.05, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 1)})},
        'cap4_2': {'prob': 0.15, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 2)})},
        'cap4_3': {'prob': 0.18, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 3)})},
        'cap4_nd': {'prob': 0.62, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): default_list})},

        'cap7_1': {'prob': 0.04, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 1)})},
        'cap7_2': {'prob': 0.15, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 2)})},
        'cap7_3': {'prob': 0.2, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 3)})},
        'cap7_nd': {'prob': 0.61, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): default_list})},

        'res1_1': {'prob': 0.06, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 1)})},
        'res1_2': {'prob': 0.12, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 2)})},
        'res1_3': {'prob': 0.19, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 3)})},
        'res1_nd': {'prob': 0.63, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): default_list})},

        'res6_1': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 1)})},
        'res6_2': {'prob': 0.16, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 2)})},
        'res6_3': {'prob': 0.17, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 3)})},
        'res6_nd': {'prob': 0.64, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): default_list})},

        'trans12_2': {'prob': 0.2, 'factor': pandas.DataFrame(data={('trans12', 'com1_loc1_out'): create_list(n_total, 2)})},
        'trans12_nd': {'prob': 0.8, 'factor': pandas.DataFrame(data={('trans12', 'com1_loc1_out'): default_list})},

        'trans25_2': {'prob': 0.3, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): create_list(n_total, 2)})},
        'trans25_nd': {'prob': 0.7, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): default_list})},
    }

    return event_dict

# %%
# Function to generate the scenario dictionary for n sets of events
def create_scenario_dict(event_dict):
    # Extract unique event prefixes (e.g., 'cap2', 'cap4', ...)
    event_prefixes = set(key.split('_')[0] for key in event_dict)

    # Group events by their prefixes
    grouped_events = {prefix: [key for key in event_dict if key.startswith(prefix)] for prefix in event_prefixes}

    # Create all possible combinations of events across the different groups
    event_combinations = list(product(*grouped_events.values()))

    scenario_dict = {}

    # Iterate over all event combinations
    for combination in event_combinations:
        # Construct the scenario key
        scenario_key = ' '.join(combination)

        # Calculate the probability of this scenario
        prob = 1
        combined_factor = None

        for event_key in combination:
            # Multiply probabilities
            prob *= event_dict[event_key]['prob']

            # Combine factors (assumes they are pandas DataFrames)
            if combined_factor is None:
                combined_factor = event_dict[event_key]['factor'].copy()
            else:
                combined_factor = combined_factor.add(event_dict[event_key]['factor'], fill_value=0)

        # Add to the scenario dictionary
        scenario_dict[scenario_key] = {'prob': prob, 'factor': combined_factor}

    return scenario_dict

# %%
def build_model(scen_df=pandas.DataFrame()):
    default_df = pandas.DataFrame(data=[1] * _exec_scenarios)
    scale_factor = 90

    # Define temporal scales
    scales = TemporalScale(discretization_list=[1, _exec_scenarios])

    # ======================================================================================================================
    # Declare resources/commodities
    # ======================================================================================================================
    com1_pur = Resource(name='com1_pur', cons_max=225*scale_factor, block={'imp': 1, 'urg': 1}, price=0.00,
                        label='Commodity 1 consumed from outside the system',
                        varying=[VaryingResource.DETERMINISTIC_AVAILABILITY])

    com1_in = Resource(name='com1_in', label='Commodity 1 received')
    com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

    com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
    com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
    com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
    com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
    com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
    com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
    com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

    com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True,
                         label='Commodity 1 sold to outside the system')

    # ======================================================================================================================
    # Declare processes/storage capacities
    # ======================================================================================================================
    com1_process_capacity = 500*scale_factor

    # prod_max = {0: 0.25*com1_process_capacity, 1: 0.5*com1_process_capacity, 2: 0.75*com1_process_capacity, 3: 0.95*com1_process_capacity, 4: com1_process_capacity}
    # prod_min = {0: 0, 1: 0.25*com1_process_capacity, 2: 0.5*com1_process_capacity, 3: 0.75*com1_process_capacity, 4: 0.95*com1_process_capacity}
    # rate_max = {0:1.25/2, 1: 1/2, 2: 0.75/2, 3: 0.5/2, 4: 0.25/2}
    # mode_ramp = {(0,1): 5, (1,2): 5}

    com1_procure = Process(name='procure com1', prod_max=com1_process_capacity, conversion={com1_pur: -1, com1_in: 1},
                           capex=25/scale_factor, vopex=0.01, prod_min=0.01, label='Procure com1')
    com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1},
                        capex=0.1/scale_factor, vopex=0.01, prod_min=0.01, label='Sell com1')
    # com1_opt_procure = Process(name='procure optional com1', prod_max=75, conversion={com1_pur: -1, com1_in:1}, capex=10, vopex=0.1, prod_min=0.01, label='Procure optional com1')

    com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity,
                                conversion={com1_loc1_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 1')
    com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity,
                                conversion={com1_loc2_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 2')
    com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity,
                                conversion={com1_loc3_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 3')
    com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity,
                                conversion={com1_loc4_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 4')
    com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity,
                                conversion={com1_loc5_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 5')
    com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity,
                                conversion={com1_loc6_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 6')
    com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity,
                                conversion={com1_loc7_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 7')

    com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},
                           capex=5/scale_factor, vopex=0.01, prod_min=0.01, label='Process the commodity through the location',
                           varying=[VaryingProcess.DETERMINISTIC_CAPACITY])

    com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=0.5/scale_factor, vopex=0.01, storage_capex=30/scale_factor, store_min=0.01,
                         store_max=200*scale_factor, prod_min=0.01, label="Storage process", storage=com1_in, storage_cost=0.02)

    com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc1_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 1')
    com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc2_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 2')
    com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc3_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 3')
    com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc4_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 4')
    com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc5_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 5')
    com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc6_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 6')
    com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc7_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 7')

    # ======================================================================================================================
    # Declare locations/warehouses
    # ======================================================================================================================
    loc1 = Location(name='loc1',
                    processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store,
                               com1_loc1_send}, label="Location 1",
                    scales=scales, demand_scale_level=1, capacity_scale_level=1, availability_scale_level=1,
                    availability_factor={
                        com1_pur: scen_df[[('loc1', 'com1_pur')]] if ('loc1', 'com1_pur') in scen_df else default_df})

    loc2 = Location(name='loc2',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store,
                               com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=1,
                    capacity_scale_level=1, availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc2', 'com1_process')]] if ('loc2',
                                                                                           'com1_process') in scen_df else default_df})

    loc3 = Location(name='loc3',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store, com1_loc3_send},
                    label="Location 3", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1)

    loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5,
                                            com1_receive_loc7, com1_process, com1_store, com1_loc4_send},
                    label="Location 4", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc4', 'com1_process')]] if ('loc4',
                                                                                           'com1_process') in scen_df else default_df})

    loc5 = Location(name='loc5',
                    processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store,
                               com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=1,
                    capacity_scale_level=1, availability_scale_level=1)

    loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store, com1_loc6_send},
                    label="Location 6", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    availability_factor={
                        com1_pur: scen_df[[('loc6', 'com1_pur')]] if ('loc6', 'com1_pur') in scen_df else default_df})

    loc7 = Location(name='loc7',
                    processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc7_send},
                    label="Location 7", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc7', 'com1_process')]] if ('loc7',
                                                                                           'com1_process') in scen_df else default_df})

    # ======================================================================================================================
    # Declare transport/trucks
    # ======================================================================================================================

    truck_cap12 = 280*scale_factor
    truck_cap13 = 270*scale_factor
    truck_cap24 = 450*scale_factor
    truck_cap25 = 270*scale_factor
    truck_cap34 = 270*scale_factor
    truck_cap45 = 500*scale_factor
    truck_cap47 = 360*scale_factor
    truck_cap64 = 450*scale_factor
    truck_cap75 = 360*scale_factor

    truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12,
                        label='Truck from location 1 to 2', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12,
    #                     label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13,
                        label='Truck from location 1 to 3', capex=0.3/scale_factor, vopex=0.03, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13,
    #                     label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=0.01)

    truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24,
                        label='Truck from location 2 to 4', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24,
    #                     label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25,
                        label='Truck from location 2 to 5', capex=0.3/scale_factor, vopex=0.03, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25,
    #                     label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=0.01)

    truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34,
                        label='Truck from location 3 to 4', capex=0.2/scale_factor, vopex=0.02, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34,
    #                     label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=0.01)

    truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45,
                        label='Truck from location 4 to 5', capex=1/scale_factor, vopex=0.1, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45,
    #                     label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=0.01)

    truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47,
                        label='Truck from location 4 to 7', capex=0.4/scale_factor, vopex=0.04, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47,
    #                     label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=0.01)

    truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64,
                        label='Truck from location 6 to 4', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64,
    #                     label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75,
                        label='Truck from location 7 to 5', capex=0.4/scale_factor, vopex=0.04, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75,
    #                     label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=0.01)

    # ======================================================================================================================
    # Declare network
    # ======================================================================================================================

    transport_matrix = [
        [[], [truck12], [truck13], [], [], [], []],  # source: location 1
        [[], [], [], [truck24], [truck25], [], []],  # source: location 2
        [[], [], [], [truck34], [], [], []],  # source: location 3
        [[], [], [], [], [truck45], [], [truck47]],  # source: location 4
        [[], [], [], [], [], [], []],  # source: location 5
        [[], [], [], [truck64], [], [], []],  # source: location 6
        [[], [], [], [], [truck75], [], []]  # source: location 7
    ]

    # transport_matrix = [
    #     [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    #     [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    #     [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    #     [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    #     [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    #     [[], [], [], [truck64], [], [], []],  # source: location 6
    #     [[], [], [], [truck74], [truck75], [], []]  # source: location 7
    # ]

    distance_matrix = [
        [0, 55, 196, M, M, M, M],
        [55, 0, M, 163, 112, M, 134],
        [196, M, 0, 63, M, M, M],
        [M, 163, 63, 0, 95, 117, 88],
        [M, 112, M, 95, 0, M, 134],
        [M, M, M, 117, M, 0, M],
        [M, 134, M, 88, 134, M, 0]
    ]

    locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

    sources = locset
    sinks = locset

    network = Network(name='Network', scales=scales, source_locations=sources, sink_locations=sinks,
                      transport_matrix=transport_matrix, distance_matrix=distance_matrix, transport_capacity_scale_level=1,
                      transport_capacity_factor={(loc1, loc2): {truck12: scen_df[[('trans12', 'com1_loc1_out')]] if ('trans12', 'com1_loc1_out') in scen_df else default_df},
                                                 (loc1, loc3): {truck13: scen_df[[('trans13', 'com1_loc1_out')]] if ('trans13', 'com1_loc1_out') in scen_df else default_df},
                                                 (loc2, loc4): {truck24: scen_df[[('trans24', 'com1_loc2_out')]] if ('trans24', 'com1_loc2_out') in scen_df else default_df},
                                                 (loc2, loc5): {truck25: scen_df[[('trans25', 'com1_loc2_out')]] if ('trans25', 'com1_loc2_out') in scen_df else default_df},
                                                 (loc3, loc4): {truck34: scen_df[[('trans34', 'com1_loc3_out')]] if ('trans34', 'com1_loc3_out') in scen_df else default_df},
                                                 (loc4, loc5): {truck45: scen_df[[('trans45', 'com1_loc4_out')]] if ('trans45', 'com1_loc4_out') in scen_df else default_df},
                                                 (loc4, loc7): {truck47: scen_df[[('trans47', 'com1_loc4_out')]] if ('trans47', 'com1_loc4_out') in scen_df else default_df},
                                                 (loc6, loc4): {truck64: scen_df[[('trans64', 'com1_loc6_out')]] if ('trans64', 'com1_loc6_out') in scen_df else default_df},
                                                 (loc7, loc5): {truck75: scen_df[[('trans75', 'com1_loc7_out')]] if ('trans75', 'com1_loc7_out') in scen_df else default_df},
                                                 })

    # ======================================================================================================================
    # Declare scenario
    # ======================================================================================================================

    daily_demand = 400*scale_factor
    demand_penalty = 200

    demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
    demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

    scenario = Scenario(name='scenario', scales=scales, scheduling_scale_level=1, network_scale_level=0,
                        purchase_scale_level=1, availability_scale_level=1, demand_scale_level=1,
                        capacity_scale_level=1, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                        label='Stochastic scenario with Multiple Locations')

    if scen_df.empty:
        # ======================================================================================================================
        # Declare problem
        # ======================================================================================================================

        problem_mincost = formulate(scenario=scenario,
                                    constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE,
                                                 Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND,
                                                 Constraints.NETWORK},
                                    demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

        scale_iter = scale_tuple(instance=problem_mincost, scale_levels=scenario.network_scale_level + 1)
        # capex_process = sum(problem_mincost.Capex_network[scale_] for scale_ in scale_iter)
        # cost_trans_capex = sum(problem_mincost.Capex_transport_network[scale_] for scale_ in scale_iter)
        
        problem_mincost.first_stage_cost = Var(within=NonNegativeReals, doc='First Stage Cost')
        
        def first_stage_cost_rule(instance):
            return (instance.first_stage_cost == sum(instance.Capex_network[scale_] for scale_ in scale_iter) + 
                                                sum(instance.Capex_transport_network[scale_] for scale_ in scale_iter))
        
        problem_mincost.constraint_first_stage_cost = Constraint(rule=first_stage_cost_rule)

        return scenario, problem_mincost
    else:
        return scenario

# %%
solver_options = {
    'MIPGap': 0.005,
    # 'TimeLimit': 60 * 15,
    'Heuristics': 0.20
}

# %%
event_dict = create_event_dict(n_total=_exec_scenarios)

# %%
scenario_dict = create_scenario_dict(event_dict=event_dict)
scenario_names = list(scenario_dict.keys())

# %%
scenario_names[0]

# %%
idx = scenario_names.index('res6_nd cap2_1 res1_nd cap7_1 trans12_nd trans25_nd cap4_nd')
scenario_names[idx]

# %%
scenario_dict[scenario_names[idx]]

# %%
results = dict()
scen, model = build_model()
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
model.constraint_nameplate_production_varying_capacity.pprint()
# Out:
# constraint_nameplate_production_varying_capacity : restricts production to varying nameplate capacity
#     Size=28, Index=locations*processes_varying_capacity*{0}*{0, 1, 2, 3}, Active=True
#     Key                            : Lower : Body                                                  : Upper : Active
#     ('loc1', 'com1_process', 0, 0) :  -Inf : P[loc1,com1_process,0,0] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 1) :  -Inf : P[loc1,com1_process,0,1] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 2) :  -Inf : P[loc1,com1_process,0,2] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 3) :  -Inf : P[loc1,com1_process,0,3] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 0) :  -Inf : P[loc2,com1_process,0,0] - Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 1) :  -Inf : P[loc2,com1_process,0,1] - Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 2) :  -Inf : P[loc2,com1_process,0,2] - Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 3) :  -Inf : P[loc2,com1_process,0,3] - Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 0) :  -Inf : P[loc3,com1_process,0,0] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 1) :  -Inf : P[loc3,com1_process,0,1] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 2) :  -Inf : P[loc3,com1_process,0,2] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 3) :  -Inf : P[loc3,com1_process,0,3] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 0) :  -Inf : P[loc4,com1_process,0,0] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 1) :  -Inf : P[loc4,com1_process,0,1] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 2) :  -Inf : P[loc4,com1_process,0,2] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 3) :  -Inf : P[loc4,com1_process,0,3] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 0) :  -Inf : P[loc5,com1_process,0,0] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 1) :  -Inf : P[loc5,com1_process,0,1] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 2) :  -Inf : P[loc5,com1_process,0,2] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 3) :  -Inf : P[loc5,com1_process,0,3] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 0) :  -Inf : P[loc6,com1_process,0,0] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 1) :  -Inf : P[loc6,com1_process,0,1] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 2) :  -Inf : P[loc6,com1_process,0,2] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 3) :  -Inf : P[loc6,com1_process,0,3] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 0) :  -Inf : P[loc7,com1_process,0,0] - Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 1) :  -Inf : P[loc7,com1_process,0,1] - Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 2) :  -Inf : P[loc7,com1_process,0,2] - Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 3) :  -Inf : P[loc7,com1_process,0,3] - Cap_P[loc7,com1_process,0] :   0.0 :   True

# %%
model.constraint_export.pprint()
# Out:
# constraint_export : capacity bound export of resource from source to sink
#     Size=1764, Index=sources*sinks*transports*{0}*{0, 1, 2, 3}, Active=True
#     Key                               : Lower : Body                                                      : Upper : Active
#     ('loc1', 'loc1', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc1', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc1,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc1', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc1,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc1', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc1,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc1', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc1,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck12', 0, 0) :  -Inf : Exp_F[loc1,loc2,truck12,0,0] - Cap_F[loc1,loc2,truck12,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck12', 0, 1) :  -Inf : Exp_F[loc1,loc2,truck12,0,1] - Cap_F[loc1,loc2,truck12,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck12', 0, 2) :  -Inf : Exp_F[loc1,loc2,truck12,0,2] - Cap_F[loc1,loc2,truck12,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck12', 0, 3) :  -Inf : Exp_F[loc1,loc2,truck12,0,3] - Cap_F[loc1,loc2,truck12,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc2', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc2,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc2', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc2,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc2', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc2,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc2', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc2,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck13', 0, 0) :  -Inf : Exp_F[loc1,loc3,truck13,0,0] - Cap_F[loc1,loc3,truck13,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck13', 0, 1) :  -Inf : Exp_F[loc1,loc3,truck13,0,1] - Cap_F[loc1,loc3,truck13,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck13', 0, 2) :  -Inf : Exp_F[loc1,loc3,truck13,0,2] - Cap_F[loc1,loc3,truck13,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck13', 0, 3) :  -Inf : Exp_F[loc1,loc3,truck13,0,3] - Cap_F[loc1,loc3,truck13,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc3', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc3,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc3', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc3,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc3', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc3,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc3', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc3,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc4', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc4,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc4', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc4,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc4', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc4,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc4', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc4,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc5', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc5,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc5', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc5,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc5', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc5,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc5', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc5,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc6', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc6,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc6', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc6,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc6', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc6,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc6', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc6,truck75,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck12,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck12,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck12,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck12,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck13,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck13,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck13,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck13,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck24,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck24,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck24,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck24,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck25,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck25,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck25,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck25,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck34,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck34,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck34,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck34,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck45,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck45,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck45,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck45,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck47,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck47,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck47,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck47,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck64,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck64,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck64,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck64,0,3] :   0.0 :   True
#     ('loc1', 'loc7', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc1,loc7,truck75,0,0] :   0.0 :   True
#     ('loc1', 'loc7', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc1,loc7,truck75,0,1] :   0.0 :   True
#     ('loc1', 'loc7', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc1,loc7,truck75,0,2] :   0.0 :   True
#     ('loc1', 'loc7', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc1,loc7,truck75,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck12,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck12,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck12,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck12,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck13,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck13,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck13,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck13,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck24,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck24,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck24,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck24,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck25,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck25,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck25,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck25,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck34,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck34,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck34,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck34,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck45,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck45,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck45,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck45,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck47,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck47,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck47,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck47,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck64,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck64,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck64,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck64,0,3] :   0.0 :   True
#     ('loc2', 'loc1', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc2,loc1,truck75,0,0] :   0.0 :   True
#     ('loc2', 'loc1', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc2,loc1,truck75,0,1] :   0.0 :   True
#     ('loc2', 'loc1', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc2,loc1,truck75,0,2] :   0.0 :   True
#     ('loc2', 'loc1', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc2,loc1,truck75,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck12,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck12,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck12,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck12,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck13,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck13,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck13,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck13,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck24,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck24,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck24,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck24,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck25,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck25,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck25,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck25,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck34,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck34,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck34,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck34,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck45,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck45,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck45,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck45,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck47,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck47,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck47,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck47,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck64,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck64,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck64,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck64,0,3] :   0.0 :   True
#     ('loc2', 'loc2', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc2,loc2,truck75,0,0] :   0.0 :   True
#     ('loc2', 'loc2', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc2,loc2,truck75,0,1] :   0.0 :   True
#     ('loc2', 'loc2', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc2,loc2,truck75,0,2] :   0.0 :   True
#     ('loc2', 'loc2', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc2,loc2,truck75,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck12,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck12,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck12,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck12,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck13,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck13,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck13,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck13,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck24,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck24,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck24,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck24,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck25,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck25,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck25,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck25,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck34,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck34,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck34,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck34,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck45,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck45,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck45,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck45,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck47,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck47,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck47,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck47,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck64,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck64,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck64,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck64,0,3] :   0.0 :   True
#     ('loc2', 'loc3', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc2,loc3,truck75,0,0] :   0.0 :   True
#     ('loc2', 'loc3', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc2,loc3,truck75,0,1] :   0.0 :   True
#     ('loc2', 'loc3', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc2,loc3,truck75,0,2] :   0.0 :   True
#     ('loc2', 'loc3', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc2,loc3,truck75,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck12,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck12,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck12,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck12,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck13,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck13,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck13,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck13,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck24', 0, 0) :  -Inf : Exp_F[loc2,loc4,truck24,0,0] - Cap_F[loc2,loc4,truck24,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck24', 0, 1) :  -Inf : Exp_F[loc2,loc4,truck24,0,1] - Cap_F[loc2,loc4,truck24,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck24', 0, 2) :  -Inf : Exp_F[loc2,loc4,truck24,0,2] - Cap_F[loc2,loc4,truck24,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck24', 0, 3) :  -Inf : Exp_F[loc2,loc4,truck24,0,3] - Cap_F[loc2,loc4,truck24,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck25,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck25,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck25,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck25,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck34,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck34,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck34,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck34,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck45,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck45,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck45,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck45,0,3] :   0.0 :   True
#     ('loc2', 'loc4', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc2,loc4,truck47,0,0] :   0.0 :   True
#     ('loc2', 'loc4', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc2,loc4,truck47,0,1] :   0.0 :   True
#     ('loc2', 'loc4', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc2,loc4,truck47,0,2] :   0.0 :   True
#     ('loc2', 'loc4', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc2,loc4,truck47,0,3] :   0.0 :   True
# ...
#     ('loc7', 'loc4', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck25,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck25,0,3] :   0.0 :   True
#     ('loc7', 'loc4', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc7,loc4,truck34,0,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc7,loc4,truck34,0,1] :   0.0 :   True
#     ('loc7', 'loc4', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck34,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck34,0,3] :   0.0 :   True
#     ('loc7', 'loc4', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc7,loc4,truck45,0,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc7,loc4,truck45,0,1] :   0.0 :   True
#     ('loc7', 'loc4', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck45,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck45,0,3] :   0.0 :   True
#     ('loc7', 'loc4', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc7,loc4,truck47,0,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc7,loc4,truck47,0,1] :   0.0 :   True
#     ('loc7', 'loc4', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck47,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck47,0,3] :   0.0 :   True
#     ('loc7', 'loc4', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc7,loc4,truck64,0,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc7,loc4,truck64,0,1] :   0.0 :   True
#     ('loc7', 'loc4', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck64,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck64,0,3] :   0.0 :   True
#     ('loc7', 'loc4', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc7,loc4,truck75,0,0] :   0.0 :   True
#     ('loc7', 'loc4', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc7,loc4,truck75,0,1] :   0.0 :   True
#     ('loc7', 'loc4', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc7,loc4,truck75,0,2] :   0.0 :   True
#     ('loc7', 'loc4', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc7,loc4,truck75,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck12,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck12,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck12,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck12,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck13,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck13,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck13,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck13,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck24,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck24,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck24,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck24,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck25,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck25,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck25,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck25,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck34,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck34,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck34,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck34,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck45,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck45,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck45,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck45,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck47,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck47,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck47,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck47,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc7,loc5,truck64,0,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc7,loc5,truck64,0,1] :   0.0 :   True
#     ('loc7', 'loc5', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc7,loc5,truck64,0,2] :   0.0 :   True
#     ('loc7', 'loc5', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc7,loc5,truck64,0,3] :   0.0 :   True
#     ('loc7', 'loc5', 'truck75', 0, 0) :  -Inf : Exp_F[loc7,loc5,truck75,0,0] - Cap_F[loc7,loc5,truck75,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck75', 0, 1) :  -Inf : Exp_F[loc7,loc5,truck75,0,1] - Cap_F[loc7,loc5,truck75,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck75', 0, 2) :  -Inf : Exp_F[loc7,loc5,truck75,0,2] - Cap_F[loc7,loc5,truck75,0] :   0.0 :   True
#     ('loc7', 'loc5', 'truck75', 0, 3) :  -Inf : Exp_F[loc7,loc5,truck75,0,3] - Cap_F[loc7,loc5,truck75,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck12,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck12,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck12,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck12,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck13,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck13,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck13,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck13,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck24,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck24,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck24,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck24,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck25,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck25,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck25,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck25,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck34,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck34,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck34,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck34,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck45,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck45,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck45,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck45,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck47,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck47,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck47,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck47,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck64,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck64,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck64,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck64,0,3] :   0.0 :   True
#     ('loc7', 'loc6', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc7,loc6,truck75,0,0] :   0.0 :   True
#     ('loc7', 'loc6', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc7,loc6,truck75,0,1] :   0.0 :   True
#     ('loc7', 'loc6', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc7,loc6,truck75,0,2] :   0.0 :   True
#     ('loc7', 'loc6', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc7,loc6,truck75,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck12', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck12,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck12', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck12,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck12', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck12,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck12', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck12,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck13', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck13,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck13', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck13,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck13', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck13,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck13', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck13,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck24', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck24,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck24', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck24,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck24', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck24,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck24', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck24,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck25', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck25,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck25', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck25,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck25', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck25,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck25', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck25,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck34', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck34,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck34', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck34,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck34', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck34,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck34', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck34,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck45', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck45,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck45', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck45,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck45', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck45,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck45', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck45,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck47', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck47,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck47', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck47,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck47', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck47,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck47', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck47,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck64', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck64,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck64', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck64,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck64', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck64,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck64', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck64,0,3] :   0.0 :   True
#     ('loc7', 'loc7', 'truck75', 0, 0) :   0.0 :                              Exp_F[loc7,loc7,truck75,0,0] :   0.0 :   True
#     ('loc7', 'loc7', 'truck75', 0, 1) :   0.0 :                              Exp_F[loc7,loc7,truck75,0,1] :   0.0 :   True
#     ('loc7', 'loc7', 'truck75', 0, 2) :   0.0 :                              Exp_F[loc7,loc7,truck75,0,2] :   0.0 :   True
#     ('loc7', 'loc7', 'truck75', 0, 3) :   0.0 :                              Exp_F[loc7,loc7,truck75,0,3] :   0.0 :   True

# %%
output_dict = dict()

# %%
scen = build_model(scen_df=scenario_dict[scenario_names[idx]]['factor'])

# %%
scen
# Out:
# scenario

# %%
model.del_component('constraint_nameplate_production_varying_capacity')
model.del_component('constraint_resource_consumption_varying')
model.del_component('constraint_export')

# %%
# Add the constraints back for this particular scenario
model.constraint_nameplate_production_varying_capacity = make_constraint(instance=model,
    type_cons=Cons.X_LEQ_BY, variable_x='P', location_set=model.locations, component_set=model.processes_varying_capacity,
    loc_comp_dict=scen.location_process_dict, b_factor=scen.capacity_factor,
                                                                            x_scale_level=scen.scheduling_scale_level,
                                                                            b_scale_level=scen.capacity_scale_level,
                                                                            y_scale_level=scen.network_scale_level,
                                                                            variable_y='Cap_P',
                                                                            label='restricts production to varying nameplate capacity')

model.constraint_resource_consumption_varying = make_constraint(
    instance=model, type_cons=Cons.X_LEQ_B, variable_x='C', location_set=model.locations,
    component_set=model.resources_varying_availability, b_max=scen.cons_max,
    loc_comp_dict=scen.location_resource_dict, b_factor=scen.availability_factor,
    x_scale_level=scen.scheduling_scale_level, b_scale_level=scen.availability_scale_level,
    label='restricts resource consumption to varying availablity')

constraint_export(instance=model, scheduling_scale_level=scen.scheduling_scale_level,
                  network_scale_level=scen.network_scale_level,
                  location_transport_resource_dict=scen.location_transport_resource_dict,
                  transport_capacity_factor=scen.transport_capacity_factor,
                  transport_capacity_scale_level=scen.transport_capacity_scale_level)
# Out:
# constraint export

# %%
model.constraint_nameplate_production_varying_capacity.pprint()
# Out:
# constraint_nameplate_production_varying_capacity : restricts production to varying nameplate capacity
#     Size=28, Index=locations*processes_varying_capacity*{0}*{0, 1, 2, 3}, Active=True
#     Key                            : Lower : Body                                                      : Upper : Active
#     ('loc1', 'com1_process', 0, 0) :  -Inf :     P[loc1,com1_process,0,0] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 1) :  -Inf :     P[loc1,com1_process,0,1] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 2) :  -Inf :     P[loc1,com1_process,0,2] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc1', 'com1_process', 0, 3) :  -Inf :     P[loc1,com1_process,0,3] - Cap_P[loc1,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 0) :  -Inf :     P[loc2,com1_process,0,0] - Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 1) :  -Inf : P[loc2,com1_process,0,1] - 0.0*Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 2) :  -Inf : P[loc2,com1_process,0,2] - 0.0*Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc2', 'com1_process', 0, 3) :  -Inf : P[loc2,com1_process,0,3] - 0.0*Cap_P[loc2,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 0) :  -Inf :     P[loc3,com1_process,0,0] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 1) :  -Inf :     P[loc3,com1_process,0,1] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 2) :  -Inf :     P[loc3,com1_process,0,2] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc3', 'com1_process', 0, 3) :  -Inf :     P[loc3,com1_process,0,3] - Cap_P[loc3,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 0) :  -Inf :     P[loc4,com1_process,0,0] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 1) :  -Inf :     P[loc4,com1_process,0,1] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 2) :  -Inf :     P[loc4,com1_process,0,2] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc4', 'com1_process', 0, 3) :  -Inf :     P[loc4,com1_process,0,3] - Cap_P[loc4,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 0) :  -Inf :     P[loc5,com1_process,0,0] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 1) :  -Inf :     P[loc5,com1_process,0,1] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 2) :  -Inf :     P[loc5,com1_process,0,2] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc5', 'com1_process', 0, 3) :  -Inf :     P[loc5,com1_process,0,3] - Cap_P[loc5,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 0) :  -Inf :     P[loc6,com1_process,0,0] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 1) :  -Inf :     P[loc6,com1_process,0,1] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 2) :  -Inf :     P[loc6,com1_process,0,2] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc6', 'com1_process', 0, 3) :  -Inf :     P[loc6,com1_process,0,3] - Cap_P[loc6,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 0) :  -Inf :     P[loc7,com1_process,0,0] - Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 1) :  -Inf : P[loc7,com1_process,0,1] - 0.0*Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 2) :  -Inf : P[loc7,com1_process,0,2] - 0.0*Cap_P[loc7,com1_process,0] :   0.0 :   True
#     ('loc7', 'com1_process', 0, 3) :  -Inf : P[loc7,com1_process,0,3] - 0.0*Cap_P[loc7,com1_process,0] :   0.0 :   True

# %%
model.Cap_P['loc1', 'com1_loc1_send',0].fix(20250.0)
model.Cap_P['loc1', 'com1_process',0].fix(20250.0)
model.Cap_P['loc1', 'procure com1',0].fix(20250.0)
model.Cap_P['loc2', 'com1_loc2_send',0].fix(20250.0)
model.Cap_P['loc2', 'com1_receive_loc1', 0].fix(20250.0)
model.Cap_P['loc3', 'com1_loc3_send', 0].fix(20250.0)
model.Cap_P['loc3', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc3', 'com1_receive_loc1', 0].fix(20250.0) 
model.Cap_P['loc4', 'com1_loc4_send', 0].fix(40500.0) 
model.Cap_P['loc4', 'com1_process', 0].fix(40500.0) 
model.Cap_P['loc4', 'com1_receive_loc3', 0].fix(20250.0) 
model.Cap_P['loc4', 'com1_receive_loc6', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_process', 0].fix(36000.0)
model.Cap_P['loc5', 'com1_receive_loc2', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_receive_loc4', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_receive_loc7', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_store', 0].fix(4500.0)
model.Cap_P['loc5', 'com1_store_discharge', 0] = 13500.0 
model.Cap_P['loc5', 'sell com1', 0].fix(36000.0)
model.Cap_P['loc6', 'com1_loc6_send', 0].fix(20250.0) 
model.Cap_P['loc1', 'com1_loc1_send', 0].fix(20250.0) 
model.Cap_P['loc1', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc1', 'procure com1', 0].fix(20250.0) 
model.Cap_P['loc2', 'com1_loc2_send', 0].fix(20250.0) 
model.Cap_P['loc2', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc2', 'com1_receive_loc1', 0].fix(20250.0) 
model.Cap_P['loc3', 'com1_loc3_send', 0].fix(20250.0) 
model.Cap_P['loc3', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc3', 'com1_receive_loc1', 0].fix(20250.0) 
model.Cap_P['loc4', 'com1_loc4_send', 0].fix(40500.0) 
model.Cap_P['loc4', 'com1_process', 0].fix(40500.0) 
model.Cap_P['loc4', 'com1_receive_loc3', 0].fix(20250.0) 
model.Cap_P['loc4', 'com1_receive_loc6', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_process', 0].fix(36000.0)
model.Cap_P['loc5', 'com1_receive_loc2', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_receive_loc4', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_receive_loc7', 0].fix(20250.0) 
model.Cap_P['loc5', 'com1_store', 0].fix(4500.0)
model.Cap_P['loc5', 'com1_store_discharge', 0] = 13500.0 
model.Cap_P['loc5', 'sell com1', 0].fix(36000.0)
model.Cap_P['loc6', 'com1_loc6_send', 0].fix(20250.0) 
model.Cap_P['loc6', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc6', 'procure com1', 0].fix(20250.0) 
model.Cap_P['loc7', 'com1_loc7_send', 0].fix(20250.0) 
model.Cap_P['loc7', 'com1_process', 0].fix(20250.0) 
model.Cap_P['loc7', 'com1_receive_loc4', 0].fix(20250.0)

model.Cap_S['loc5', 'com1_store_com1_in_stored', 0].fix(13500.0)

model.Cap_F['loc1', 'loc2', 'truck12', 0].fix(20250.0)
model.Cap_F['loc1', 'loc3', 'truck13', 0].fix(20250.0)
model.Cap_F['loc2', 'loc5', 'truck25', 0].fix(20250.0)
model.Cap_F['loc3', 'loc4', 'truck34', 0].fix(20250.0)
model.Cap_F['loc4', 'loc5', 'truck45', 0].fix(20250.0)
model.Cap_F['loc4', 'loc7', 'truck47', 0].fix(20250.0)
model.Cap_F['loc6', 'loc4', 'truck64', 0].fix(20250.0)
model.Cap_F['loc7', 'loc5', 'truck75', 0].fix(20250.0)

model.S['loc5','com1_sold',0,0].fix(36000.0)
model.S['loc5','com1_sold',0,1].fix(36000.0)
model.S['loc5','com1_sold',0,2].fix(36000.0)
model.S['loc5','com1_sold',0,3].fix(36000.0)

# %%
model.S.pprint()
# Out:
# S : Resource Dispensed/Sold
#     Size=28, Index=locations*resources_sell*scales_scheduling
#     Key                         : Lower : Value   : Upper : Fixed : Stale : Domain
#     ('loc1', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc1', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc1', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc1', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc2', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc2', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc2', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc2', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc3', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc3', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc3', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc3', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc4', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc4', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc4', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc4', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc5', 'com1_sold', 0, 0) :     0 : 36000.0 :  None :  True : False : NonNegativeReals
#     ('loc5', 'com1_sold', 0, 1) :     0 : 36000.0 :  None :  True : False : NonNegativeReals
#     ('loc5', 'com1_sold', 0, 2) :     0 : 36000.0 :  None :  True : False : NonNegativeReals
#     ('loc5', 'com1_sold', 0, 3) :     0 : 36000.0 :  None :  True : False : NonNegativeReals
#     ('loc6', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc6', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc6', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc6', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc7', 'com1_sold', 0, 0) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc7', 'com1_sold', 0, 1) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc7', 'com1_sold', 0, 2) :     0 :    None :  None : False :  True : NonNegativeReals
#     ('loc7', 'com1_sold', 0, 3) :     0 :    None :  None : False :  True : NonNegativeReals

# %%
g = SolverFactory('gurobi')

compute_infeasibility_explanation(model=model, solver=g)
# Out:
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Model was proven to be infeasible.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Model was proven to be infeasible.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Model was proven to be infeasible.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# WARNING: EXPORT Suffix 'dual' found on 1 block:
#         dual
#     LP writer cannot export suffixes to LP files.  Skipping.
# INFO: Model unknown may be infeasible. A feasible solution was found with only
# the following variable bounds relaxed:
#             lb of var P_m[loc2,com1_receive_loc2,0,0,2] by 6750.0 lb of var
#             P_m[loc7,com1_receive_loc7,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc7,0,0,3] by 15750.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc7,com1_loc4_send,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_loc4_send,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_loc4_send,0,0,3] by 2250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var Inv[loc5,com1_store_com1_in_stored,0,3] by 2250.0 lb of
#             var P_m[loc2,com1_loc1_send,0,0,2] by 20250.0 lb of var
#             P_m[loc2,com1_receive_loc2,0,0,1] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc2,com1_loc1_send,0,0,1] by 20250.0 lb of var
#             P_m[loc2,com1_loc1_send,0,0,3] by 2250.0 lb of var
#             P_m[loc7,com1_receive_loc7,0,0,2] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var S[loc2,com1_sold,0,1] by 20250.0 lb of var
#             S[loc2,com1_sold,0,2] by 6750.0 lb of var P_m[loc2,sell
#             com1,0,0,1] by 20250.0 lb of var P_m[loc2,sell com1,0,0,2] by
#             6750.0 lb of var P_m[loc2,com1_receive_loc2,0,0,3] by 15750.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var S[loc2,com1_sold,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc3_send,0,0,2] by 20250.0 lb of var P_m[loc2,sell
#             com1,0,0,3] by 2250.0 lb of var P_m[loc2,com1_receive_loc3,0,0,2]
#             by 20250.0 lb of var P_m[loc7,com1_loc6_send,0,0,1] by 20250.0 lb
#             of var P_m[loc7,com1_receive_loc6,0,0,1] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var S[loc7,com1_sold,0,1] by 20250.0 lb of var
#             S[loc7,com1_sold,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_receive_loc7,0,0,2] by 20250.0 lb of var
#             P_m[loc2,com1_loc7_send,0,0,2] by 20250.0 lb of var P_m[loc7,sell
#             com1,0,0,1] by 20250.0 lb of var P_m[loc7,sell com1,0,0,3] by
#             2250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc7,com1_loc3_send,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_loc2_send,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_loc2_send,0,0,3] by 2250.0 lb of var
#             P_m[loc7,com1_receive_loc2,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc2,0,0,3] by 2250.0 lb of var
#             P_m[loc7,com1_receive_loc3,0,0,1] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc2,com1_receive_loc7,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc6_send,0,0,2] by 20250.0 lb of var
#             P_m[loc2,com1_loc7_send,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_receive_loc6,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_loc1_send,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc1,0,0,1] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var S[loc7,com1_sold,0,2] by 20250.0 lb of var P_m[loc7,sell
#             com1,0,0,2] by 20250.0 lb of var P_m[loc7,com1_loc1_send,0,0,3] by
#             2250.0 lb of var P_m[loc7,com1_loc2_send,0,0,1] by 20250.0 lb of
#             var P_m[loc7,com1_receive_loc2,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc1,0,0,3] by 2250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc2,com1_loc3_send,0,0,1] by 20250.0 lb of var
#             P_m[loc2,com1_loc6_send,0,0,3] by 15750.0 lb of var
#             P_m[loc2,com1_receive_loc3,0,0,1] by 20250.0 lb of var
#             P_m[loc2,com1_receive_loc6,0,0,3] by 15750.0 lb of var
#             P_m[loc7,com1_loc6_send,0,0,2] by 6750.0 lb of var
#             P_m[loc7,com1_receive_loc6,0,0,2] by 6750.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc2,com1_loc3_send,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc6_send,0,0,1] by 20250.0 lb of var
#             P_m[loc2,com1_receive_loc3,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_receive_loc6,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_loc1_send,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc1,0,0,2] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P_m[loc2,com1_receive_loc7,0,0,1] by 20250.0 lb of var
#             P_m[loc2,com1_loc7_send,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_loc3_send,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_loc3_send,0,0,3] by 2250.0 lb of var
#             P_m[loc7,com1_receive_loc3,0,0,2] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc3,0,0,3] by 2250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P[loc2,com1_receive_loc5,0,1] by 2250.0 lb of var
#             P[loc5,com1_store_discharge,0,0] by 9000.0 lb of var
#             S[loc2,com1_sold,0,0] by 2250.0 lb of var
#             Inv[loc3,com1_store_com1_in_stored,0,0] by 6750.0 lb of var
#             Inv[loc5,com1_store_com1_in_stored,0,2] by 4500.0 lb of var
#             P_m[loc2,com1_loc5_send,0,0,1] by 2250.0 lb of var P_m[loc2,sell
#             com1,0,0,0] by 2250.0 lb of var P_m[loc2,com1_receive_loc5,0,0,1]
#             by 2250.0 lb of var P_m[loc5,com1_store_discharge,0,0,0] by 9000.0
#             lb of var P_m[loc7,com1_loc6_send,0,0,3] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc6,0,0,3] by 20250.0 lb of var
#             Exp_R[loc2,loc4,com1_loc2_out,0,2] by 11250.0 lb of var
#             Exp_F[loc2,loc4,truck24,0,2] by 11250.0 lb of var
#             Exp[loc2,loc4,truck24,com1_loc2_out,0,2] by 11250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P[loc2,com1_receive_loc5,0,2] by 20250.0 lb of var
#             P[loc2,com1_receive_loc5,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc5_send,0,0,2] by 20250.0 lb of var
#             P_m[loc2,com1_loc5_send,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc1_send,0,0,0] by 20250.0 lb of var
#             P_m[loc2,com1_receive_loc2,0,0,0] by 2250.0 lb of var
#             P_m[loc2,com1_receive_loc5,0,0,2] by 20250.0 lb of var
#             P_m[loc2,com1_receive_loc5,0,0,3] by 2250.0 lb of var
#             Exp_R[loc2,loc4,com1_loc2_out,0,1] by 20250.0 lb of var
#             Exp_F[loc2,loc4,truck24,0,1] by 20250.0 lb of var
#             Exp[loc2,loc4,truck24,com1_loc2_out,0,1] by 20250.0
#     Another feasible solution was found with only the following variable
#     bounds relaxed:
#             lb of var P[loc2,com1_receive_loc4,0,2] by 18000.0 lb of var
#             P[loc2,com1_receive_loc4,0,3] by 2250.0 lb of var
#             P[loc7,com1_receive_loc5,0,1] by 20250.0 lb of var
#             P[loc7,com1_receive_loc5,0,2] by 2250.0 lb of var
#             P_m[loc2,com1_receive_loc4,0,0,2] by 18000.0 lb of var
#             P_m[loc2,com1_receive_loc4,0,0,3] by 2250.0 lb of var
#             P_m[loc2,com1_loc4_send,0,0,2] by 18000.0 lb of var
#             P_m[loc2,com1_loc4_send,0,0,3] by 2250.0 lb of var
#             P_m[loc7,com1_loc5_send,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_loc5_send,0,0,2] by 2250.0 lb of var
#             P_m[loc7,com1_receive_loc7,0,0,0] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc5,0,0,1] by 20250.0 lb of var
#             P_m[loc7,com1_receive_loc5,0,0,2] by 2250.0 lb of var
#             P_m[loc7,com1_loc4_send,0,0,0] by 2250.0
#     Another feasible solution was found with only the following inequality
#     constraints and/or variable bounds relaxed:
#             constraint: constraint_nameplate_production_varying_capacity[loc2,
#             com1_process,0,1] by 15750.0 constraint: constraint_nameplate_prod
#             uction_varying_capacity[loc2,com1_process,0,2] by 11250.0
#             constraint: constraint_nameplate_production_varying_capacity[loc2,
#             com1_process,0,3] by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints and/or variable bounds relaxed:
#             constraint: constraint_nameplate_production_varying_capacity[loc7,
#             com1_process,0,1] by 11250.0 constraint: constraint_nameplate_prod
#             uction_varying_capacity[loc7,com1_process,0,2] by 15750.0
#             constraint: constraint_nameplate_production_varying_capacity[loc7,
#             com1_process,0,3] by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints and/or variable bounds relaxed:
#             constraint: constraint_nameplate_production_certain_capacity[loc5,
#             com1_receive_loc4,0,1] by 20250.0 constraint: constraint_nameplate
#             _production_certain_capacity[loc5,com1_receive_loc4,0,3] by
#             15750.0 constraint: constraint_export[loc4,loc5,truck45,0,1] by
#             20250.0 constraint: constraint_export[loc4,loc5,truck45,0,2] by
#             6750.0 constraint: constraint_export[loc4,loc5,truck45,0,3] by
#             15750.0 lb of var P_m[loc5,com1_loc4_send,0,0,2] by 6750.0
#     Another feasible solution was found with only the following inequality
#     constraints and/or variable bounds relaxed:
#             constraint:
#             constraint_nameplate_inventory[loc5,com1_store_com1_in_stored,0,0]
#             by 6750.0 constraint:
#             constraint_nameplate_inventory[loc5,com1_store_com1_in_stored,0,1]
#             by 2250.0 constraint: constraint_nameplate_production_certain_capa
#             city[loc5,com1_store,0,0] by 15750.0 constraint: constraint_namepl
#             ate_production_varying_capacity[loc2,com1_process,0,0] by 6750.0
#             lb of var P[loc2,com1_receive_loc4,0,1] by 11250.0 lb of var
#             P[loc7,com1_receive_loc5,0,3] by 15750.0 lb of var
#             S[loc7,com1_sold,0,0] by 15750.0 lb of var
#             P_m[loc2,com1_receive_loc4,0,0,1] by 11250.0 lb of var
#             P_m[loc2,com1_loc4_send,0,0,1] by 11250.0 lb of var
#             P_m[loc7,com1_loc5_send,0,0,3] by 15750.0 lb of var P_m[loc7,sell
#             com1,0,0,0] by 15750.0 lb of var P_m[loc7,com1_receive_loc5,0,0,3]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc3_out,0,2]
#             by 11250.0 constraint:
#             constraint_inventory_balance[loc5,com1_out,0,1] by 15750.0
#             constraint: constraint_inventory_balance[loc5,com1_out,0,3] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_in,0,3] by
#             15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,1]
#             by 11250.0 constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,2]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_in,0,1] by
#             11250.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc3_out,0,3] by 15750.0
#             constraint: constraint_inventory_balance[loc5,com1_pur,0,2] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,1]
#             by 2250.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc6_out,0,2] by 15750.0
#             constraint: constraint_inventory_balance[loc5,com1_pur,0,3] by
#             15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,0]
#             by 9000.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,1]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc6_out,0,3] by 15750.0
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,2]
#             by 11250.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,3]
#             by 11250.0 constraint:
#             constraint_inventory_balance[loc5,com1_out,0,2] by 15750.0
#             constraint: constraint_inventory_balance[loc5,com1_sold,0,1] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_in,0,2] by
#             15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_pur,0,1] by 11250.0
#             constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,3]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,2]
#             by 11250.0 constraint:
#             constraint_inventory_balance[loc5,com1_sold,0,3] by 15750.0
#             constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,1] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,2]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc3_out,0,1] by 11250.0
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,3]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,3]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_sold,0,2] by 15750.0
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,1]
#             by 11250.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc5,com1_loc6_out,0,1]
#             by 11250.0 constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,2] by
#             15750.0 constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,3] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,1]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc2_out,0,2] by 15750.0
#             constraint: constraint_inventory_balance[loc7,com1_out,0,3] by
#             11250.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc2,com1_out,0,1] by
#             15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc7_out,0,2] by 15750.0
#             constraint: constraint_inventory_balance[loc5,com1_loc7_out,0,3]
#             by 11250.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,3]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc2,com1_out,0,2] by 11250.0
#             constraint: constraint_inventory_balance[loc5,com1_loc7_out,0,1]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc2,com1_out,0,3] by
#             11250.0 constraint:
#             constraint_inventory_balance[loc7,com1_out,0,1] by 15750.0
#             constraint: constraint_inventory_balance[loc7,com1_out,0,2] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,2]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc2_out,0,1] by 11250.0
#             constraint: constraint_inventory_balance[loc5,com1_loc2_out,0,3]
#             by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_production_mode[loc2,com1_process,0,1] by
#             15750.0 constraint:
#             constraint_production_mode[loc2,com1_process,0,2] by 15750.0
#             constraint: constraint_production_mode[loc2,com1_process,0,3] by
#             11250.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_production_mode[loc7,com1_process,0,1] by
#             11250.0 constraint:
#             constraint_production_mode[loc7,com1_process,0,2] by 15750.0
#             constraint: constraint_production_mode[loc7,com1_process,0,3] by
#             15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_production_mode[loc5,com1_store,0,0] by
#             9000.0 constraint: constraint_nameplate_production_certain_capacit
#             y[loc5,com1_receive_loc4,0,2] by 2250.0 constraint:
#             constraint_inventory_balance[loc5,com1_in,0,0] by 9000.0
#             constraint: constraint_inventory_balance[loc5,com1_loc4_out,0,1]
#             by 15750.0 constraint:
#             constraint_inventory_balance[loc5,com1_loc4_out,0,2] by 2250.0
#             constraint: constraint_inventory_balance[loc5,com1_loc4_out,0,3]
#             by 15750.0 lb of var P_m[loc5,com1_loc4_send,0,0,1] by 15750.0 lb
#             of var P_m[loc5,com1_loc4_send,0,0,3] by 15750.0
#     Another feasible solution was found with only the following inequality
#     constraints, equality constraints, and/or variable bounds relaxed:
#             constraint: constraint_production_mode[loc5,com1_receive_loc4,0,1]
#             by 11250.0 constraint:
#             constraint_production_mode[loc5,com1_receive_loc4,0,2] by 15750.0
#             constraint: constraint_production_mode[loc5,com1_receive_loc4,0,3]
#             by 15750.0 constraint:
#             constraint_transport_export[loc4,loc5,truck45,0,1] by 11250.0
#             constraint: constraint_transport_export[loc4,loc5,truck45,0,2] by
#             15750.0 constraint:
#             constraint_transport_export[loc4,loc5,truck45,0,3] by 15750.0
#     Computed Minimal Intractable System (MIS)! Constraints / bounds in MIS:
#     Constraints / bounds in guards for stability:   lb of var
#     P_m[loc2,com1_receive_loc2,0,0,2]
#             lb of var P_m[loc7,com1_receive_loc7,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc7,0,0,3] lb of var
#             P_m[loc7,com1_loc4_send,0,0,1] lb of var
#             P_m[loc7,com1_loc4_send,0,0,2] lb of var
#             P_m[loc7,com1_loc4_send,0,0,3] lb of var
#             Inv[loc5,com1_store_com1_in_stored,0,3] lb of var
#             P_m[loc2,com1_loc1_send,0,0,2] lb of var
#             P_m[loc2,com1_receive_loc2,0,0,1] lb of var
#             P_m[loc2,com1_loc1_send,0,0,1] lb of var
#             P_m[loc2,com1_loc1_send,0,0,3] lb of var
#             P_m[loc7,com1_receive_loc7,0,0,2] lb of var S[loc2,com1_sold,0,1]
#             lb of var S[loc2,com1_sold,0,2] lb of var P_m[loc2,sell
#             com1,0,0,1] lb of var P_m[loc2,sell com1,0,0,2] lb of var
#             P_m[loc2,com1_receive_loc2,0,0,3] lb of var S[loc2,com1_sold,0,3]
#             lb of var P_m[loc2,com1_loc3_send,0,0,2] lb of var P_m[loc2,sell
#             com1,0,0,3] lb of var P_m[loc2,com1_receive_loc3,0,0,2] lb of var
#             P_m[loc7,com1_loc6_send,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc6,0,0,1] lb of var S[loc7,com1_sold,0,1]
#             lb of var S[loc7,com1_sold,0,3] lb of var
#             P_m[loc2,com1_receive_loc7,0,0,2] lb of var
#             P_m[loc2,com1_loc7_send,0,0,2] lb of var P_m[loc7,sell com1,0,0,1]
#             lb of var P_m[loc7,sell com1,0,0,3] lb of var
#             P_m[loc7,com1_loc3_send,0,0,1] lb of var
#             P_m[loc7,com1_loc2_send,0,0,2] lb of var
#             P_m[loc7,com1_loc2_send,0,0,3] lb of var
#             P_m[loc7,com1_receive_loc2,0,0,2] lb of var
#             P_m[loc7,com1_receive_loc2,0,0,3] lb of var
#             P_m[loc7,com1_receive_loc3,0,0,1] lb of var
#             P_m[loc2,com1_receive_loc7,0,0,3] lb of var
#             P_m[loc2,com1_loc6_send,0,0,2] lb of var
#             P_m[loc2,com1_loc7_send,0,0,3] lb of var
#             P_m[loc2,com1_receive_loc6,0,0,2] lb of var
#             P_m[loc7,com1_loc1_send,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc1,0,0,1] lb of var S[loc7,com1_sold,0,2]
#             lb of var P_m[loc7,sell com1,0,0,2] lb of var
#             P_m[loc7,com1_loc1_send,0,0,3] lb of var
#             P_m[loc7,com1_loc2_send,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc2,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc1,0,0,3] lb of var
#             P_m[loc2,com1_loc3_send,0,0,1] lb of var
#             P_m[loc2,com1_loc6_send,0,0,3] lb of var
#             P_m[loc2,com1_receive_loc3,0,0,1] lb of var
#             P_m[loc2,com1_receive_loc6,0,0,3] lb of var
#             P_m[loc7,com1_loc6_send,0,0,2] lb of var
#             P_m[loc7,com1_receive_loc6,0,0,2] lb of var
#             P_m[loc2,com1_loc3_send,0,0,3] lb of var
#             P_m[loc2,com1_loc6_send,0,0,1] lb of var
#             P_m[loc2,com1_receive_loc3,0,0,3] lb of var
#             P_m[loc2,com1_receive_loc6,0,0,1] lb of var
#             P_m[loc7,com1_loc1_send,0,0,2] lb of var
#             P_m[loc7,com1_receive_loc1,0,0,2] lb of var
#             P_m[loc2,com1_receive_loc7,0,0,1] lb of var
#             P_m[loc2,com1_loc7_send,0,0,1] lb of var
#             P_m[loc7,com1_loc3_send,0,0,2] lb of var
#             P_m[loc7,com1_loc3_send,0,0,3] lb of var
#             P_m[loc7,com1_receive_loc3,0,0,2] lb of var
#             P_m[loc7,com1_receive_loc3,0,0,3] lb of var
#             P[loc2,com1_receive_loc5,0,1] lb of var
#             P[loc5,com1_store_discharge,0,0] lb of var S[loc2,com1_sold,0,0]
#             lb of var Inv[loc3,com1_store_com1_in_stored,0,0] lb of var
#             Inv[loc5,com1_store_com1_in_stored,0,2] lb of var
#             P_m[loc2,com1_loc5_send,0,0,1] lb of var P_m[loc2,sell com1,0,0,0]
#             lb of var P_m[loc2,com1_receive_loc5,0,0,1] lb of var
#             P_m[loc5,com1_store_discharge,0,0,0] lb of var
#             P_m[loc7,com1_loc6_send,0,0,3] lb of var
#             P_m[loc7,com1_receive_loc6,0,0,3] lb of var
#             Exp_R[loc2,loc4,com1_loc2_out,0,2] lb of var
#             Exp_F[loc2,loc4,truck24,0,2] lb of var
#             Exp[loc2,loc4,truck24,com1_loc2_out,0,2] lb of var
#             P[loc2,com1_receive_loc5,0,2] lb of var
#             P[loc2,com1_receive_loc5,0,3] lb of var
#             P_m[loc2,com1_loc5_send,0,0,2] lb of var
#             P_m[loc2,com1_loc5_send,0,0,3] lb of var
#             P_m[loc2,com1_loc1_send,0,0,0] lb of var
#             P_m[loc2,com1_receive_loc2,0,0,0] lb of var
#             P_m[loc2,com1_receive_loc5,0,0,2] lb of var
#             P_m[loc2,com1_receive_loc5,0,0,3] lb of var
#             Exp_R[loc2,loc4,com1_loc2_out,0,1] lb of var
#             Exp_F[loc2,loc4,truck24,0,1] lb of var
#             Exp[loc2,loc4,truck24,com1_loc2_out,0,1] lb of var
#             P[loc2,com1_receive_loc4,0,2] lb of var
#             P[loc2,com1_receive_loc4,0,3] lb of var
#             P[loc7,com1_receive_loc5,0,1] lb of var
#             P[loc7,com1_receive_loc5,0,2] lb of var
#             P_m[loc2,com1_receive_loc4,0,0,2] lb of var
#             P_m[loc2,com1_receive_loc4,0,0,3] lb of var
#             P_m[loc2,com1_loc4_send,0,0,2] lb of var
#             P_m[loc2,com1_loc4_send,0,0,3] lb of var
#             P_m[loc7,com1_loc5_send,0,0,1] lb of var
#             P_m[loc7,com1_loc5_send,0,0,2] lb of var
#             P_m[loc7,com1_receive_loc7,0,0,0] lb of var
#             P_m[loc7,com1_receive_loc5,0,0,1] lb of var
#             P_m[loc7,com1_receive_loc5,0,0,2] lb of var
#             P_m[loc7,com1_loc4_send,0,0,0] constraint: constraint_nameplate_pr
#             oduction_varying_capacity[loc2,com1_process,0,1] constraint: const
#             raint_nameplate_production_varying_capacity[loc2,com1_process,0,2]
#             constraint: constraint_nameplate_production_varying_capacity[loc2,
#             com1_process,0,3] constraint: constraint_nameplate_production_vary
#             ing_capacity[loc7,com1_process,0,1] constraint: constraint_namepla
#             te_production_varying_capacity[loc7,com1_process,0,2] constraint:
#             constraint_nameplate_production_varying_capacity[loc7,com1_process
#             ,0,3] constraint: constraint_nameplate_production_certain_capacity
#             [loc5,com1_receive_loc4,0,1] constraint: constraint_nameplate_prod
#             uction_certain_capacity[loc5,com1_receive_loc4,0,3] constraint:
#             constraint_export[loc4,loc5,truck45,0,1] constraint:
#             constraint_export[loc4,loc5,truck45,0,2] constraint:
#             constraint_export[loc4,loc5,truck45,0,3] lb of var
#             P_m[loc5,com1_loc4_send,0,0,2] constraint:
#             constraint_nameplate_inventory[loc5,com1_store_com1_in_stored,0,0]
#             constraint:
#             constraint_nameplate_inventory[loc5,com1_store_com1_in_stored,0,1]
#             constraint: constraint_nameplate_production_certain_capacity[loc5,
#             com1_store,0,0] constraint: constraint_nameplate_production_varyin
#             g_capacity[loc2,com1_process,0,0] lb of var
#             P[loc2,com1_receive_loc4,0,1] lb of var
#             P[loc7,com1_receive_loc5,0,3] lb of var S[loc7,com1_sold,0,0] lb
#             of var P_m[loc2,com1_receive_loc4,0,0,1] lb of var
#             P_m[loc2,com1_loc4_send,0,0,1] lb of var
#             P_m[loc7,com1_loc5_send,0,0,3] lb of var P_m[loc7,sell com1,0,0,0]
#             lb of var P_m[loc7,com1_receive_loc5,0,0,3] constraint:
#             constraint_inventory_balance[loc5,com1_loc3_out,0,2] constraint:
#             constraint_inventory_balance[loc5,com1_out,0,1] constraint:
#             constraint_inventory_balance[loc5,com1_out,0,3] constraint:
#             constraint_inventory_balance[loc5,com1_in,0,3] constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,1]
#             constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_in,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc3_out,0,3]
#             constraint: constraint_inventory_balance[loc5,com1_pur,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc6_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_pur,0,3]
#             constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,0]
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc6_out,0,3]
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,3]
#             constraint: constraint_inventory_balance[loc5,com1_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_sold,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_in,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_pur,0,1]
#             constraint:
#             constraint_inventory_balance[loc5,com1_store_com1_in_stored,0,3]
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_sold,0,3]
#             constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc1_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc3_out,0,1]
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,3]
#             constraint: constraint_inventory_balance[loc5,com1_loc5_out,0,3]
#             constraint: constraint_inventory_balance[loc5,com1_sold,0,2]
#             constraint: constraint_inventory_balance[loc7,com1_loc7_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc6_out,0,1]
#             constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,2]
#             constraint:
#             constraint_resource_consumption_varying[loc5,com1_pur,0,3]
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc2_out,0,2]
#             constraint: constraint_inventory_balance[loc7,com1_out,0,3]
#             constraint: constraint_inventory_balance[loc2,com1_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc7_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc7_out,0,3]
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,3]
#             constraint: constraint_inventory_balance[loc2,com1_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc7_out,0,1]
#             constraint: constraint_inventory_balance[loc2,com1_out,0,3]
#             constraint: constraint_inventory_balance[loc7,com1_out,0,1]
#             constraint: constraint_inventory_balance[loc7,com1_out,0,2]
#             constraint: constraint_inventory_balance[loc2,com1_loc2_out,0,2]
#             constraint: constraint_inventory_balance[loc5,com1_loc2_out,0,1]
#             constraint: constraint_inventory_balance[loc5,com1_loc2_out,0,3]
#             constraint: constraint_production_mode[loc2,com1_process,0,1]
#             constraint: constraint_production_mode[loc2,com1_process,0,2]
#             constraint: constraint_production_mode[loc2,com1_process,0,3]
#             constraint: constraint_production_mode[loc7,com1_process,0,1]
#             constraint: constraint_production_mode[loc7,com1_process,0,2]
#             constraint: constraint_production_mode[loc7,com1_process,0,3]
#             constraint: constraint_production_mode[loc5,com1_store,0,0]
#             constraint: constraint_nameplate_production_certain_capacity[loc5,
#             com1_receive_loc4,0,2] constraint:
#             constraint_inventory_balance[loc5,com1_in,0,0] constraint:
#             constraint_inventory_balance[loc5,com1_loc4_out,0,1] constraint:
#             constraint_inventory_balance[loc5,com1_loc4_out,0,2] constraint:
#             constraint_inventory_balance[loc5,com1_loc4_out,0,3] lb of var
#             P_m[loc5,com1_loc4_send,0,0,1] lb of var
#             P_m[loc5,com1_loc4_send,0,0,3] constraint:
#             constraint_production_mode[loc5,com1_receive_loc4,0,1] constraint:
#             constraint_production_mode[loc5,com1_receive_loc4,0,2] constraint:
#             constraint_production_mode[loc5,com1_receive_loc4,0,3] constraint:
#             constraint_transport_export[loc4,loc5,truck45,0,1] constraint:
#             constraint_transport_export[loc4,loc5,truck45,0,2] constraint:
#             constraint_transport_export[loc4,loc5,truck45,0,3]

# %%
result = solve(scenario=scen, instance=model, solver='gurobi', name=scen,solver_options=solver_options)
# Out:
# Set parameter OutputFlag to value 1
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# MIPGap  0.005
# Heuristics  0.2
# QCPDual  1
#
# Optimize a model with 9763 rows, 29101 columns and 13789 nonzeros
# Model fingerprint: 0x387b25c6
# Variable types: 28520 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 7e+04]
# Presolve removed 9469 rows and 28717 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>

# %%
print(*[(key, value) for key, value in result.output['S'].items() if value], sep='\n')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 print(*[(key, value) for key, value in result.output['S'].items() if value], sep='\n')
#
# KeyError: 'S'

# %%
print(*[(key, value) for key, value in result.output['Cap_F'].items() if value], sep='\n')

# %%
print(*[(key, value) for key, value in result.output['Cap_P'].items() if value and key[0]=='loc7'], sep='\n')

# %%
print(*[(key, value) for key, value in result.output['Exp'].items() if key[0:2]==('loc3','loc4') and value is not None], sep='\n')

# %%
print(*[(key, value) for key, value in result.output['Inv'].items() if value], sep='\n')

# %%
model.constraint_export['loc3','loc4','truck34',0,0].pprint()

# %%
model.constraint_export['loc3','loc4','truck34',0,1].pprint()

# %%
model.constraint_export['loc3','loc4','truck34',0,2].pprint()

# %%
model.constraint_export['loc3','loc4','truck34',0,3].pprint()

# %%
model.constraint_nameplate_production_certain_capacity.pprint()

# %%
model.constraint_resource_consumption_varying.pprint()

# %%
model.Cap_P['loc1','procure com1',0].pprint()

# %%
print(*[(key, value) for key, value in result.output['C'].items() if key[:2]==('loc1','com1_pur')], sep='\n')

# %%
print(*[(key, value) for key, value in result.output['P'].items() if key[:2]==('loc1','procure com1')], sep='\n')

# %%
model.Cap_P['loc1','com1_loc1_send',0].pprint()

# %%
model.Cap_F['loc1','loc3','truck13',0].pprint()

# %%
model.Cap_P['loc3','com1_receive_loc1',0].pprint()

# %%
model.Cap_S.pprint()

# %%
model.Demand_penalty_network.pprint()

# %%
# Out:
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Model was proven to be infeasible.
# WARNING: log_infeasible_constraints() called with a logger whose effective
# level is higher than logging.INFO: no output will be logged regardless of
# constraint feasibility

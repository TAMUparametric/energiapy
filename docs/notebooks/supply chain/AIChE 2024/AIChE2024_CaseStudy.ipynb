# %%
import os
from pyomo.environ import *
import mpisppy.utils.sputils as sputils
from mpisppy.opt.ef import ExtensiveForm
import matplotlib.pyplot as plt
from matplotlib import rc
import sys
sys.path.append('../../../../src')
import pandas
import random
import math
import re
from itertools import product
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, ProcessMode, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport, VaryingTransport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
# from energiapy.model.constraints.demand import constraint_demand2
from energiapy.components.result import Result
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.plot import plot_results, plot_scenario, plot_location
from energiapy.model.solve import solve
from pyomo.environ import Param
from energiapy.utils.scale_utils import scale_pyomo_set
from energiapy.utils.scale_utils import scale_list, scale_tuple
from energiapy.model.constraints.constraints import make_constraint, Cons
from energiapy.model.formulate import constraint_export
from functools import reduce
import pickle
from pyomo.environ import value as pyoval
# Out:
# [    0.00] Initializing mpi-sppy

# %%
# _time_intervals = 7  # Number of time intervals in a planning horizon    (L_chi)
_exec_scenarios = 4  # Number of execution scenarios                     (chi)

M = 1e5  # Big M

# %%
def create_list(n_total: int, n: int):
    return [1] * n + [0] * (n_total - n)

# %%
def create_event_dict(n_total: int):
    default_list = [1] * n_total

    # If event names are same before '_'; they are considered mutually exclusive
    event_dict = {
        'cap2_1': {'prob': 0.05, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 1)})},
        'cap2_2': {'prob': 0.15, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 2)})},
        'cap2_3': {'prob': 0.2, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): create_list(n_total, 3)})},
        'cap2_nd': {'prob': 0.6, 'factor': pandas.DataFrame(data={('loc2', 'com1_process'): default_list})},

        'cap4_1': {'prob': 0.01, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 1)})},
        'cap4_2': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 2)})},
        'cap4_3': {'prob': 0.06, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): create_list(n_total, 3)})},
        'cap4_nd': {'prob': 0.9, 'factor': pandas.DataFrame(data={('loc4', 'com1_process'): default_list})},

        'cap7_1': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 1)})},
        'cap7_2': {'prob': 0.07, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 2)})},
        'cap7_3': {'prob': 0.1, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): create_list(n_total, 3)})},
        'cap7_nd': {'prob': 0.80, 'factor': pandas.DataFrame(data={('loc7', 'com1_process'): default_list})},

        'res1_1': {'prob': 0.02, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 1)})},
        'res1_2': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 2)})},
        'res1_3': {'prob': 0.1, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): create_list(n_total, 3)})},
        'res1_nd': {'prob': 0.85, 'factor': pandas.DataFrame(data={('loc1', 'com1_pur'): default_list})},

        'res6_1': {'prob': 0.03, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 1)})},
        'res6_2': {'prob': 0.06, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 2)})},
        'res6_3': {'prob': 0.11, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): create_list(n_total, 3)})},
        'res6_nd': {'prob': 0.8, 'factor': pandas.DataFrame(data={('loc6', 'com1_pur'): default_list})},

        'trans12_2': {'prob': 0.2, 'factor': pandas.DataFrame(data={('trans12', 'com1_loc1_out'): create_list(n_total, 2)})},
        'trans12_nd': {'prob': 0.8, 'factor': pandas.DataFrame(data={('trans12', 'com1_loc1_out'): default_list})},

        'trans25_2': {'prob': 0.3, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): create_list(n_total, 2)})},
        'trans25_nd': {'prob': 0.7, 'factor': pandas.DataFrame(data={('trans25', 'com1_loc2_out'): default_list})},
    }

    return event_dict

# %%
# def remove_scenarios(input_tuples, tuples_to_check):
#     filtered_tuples = []
# 
#     for s_tuple in input_tuples:
#         should_remove = False
# 
#         # Join the tuple elements into a single string for easier processing
#         s = ' '.join(s_tuple)
# 
#         # Loop through each tuple in the list of tuples to check
#         for tuple_group in tuples_to_check:
#             all_have_suffix_1 = True  # Assume all have '_1'
# 
#             # Loop through each element in the tuple
#             for res in tuple_group:
#                 # Build regex pattern to match occurrences like 'res1_1' exactly
#                 res_pattern = fr'{res}_1'
# 
#                 # Check if the pattern 'res_x_1' is in the joined string
#                 if not re.search(res_pattern, s):
#                     all_have_suffix_1 = False
#                     break
# 
#             # If all elements in the tuple have '_1', mark for removal
#             if all_have_suffix_1:
#                 should_remove = True
#                 break
# 
#         # If the tuple doesn't meet removal criteria, add it to the filtered list
#         if not should_remove:
#             filtered_tuples.append(s_tuple)
# 
#     return filtered_tuples

# %%
def remove_scenarios(input_tuples, tuples_to_check):
    filtered_tuples = []

    for s_tuple in input_tuples:
        should_remove = False

        # Join the tuple elements into a single string for easier processing
        s = ' '.join(s_tuple)

        # Loop through each tuple in the list of tuples to check
        for tuple_group in tuples_to_check:
            all_present = True
            any_nom = False

            # Loop through each element in the tuple
            for res in tuple_group:
                # Build regex pattern to match occurrences like 'res1_x' where x can be any number
                res_pattern = fr'{res}(_\d+)?'

                # Check if the pattern is in the joined string
                if not re.search(res_pattern, s):
                    all_present = False
                    break

                # Check if '_nom' is in the string
                if f'{res}_nd' in s:
                    any_nom = True

            # If all elements are present and none of them have '_nom', mark for removal
            if all_present and not any_nom:
                should_remove = True
                break

        # If the tuple doesn't meet removal criteria, add it to the filtered list
        if not should_remove:
            filtered_tuples.append(s_tuple)

    return filtered_tuples

# %%
# Function to generate the scenario dictionary for n sets of events
def create_scenario_dict(event_dict, remove=None):
    # Extract unique event prefixes (e.g., 'cap2', 'cap4', ...)
    event_prefixes = set(key.split('_')[0] for key in event_dict)

    # Group events by their prefixes
    grouped_events = {prefix: [key for key in event_dict if key.startswith(prefix)] for prefix in event_prefixes}

    # Create all possible combinations of events across the different groups
    filtered_event_combinations = list(product(*grouped_events.values()))
    # print(filtered_event_combinations)

    if remove is not None:
        filtered_event_combinations = remove_scenarios(filtered_event_combinations, remove)
    # print(filtered_event_combinations)

    scenario_dict = {}

    # Iterate over all event combinations
    for combination in filtered_event_combinations:
        # Construct the scenario key
        scenario_key = ' '.join(combination)

        # Calculate the probability of this scenario
        prob = 1
        combined_factor = None

        for event_key in combination:
            # Multiply probabilities
            prob *= event_dict[event_key]['prob']

            # Combine factors (assumes they are pandas DataFrames)
            if combined_factor is None:
                combined_factor = event_dict[event_key]['factor'].copy()
            else:
                combined_factor = combined_factor.add(event_dict[event_key]['factor'], fill_value=0)

        # Add to the scenario dictionary
        scenario_dict[scenario_key] = {'prob': prob, 'factor': combined_factor}
        norm_factor = sum(data['prob'] for key, data in scenario_dict.items())

        for key in scenario_dict:
            scenario_dict[key]['prob'] = scenario_dict[key]['prob']/norm_factor

    return scenario_dict

# %%
def build_model(scen_df=pandas.DataFrame()):
    default_df = pandas.DataFrame(data=[1] * _exec_scenarios)
    scale_factor = 90

    # Define temporal scales
    scales = TemporalScale(discretization_list=[1, _exec_scenarios])

    # ======================================================================================================================
    # Declare resources/commodities
    # ======================================================================================================================
    com1_pur = Resource(name='com1_pur', cons_max=225*scale_factor, block={'imp': 1, 'urg': 1}, price=0.00,
                        label='Commodity 1 consumed from outside the system',
                        varying=[VaryingResource.DETERMINISTIC_AVAILABILITY])

    com1_in = Resource(name='com1_in', label='Commodity 1 received')
    com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

    com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
    com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
    com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
    com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
    com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
    com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
    com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

    com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True,
                         label='Commodity 1 sold to outside the system')

    # ======================================================================================================================
    # Declare processes/storage capacities
    # ======================================================================================================================
    com1_process_capacity = 500*scale_factor

    # prod_max = {0: 0.25*com1_process_capacity, 1: 0.5*com1_process_capacity, 2: 0.75*com1_process_capacity, 3: 0.95*com1_process_capacity, 4: com1_process_capacity}
    # prod_min = {0: 0, 1: 0.25*com1_process_capacity, 2: 0.5*com1_process_capacity, 3: 0.75*com1_process_capacity, 4: 0.95*com1_process_capacity}
    # rate_max = {0:1.25/2, 1: 1/2, 2: 0.75/2, 3: 0.5/2, 4: 0.25/2}
    # mode_ramp = {(0,1): 5, (1,2): 5}

    com1_procure = Process(name='procure com1', prod_max=com1_process_capacity, conversion={com1_pur: -1, com1_in: 1},
                           capex=25/scale_factor, vopex=0.01, prod_min=0.01, label='Procure com1')
    com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1},
                        capex=0.1/scale_factor, vopex=0.01, prod_min=0.01, label='Sell com1')
    # com1_opt_procure = Process(name='procure optional com1', prod_max=75, conversion={com1_pur: -1, com1_in:1}, capex=10, vopex=0.1, prod_min=0.01, label='Procure optional com1')

    com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity,
                                conversion={com1_loc1_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 1')
    com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity,
                                conversion={com1_loc2_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 2')
    com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity,
                                conversion={com1_loc3_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 3')
    com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity,
                                conversion={com1_loc4_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 4')
    com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity,
                                conversion={com1_loc5_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 5')
    com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity,
                                conversion={com1_loc6_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 6')
    com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity,
                                conversion={com1_loc7_out: -1, com1_in: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                                label='Commodity 1 received from location 7')

    com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},
                           capex=5/scale_factor, vopex=0.01, prod_min=0.01, label='Process the commodity through the location',
                           varying=[VaryingProcess.DETERMINISTIC_CAPACITY])

    com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=0.5/scale_factor, vopex=0.01, storage_capex=30/scale_factor, store_min=0.01,
                         store_max=200*scale_factor, prod_min=0.01, label="Storage process", storage=com1_in, storage_cost=0.02)

    com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc1_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 1')
    com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc2_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 2')
    com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc3_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 3')
    com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc4_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 4')
    com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc5_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 5')
    com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc6_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 6')
    com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc7_out: 1}, capex=0.1/scale_factor, vopex=0.01, prod_min=0.01,
                             label='Send commodity one from location 7')

    # ======================================================================================================================
    # Declare locations/warehouses
    # ======================================================================================================================
    loc1 = Location(name='loc1',
                    processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store,
                               com1_loc1_send}, label="Location 1",
                    scales=scales, demand_scale_level=1, capacity_scale_level=1, availability_scale_level=1,
                    availability_factor={
                        com1_pur: scen_df[[('loc1', 'com1_pur')]] if ('loc1', 'com1_pur') in scen_df else default_df})

    loc2 = Location(name='loc2',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store,
                               com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=1,
                    capacity_scale_level=1, availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc2', 'com1_process')]] if ('loc2',
                                                                                           'com1_process') in scen_df else default_df})

    loc3 = Location(name='loc3',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store, com1_loc3_send},
                    label="Location 3", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1)

    loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5,
                                            com1_receive_loc7, com1_process, com1_store, com1_loc4_send},
                    label="Location 4", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc4', 'com1_process')]] if ('loc4',
                                                                                           'com1_process') in scen_df else default_df})

    loc5 = Location(name='loc5',
                    processes={com1_receive_loc2, com1_receive_loc4, com1_receive_loc7, com1_process, com1_store,
                               com1_loc5_send, com1_sell}, label="Location 5", scales=scales, demand_scale_level=1,
                    capacity_scale_level=1, availability_scale_level=1)

    loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store, com1_loc6_send},
                    label="Location 6", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    availability_factor={
                        com1_pur: scen_df[[('loc6', 'com1_pur')]] if ('loc6', 'com1_pur') in scen_df else default_df})

    loc7 = Location(name='loc7',
                    processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc7_send},
                    label="Location 7", scales=scales, demand_scale_level=1, capacity_scale_level=1,
                    availability_scale_level=1,
                    capacity_factor={com1_process: scen_df[[('loc7', 'com1_process')]] if ('loc7',
                                                                                           'com1_process') in scen_df else default_df})

    # ======================================================================================================================
    # Declare transport/trucks
    # ======================================================================================================================

    truck_cap12 = 280*scale_factor
    truck_cap13 = 270*scale_factor
    truck_cap24 = 450*scale_factor
    truck_cap25 = 270*scale_factor
    truck_cap34 = 270*scale_factor
    truck_cap45 = 500*scale_factor
    truck_cap47 = 360*scale_factor
    truck_cap64 = 450*scale_factor
    truck_cap75 = 360*scale_factor

    truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12,
                        label='Truck from location 1 to 2', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12,
    #                     label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13,
                        label='Truck from location 1 to 3', capex=0.3/scale_factor, vopex=0.03, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13,
    #                     label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=0.01)

    truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24,
                        label='Truck from location 2 to 4', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24,
    #                     label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25,
                        label='Truck from location 2 to 5', capex=0.3/scale_factor, vopex=0.03, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25,
    #                     label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=0.01)

    truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34,
                        label='Truck from location 3 to 4', capex=0.2/scale_factor, vopex=0.02, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34,
    #                     label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=0.01)

    truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45,
                        label='Truck from location 4 to 5', capex=1/scale_factor, vopex=0.1, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45,
    #                     label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=0.01)

    truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47,
                        label='Truck from location 4 to 7', capex=0.4/scale_factor, vopex=0.04, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47,
    #                     label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=0.01)

    truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64,
                        label='Truck from location 6 to 4', capex=0.5/scale_factor, vopex=0.05, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64,
    #                     label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=0.01)

    truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75,
                        label='Truck from location 7 to 5', capex=0.4/scale_factor, vopex=0.04, trans_min=0.01, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])
    # truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75,
    #                     label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=0.01)

    # ======================================================================================================================
    # Declare network
    # ======================================================================================================================

    transport_matrix = [
        [[], [truck12], [truck13], [], [], [], []],  # source: location 1
        [[], [], [], [truck24], [truck25], [], []],  # source: location 2
        [[], [], [], [truck34], [], [], []],  # source: location 3
        [[], [], [], [], [truck45], [], [truck47]],  # source: location 4
        [[], [], [], [], [], [], []],  # source: location 5
        [[], [], [], [truck64], [], [], []],  # source: location 6
        [[], [], [], [], [truck75], [], []]  # source: location 7
    ]

    # transport_matrix = [
    #     [[], [truck12], [truck13], [], [], [], []],  # source: location 1
    #     [[truck21], [], [], [truck24], [truck25], [], []],  # source: location 2
    #     [[truck31], [], [], [truck34], [], [], []],  # source: location 3
    #     [[], [truck42], [truck43], [], [truck45], [truck46], [truck47]],  # source: location 4
    #     [[], [truck52], [], [truck54], [], [], [truck57]],  # source: location 5
    #     [[], [], [], [truck64], [], [], []],  # source: location 6
    #     [[], [], [], [truck74], [truck75], [], []]  # source: location 7
    # ]

    distance_matrix = [
        [0, 55, 196, M, M, M, M],
        [55, 0, M, 163, 112, M, 134],
        [196, M, 0, 63, M, M, M],
        [M, 163, 63, 0, 95, 117, 88],
        [M, 112, M, 95, 0, M, 134],
        [M, M, M, 117, M, 0, M],
        [M, 134, M, 88, 134, M, 0]
    ]

    locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

    sources = locset
    sinks = locset

    network = Network(name='Network', scales=scales, source_locations=sources, sink_locations=sinks,
                      transport_matrix=transport_matrix, distance_matrix=distance_matrix, transport_capacity_scale_level=1,
                      transport_capacity_factor={(loc1, loc2): {truck12: scen_df[[('trans12', 'com1_loc1_out')]] if ('trans12', 'com1_loc1_out') in scen_df else default_df},
                                                 (loc1, loc3): {truck13: scen_df[[('trans13', 'com1_loc1_out')]] if ('trans13', 'com1_loc1_out') in scen_df else default_df},
                                                 (loc2, loc4): {truck24: scen_df[[('trans24', 'com1_loc2_out')]] if ('trans24', 'com1_loc2_out') in scen_df else default_df},
                                                 (loc2, loc5): {truck25: scen_df[[('trans25', 'com1_loc2_out')]] if ('trans25', 'com1_loc2_out') in scen_df else default_df},
                                                 (loc3, loc4): {truck34: scen_df[[('trans34', 'com1_loc3_out')]] if ('trans34', 'com1_loc3_out') in scen_df else default_df},
                                                 (loc4, loc5): {truck45: scen_df[[('trans45', 'com1_loc4_out')]] if ('trans45', 'com1_loc4_out') in scen_df else default_df},
                                                 (loc4, loc7): {truck47: scen_df[[('trans47', 'com1_loc4_out')]] if ('trans47', 'com1_loc4_out') in scen_df else default_df},
                                                 (loc6, loc4): {truck64: scen_df[[('trans64', 'com1_loc6_out')]] if ('trans64', 'com1_loc6_out') in scen_df else default_df},
                                                 (loc7, loc5): {truck75: scen_df[[('trans75', 'com1_loc7_out')]] if ('trans75', 'com1_loc7_out') in scen_df else default_df},
                                                 })

    # ======================================================================================================================
    # Declare scenario
    # ======================================================================================================================

    daily_demand = 400*scale_factor
    demand_penalty = 20

    demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
    demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}

    scenario = Scenario(name='scenario', scales=scales, scheduling_scale_level=1, network_scale_level=0,
                        purchase_scale_level=1, availability_scale_level=1, demand_scale_level=1,
                        capacity_scale_level=1, network=network, demand=demand_dict, demand_penalty=demand_penalty_dict,
                        label='Stochastic scenario with Multiple Locations')

    if scen_df.empty:
        # ======================================================================================================================
        # Declare problem
        # ======================================================================================================================

        problem_mincost = formulate(scenario=scenario,
                                    constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE,
                                                 Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND,
                                                 Constraints.NETWORK},
                                    demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

        scale_iter = scale_tuple(instance=problem_mincost, scale_levels=scenario.network_scale_level + 1)
        # capex_process = sum(problem_mincost.Capex_network[scale_] for scale_ in scale_iter)
        # cost_trans_capex = sum(problem_mincost.Capex_transport_network[scale_] for scale_ in scale_iter)
        
        problem_mincost.first_stage_cost = Var(within=NonNegativeReals, doc='First Stage Cost')
        
        def first_stage_cost_rule(instance):
            return (instance.first_stage_cost == sum(instance.Capex_network[scale_] for scale_ in scale_iter) + 
                                                sum(instance.Capex_transport_network[scale_] for scale_ in scale_iter))
        
        problem_mincost.constraint_first_stage_cost = Constraint(rule=first_stage_cost_rule)

        return scenario, problem_mincost

    else:
        return scenario

# %%
def build_smodel(scen_df=pandas.DataFrame()):

    scenario = build_model(scen_df)
    # ======================================================================================================================
    # Declare problem
    # ======================================================================================================================

    problem_mincost = formulate(scenario=scenario,
                                constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE,
                                             Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.DEMAND,
                                             Constraints.NETWORK},
                                demand_sign='eq', objective=Objective.COST_W_DEMAND_PENALTY)

    scale_iter = scale_tuple(instance=problem_mincost, scale_levels=scenario.network_scale_level + 1)
    # capex_process = sum(problem_mincost.Capex_network[scale_] for scale_ in scale_iter)
    # cost_trans_capex = sum(problem_mincost.Capex_transport_network[scale_] for scale_ in scale_iter)
    
    problem_mincost.first_stage_cost = Var(within=NonNegativeReals, doc='First Stage Cost')
    
    def first_stage_cost_rule(instance):
        return (instance.first_stage_cost == sum(instance.Capex_network[scale_] for scale_ in scale_iter) + 
                                            sum(instance.Capex_transport_network[scale_] for scale_ in scale_iter))
    
    problem_mincost.constraint_first_stage_cost = Constraint(rule=first_stage_cost_rule)

    return scenario, problem_mincost

# %%
def scenario_creator(scen_name, **kwargs):
    scen_dict = kwargs.get('scenario_dict')
    scen, model = build_smodel(scen_df=scen_dict[scen_name]['factor'])
    sputils.attach_root_node(model, model.first_stage_cost,
                             [model.X_P, model.Cap_P, model.X_S, model.Cap_S, model.X_F, model.Cap_F])
    model._mpisppy_probability = scen_dict[scen_name]['prob']
    return model

# %%
PI_pickle_dump_folder = r'C:\Users\shivam.vedant\PycharmProjects\energiapy\docs\notebooks\supply chain\AIChE 2024\Pickle Dump'
FD_pickle_dump_folder = r'C:\Users\shivam.vedant\PycharmProjects\energiapy\docs\notebooks\supply chain\AIChE 2024\FD Pickle Dump'

# %%
# solver_options = {
#     'MIPGap': 0.005,
#     # 'TimeLimit': 60 * 15,
#     'Heuristics': 0.20
# }
# 
# event_dict = create_event_dict(n_total=_exec_scenarios)
# scenarios_to_remove = [('res1', 'res6'), ('res1', 'cap4'), ('cap2', 'cap4'), ('trans12', 'cap4'), ('trans25', 'cap4')]
# scenario_dict = create_scenario_dict(event_dict=event_dict, remove=scenarios_to_remove)
# scenario_names = list(scenario_dict.keys())
# 
# with open('scenario_dict.pkl', 'wb') as file:
#     pickle.dump(scenario_dict, file)
# 
# print(f"Sum of probabilities of all scenarios: {sum(scenario_dict[scen]['prob'] for scen in scenario_dict):.6f}")
# print(f'Number of considered scenarios: {len(scenario_names)}')
# Out:
# Sum of probabilities of all scenarios: 1.000000
# Number of considered scenarios: 496

# %%
with open('scenario_dict.pkl', 'rb') as file:
    load_scenario_dict = pickle.load(file)

load_scenario_names = list(load_scenario_dict.keys())

# %%
# exCost_PI = 0
# results_PI = dict()
# scen_PI, model_PI = build_model()
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
# # Deterministic Scenarios for Perfect Information
# counter = 0
# PI_output_dict=dict()
# 
# for scen_name in load_scenario_names:
#     scen_PI = build_model(scen_df=load_scenario_dict[scen_name]['factor'])
#     counter+=1
#     # Delete process capacity factors, resource availability factors, transport capacity factors
#     model_PI.del_component('constraint_nameplate_production_varying_capacity')
#     model_PI.del_component('constraint_resource_consumption_varying')
#     model_PI.del_component('constraint_export')
# 
#     # Add the constraints back for this particular scenario
#     model_PI.constraint_nameplate_production_varying_capacity = make_constraint(instance=model_PI,
#         type_cons=Cons.X_LEQ_BY, variable_x='P', location_set=model_PI.locations, component_set=model_PI.processes_varying_capacity,
#         loc_comp_dict=scen_PI.location_process_dict, b_factor=scen_PI.capacity_factor,
#                                                                                 x_scale_level=scen_PI.scheduling_scale_level,
#                                                                                 b_scale_level=scen_PI.capacity_scale_level,
#                                                                                 y_scale_level=scen_PI.network_scale_level,
#                                                                                 variable_y='Cap_P',
#                                                                                 label='restricts production to varying nameplate capacity')
# 
#     model_PI.constraint_resource_consumption_varying = make_constraint(
#         instance=model_PI, type_cons=Cons.X_LEQ_B, variable_x='C', location_set=model_PI.locations,
#         component_set=model_PI.resources_varying_availability, b_max=scen_PI.cons_max,
#         loc_comp_dict=scen_PI.location_resource_dict, b_factor=scen_PI.availability_factor,
#         x_scale_level=scen_PI.scheduling_scale_level, b_scale_level=scen_PI.availability_scale_level,
#         label='restricts resource consumption to varying availablity')
# 
#     constraint_export(instance=model_PI, scheduling_scale_level=scen_PI.scheduling_scale_level,
#                       network_scale_level=scen_PI.network_scale_level,
#                       location_transport_resource_dict=scen_PI.location_transport_resource_dict,
#                       transport_capacity_factor=scen_PI.transport_capacity_factor,
#                       transport_capacity_scale_level=scen_PI.transport_capacity_scale_level)
# 
#     results_PI = solve(scenario=scen_PI, instance=model_PI, solver='gurobi', name=scen_name,
#                        solver_options=solver_options)
# 
#     print(f'######################## Finished solving {scen_name} ({counter} of {len(load_scenario_dict)}) ########################')
# 
#     model_vars = model_PI.component_map(ctype=Var)
#     vars_dict = {i: model_vars[i].extract_values() for i in model_vars.keys()}
#     obj_dict = {'objective': pyoval(model_PI.objective_cost_w_demand_penalty)}
# 
#     PI_output_dict[scen_name] = {**vars_dict, **obj_dict}
# 
#     with open(os.path.join(PI_pickle_dump_folder, scen_name+'.pkl'), 'wb') as file:
#         pickle.dump(PI_output_dict[scen_name], file)
# 
#     exCost_PI += pyoval(model_PI.objective_cost_w_demand_penalty) * load_scenario_dict[scen_name]['prob']
# Out:
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14985 nonzeros
# Model fingerprint: 0xeb9cf6c6
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9486 rows and 18343 columns
# Presolve time: 0.01s
# Presolved: 277 rows, 174 columns, 639 nonzeros
# Variable types: 124 continuous, 50 integer (50 binary)
#
# Root relaxation: objective 2.395628e+06, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2395627.5000 2395627.50  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.39563e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.395627500000e+06, best bound 2.395627500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_1 res1_nd (1 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14986 nonzeros
# Model fingerprint: 0x4513fda0
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9473 rows and 18335 columns
# Presolve time: 0.01s
# Presolved: 290 rows, 182 columns, 677 nonzeros
# Variable types: 131 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.180678e+06, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (123 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_2 res1_nd (2 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14987 nonzeros
# Model fingerprint: 0xe65236bf
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9468 rows and 18334 columns
# Presolve time: 0.01s
# Presolved: 295 rows, 183 columns, 690 nonzeros
# Variable types: 132 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.180678e+06, 118 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (118 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_3 res1_nd (3 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0x3718fbd6
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9463 rows and 18333 columns
# Presolve time: 0.01s
# Presolved: 300 rows, 184 columns, 703 nonzeros
# Variable types: 133 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.180678e+06, 124 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (124 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_nd res1_nd (4 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14987 nonzeros
# Model fingerprint: 0xb38d3d83
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9480 rows and 18341 columns
# Presolve time: 0.01s
# Presolved: 283 rows, 176 columns, 659 nonzeros
# Variable types: 126 continuous, 50 integer (50 binary)
#
# Root relaxation: objective 2.395628e+06, 98 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2395627.5000 2395627.50  0.00%     -    0s
#
# Explored 1 nodes (98 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.39563e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.395627500000e+06, best bound 2.395627500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_1 res1_nd (5 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0xae8e9c86
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9467 rows and 18333 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 184 columns, 697 nonzeros
# Variable types: 133 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.180678e+06, 124 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (124 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_2 res1_nd (6 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x74c7d040
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9459 rows and 18329 columns
# Presolve time: 0.01s
# Presolved: 304 rows, 188 columns, 717 nonzeros
# Variable types: 137 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.180678e+06, 135 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (135 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_3 res1_nd (7 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0x1b9254e9
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9451 rows and 18325 columns
# Presolve time: 0.01s
# Presolved: 312 rows, 192 columns, 737 nonzeros
# Variable types: 141 continuous, 51 integer (51 binary)
# Root relaxation: objective 2.180678e+06, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2180677.5000 2180677.50  0.00%     -    0s
#
# Explored 1 nodes (123 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.18068e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.180677500000e+06, best bound 2.180677500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_nd res1_nd (8 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14986 nonzeros
# Model fingerprint: 0xd63f3775
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9477 rows and 18337 columns
# Presolve time: 0.01s
# Presolved: 286 rows, 180 columns, 661 nonzeros
# Variable types: 129 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.393005e+06, 143 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2393005.0000 2393005.00  0.00%     -    0s
#
# Explored 1 nodes (143 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.39301e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.393005000000e+06, best bound 2.393005000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_1 res1_nd (9 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14987 nonzeros
# Model fingerprint: 0xb570e342
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9464 rows and 18329 columns
# Presolve time: 0.01s
# Presolved: 299 rows, 188 columns, 699 nonzeros
# Variable types: 136 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 117 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (117 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_2 res1_nd (10 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0x2f061c8a
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9459 rows and 18328 columns
# Presolve time: 0.01s
# Presolved: 304 rows, 189 columns, 712 nonzeros
# Variable types: 137 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 117 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (117 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_3 res1_nd (11 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x89fe600f
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9454 rows and 18327 columns
# Presolve time: 0.01s
# Presolved: 309 rows, 190 columns, 725 nonzeros
# Variable types: 138 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (136 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_nd res1_nd (12 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0xba84023d
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9471 rows and 18335 columns
# Presolve time: 0.01s
# Presolved: 292 rows, 182 columns, 681 nonzeros
# Variable types: 131 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.393005e+06, 118 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2393005.0000 2393005.00  0.00%     -    0s
#
# Explored 1 nodes (118 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.39301e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.393005000000e+06, best bound 2.393005000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_1 res1_nd (13 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x3da4424d
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9458 rows and 18327 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 190 columns, 719 nonzeros
# Variable types: 138 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 130 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (130 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_2 res1_nd (14 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0x64ab8614
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9450 rows and 18323 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 194 columns, 739 nonzeros
# Variable types: 142 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 139 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (139 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_3 res1_nd (15 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14991 nonzeros
# Model fingerprint: 0x516e8514
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9442 rows and 18319 columns
# Presolve time: 0.01s
# Presolved: 321 rows, 198 columns, 759 nonzeros
# Variable types: 146 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.179316e+06, 149 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2179316.2500 2179316.25  0.00%     -    0s
#
# Explored 1 nodes (149 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17932e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.179316250000e+06, best bound 2.179316250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_nd res1_nd (16 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14987 nonzeros
# Model fingerprint: 0x47b84c25
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9470 rows and 18333 columns
# Presolve time: 0.01s
# Presolved: 293 rows, 184 columns, 679 nonzeros
# Variable types: 133 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.381973e+06, 158 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2381972.5000 2381972.50  0.00%     -    0s
#
# Explored 1 nodes (158 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.38197e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.381972500000e+06, best bound 2.381972500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_1 res1_nd (17 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0xbb85fd5e
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9457 rows and 18325 columns
# Presolve time: 0.01s
# Presolved: 306 rows, 192 columns, 717 nonzeros
# Variable types: 140 continuous, 52 integer (52 binary)
# Root relaxation: objective 2.173343e+06, 162 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (162 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_2 res1_nd (18 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x39a8c508
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9452 rows and 18324 columns
# Presolve time: 0.01s
# Presolved: 311 rows, 193 columns, 730 nonzeros
# Variable types: 141 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.173343e+06, 162 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (162 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_3 res1_nd (19 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0xacba346d
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9447 rows and 18323 columns
# Presolve time: 0.01s
# Presolved: 316 rows, 194 columns, 743 nonzeros
# Variable types: 142 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.173343e+06, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (157 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_nd res1_nd (20 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x0f931cb5
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9464 rows and 18331 columns
# Presolve time: 0.01s
# Presolved: 299 rows, 186 columns, 699 nonzeros
# Variable types: 135 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.381973e+06, 151 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2381972.5000 2381972.50  0.00%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.38197e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.381972500000e+06, best bound 2.381972500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_1 res1_nd (21 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0xfa8a3ae3
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9451 rows and 18323 columns
# Presolve time: 0.01s
# Presolved: 312 rows, 194 columns, 737 nonzeros
# Variable types: 142 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.173343e+06, 162 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (162 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_2 res1_nd (22 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14991 nonzeros
# Model fingerprint: 0x240b2b96
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9443 rows and 18319 columns
# Presolve time: 0.01s
# Presolved: 320 rows, 198 columns, 757 nonzeros
# Variable types: 146 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.173343e+06, 128 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (128 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_3 res1_nd (23 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14992 nonzeros
# Model fingerprint: 0x3b127eda
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9435 rows and 18315 columns
# Presolve time: 0.01s
# Presolved: 328 rows, 202 columns, 777 nonzeros
# Variable types: 150 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.173343e+06, 167 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2173342.5000 2173342.50  0.00%     -    0s
#
# Explored 1 nodes (167 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.17334e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.173342500000e+06, best bound 2.173342500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_nd res1_nd (24 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14988 nonzeros
# Model fingerprint: 0xc446e2f6
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9463 rows and 18329 columns
# Presolve time: 0.01s
# Presolved: 300 rows, 188 columns, 697 nonzeros
# Variable types: 137 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.347596e+06, 132 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2347595.8333 2347595.83  0.00%     -    0s
#
# Explored 1 nodes (132 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.3476e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.347595833333e+06, best bound 2.347595833333e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_1 res1_nd (25 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14989 nonzeros
# Model fingerprint: 0x7e192908
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9450 rows and 18321 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 196 columns, 735 nonzeros
# Variable types: 144 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.144610e+06, 165 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2144610.0000 2144610.00  0.00%     -    0s
# Explored 1 nodes (165 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.14461e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.144610000000e+06, best bound 2.144610000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_2 res1_nd (26 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0x88ba6194
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9445 rows and 18320 columns
# Presolve time: 0.01s
# Presolved: 318 rows, 197 columns, 748 nonzeros
# Variable types: 145 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.144610e+06, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2144610.0000 2144610.00  0.00%     -    0s
#
# Explored 1 nodes (157 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.14461e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.144610000000e+06, best bound 2.144610000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_3 res1_nd (27 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14991 nonzeros
# Model fingerprint: 0xeb79716a
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9440 rows and 18319 columns
# Presolve time: 0.01s
# Presolved: 323 rows, 198 columns, 761 nonzeros
# Variable types: 146 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.144610e+06, 156 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2144610.0000 2144610.00  0.00%     -    0s
#
# Explored 1 nodes (156 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.14461e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.144610000000e+06, best bound 2.144610000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_nd res1_nd (28 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14990 nonzeros
# Model fingerprint: 0x063ffc29
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9457 rows and 18327 columns
# Presolve time: 0.01s
# Presolved: 306 rows, 190 columns, 717 nonzeros
# Variable types: 139 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 2.347596e+06, 127 iterations, 0.00 seconds (0.00 work units)
#
# ...
# Variable types: 155 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.924296e+06, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    1924296.2500 1924296.25  0.00%     -    0s
#
# Explored 1 nodes (150 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.9243e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.924296250000e+06, best bound 1.924296250000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_2 res1_3 (487 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14993 nonzeros
# Model fingerprint: 0xbc040577
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9431 rows and 18307 columns
# Presolve time: 0.01s
# Presolved: 332 rows, 210 columns, 791 nonzeros
# Variable types: 158 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.910768e+06, 128 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1910767.5000 1910767.50  0.00%     -    0s
#
# Explored 1 nodes (128 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.91077e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.910767500000e+06, best bound 1.910767500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_2 res1_nd (488 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14994 nonzeros
# Model fingerprint: 0xe22d2d25
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9431 rows and 18311 columns
# Presolve time: 0.01s
# Presolved: 332 rows, 206 columns, 783 nonzeros
# Variable types: 154 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.245560e+06, 120 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2245560.0000 2245560.00  0.00%     -    0s
#
# Explored 1 nodes (120 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.24556e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.245560000000e+06, best bound 2.245560000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_1 (489 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14994 nonzeros
# Model fingerprint: 0x559244ea
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9429 rows and 18308 columns
# Presolve time: 0.01s
# Presolved: 334 rows, 209 columns, 795 nonzeros
# Variable types: 157 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.972790e+06, 128 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1972790.0000 1972790.00  0.00%     -    0s
#
# Explored 1 nodes (128 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.97279e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.972790000000e+06, best bound 1.972790000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_2 (490 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14994 nonzeros
# Model fingerprint: 0xf5fc67b9
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9425 rows and 18305 columns
# Presolve time: 0.01s
# Presolved: 338 rows, 212 columns, 807 nonzeros
# Variable types: 160 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.700230e+06, 141 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1700230.0000 1700230.00  0.00%     -    0s
#
# Explored 1 nodes (141 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.70023e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.700230000000e+06, best bound 1.700230000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_3 (491 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14994 nonzeros
# Model fingerprint: 0xbc324548
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9421 rows and 18302 columns
# Presolve time: 0.01s
# Presolved: 342 rows, 215 columns, 819 nonzeros
# Variable types: 163 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.696010e+06, 141 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1696010.0000 1696010.00  0.00%     -    0s
#
# Explored 1 nodes (141 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.69601e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.696010000000e+06, best bound 1.696010000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_nd (492 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14995 nonzeros
# Model fingerprint: 0x0d7eb1cd
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9421 rows and 18306 columns
# Presolve time: 0.01s
# Presolved: 342 rows, 211 columns, 811 nonzeros
# Variable types: 159 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 2.244353e+06, 133 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2244352.5000 2244352.50  0.00%     -    0s
#
# Explored 1 nodes (133 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.24435e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.244352500000e+06, best bound 2.244352500000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_1 (493 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14995 nonzeros
# Model fingerprint: 0xa3f995ee
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9419 rows and 18303 columns
# Presolve time: 0.01s
# Presolved: 344 rows, 214 columns, 823 nonzeros
# Variable types: 162 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.971380e+06, 158 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1971380.0000 1971380.00  0.00%     -    0s
#
# Explored 1 nodes (158 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.97138e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.971380000000e+06, best bound 1.971380000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_2 (494 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14995 nonzeros
# Model fingerprint: 0x037477e0
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9415 rows and 18300 columns
# Presolve time: 0.01s
# Presolved: 348 rows, 217 columns, 835 nonzeros
# Variable types: 165 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.696655e+06, 181 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1696655.0000 1696655.00  0.00%     -    0s
#
# Explored 1 nodes (181 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.69666e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.696655000000e+06, best bound 1.696655000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_3 (495 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 14995 nonzeros
# Model fingerprint: 0x18a3487a
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Found heuristic solution: objective 2880000.0000
# Presolve removed 9411 rows and 18297 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 220 columns, 847 nonzeros
# Variable types: 168 continuous, 52 integer (52 binary)
#
# Root relaxation: objective 1.494385e+06, 114 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1494385.0000 1494385.00  0.00%     -    0s
#
# Explored 1 nodes (114 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.49439e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.494385000000e+06, best bound 1.494385000000e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_nd (496 of 496) ########################

# %%
PI_load_dict = dict()
for file in os.listdir(PI_pickle_dump_folder):
    if file.endswith('.pkl'):
        full_file_path = os.path.join(PI_pickle_dump_folder, file)
        
        with open(full_file_path, 'rb') as f:
            PI_load_dict[file.removesuffix('.pkl')] = pickle.load(f)

# %%
# print(f"Total Expected Cost considering perfect information: {exCost_PI:.4f}")
# 
# with open('exCost_PI.pkl', 'wb') as file:
#     pickle.dump(exCost_PI, file)
    
with open('exCost_PI.pkl','rb') as file:
    load_exCost_PI = pickle.load(file)
# Out:
# Total Expected Cost considering perfect information: 2026549.7304

# %%
def find_common_substring(lst):
    
    # Split each string into substrings and create sets
    substring_sets = [set(item.split()) for item in lst]
    
    # Find the intersection of all sets to get common substrings
    common_substrings = reduce(lambda a, b: a & b, substring_sets)
    
    return common_substrings

# %%
def explore_dict(d, level=0):
    indent = "    " * level  # Indentation for better readability
    for key, value in d.items():
        print(f"{indent}Key: {key}, Type of value: {type(value)}")
        if isinstance(value, dict):  # Recursively explore dictionaries
            explore_dict(value, level + 1)

# %%
def filter_scenarios():
    # Initialize the result dictionary
    result = {}
    
    # Step 1: Iterate over the original data
    for scenario, data in PI_load_dict.items():
        x_val = data['Demand_penalty_network'][('com1_sold',0)]
        obj_val = data['objective'] - data['Demand_penalty_network'][('com1_sold',0)]
        
        # Step 2: Check if x_val is already a key in the result
        if x_val not in result:
            result[x_val] = {'count': 0, 'objectives': {}}
        
        # Increment the count for the x value
        result[x_val]['count'] += 1
        
        # Step 3: Check if obj_val is already a key under the 'objectives' for this x
        if obj_val not in result[x_val]['objectives']:
            result[x_val]['objectives'][obj_val] = {'scenarios': [], 'count': 0}
        
        # Add the scenario to the list and increment the count for the objective
        result[x_val]['objectives'][obj_val]['scenarios'].append(scenario)
        result[x_val]['objectives'][obj_val]['count'] += 1
    
    # Step 4: Sort the result by x values (in decreasing order) and objectives (in decreasing order)
    sorted_result = {
        x_val: {
            'count': result[x_val]['count'],
            'count_obj': len(result[x_val]['objectives']),
            'objectives': {
                obj_val: result[x_val]['objectives'][obj_val]
                for obj_val in sorted(result[x_val]['objectives'].keys(), reverse=True)
            }
        }
        for x_val in sorted(result.keys(), reverse=True)
    }
    
    return sorted_result

# %%
def pick_scenarios(sorted_dict, n):
    selected_scenarios = {}
    total_selected = 0

    # Iterate over sorted x values
    for x_val, x_data in sorted_dict.items():
        if total_selected >= n:
            break  # Stop if we have selected enough scenarios

        # Iterate over sorted objective values within each x
        for obj_val, obj_data in x_data['objectives'].items():
            if total_selected >= n:
                break  # Stop if we have selected enough scenarios

            # Randomly select from the list of scenarios if there are multiple
            scenarios_to_choose = obj_data['scenarios']
            num_to_pick = min(len(scenarios_to_choose), 1)
            chosen_scenarios = random.sample(scenarios_to_choose, num_to_pick)

            # Add the selected scenarios to the result
            if x_val not in selected_scenarios:
                selected_scenarios[x_val] = {}
            
            if obj_val not in selected_scenarios[x_val]:
                selected_scenarios[x_val][obj_val] = {}

            for scenario in chosen_scenarios:
                selected_scenarios[x_val][obj_val][scenario] = {
                    'prob': load_scenario_dict[scenario]['prob'],
                    'factor': load_scenario_dict[scenario]['factor'].copy()
                }
                total_selected += 1

                if total_selected >= n:
                    break  # Stop if we have selected enough scenarios

    return selected_scenarios

# %%
def sum_probabilities(d):
    total_prob = 0
    
    def recursive_sum(current_dict):
        nonlocal total_prob
        for key, value in current_dict.items():
            if isinstance(value, dict):
                # Recursively traverse if it's still a dictionary
                recursive_sum(value)
            elif key == 'prob':
                # Add the probability value
                total_prob += value

    recursive_sum(d)
    return total_prob

# %%
sorted_result = filter_scenarios()

# %%
sum(data['count_obj'] for key, data in sorted_result.items())
# Out:
# 159

# %%
# Example data
n = len(list(sorted_result.keys()))
list1 = [i for i in range(1,n+1)]  # X-axis labels
list2 = [sorted_result[key]['count'] for key, data in sorted_result.items()]

# Create a bar chart
plt.bar(list1, list2)

# Add labels and title
plt.xlabel('Demand Penalty Values')
plt.ylabel('Number of Scenarios')
plt.title('Demand Penalty Value Histogram')

for i, value in enumerate(list2):
    plt.text(i+1, value, str(value), ha='center', va='bottom')

# Rotate the x-axis labels if they are too long or overlapping
plt.xticks()

# Show the plot
plt.show()

# %%
# Example data

penalty_key = list(sorted_result.keys())[0]
n = len(list(sorted_result[penalty_key]['objectives'].keys()))
obj_keys = [list(sorted_result[penalty_key]['objectives'].keys())[i] for i in range(n)]
list1 = [i for i in range(1,n+1)]  # X-axis labels
list2 = [sorted_result[penalty_key]['objectives'][obj_keys[i]]['count'] for i in range(n)]

plt.figure(figsize=(20,8))

# Create a bar chart
plt.bar(list1, list2, width = 0.5)

# Add labels and title
plt.xlabel('Scenarios')
plt.ylabel('#')
plt.title('Number of occurences')

for i, value in enumerate(list2):
    plt.text(i+1, value, str(value), ha='center', va='bottom', fontsize=13)

# Rotate the x-axis labels if they are too long or overlapping
# plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
selected_scenario_names = load_scenario_names

# %%
options = {"solver": "gurobi"}
scenario_creator_kwargs = {'scenario_dict': load_scenario_dict}
ef_UI = ExtensiveForm(options, selected_scenario_names, scenario_creator, scenario_creator_kwargs=scenario_creator_kwargs)
results = ef_UI.solve_extensive_form(solver_options=solver_options)
# Out:
# [  324.91] Initializing SPBase
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# ...
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty
# Set parameter TokenServer to value "coe-vtls1.engr.tamu.edu"
# Read LP format model from file C:\Users\SHIVAM~1.VED\AppData\Local\Temp\tmpotla4i36.pyomo.lp
# Reading time = 5.56 seconds
# x1: 5417638 rows, 3929808 columns, 8585492 nonzeros
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 5417638 rows, 3929808 columns and 8585492 nonzeros
# Model fingerprint: 0xbae66b90
# Variable types: 3641632 continuous, 288176 integer (288176 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+04]
#   Objective range  [6e-07, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+04, 5e+04]
# Presolve removed 5170782 rows and 3745958 columns
# Presolve time: 1.16s
# Presolved: 246856 rows, 183850 columns, 725640 nonzeros
# Variable types: 183785 continuous, 65 integer (65 binary)
# Found heuristic solution: objective 2880000.0000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
# Root relaxation presolved: 110052 rows, 46295 columns, 276064 nonzeros
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    16692    2.1585349e+06   0.000000e+00   1.489675e+03      5s
# Concurrent spin time: 0.74s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 2.058463e+06, 71320 iterations, 2.28 seconds (2.32 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2058463.3557 2058463.36  0.00%     -    6s
#
# Explored 1 nodes (71320 simplex iterations) in 6.35 seconds (8.52 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 2.05846e+06 2.88e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.058463355744e+06, best bound 2.058463355744e+06, gap 0.0000%

# %%
exCost_UI = ef_UI.get_objective_value()
# exCost_UI

with open(fr'{FD_pickle_dump_folder}\{len(selected_scenario_names)}\exCost_{len(selected_scenario_names)}_UI.pkl', 'wb') as file:
    pickle.dump(exCost_UI, file)
    
with open(fr'{FD_pickle_dump_folder}\{len(selected_scenario_names)}\exCost_{len(selected_scenario_names)}_UI.pkl', 'wb') as file:
    load_exCost_UI = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 exCost_UI = ef_UI.get_objective_value()
#       2 # exCost_UI
# ----> 4 with open(fr'{FD_pickle_dump_folder}\{len(selected_scenario_names)}\exCost_{len(selected_scenario_names)}_UI.pkl', 'wb') as file:
#       5     pickle.dump(exCost_UI, file)
#       7 with open(fr'{FD_pickle_dump_folder}\{len(selected_scenario_names)}\exCost_{len(selected_scenario_names)}_UI.pkl', 'wb') as file:
#
# NameError: name 'FD_pickle_dump_folder' is not defined

# %%
# exCost_UI = 2133007.7662
EVPI = load_exCost_UI - load_exCost_PI
p_inc = EVPI * 100 / load_exCost_PI
p_dec = EVPI * 100 / exCost_UI

# %%
print(f"Total Expected Cost considering perfect information: {load_exCost_PI:.4f}")
print(f"Total Expected Cost considering disruptions (stochastic solution): {load_exCost_UI:.4f}")
print(f"Expected Value of Perfect Information: {EVPI:.4f}")
print(f"Percentage Increase in Cost: {p_inc:.4f}%%")
print(f"Percentage Decrease in Cost: {p_dec:.4f}%%")
# Out:
# Total Expected Cost considering perfect information: 2026549.7304
# Total Expected Cost considering disruptions (stochastic solution): 2058463.3557
# Expected Value of Perfect Information: 31913.6254
# Percentage Increase in Cost: 1.5748%%
# Percentage Decrease in Cost: 1.5504%%

# %%
ssoln_dict = ef_UI.get_root_solution()

with open('ssoln.pkl', 'wb') as file:
    pickle.dump(ssoln_dict, file)
    
with open('ssoln.pkl', 'rb') as file:
    load_ssoln_dict = pickle.load(file)

# %% [markdown]
# # FIXED DESIGN

# %%
exCost_FD = 0
exDF_FD = 0
results_FD = dict()
scen_FD, model_FD = build_model()
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint process incidental
# constraint location capex
# constraint location fopex
# constraint storage cost
# constraint storage capex
# constraint storage cost location
# constraint storage cost network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint resource export
# constraint transport export
# constraint export
# constraint transport capex
# constraint transport network capex
# constraint transport export network
# constraint transport vopex
# constraint transport network vopex
# constraint transport fopex
# constraint transport network fopex
# constraint transport capacity UB no bin
# constraint transport capacity LB no bin
# constraint storage facility
# constraint production facility
# constraint min production facility
# constraint min storage facility
# constraint transport capacity UB
# constraint transport capacity LB
# constraint demand penalty
# constraint demand penalty location
# constraint demand penalty network
# constraint demand penalty cost
# constraint demand penalty cost location
# constraint demand penalty cost network
# objective cost w demand penalty

# %%
def fix_variables(model1: ConcreteModel, model2:ConcreteModel, scen_name:str):
    # vars_to_fix = ['X_P', 'Cap_P', 'X_S', 'Cap_S', 'X_F', 'Cap_F']
    model = getattr(model1, scen_name)
    def fix(var1, var2):
        for i in list(var1.keys()):
            if var1[i].value is None:
                continue
            else:
                var2[i].fixed = True
                var2[i] = var1[i].value
            # var2[i].pprint()
            
    fix(model.X_P, model2.X_P)
    fix(model.Cap_P, model2.Cap_P)
    fix(model.X_S, model2.X_S)
    fix(model.Cap_S, model2.Cap_S)
    fix(model.X_F, model2.X_F)
    fix(model.Cap_F, model2.Cap_F)

# %%
# Deterministic Scenarios for Fixed Design
counter = 0
FD_output_dict=dict()
fix_variables(model1=ef_UI.ef, model2=model_FD, scen_name=selected_scenario_names[0])

for scen_name in selected_scenario_names:
    scen_FD = build_model(scen_df=load_scenario_dict[scen_name]['factor'])
    counter+=1
    # Delete process capacity factors, resource availability factors, transport capacity factors
    model_FD.del_component('constraint_nameplate_production_varying_capacity')
    model_FD.del_component('constraint_resource_consumption_varying')
    model_FD.del_component('constraint_export')

    # Add the constraints back for this particular scenario
    model_FD.constraint_nameplate_production_varying_capacity = make_constraint(instance=model_FD,
        type_cons=Cons.X_LEQ_BY, variable_x='P', location_set=model_FD.locations, component_set=model_FD.processes_varying_capacity,
        loc_comp_dict=scen_FD.location_process_dict, b_factor=scen_FD.capacity_factor,
                                                                                x_scale_level=scen_FD.scheduling_scale_level,
                                                                                b_scale_level=scen_FD.capacity_scale_level,
                                                                                y_scale_level=scen_FD.network_scale_level,
                                                                                variable_y='Cap_P',
                                                                                label='restricts production to varying nameplate capacity')

    model_FD.constraint_resource_consumption_varying = make_constraint(
        instance=model_FD, type_cons=Cons.X_LEQ_B, variable_x='C', location_set=model_FD.locations,
        component_set=model_FD.resources_varying_availability, b_max=scen_FD.cons_max,
        loc_comp_dict=scen_FD.location_resource_dict, b_factor=scen_FD.availability_factor,
        x_scale_level=scen_FD.scheduling_scale_level, b_scale_level=scen_FD.availability_scale_level,
        label='restricts resource consumption to varying availablity')

    constraint_export(instance=model_FD, scheduling_scale_level=scen_FD.scheduling_scale_level,
                      network_scale_level=scen_FD.network_scale_level,
                      location_transport_resource_dict=scen_FD.location_transport_resource_dict,
                      transport_capacity_factor=scen_FD.transport_capacity_factor,
                      transport_capacity_scale_level=scen_FD.transport_capacity_scale_level)

    results_FD = solve(scenario=scen_FD, instance=model_FD, solver='gurobi', name=scen_name,
                       solver_options=solver_options)

    print(f'######################## Finished solving {scen_name} ({counter} of {len(load_scenario_dict)}) ########################')

    model_vars = model_FD.component_map(ctype=Var)
    vars_dict = {i: model_vars[i].extract_values() for i in model_vars.keys()}
    obj_dict = {'objective': pyoval(model_FD.objective_cost_w_demand_penalty)}

    FD_output_dict[scen_name] = {**vars_dict, **obj_dict}

    folder_path = r'C:\Users\shivam.vedant\PycharmProjects\energiapy\docs\notebooks\supply chain\AIChE 2024\Ext FD Pickle Dump'
    
    with open(os.path.join(folder_path, str(len(selected_scenario_names)), scen_name+'.pkl'), 'wb') as file:
        pickle.dump(FD_output_dict[scen_name], file)

    exCost_FD += pyoval(model_FD.objective_cost_w_demand_penalty) * load_scenario_dict[scen_name]['prob']
    exDF_FD += pyoval(model_FD.Demand_penalty_network[('com1_sold',0)]) * load_scenario_dict[scen_name]['prob']
# Out:
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x45b4eb3a
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9753 rows and 18500 columns
# Presolve time: 0.04s
# Presolved: 10 rows, 17 columns, 33 nonzeros
# Variable types: 17 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.410487e+06, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2410486.6667 2410486.67  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.41049e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.410486666667e+06, best bound 2.410486666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_1 res1_nd (1 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x06edd99e
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_2 res1_nd (2 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x4d6af139
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_3 res1_nd (3 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x789ef772
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_2 cap2_nd res1_nd (4 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xcb2c31b0
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9753 rows and 18500 columns
# Presolve time: 0.03s
# Presolved: 10 rows, 17 columns, 33 nonzeros
# Variable types: 17 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.410487e+06, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2410486.6667 2410486.67  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.41049e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.410486666667e+06, best bound 2.410486666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_1 res1_nd (5 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xb47a6c3c
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_2 res1_nd (6 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x6bb4f7ae
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_3 res1_nd (7 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x95d9a3c7
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.03s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_1 trans12_nd cap2_nd res1_nd (8 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x34d43ce1
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.399424e+06, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2399424.1667 2399424.17  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.39942e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.399424166667e+06, best bound 2.399424166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_1 res1_nd (9 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xe330fb5c
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_2 res1_nd (10 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xfd1bd8aa
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_3 res1_nd (11 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x2d4fddd2
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_2 cap2_nd res1_nd (12 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xbf9d6126
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9747 rows and 18491 columns
# Presolve time: 0.04s
# Presolved: 16 rows, 26 columns, 52 nonzeros
# Variable types: 26 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.399424e+06, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2399424.1667 2399424.17  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.39942e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.399424166667e+06, best bound 2.399424166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_1 res1_nd (13 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x72a96974
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_2 res1_nd (14 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x85c952b8
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_3 res1_nd (15 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x80c47710
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9746 rows and 18488 columns
# Presolve time: 0.04s
# Presolved: 17 rows, 29 columns, 58 nonzeros
# Variable types: 29 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.196647e+06, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2196646.6667 2196646.67  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.19665e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.196646666667e+06, best bound 2.196646666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_2 trans12_nd cap2_nd res1_nd (16 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x5dc324cc
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9741 rows and 18480 columns
# Presolve time: 0.03s
# Presolved: 22 rows, 37 columns, 73 nonzeros
# Variable types: 37 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.388362e+06, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2388361.6667 2388361.67  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.38836e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.388361666667e+06, best bound 2.388361666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_1 res1_nd (17 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xa24dfe31
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_2 res1_nd (18 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x27ffc2a2
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_3 res1_nd (19 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xa26f1ba1
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.04s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_2 cap2_nd res1_nd (20 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x258b9996
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9741 rows and 18480 columns
# Presolve time: 0.03s
# Presolved: 22 rows, 37 columns, 73 nonzeros
# Variable types: 37 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.388362e+06, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2388361.6667 2388361.67  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.38836e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.388361666667e+06, best bound 2.388361666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_1 res1_nd (21 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x24f0e09b
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.04s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_2 res1_nd (22 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x9638a58f
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_3 res1_nd (23 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x402e0242
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9740 rows and 18477 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 40 columns, 79 nonzeros
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.185584e+06, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2185584.1667 2185584.17  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.18558e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.185584166667e+06, best bound 2.185584166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_3 trans12_nd cap2_nd res1_nd (24 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xff0bef33
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9735 rows and 18470 columns
# Presolve time: 0.03s
# Presolved: 28 rows, 47 columns, 93 nonzeros
# Variable types: 47 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.377299e+06, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2377299.1667 2377299.17  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.3773e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.377299166667e+06, best bound 2.377299166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_1 res1_nd (25 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x73e5c634
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9734 rows and 18467 columns
# Presolve time: 0.03s
# Presolved: 29 rows, 50 columns, 99 nonzeros
# Variable types: 50 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.174522e+06, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2174521.6667 2174521.67  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.17452e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.174521666667e+06, best bound 2.174521666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_2 res1_nd (26 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xc69adc53
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9734 rows and 18467 columns
# Presolve time: 0.03s
# Presolved: 29 rows, 50 columns, 99 nonzeros
# Variable types: 50 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.174522e+06, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2174521.6667 2174521.67  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.17452e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.174521666667e+06, best bound 2.174521666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_3 res1_nd (27 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xdee88393
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9734 rows and 18467 columns
# Presolve time: 0.03s
# Presolved: 29 rows, 50 columns, 99 nonzeros
# Variable types: 50 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.174522e+06, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2174521.6667 2174521.67  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.17452e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.174521666667e+06, best bound 2.174521666667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_2 cap2_nd res1_nd (28 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x51ffa4df
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9735 rows and 18470 columns
# Presolve time: 0.03s
# Presolved: 28 rows, 47 columns, 93 nonzeros
# Variable types: 47 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.377299e+06, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2377299.1667 2377299.17  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.3773e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.377299166667e+06, best bound 2.377299166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_2 res6_1 cap4_nd cap7_nd trans12_nd cap2_1 res1_nd (29 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xd09f29b8
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9734 rows and 18467 columns
# Presolve time: 0.03s
# Presolved: 29 rows, 50 columns, 99 nonzeros
# Variable types: 50 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.174522e+06, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2174521.6667 2174521.67  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.05 seconds (0.01 work units)
# ...
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x27d42427
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9727 rows and 18456 columns
# Presolve time: 0.03s
# Presolved: 36 rows, 61 columns, 121 nonzeros
# Variable types: 61 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.967034e+06, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1967034.1667 1967034.17  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.96703e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.967034166667e+06, best bound 1.967034166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_2 res1_3 (487 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x7b607b75
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9724 rows and 18451 columns
# Presolve time: 0.03s
# Presolved: 39 rows, 66 columns, 131 nonzeros
# Variable types: 66 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.944984e+06, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1944984.1667 1944984.17  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.94498e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.944984166667e+06, best bound 1.944984166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_2 res1_nd (488 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xba0fbbeb
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9735 rows and 18470 columns
# Presolve time: 0.03s
# Presolved: 28 rows, 47 columns, 93 nonzeros
# Variable types: 47 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.297109e+06, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2297109.1667 2297109.17  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.29711e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.297109166667e+06, best bound 2.297109166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_1 (489 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x22ef4bb6
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9730 rows and 18461 columns
# Presolve time: 0.04s
# Presolved: 33 rows, 56 columns, 111 nonzeros
# Variable types: 56 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.017884e+06, 28 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2017884.1667 2017884.17  0.00%     -    0s
#
# Explored 1 nodes (28 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.01788e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.017884166667e+06, best bound 2.017884166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_2 (490 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xb33106de
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9725 rows and 18452 columns
# Presolve time: 0.03s
# Presolved: 38 rows, 65 columns, 129 nonzeros
# Variable types: 65 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.759044e+06, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1759044.1667 1759044.17  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.75904e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.759044166667e+06, best bound 1.759044166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_3 (491 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xdca95424
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9722 rows and 18447 columns
# Presolve time: 0.03s
# Presolved: 41 rows, 70 columns, 139 nonzeros
# Variable types: 70 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.737174e+06, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1737174.1667 1737174.17  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.73717e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.737174166667e+06, best bound 1.737174166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_3 res1_nd (492 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xcb2f30dc
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9735 rows and 18470 columns
# Presolve time: 0.04s
# Presolved: 28 rows, 47 columns, 93 nonzeros
# Variable types: 47 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.297109e+06, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2297109.1667 2297109.17  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.29711e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.297109166667e+06, best bound 2.297109166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_1 (493 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xa4015164
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9730 rows and 18461 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 56 columns, 111 nonzeros
# Variable types: 56 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.017884e+06, 28 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2017884.1667 2017884.17  0.00%     -    0s
#
# Explored 1 nodes (28 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 2.01788e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 2.017884166667e+06, best bound 2.017884166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_2 (494 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0x5e79890e
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9725 rows and 18452 columns
# Presolve time: 0.03s
# Presolved: 38 rows, 65 columns, 129 nonzeros
# Variable types: 65 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.759044e+06, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1759044.1667 1759044.17  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.75904e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.759044166667e+06, best bound 1.759044166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_3 (495 of 496) ########################
# constraint export
# Set parameter MIPGap to value 0.005
# Set parameter Heuristics to value 0.2
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 9763 rows, 18517 columns and 13154 nonzeros
# Model fingerprint: 0xd8d42134
# Variable types: 17936 continuous, 581 integer (581 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 4e+04]
#   RHS range        [2e+01, 5e+04]
# Presolve removed 9720 rows and 18443 columns
# Presolve time: 0.03s
# Presolved: 43 rows, 74 columns, 147 nonzeros
# Variable types: 74 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.547784e+06, 35 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1547784.1667 1547784.17  0.00%     -    0s
#
# Explored 1 nodes (35 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 1.54778e+06
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 1.547784166667e+06, best bound 1.547784166667e+06, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# ######################## Finished solving trans25_nd res6_nd cap4_nd cap7_nd trans12_nd cap2_nd res1_nd (496 of 496) ########################

# %%
final_results_dict = {len(selected_scenario_names): {'Expected Cost UI': exCost_UI,
                                            'Expected Cost FD': exCost_FD,
                                            'Expected Resilience': 1- exDF_FD/(20*400*90*4)}}
    
with open(os.path.join(folder_path, str(len(selected_scenario_names)),'FD_final_results.pkl'), 'wb') as file:
    pickle.dump(final_results_dict, file)

# %%
final_results_dict
# Out:
# {496: {'Expected Cost UI': 2058463.3557439938,
#   'Expected Cost FD': 2058463.3422047312,
#   'Expected Resilience': 0.9926811262189826}}

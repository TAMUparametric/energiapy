# %% [markdown]
# # Paramter Bound
#
# A parameter bound sets a limit on a decision or derived variable.
#
# If bounding a set of variables, this bound is the vector $\mathrm{P}$

# %%
from energia import *

# %% [markdown]
# Bounds can be provided as attributes

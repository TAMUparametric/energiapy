# %%
import sys 
sys.path.append('../src')

# %%
#at the given temporal scale 
flt = 0.5 # single value, held constant, x = flt 
tpl = (1.5, 3.5) # domain of parameter, x >= 1.5 and x <= 3.5 or x in {1.5, 3.5} 
tpltpl = ((1.5, 2), (3.5, 4)) # domain of lb and ub  
lst = [1.5, 3.5, 2.5, 1, 2]
tpllst = ([1.5, 3.5, 2.5, 1, 2], 4)
tpltpllst = (([1.5, 3.5, 2.5, 1, 2], 4), (1, [2.5, 3, 2]))

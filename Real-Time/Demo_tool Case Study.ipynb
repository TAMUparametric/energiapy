# %% [markdown]
# # Real-time carbon accounting and material transition for hydrogen systems

# %% [markdown]
# __author__ = "Marco De Sousa"
# __copyright__ = "Copyright 2023, Multi-parametric Optimization & Control Lab"
# __credits__ = ["Marco De Sousa", "Rahul Kakodkar", "Efstratios N. Pistikopoulos"]
# __license__ = "MIT"
# __version__ = "1.1.0"
# __maintainer__ = "Marco De Sousa"
# __email__ = "marcopdsousa@tamu.edu"
# __status__ = "Production"

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### The following problem consists over four hydrogen production technologies:
#
# (i) Steam Methane Reforming w\wo CCS
#
# (ii) Autothermal Reforming w\wo CCS
#
# (iii) Proton Exchange Membrane Electrolyzer
#
# (iv) Alkaline Water Electrolyzer
#
# ### These hydrogen systems can be powered by three different power suppliers:
#
# (i) Large Grid Supplier with no capacity on production
#
# (ii) Power Purchase Agreements with a supplier utilizing only solar farms
#
# (iii) Power Purchase Agreements with a supplier utilizing only wind farms

# %% [markdown]
# ## Nomenclature
#
# SMR - Steam Methane Reformer
#
# ATR - Autothermal Reformer
#
# PEM - Proton Exchange Membrane
#
# AWE - Alkaline Water Electrolyzer
#
# CCS - Carbon Capture and Storage
#
# PPA - Power Purchase Agreement

# %% [markdown]
# ## MILP Formulation

# %% [markdown]
# ## Import Modules

# %%
import sys
sys.path.append('../src')

# %%
import pandas as pd
import numpy
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource, Scope
from energiapy.components.process import Process, VaryingProcess
from energiapy.components.material import Material
from energiapy.components.location import Location
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
from energiapy.components.transport import Transport
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.utils.nsrdb_utils import fetch_nsrdb_data
from energiapy.plot import plot_results, plot_scenario
from energiapy.plot.plot_results import CostY, CostX
from energiapy.model.solve import solve
from itertools import product
from energiapy.components.result import Result
from itertools import product
from matplotlib import rc
import matplotlib.pyplot as plt
from energiapy.model.solve import solve
from energiapy.plot.plot_results import CostY, CostX
from energiapy.components.location import Location
from energiapy.plot import plot_results, plot_scenario
from energiapy.utils.nsrdb_utils import fetch_nsrdb_data
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.model.bounds import CapacityBounds
from energiapy.utils.data_utils import get_data, make_henry_price_df, remove_outliers, load_results
from energiapy.conversion.photovoltaic import solar_power_output
from energiapy.conversion.windmill import wind_power_output
from energiapy.model.constraints.integer_cuts import constraint_block_integer_cut, constraint_block_integer_cut_min

# %% [markdown]
# ## Setting up our time horizon and our time discretization

# %% [markdown]
# We set our horizon for one day which represents one day into the future

# %%
horizon = 1

# %% [markdown]
# We discretize our temporal scale of one day into 24 hours

# %%
scales = TemporalScale(discretization_list=[1, 24])

# %% [markdown]
# We utilize the Big M formulation within our model

# %%
bigM = 10**8
smallM = 0.001

# %% [markdown]
# ## Introducing our historical data into the model

# %% [markdown]
# ### Hourly electricity prices of the grid supplier

# %%
elec_price_df = pd.read_csv('C:/Users/marcopdsousa/Documents/energiapy/Real-Time/Dataset/RT 20 AUGUST 2024.csv')
elec_price_df = elec_price_df[['DAM Houston']].reset_index(drop = True)[:24]

# %% [markdown]
# ### Hourly natural gas prices available for purchase on an hourly time scale

# %%
#The natural gas price is calculated as the average between the high and low cost, also the unit used is $/kg of natural gas
NG_price_df = pd.read_csv('C:/Users/marcopdsousa/Documents/energiapy/Real-Time/Dataset/RT 20 AUGUST 2024.csv')
# NG_price_df = pd.DataFrame(NG_price_df['USD/kg'])[::-1].reset_index()
NG_price_df = NG_price_df[['NG_Price']][:24]
# NG_price_df

# %% [markdown]
# ### Introducing a time varying emission factor of the grid supplier, as the grid mix adapts, the carbon intensity changes as well

# %%
GWP_df = pd.read_csv('C:/Users/marcopdsousa/Documents/energiapy/Real-Time/Dataset/RT 20 AUGUST 2024.csv')
GWP_df = GWP_df[['GWP']]
GWP_df = GWP_df[:24].reset_index(drop = True)
# GWP_df

# %% [markdown]
# ### Noting the maximum values observed of the three respective datasets

# %%
elec_price = elec_price_df.max().iloc[0]
NG_price = NG_price_df.max().iloc[0]
GWP_value = GWP_df.max().iloc[0]

# %% [markdown]
# ### Wind availability for power generation through the wind powered PPA

# %%
Wind_df = pd.read_csv('C:/Users/marcopdsousa/Documents/energiapy/Real-Time/Dataset/RT 20 AUGUST 2024.csv')
Wind_df = Wind_df[['WGRPP_HO']][:24]

# %% [markdown]
# ### Solar availability for power generation through the solar powered PPA

# %%
Solar_df = pd.read_csv('C:/Users/marcopdsousa/Documents/energiapy/Real-Time/Dataset/RT 20 AUGUST 2024.csv')
Solar_df = Solar_df[['PVGRPP_HO']][:24]

# %% [markdown]
# ## Declare Resources - Here we define all resource flow in and out of the system

# %%
# We start off with our energy generating resources

Solar = Resource(name='Solar', cons_max=bigM, basis='MW', label='Solar Power', price= 52.69, gwp=0, scope=Scope.TWO)

Wind = Resource(name='Wind', cons_max=bigM, basis='MW', label='Wind Power', price= 60.11, gwp=0, scope=Scope.TWO)

GridPower = Resource(name='GridPower', basis='MW',
                     cons_max=bigM, label='Power bought', gwp= GWP_value, price =elec_price ,varying = [VaryingResource.DETERMINISTIC_PRICE, VaryingResource.DETERMINISTIC_GWP], scope = Scope.TWO)

# Power is the universal resource that the above three equate to, this will be the standardized resource for energy 

Power = Resource(name='Power', basis='MW',
                 label='Power generated')

#----------------------------------------------------------------------------------------------------------------------------

# Below are the different carbon dioxide resources that are used in the process

CO2 = Resource(name='CO2', basis='kg/hr',
               label='Carbon dioxide', block='Resource')

CO2_Stack = Resource(name='CO2 to Stack', basis='kg/hr', sell=True,
               label='Carbon dioxide to Stack', block='Resource', gwp = 1, scope = Scope.ONE)

CO2_Air = Resource(name='CO2 from air', basis='kg/hr',
               label='Carbon dioxide from air', block='Resource', cons_max=bigM)

CO2_Vent = Resource(name='CO2 Vented from the process', basis='kg/hr',
               label='Carbon dioxide vented from the process', block='Resource', gwp = 1, sell=True, scope = Scope.ONE)

CO2cpt = Resource(name='CO2 Captured', basis='kg/hr', sell=True, label='Captured carbon dioxide', block='Resource')

CO2_Blowdown= Resource(name='CO2 Blowdown', basis='kg/hr', block='Resource', sell = True, gwp = 1) 

#----------------------------------------------------------------------------------------------------------------------------



#----------------------------------------------------------------------------------------------------------------------------

# Hydrogen is what I want to sell/satisfy a specific demand for

H2 = Resource(name='Hydrogen', basis='kg/hr', label='Hydrogen', block='Resource')

H2Pure = Resource(name='Pure Hydrogen', demand = True, basis='kg/hr', label='Pure Hydrogen', block='Resource')

#----------------------------------------------------------------------------------------------------------------------------

# Water that is required for electrolyzer process, also not that there are different sources of water that are used in the process

H2O = Resource(name='H2O',
               basis='kg/hr', cons_max=bigM, label='Water', block='Resource')

#Industrial water price is 0.002 USD/kg of water
H2OFresh = Resource(name="H2O Fresh", cons_max=bigM, price = 0.002, basis='kg/hr', label='Fresh Water', block='Resource')

H2O_Air = Resource(name='H2O from air', cons_max=bigM,
               basis='kg/hr', label='Water from air', block='Resource')

H2O_Vent = Resource(name='H2O vented from the process',
               basis='kg/hr', sell=True, label='Water vented from the process', block='Resource')


H2O_Stack = Resource(name='H2O to Stack',
               basis='kg/hr', sell= True, label='Water to Stack', block='Resource')

H2O_Vent_ASU = Resource(name='H2O Vent from ASU',
               basis='kg/hr', sell= True, label='Water vented from ASU', block='Resource')

H2O_Blowdown = Resource(name='H2O in Blowdown',
               basis='kg/hr', sell= True, label='H2O present in air - Stream 5', block='Resource') 


#----------------------------------------------------------------------------------------------------------------------------

# Air components

N2 = Resource(name='N2', basis='kg/hr',
               label='Nitrogen', block='Resource')

N2_SMR = Resource(name='N2 from SMR', basis='kg/hr',
               label='Nitrogen from SMR', block='Resource')

N2_WGS = Resource(name='N2 from WGS', basis='kg/hr',
               label='Nitrogen from WGS', block='Resource')

N2_FG = Resource(name='N2 from FG', basis='kg/hr',
               label='Nitrogen from FG', block='Resource')

N2_Air = Resource(name='N2 from Air', basis='kg/hr', cons_max= bigM,
               label='Nitrogen from Air', block='Resource')

N2_Vent = Resource(name='N2 vented from the process', basis='kg/hr', sell= True,
               label='Nitrogen vented from the process', block='Resource')

N2Prod = Resource(name='N2 in product stream', basis='kg/hr', sell = True,
               label='Nitrogen in product stream', block='Resource')

N2_Stack = Resource(name='N2 to Stack', basis='kg/hr', sell= True,
               label='Nitrogen to stack', block='Resource')

N2_Desorped = Resource(name='N2 Desorped', basis='kg/hr', sell = True,
               label='Nitrogen in CO2 desorption stream', block='Resource')

N2_Vented_Stack = Resource(name='N2 in Stack', basis='kg/hr', sell = True,
               label='Nitrogen in Stack', block='Resource')

N2_Blowdown = Resource(name='N2 in Blowdown', basis='kg/hr', sell = True,
               label='Nitrogen in Blowdown stream', block='Resource') 

O2 = Resource(name='O2', basis='kg/hr',
               label='Oxygen', block='Resource')

O2_Air = Resource(name='O2 from air', basis='kg/hr',
               label='Oxygen from air', block='Resource', cons_max = bigM)

O2_Vent = Resource(name='O2 vented from the process', basis='kg/hr', sell=True,
               label='Oxygen vented from the process', block='Resource')

O2_Stack = Resource(name='O2 to Stack', basis='kg/hr', sell= True,
               label='Oxygen to Stack', block='Resource')

O2_Desorped = Resource(name='O2 Desorped', basis='kg/hr',
               label='Oxygen in CO2 desorption stream', block='Resource')

O2_ASU = Resource(name='O2 vented out of ASU', basis='kg/hr', sell = True,
               label='O2 vented out of ASU', block='Resource')

O2_Blowdown = Resource(name='O2 in Blowdown', basis='kg/hr',
               label='O2 in Blowdown stream', block='Resource')

#----------------------------------------------------------------------------------------------------------------------------

CH4 = Resource(name='CH4', basis='kg/hr', label='Methane', block='Resource')

NG = Resource(name='Natural Gas', basis='kg/hr', cons_max=bigM, label='Natural Gas', gwp = 0.660979, price = NG_price, varying = [VaryingResource.DETERMINISTIC_PRICE])

CH4_Desorped = Resource(name='CH4_Desorped', basis='kg/hr', label='Methane', block='Resource')

# %% [markdown]
# ## Declare Processes - Here we define the processes that generate power, produce hydrogen, capture carbon, etc.

# %%
'''Purchasing electricity from a traditional power production system'''

Grid = Process(name='Grid', conversion={GridPower: -1, Power: 1}, prod_min=smallM, prod_max=bigM, label='Grid', basis='MW')

PV = Process(name='PV', conversion={Solar: -1, Power: 1},
             prod_max=100, prod_min=100,  varying= [VaryingProcess.DETERMINISTIC_CAPACITY], label='Solar PV', basis='MW')


WF = Process(name='WF', conversion={Wind: -1, Power: 1},
             prod_max=300, prod_min=300, label='Wind mill array', varying=[VaryingProcess.DETERMINISTIC_CAPACITY], basis='MW')


SMR = Process(name='SMR', conversion={Power: -0.00065, NG: -3.535189, H2OFresh: -16.78877421, N2_Air: -19.2134, O2_Air: -5.88716, H2O_Air: -0.1582, CO2_Air: -0.01171, 
                                            H2Pure: 1, CO2_Stack: 9.3713,  H2O_Stack: 3.94959, N2_Stack: 19.29814, O2_Stack: 0.535434}, capex=0.0001,
               vopex=0.84, fopex=0.001, prod_min=smallM, prod_max=20000, label='SMR', basis='kg/hr')

#The CCS system that can be utilized in tandem with the SMR technology

SMRCCS = Process(name='SMRCCS', conversion={Power: -0.00139, N2_Air: -22.2315, O2_Air: -6.811924, H2O_Air: -0.183055, CO2_Air: -0.013551, CO2_Stack: -9.3713,
                                             H2O_Vent: 3.826767, CO2cpt: 8.903, CO2_Vent: 0.46856, H2O_Stack: 0.558114, N2_Stack: 22.32218, O2_Stack: 0.6203032, }, capex=0.0001,
                vopex=1.1, fopex=0.001, prod_min=smallM, prod_max=bigM, label='SMRCCS', basis='kg/hr')


PEM = Process(name='PEM', conversion={Power: -0.064, H2OFresh: -9.5, H2Pure: 1}, capex=0.0001,vopex=3.73, fopex=0.001, prod_min=smallM, prod_max=18.75, label='PEM', basis='kg/hr')

# %% [markdown]
# ### Declare Process Set - Here include every process that needs to be considered within the optimization model

# %%
process_set = {Grid, PV, WF, SMRCCS, PEM, SMR}

# %% [markdown]
# ### Declare Location - Here we define which location the case study is carried out in, in this example we used the historical data from the Houston, TX region.

# %%
houston = Location(name='HO', processes=process_set,  price_factor={GridPower: elec_price_df, NG: NG_price_df}, gwp_factor={GridPower: GWP_df}, capacity_factor={PV: Solar_df, WF: Wind_df},
                   scales=scales, label='Houston', expenditure_scale_level=0, demand_scale_level=0, price_scale_level=1, gwp_scale_level = 1, capacity_scale_level=1)

# %% [markdown]
# ### Declare Scenario - This is done after defining our location, now we set the demand for our Hydrogen product. If facing a multi-locational problem we would setup a network of different defined locations

# %%
scenario = Scenario(name='scenario_full', network=houston, scales=scales,  expenditure_scale_level=0, demand_scale_level=0, 
                    purchase_scale_level = 1, scheduling_scale_level=1, network_scale_level=0, capacity_scale_level=1, gwp_scale_level = 1, 
                    label='full_case', demand={houston: {H2Pure:240000}})

# %% [markdown]
# The following is to visualize to changing electricity prices and emission factor of the Grid supplier in Houston which is known as ERCOT. Additional visualizations are made for varying natural gas prices and renewable availability

# %%
plot_scenario.price_factor(
    scenario=scenario, location=houston, resource=GridPower, fig_size=(9, 5), color='black')

# %%
plot_scenario.gwp_factor(
    scenario=scenario, location=houston, resource=GridPower, fig_size=(9, 5), color='midnightblue')

# %%
plot_scenario.price_factor(
    scenario=scenario, location=houston, resource=NG, fig_size=(9, 5), color='blue')

# %%
plot_scenario.capacity_factor(
    scenario=scenario, location=houston, process=PV, fig_size=(9, 5), color='red')

# %%
plot_scenario.capacity_factor(
    scenario=scenario, location=houston, process=WF, fig_size=(9, 5), color='green')

# %% [markdown]
# ## Formulate MILP

# %% [markdown]
# The problem is formulated below with the objective to minimize overall cost

# %%
#, Constraints.MODE

milp_cost = formulate(scenario=scenario, constraints={Constraints.COST, Constraints.INVENTORY, Constraints.PRODUCTION,
                      Constraints.RESOURCE_BALANCE, Constraints.DEMAND, Constraints.EMISSION}, objective=Objective.COST, demand_sign = 'eq')
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost

# %% [markdown]
# ### Ramping constratints are added to both SMR and ATR Technologies

# %%
# #model.component

from pyomo.environ import ConstraintList

ramping_limit = 1000

milp_cost.cons2 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons2.add(expr = milp_cost.P['HO', 'SMR', *i] - milp_cost.P['HO', 'SMR', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limit)

milp_cost.cons3 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons3.add(expr = milp_cost.P['HO', 'SMR', *i] - milp_cost.P['HO', 'SMR', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limit)

# %%
from pyomo.environ import ConstraintList



ramping_limitATR = 2000

milp_cost.cons4 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons4.add(expr = milp_cost.P['HO', 'ATR_CCS_R', *i] - milp_cost.P['HO', 'ATR_CCS_R', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitATR)

milp_cost.cons5 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons5.add(expr = milp_cost.P['HO', 'ATR_CCS_R', *i] - milp_cost.P['HO', 'ATR_CCS_R', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitATR)

milp_cost.cons6 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons6.add(expr = milp_cost.P['HO', 'ATR_CCS_OC', *i] - milp_cost.P['HO', 'ATR_CCS_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitATR)

milp_cost.cons7 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons7.add(expr = milp_cost.P['HO', 'ATR_CCS_OC', *i] - milp_cost.P['HO', 'ATR_CCS_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitATR)        

milp_cost.cons8 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons8.add(expr = milp_cost.P['HO', 'ATR_CCS_R_OC', *i] - milp_cost.P['HO', 'ATR_CCS_R_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitATR)

milp_cost.cons9 = ConstraintList()
for i in scales.scale_iter(1):
    if i != (0,0):
        milp_cost.cons9.add(expr = milp_cost.P['HO', 'ATR_CCS_R_OC', *i] - milp_cost.P['HO', 'ATR_CCS_R_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitATR)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 10
#       8 for i in scales.scale_iter(1):
#       9     if i != (0,0):
# ---> 10         milp_cost.cons4.add(expr = milp_cost.P['HO', 'ATR_CCS_R', *i] - milp_cost.P['HO', 'ATR_CCS_R', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitATR)
#      12 milp_cost.cons5 = ConstraintList()
#      13 for i in scales.scale_iter(1):
#
# File c:\Users\marcopdsousa\Documents\energiapy\.venv\Lib\site-packages\pyomo\core\base\var.py:999, in IndexedVar.__getitem__(self, args)
#     997 def __getitem__(self, args) -> VarData:
#     998     try:
# --> 999         return super().__getitem__(args)
#    1000     except RuntimeError:
#    1001         tmp = args if args.__class__ is tuple else (args,)
#
# File c:\Users\marcopdsousa\Documents\energiapy\.venv\Lib\site-packages\pyomo\core\base\indexed_component.py:648, in IndexedComponent.__getitem__(self, index)
#     646 if isinstance(index, EXPR.GetItemExpression):
#     647     return index
# --> 648 validated_index = self._validate_index(index)
#     649 if validated_index is not index:
#     650     index = validated_index
#
# File c:\Users\marcopdsousa\Documents\energiapy\.venv\Lib\site-packages\pyomo\core\base\indexed_component.py:870, in IndexedComponent._validate_index(self, idx)
#     863     raise KeyError(
#     864         "Cannot treat the scalar component '%s' "
#     865         "as an indexed component" % (self.name,)
#     866     )
#     867 #
#     868 # Raise an exception
#     869 #
# --> 870 raise KeyError(
#     871     "Index '%s' is not valid for indexed component '%s'"
#     872     % (normalized_idx, self.name)
#     873 )
#
# KeyError: "Index '('HO', 'ATR_CCS_R', 0, 1)' is not valid for indexed component 'P'"

# %%
results_cost = solve(scenario=scenario, instance=milp_cost,
                     solver='gurobi', name=f"res_cost", print_solversteps=True, saveformat = '.pkl')
# Out:
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3205 rows, 17217 columns and 8757 nonzeros
# Model fingerprint: 0x5c362205
# Coefficient statistics:
#   Matrix range     [1e-04, 4e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2896 rows and 16956 columns
# Presolve time: 0.01s
# Presolved: 309 rows, 353 columns, 1272 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0354964e+05   2.361350e+05   0.000000e+00      0s
#      146    3.1599812e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 146 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.159981223e+05

# %% [markdown]
# Cost Objective:

# %%
results_cost.output['objective']
# Out:
# 315998.12234188966

# %% [markdown]
# Global Warming Potential:

# %%
results_cost.output['global_warming_potential_location']
# Out:
# {('HO', 0): 757128.8793809505}

# %% [markdown]
# Global Warming Potential from different resources:

# %%
results_cost.output['global_warming_potential_resource']
# Out:
# {('HO', 'CO2 Blowdown', 0, 0): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 1): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 2): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 3): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 4): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 5): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 6): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 7): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 8): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 9): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 10): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 11): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 12): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 13): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 14): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 15): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 16): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 17): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 18): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 19): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 20): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 21): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 22): 0.0,
#  ('HO', 'CO2 Blowdown', 0, 23): 0.0,
#  ('HO', 'CO2 Captured', 0, 0): 0.0,
#  ('HO', 'CO2 Captured', 0, 1): 0.0,
#  ('HO', 'CO2 Captured', 0, 2): 0.0,
#  ('HO', 'CO2 Captured', 0, 3): 0.0,
#  ('HO', 'CO2 Captured', 0, 4): 0.0,
#  ('HO', 'CO2 Captured', 0, 5): 0.0,
#  ('HO', 'CO2 Captured', 0, 6): 0.0,
#  ('HO', 'CO2 Captured', 0, 7): 0.0,
#  ('HO', 'CO2 Captured', 0, 8): 0.0,
#  ('HO', 'CO2 Captured', 0, 9): 0.0,
#  ('HO', 'CO2 Captured', 0, 10): 0.0,
#  ('HO', 'CO2 Captured', 0, 11): 0.0,
#  ('HO', 'CO2 Captured', 0, 12): 0.0,
#  ('HO', 'CO2 Captured', 0, 13): 0.0,
#  ('HO', 'CO2 Captured', 0, 14): 0.0,
#  ('HO', 'CO2 Captured', 0, 15): 0.0,
#  ('HO', 'CO2 Captured', 0, 16): 0.0,
#  ('HO', 'CO2 Captured', 0, 17): 0.0,
#  ('HO', 'CO2 Captured', 0, 18): 0.0,
#  ('HO', 'CO2 Captured', 0, 19): 0.0,
#  ('HO', 'CO2 Captured', 0, 20): 0.0,
#  ('HO', 'CO2 Captured', 0, 21): 0.0,
#  ('HO', 'CO2 Captured', 0, 22): 0.0,
#  ('HO', 'CO2 Captured', 0, 23): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 0): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 1): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 2): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 3): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 4): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 5): 9145.53204,
#  ('HO', 'CO2 Vented from the process', 0, 6): 9054.0767196,
#  ('HO', 'CO2 Vented from the process', 0, 7): 8139.5235156,
#  ('HO', 'CO2 Vented from the process', 0, 8): 7224.9703116,
#  ('HO', 'CO2 Vented from the process', 0, 9): 6310.417107599999,
#  ('HO', 'CO2 Vented from the process', 0, 10): 5395.8639035999995,
#  ('HO', 'CO2 Vented from the process', 0, 11): 4481.3106996,
#  ('HO', 'CO2 Vented from the process', 0, 12): 3566.7574956,
#  ('HO', 'CO2 Vented from the process', 0, 13): 2652.2042916,
#  ('HO', 'CO2 Vented from the process', 0, 14): 1737.6510876,
#  ('HO', 'CO2 Vented from the process', 0, 15): 823.0978835999999,
#  ('HO', 'CO2 Vented from the process', 0, 16): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 17): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 18): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 19): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 20): 0.0,
#  ('HO', 'CO2 Vented from the process', 0, 21): 914.5532039999999,
#  ('HO', 'CO2 Vented from the process', 0, 22): 1829.1064079999999,
#  ('HO', 'CO2 Vented from the process', 0, 23): 2743.659612,
#  ('HO', 'CO2 from air', 0, 0): 0.0,
#  ('HO', 'CO2 from air', 0, 1): 0.0,
#  ('HO', 'CO2 from air', 0, 2): 0.0,
#  ('HO', 'CO2 from air', 0, 3): 0.0,
#  ('HO', 'CO2 from air', 0, 4): 0.0,
#  ('HO', 'CO2 from air', 0, 5): 0.0,
#  ('HO', 'CO2 from air', 0, 6): 0.0,
#  ('HO', 'CO2 from air', 0, 7): 0.0,
#  ('HO', 'CO2 from air', 0, 8): 0.0,
#  ('HO', 'CO2 from air', 0, 9): 0.0,
#  ('HO', 'CO2 from air', 0, 10): 0.0,
#  ('HO', 'CO2 from air', 0, 11): 0.0,
#  ('HO', 'CO2 from air', 0, 12): 0.0,
#  ('HO', 'CO2 from air', 0, 13): 0.0,
#  ('HO', 'CO2 from air', 0, 14): 0.0,
#  ('HO', 'CO2 from air', 0, 15): 0.0,
#  ('HO', 'CO2 from air', 0, 16): 0.0,
#  ('HO', 'CO2 from air', 0, 17): 0.0,
#  ('HO', 'CO2 from air', 0, 18): 0.0,
#  ('HO', 'CO2 from air', 0, 19): 0.0,
#  ('HO', 'CO2 from air', 0, 20): 0.0,
#  ('HO', 'CO2 from air', 0, 21): 0.0,
#  ('HO', 'CO2 from air', 0, 22): 0.0,
#  ('HO', 'CO2 from air', 0, 23): 0.0,
#  ('HO', 'CO2 to Stack', 0, 0): 0.0,
#  ('HO', 'CO2 to Stack', 0, 1): 0.0,
#  ('HO', 'CO2 to Stack', 0, 2): 0.0,
#  ('HO', 'CO2 to Stack', 0, 3): 0.0,
#  ('HO', 'CO2 to Stack', 0, 4): 0.0,
#  ('HO', 'CO2 to Stack', 0, 5): 0.0,
#  ('HO', 'CO2 to Stack', 0, 6): 0.0,
#  ('HO', 'CO2 to Stack', 0, 7): 0.0,
#  ('HO', 'CO2 to Stack', 0, 8): 0.0,
#  ('HO', 'CO2 to Stack', 0, 9): 0.0,
#  ('HO', 'CO2 to Stack', 0, 10): 0.0,
#  ('HO', 'CO2 to Stack', 0, 11): 0.0,
#  ('HO', 'CO2 to Stack', 0, 12): 0.0,
#  ('HO', 'CO2 to Stack', 0, 13): 0.0,
#  ('HO', 'CO2 to Stack', 0, 14): 0.0,
#  ('HO', 'CO2 to Stack', 0, 15): 0.0,
#  ('HO', 'CO2 to Stack', 0, 16): 0.0,
#  ('HO', 'CO2 to Stack', 0, 17): 0.0,
#  ('HO', 'CO2 to Stack', 0, 18): 0.0,
#  ('HO', 'CO2 to Stack', 0, 19): 0.0,
#  ('HO', 'CO2 to Stack', 0, 20): 0.0,
#  ('HO', 'CO2 to Stack', 0, 21): 0.0,
#  ('HO', 'CO2 to Stack', 0, 22): 0.0,
#  ('HO', 'CO2 to Stack', 0, 23): 0.0,
#  ('HO', 'GridPower', 0, 0): 12219.017204726113,
#  ('HO', 'GridPower', 0, 1): 11730.04565501802,
#  ('HO', 'GridPower', 0, 2): 11531.541924837979,
#  ('HO', 'GridPower', 0, 3): 11238.414395467245,
#  ('HO', 'GridPower', 0, 4): 11176.880028580246,
#  ('HO', 'GridPower', 0, 5): 11623.75107423966,
#  ('HO', 'GridPower', 0, 6): 12253.329592606382,
#  ('HO', 'GridPower', 0, 7): 11452.407645117479,
#  ('HO', 'GridPower', 0, 8): 9632.740548766067,
#  ('HO', 'GridPower', 0, 9): 7279.234512086989,
#  ('HO', 'GridPower', 0, 10): 5713.433769858489,
#  ('HO', 'GridPower', 0, 11): 4952.913851550986,
#  ('HO', 'GridPower', 0, 12): 4287.904578303489,
#  ('HO', 'GridPower', 0, 13): 3276.047692325969,
#  ('HO', 'GridPower', 0, 14): 2201.9868914456674,
#  ('HO', 'GridPower', 0, 15): 0.0,
#  ('HO', 'GridPower', 0, 16): 0.0,
#  ('HO', 'GridPower', 0, 17): 0.0,
#  ('HO', 'GridPower', 0, 18): 0.0,
#  ('HO', 'GridPower', 0, 19): 0.0,
#  ('HO', 'GridPower', 0, 20): 0.0,
#  ('HO', 'GridPower', 0, 21): 1414.6583174008215,
#  ('HO', 'GridPower', 0, 22): 2703.5739098135928,
#  ('HO', 'GridPower', 0, 23): 3789.108805453339,
#  ('HO', 'H2O Fresh', 0, 0): 0.0,
#  ('HO', 'H2O Fresh', 0, 1): 0.0,
#  ('HO', 'H2O Fresh', 0, 2): 0.0,
#  ('HO', 'H2O Fresh', 0, 3): 0.0,
#  ('HO', 'H2O Fresh', 0, 4): 0.0,
#  ('HO', 'H2O Fresh', 0, 5): 0.0,
#  ('HO', 'H2O Fresh', 0, 6): 0.0,
#  ('HO', 'H2O Fresh', 0, 7): 0.0,
#  ('HO', 'H2O Fresh', 0, 8): 0.0,
#  ('HO', 'H2O Fresh', 0, 9): 0.0,
#  ('HO', 'H2O Fresh', 0, 10): 0.0,
#  ('HO', 'H2O Fresh', 0, 11): 0.0,
#  ('HO', 'H2O Fresh', 0, 12): 0.0,
#  ('HO', 'H2O Fresh', 0, 13): 0.0,
#  ('HO', 'H2O Fresh', 0, 14): 0.0,
#  ('HO', 'H2O Fresh', 0, 15): 0.0,
#  ('HO', 'H2O Fresh', 0, 16): 0.0,
#  ('HO', 'H2O Fresh', 0, 17): 0.0,
#  ('HO', 'H2O Fresh', 0, 18): 0.0,
#  ('HO', 'H2O Fresh', 0, 19): 0.0,
#  ('HO', 'H2O Fresh', 0, 20): 0.0,
#  ('HO', 'H2O Fresh', 0, 21): 0.0,
#  ('HO', 'H2O Fresh', 0, 22): 0.0,
#  ('HO', 'H2O Fresh', 0, 23): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 0): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 1): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 2): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 3): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 4): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 5): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 6): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 7): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 8): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 9): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 10): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 11): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 12): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 13): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 14): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 15): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 16): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 17): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 18): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 19): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 20): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 21): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 22): 0.0,
#  ('HO', 'H2O Vent from ASU', 0, 23): 0.0,
#  ('HO', 'H2O from air', 0, 0): 0.0,
#  ('HO', 'H2O from air', 0, 1): 0.0,
#  ('HO', 'H2O from air', 0, 2): 0.0,
#  ('HO', 'H2O from air', 0, 3): 0.0,
#  ('HO', 'H2O from air', 0, 4): 0.0,
#  ('HO', 'H2O from air', 0, 5): 0.0,
#  ('HO', 'H2O from air', 0, 6): 0.0,
#  ('HO', 'H2O from air', 0, 7): 0.0,
#  ('HO', 'H2O from air', 0, 8): 0.0,
#  ('HO', 'H2O from air', 0, 9): 0.0,
#  ('HO', 'H2O from air', 0, 10): 0.0,
#  ('HO', 'H2O from air', 0, 11): 0.0,
#  ('HO', 'H2O from air', 0, 12): 0.0,
#  ('HO', 'H2O from air', 0, 13): 0.0,
#  ('HO', 'H2O from air', 0, 14): 0.0,
#  ('HO', 'H2O from air', 0, 15): 0.0,
#  ('HO', 'H2O from air', 0, 16): 0.0,
#  ('HO', 'H2O from air', 0, 17): 0.0,
#  ('HO', 'H2O from air', 0, 18): 0.0,
#  ('HO', 'H2O from air', 0, 19): 0.0,
#  ('HO', 'H2O from air', 0, 20): 0.0,
#  ('HO', 'H2O from air', 0, 21): 0.0,
#  ('HO', 'H2O from air', 0, 22): 0.0,
#  ('HO', 'H2O from air', 0, 23): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 0): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 1): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 2): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 3): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 4): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 5): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 6): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 7): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 8): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 9): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 10): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 11): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 12): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 13): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 14): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 15): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 16): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 17): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 18): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 19): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 20): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 21): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 22): 0.0,
#  ('HO', 'H2O in Blowdown', 0, 23): 0.0,
#  ('HO', 'H2O to Stack', 0, 0): 0.0,
#  ('HO', 'H2O to Stack', 0, 1): 0.0,
#  ('HO', 'H2O to Stack', 0, 2): 0.0,
#  ('HO', 'H2O to Stack', 0, 3): 0.0,
#  ('HO', 'H2O to Stack', 0, 4): 0.0,
#  ('HO', 'H2O to Stack', 0, 5): 0.0,
#  ('HO', 'H2O to Stack', 0, 6): 0.0,
#  ('HO', 'H2O to Stack', 0, 7): 0.0,
#  ('HO', 'H2O to Stack', 0, 8): 0.0,
#  ('HO', 'H2O to Stack', 0, 9): 0.0,
#  ('HO', 'H2O to Stack', 0, 10): 0.0,
#  ('HO', 'H2O to Stack', 0, 11): 0.0,
#  ('HO', 'H2O to Stack', 0, 12): 0.0,
#  ('HO', 'H2O to Stack', 0, 13): 0.0,
#  ('HO', 'H2O to Stack', 0, 14): 0.0,
#  ('HO', 'H2O to Stack', 0, 15): 0.0,
#  ('HO', 'H2O to Stack', 0, 16): 0.0,
#  ('HO', 'H2O to Stack', 0, 17): 0.0,
#  ('HO', 'H2O to Stack', 0, 18): 0.0,
#  ('HO', 'H2O to Stack', 0, 19): 0.0,
#  ('HO', 'H2O to Stack', 0, 20): 0.0,
#  ('HO', 'H2O to Stack', 0, 21): 0.0,
#  ('HO', 'H2O to Stack', 0, 22): 0.0,
#  ('HO', 'H2O to Stack', 0, 23): 0.0,
#  ('HO', 'H2O vented from the process', 0, 0): 0.0,
#  ('HO', 'H2O vented from the process', 0, 1): 0.0,
#  ('HO', 'H2O vented from the process', 0, 2): 0.0,
#  ('HO', 'H2O vented from the process', 0, 3): 0.0,
#  ('HO', 'H2O vented from the process', 0, 4): 0.0,
#  ('HO', 'H2O vented from the process', 0, 5): 0.0,
#  ('HO', 'H2O vented from the process', 0, 6): 0.0,
#  ('HO', 'H2O vented from the process', 0, 7): 0.0,
#  ('HO', 'H2O vented from the process', 0, 8): 0.0,
#  ('HO', 'H2O vented from the process', 0, 9): 0.0,
#  ('HO', 'H2O vented from the process', 0, 10): 0.0,
#  ('HO', 'H2O vented from the process', 0, 11): 0.0,
#  ('HO', 'H2O vented from the process', 0, 12): 0.0,
#  ('HO', 'H2O vented from the process', 0, 13): 0.0,
#  ('HO', 'H2O vented from the process', 0, 14): 0.0,
#  ('HO', 'H2O vented from the process', 0, 15): 0.0,
#  ('HO', 'H2O vented from the process', 0, 16): 0.0,
#  ('HO', 'H2O vented from the process', 0, 17): 0.0,
#  ('HO', 'H2O vented from the process', 0, 18): 0.0,
#  ('HO', 'H2O vented from the process', 0, 19): 0.0,
#  ('HO', 'H2O vented from the process', 0, 20): 0.0,
#  ('HO', 'H2O vented from the process', 0, 21): 0.0,
#  ('HO', 'H2O vented from the process', 0, 22): 0.0,
#  ('HO', 'H2O vented from the process', 0, 23): 0.0,
#  ('HO', 'N2 Desorped', 0, 0): 0.0,
#  ('HO', 'N2 Desorped', 0, 1): 0.0,
#  ('HO', 'N2 Desorped', 0, 2): 0.0,
#  ('HO', 'N2 Desorped', 0, 3): 0.0,
#  ('HO', 'N2 Desorped', 0, 4): 0.0,
#  ('HO', 'N2 Desorped', 0, 5): 0.0,
#  ('HO', 'N2 Desorped', 0, 6): 0.0,
#  ('HO', 'N2 Desorped', 0, 7): 0.0,
#  ('HO', 'N2 Desorped', 0, 8): 0.0,
#  ('HO', 'N2 Desorped', 0, 9): 0.0,
#  ('HO', 'N2 Desorped', 0, 10): 0.0,
#  ('HO', 'N2 Desorped', 0, 11): 0.0,
#  ('HO', 'N2 Desorped', 0, 12): 0.0,
#  ('HO', 'N2 Desorped', 0, 13): 0.0,
#  ('HO', 'N2 Desorped', 0, 14): 0.0,
#  ('HO', 'N2 Desorped', 0, 15): 0.0,
#  ('HO', 'N2 Desorped', 0, 16): 0.0,
#  ('HO', 'N2 Desorped', 0, 17): 0.0,
#  ('HO', 'N2 Desorped', 0, 18): 0.0,
#  ('HO', 'N2 Desorped', 0, 19): 0.0,
#  ('HO', 'N2 Desorped', 0, 20): 0.0,
#  ('HO', 'N2 Desorped', 0, 21): 0.0,
#  ('HO', 'N2 Desorped', 0, 22): 0.0,
#  ('HO', 'N2 Desorped', 0, 23): 0.0,
#  ('HO', 'N2 from Air', 0, 0): 0.0,
#  ('HO', 'N2 from Air', 0, 1): 0.0,
#  ('HO', 'N2 from Air', 0, 2): 0.0,
#  ('HO', 'N2 from Air', 0, 3): 0.0,
#  ('HO', 'N2 from Air', 0, 4): 0.0,
#  ('HO', 'N2 from Air', 0, 5): 0.0,
#  ('HO', 'N2 from Air', 0, 6): 0.0,
#  ('HO', 'N2 from Air', 0, 7): 0.0,
#  ('HO', 'N2 from Air', 0, 8): 0.0,
#  ('HO', 'N2 from Air', 0, 9): 0.0,
#  ('HO', 'N2 from Air', 0, 10): 0.0,
#  ('HO', 'N2 from Air', 0, 11): 0.0,
#  ('HO', 'N2 from Air', 0, 12): 0.0,
#  ('HO', 'N2 from Air', 0, 13): 0.0,
#  ('HO', 'N2 from Air', 0, 14): 0.0,
#  ('HO', 'N2 from Air', 0, 15): 0.0,
#  ('HO', 'N2 from Air', 0, 16): 0.0,
#  ('HO', 'N2 from Air', 0, 17): 0.0,
#  ('HO', 'N2 from Air', 0, 18): 0.0,
#  ('HO', 'N2 from Air', 0, 19): 0.0,
#  ('HO', 'N2 from Air', 0, 20): 0.0,
#  ('HO', 'N2 from Air', 0, 21): 0.0,
#  ('HO', 'N2 from Air', 0, 22): 0.0,
#  ('HO', 'N2 from Air', 0, 23): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 0): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 1): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 2): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 3): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 4): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 5): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 6): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 7): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 8): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 9): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 10): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 11): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 12): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 13): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 14): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 15): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 16): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 17): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 18): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 19): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 20): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 21): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 22): 0.0,
#  ('HO', 'N2 in Blowdown', 0, 23): 0.0,
#  ('HO', 'N2 in Stack', 0, 0): 0.0,
#  ('HO', 'N2 in Stack', 0, 1): 0.0,
#  ('HO', 'N2 in Stack', 0, 2): 0.0,
#  ('HO', 'N2 in Stack', 0, 3): 0.0,
#  ('HO', 'N2 in Stack', 0, 4): 0.0,
#  ('HO', 'N2 in Stack', 0, 5): 0.0,
#  ('HO', 'N2 in Stack', 0, 6): 0.0,
#  ('HO', 'N2 in Stack', 0, 7): 0.0,
#  ('HO', 'N2 in Stack', 0, 8): 0.0,
#  ('HO', 'N2 in Stack', 0, 9): 0.0,
#  ('HO', 'N2 in Stack', 0, 10): 0.0,
#  ('HO', 'N2 in Stack', 0, 11): 0.0,
#  ('HO', 'N2 in Stack', 0, 12): 0.0,
#  ('HO', 'N2 in Stack', 0, 13): 0.0,
#  ('HO', 'N2 in Stack', 0, 14): 0.0,
#  ('HO', 'N2 in Stack', 0, 15): 0.0,
#  ('HO', 'N2 in Stack', 0, 16): 0.0,
#  ('HO', 'N2 in Stack', 0, 17): 0.0,
#  ('HO', 'N2 in Stack', 0, 18): 0.0,
#  ('HO', 'N2 in Stack', 0, 19): 0.0,
#  ('HO', 'N2 in Stack', 0, 20): 0.0,
#  ('HO', 'N2 in Stack', 0, 21): 0.0,
#  ('HO', 'N2 in Stack', 0, 22): 0.0,
#  ('HO', 'N2 in Stack', 0, 23): 0.0,
#  ('HO', 'N2 in product stream', 0, 0): 0.0,
#  ('HO', 'N2 in product stream', 0, 1): 0.0,
#  ('HO', 'N2 in product stream', 0, 2): 0.0,
#  ('HO', 'N2 in product stream', 0, 3): 0.0,
#  ('HO', 'N2 in product stream', 0, 4): 0.0,
#  ('HO', 'N2 in product stream', 0, 5): 0.0,
#  ('HO', 'N2 in product stream', 0, 6): 0.0,
#  ('HO', 'N2 in product stream', 0, 7): 0.0,
#  ('HO', 'N2 in product stream', 0, 8): 0.0,
#  ('HO', 'N2 in product stream', 0, 9): 0.0,
#  ('HO', 'N2 in product stream', 0, 10): 0.0,
#  ('HO', 'N2 in product stream', 0, 11): 0.0,
#  ('HO', 'N2 in product stream', 0, 12): 0.0,
#  ('HO', 'N2 in product stream', 0, 13): 0.0,
#  ('HO', 'N2 in product stream', 0, 14): 0.0,
#  ('HO', 'N2 in product stream', 0, 15): 0.0,
#  ('HO', 'N2 in product stream', 0, 16): 0.0,
#  ('HO', 'N2 in product stream', 0, 17): 0.0,
#  ('HO', 'N2 in product stream', 0, 18): 0.0,
#  ('HO', 'N2 in product stream', 0, 19): 0.0,
#  ('HO', 'N2 in product stream', 0, 20): 0.0,
#  ('HO', 'N2 in product stream', 0, 21): 0.0,
#  ('HO', 'N2 in product stream', 0, 22): 0.0,
#  ('HO', 'N2 in product stream', 0, 23): 0.0,
#  ('HO', 'N2 to Stack', 0, 0): 0.0,
#  ('HO', 'N2 to Stack', 0, 1): 0.0,
#  ('HO', 'N2 to Stack', 0, 2): 0.0,
#  ('HO', 'N2 to Stack', 0, 3): 0.0,
#  ('HO', 'N2 to Stack', 0, 4): 0.0,
#  ('HO', 'N2 to Stack', 0, 5): 0.0,
#  ('HO', 'N2 to Stack', 0, 6): 0.0,
#  ('HO', 'N2 to Stack', 0, 7): 0.0,
#  ('HO', 'N2 to Stack', 0, 8): 0.0,
#  ('HO', 'N2 to Stack', 0, 9): 0.0,
#  ('HO', 'N2 to Stack', 0, 10): 0.0,
#  ('HO', 'N2 to Stack', 0, 11): 0.0,
#  ('HO', 'N2 to Stack', 0, 12): 0.0,
#  ('HO', 'N2 to Stack', 0, 13): 0.0,
#  ('HO', 'N2 to Stack', 0, 14): 0.0,
#  ('HO', 'N2 to Stack', 0, 15): 0.0,
#  ('HO', 'N2 to Stack', 0, 16): 0.0,
#  ('HO', 'N2 to Stack', 0, 17): 0.0,
#  ('HO', 'N2 to Stack', 0, 18): 0.0,
#  ('HO', 'N2 to Stack', 0, 19): 0.0,
#  ('HO', 'N2 to Stack', 0, 20): 0.0,
#  ('HO', 'N2 to Stack', 0, 21): 0.0,
#  ('HO', 'N2 to Stack', 0, 22): 0.0,
#  ('HO', 'N2 to Stack', 0, 23): 0.0,
#  ('HO', 'N2 vented from the process', 0, 0): 0.0,
#  ('HO', 'N2 vented from the process', 0, 1): 0.0,
#  ('HO', 'N2 vented from the process', 0, 2): 0.0,
#  ('HO', 'N2 vented from the process', 0, 3): 0.0,
#  ('HO', 'N2 vented from the process', 0, 4): 0.0,
#  ('HO', 'N2 vented from the process', 0, 5): 0.0,
#  ('HO', 'N2 vented from the process', 0, 6): 0.0,
#  ('HO', 'N2 vented from the process', 0, 7): 0.0,
#  ('HO', 'N2 vented from the process', 0, 8): 0.0,
#  ('HO', 'N2 vented from the process', 0, 9): 0.0,
#  ('HO', 'N2 vented from the process', 0, 10): 0.0,
#  ('HO', 'N2 vented from the process', 0, 11): 0.0,
#  ('HO', 'N2 vented from the process', 0, 12): 0.0,
#  ('HO', 'N2 vented from the process', 0, 13): 0.0,
#  ('HO', 'N2 vented from the process', 0, 14): 0.0,
#  ('HO', 'N2 vented from the process', 0, 15): 0.0,
#  ('HO', 'N2 vented from the process', 0, 16): 0.0,
#  ('HO', 'N2 vented from the process', 0, 17): 0.0,
#  ('HO', 'N2 vented from the process', 0, 18): 0.0,
#  ('HO', 'N2 vented from the process', 0, 19): 0.0,
#  ('HO', 'N2 vented from the process', 0, 20): 0.0,
#  ('HO', 'N2 vented from the process', 0, 21): 0.0,
#  ('HO', 'N2 vented from the process', 0, 22): 0.0,
#  ('HO', 'N2 vented from the process', 0, 23): 0.0,
#  ('HO', 'Natural Gas', 0, 0): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 1): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 2): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 3): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 4): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 5): 42408.79204194599,
#  ('HO', 'Natural Gas', 0, 6): 41984.704121526534,
#  ('HO', 'Natural Gas', 0, 7): 37743.824917331935,
#  ('HO', 'Natural Gas', 0, 8): 33502.945713137335,
#  ('HO', 'Natural Gas', 0, 9): 29262.06650894274,
#  ('HO', 'Natural Gas', 0, 10): 25021.187304748135,
#  ('HO', 'Natural Gas', 0, 11): 20780.30810055354,
#  ('HO', 'Natural Gas', 0, 12): 16539.42889635894,
#  ('HO', 'Natural Gas', 0, 13): 12298.549692164339,
#  ('HO', 'Natural Gas', 0, 14): 8057.67048796974,
#  ('HO', 'Natural Gas', 0, 15): 3816.7912837751396,
#  ('HO', 'Natural Gas', 0, 16): 0.0,
#  ('HO', 'Natural Gas', 0, 17): 0.0,
#  ('HO', 'Natural Gas', 0, 18): 0.0,
#  ('HO', 'Natural Gas', 0, 19): 0.0,
#  ('HO', 'Natural Gas', 0, 20): 0.0,
#  ('HO', 'Natural Gas', 0, 21): 4240.8792041946,
#  ('HO', 'Natural Gas', 0, 22): 8481.7584083892,
#  ('HO', 'Natural Gas', 0, 23): 12722.6376125838,
#  ('HO', 'O2 from air', 0, 0): 0.0,
#  ('HO', 'O2 from air', 0, 1): 0.0,
#  ('HO', 'O2 from air', 0, 2): 0.0,
#  ('HO', 'O2 from air', 0, 3): 0.0,
#  ('HO', 'O2 from air', 0, 4): 0.0,
#  ('HO', 'O2 from air', 0, 5): 0.0,
#  ('HO', 'O2 from air', 0, 6): 0.0,
#  ('HO', 'O2 from air', 0, 7): 0.0,
#  ('HO', 'O2 from air', 0, 8): 0.0,
#  ('HO', 'O2 from air', 0, 9): 0.0,
#  ('HO', 'O2 from air', 0, 10): 0.0,
#  ('HO', 'O2 from air', 0, 11): 0.0,
#  ('HO', 'O2 from air', 0, 12): 0.0,
#  ('HO', 'O2 from air', 0, 13): 0.0,
#  ('HO', 'O2 from air', 0, 14): 0.0,
#  ('HO', 'O2 from air', 0, 15): 0.0,
#  ('HO', 'O2 from air', 0, 16): 0.0,
#  ('HO', 'O2 from air', 0, 17): 0.0,
#  ('HO', 'O2 from air', 0, 18): 0.0,
#  ('HO', 'O2 from air', 0, 19): 0.0,
#  ('HO', 'O2 from air', 0, 20): 0.0,
#  ('HO', 'O2 from air', 0, 21): 0.0,
#  ('HO', 'O2 from air', 0, 22): 0.0,
#  ('HO', 'O2 from air', 0, 23): 0.0,
#  ('HO', 'O2 to Stack', 0, 0): 0.0,
#  ('HO', 'O2 to Stack', 0, 1): 0.0,
#  ('HO', 'O2 to Stack', 0, 2): 0.0,
#  ('HO', 'O2 to Stack', 0, 3): 0.0,
#  ('HO', 'O2 to Stack', 0, 4): 0.0,
#  ('HO', 'O2 to Stack', 0, 5): 0.0,
#  ('HO', 'O2 to Stack', 0, 6): 0.0,
#  ('HO', 'O2 to Stack', 0, 7): 0.0,
#  ('HO', 'O2 to Stack', 0, 8): 0.0,
#  ('HO', 'O2 to Stack', 0, 9): 0.0,
#  ('HO', 'O2 to Stack', 0, 10): 0.0,
#  ('HO', 'O2 to Stack', 0, 11): 0.0,
#  ('HO', 'O2 to Stack', 0, 12): 0.0,
#  ('HO', 'O2 to Stack', 0, 13): 0.0,
#  ('HO', 'O2 to Stack', 0, 14): 0.0,
#  ('HO', 'O2 to Stack', 0, 15): 0.0,
#  ('HO', 'O2 to Stack', 0, 16): 0.0,
#  ('HO', 'O2 to Stack', 0, 17): 0.0,
#  ('HO', 'O2 to Stack', 0, 18): 0.0,
#  ('HO', 'O2 to Stack', 0, 19): 0.0,
#  ('HO', 'O2 to Stack', 0, 20): 0.0,
#  ('HO', 'O2 to Stack', 0, 21): 0.0,
#  ('HO', 'O2 to Stack', 0, 22): 0.0,
#  ('HO', 'O2 to Stack', 0, 23): 0.0,
#  ('HO', 'O2 vented from the process', 0, 0): 0.0,
#  ('HO', 'O2 vented from the process', 0, 1): 0.0,
#  ('HO', 'O2 vented from the process', 0, 2): 0.0,
#  ('HO', 'O2 vented from the process', 0, 3): 0.0,
#  ('HO', 'O2 vented from the process', 0, 4): 0.0,
#  ('HO', 'O2 vented from the process', 0, 5): 0.0,
#  ('HO', 'O2 vented from the process', 0, 6): 0.0,
#  ('HO', 'O2 vented from the process', 0, 7): 0.0,
#  ('HO', 'O2 vented from the process', 0, 8): 0.0,
#  ('HO', 'O2 vented from the process', 0, 9): 0.0,
#  ('HO', 'O2 vented from the process', 0, 10): 0.0,
#  ('HO', 'O2 vented from the process', 0, 11): 0.0,
#  ('HO', 'O2 vented from the process', 0, 12): 0.0,
#  ('HO', 'O2 vented from the process', 0, 13): 0.0,
#  ('HO', 'O2 vented from the process', 0, 14): 0.0,
#  ('HO', 'O2 vented from the process', 0, 15): 0.0,
#  ('HO', 'O2 vented from the process', 0, 16): 0.0,
#  ('HO', 'O2 vented from the process', 0, 17): 0.0,
#  ('HO', 'O2 vented from the process', 0, 18): 0.0,
#  ('HO', 'O2 vented from the process', 0, 19): 0.0,
#  ('HO', 'O2 vented from the process', 0, 20): 0.0,
#  ('HO', 'O2 vented from the process', 0, 21): 0.0,
#  ('HO', 'O2 vented from the process', 0, 22): 0.0,
#  ('HO', 'O2 vented from the process', 0, 23): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 0): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 1): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 2): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 3): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 4): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 5): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 6): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 7): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 8): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 9): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 10): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 11): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 12): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 13): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 14): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 15): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 16): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 17): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 18): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 19): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 20): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 21): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 22): 0.0,
#  ('HO', 'O2 vented out of ASU', 0, 23): 0.0,
#  ('HO', 'Power', 0, 0): 0.0,
#  ('HO', 'Power', 0, 1): 0.0,
#  ('HO', 'Power', 0, 2): 0.0,
#  ('HO', 'Power', 0, 3): 0.0,
#  ('HO', 'Power', 0, 4): 0.0,
#  ('HO', 'Power', 0, 5): 0.0,
#  ('HO', 'Power', 0, 6): 0.0,
#  ('HO', 'Power', 0, 7): 0.0,
#  ('HO', 'Power', 0, 8): 0.0,
#  ('HO', 'Power', 0, 9): 0.0,
#  ('HO', 'Power', 0, 10): 0.0,
#  ('HO', 'Power', 0, 11): 0.0,
#  ('HO', 'Power', 0, 12): 0.0,
#  ('HO', 'Power', 0, 13): 0.0,
#  ('HO', 'Power', 0, 14): 0.0,
#  ('HO', 'Power', 0, 15): 0.0,
#  ('HO', 'Power', 0, 16): 0.0,
#  ('HO', 'Power', 0, 17): 0.0,
#  ('HO', 'Power', 0, 18): 0.0,
#  ('HO', 'Power', 0, 19): 0.0,
#  ('HO', 'Power', 0, 20): 0.0,
#  ('HO', 'Power', 0, 21): 0.0,
#  ('HO', 'Power', 0, 22): 0.0,
#  ('HO', 'Power', 0, 23): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 0): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 1): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 2): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 3): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 4): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 5): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 6): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 7): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 8): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 9): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 10): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 11): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 12): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 13): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 14): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 15): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 16): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 17): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 18): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 19): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 20): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 21): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 22): 0.0,
#  ('HO', 'Pure Hydrogen', 0, 23): 0.0,
#  ('HO', 'Solar', 0, 0): 0.0,
#  ('HO', 'Solar', 0, 1): 0.0,
#  ('HO', 'Solar', 0, 2): 0.0,
#  ('HO', 'Solar', 0, 3): 0.0,
#  ('HO', 'Solar', 0, 4): 0.0,
#  ('HO', 'Solar', 0, 5): 0.0,
#  ('HO', 'Solar', 0, 6): 0.0,
#  ('HO', 'Solar', 0, 7): 0.0,
#  ('HO', 'Solar', 0, 8): 0.0,
#  ('HO', 'Solar', 0, 9): 0.0,
#  ('HO', 'Solar', 0, 10): 0.0,
#  ('HO', 'Solar', 0, 11): 0.0,
#  ('HO', 'Solar', 0, 12): 0.0,
#  ('HO', 'Solar', 0, 13): 0.0,
#  ('HO', 'Solar', 0, 14): 0.0,
#  ('HO', 'Solar', 0, 15): 0.0,
#  ('HO', 'Solar', 0, 16): 0.0,
#  ('HO', 'Solar', 0, 17): 0.0,
#  ('HO', 'Solar', 0, 18): 0.0,
#  ('HO', 'Solar', 0, 19): 0.0,
#  ('HO', 'Solar', 0, 20): 0.0,
#  ('HO', 'Solar', 0, 21): 0.0,
#  ('HO', 'Solar', 0, 22): 0.0,
#  ('HO', 'Solar', 0, 23): 0.0,
#  ('HO', 'Wind', 0, 0): 0.0,
#  ('HO', 'Wind', 0, 1): 0.0,
#  ('HO', 'Wind', 0, 2): 0.0,
#  ('HO', 'Wind', 0, 3): 0.0,
#  ('HO', 'Wind', 0, 4): 0.0,
#  ('HO', 'Wind', 0, 5): 0.0,
#  ('HO', 'Wind', 0, 6): 0.0,
#  ('HO', 'Wind', 0, 7): 0.0,
#  ('HO', 'Wind', 0, 8): 0.0,
#  ('HO', 'Wind', 0, 9): 0.0,
#  ('HO', 'Wind', 0, 10): 0.0,
#  ('HO', 'Wind', 0, 11): 0.0,
#  ('HO', 'Wind', 0, 12): 0.0,
#  ('HO', 'Wind', 0, 13): 0.0,
#  ('HO', 'Wind', 0, 14): 0.0,
#  ('HO', 'Wind', 0, 15): 0.0,
#  ('HO', 'Wind', 0, 16): 0.0,
#  ('HO', 'Wind', 0, 17): 0.0,
#  ('HO', 'Wind', 0, 18): 0.0,
#  ('HO', 'Wind', 0, 19): 0.0,
#  ('HO', 'Wind', 0, 20): 0.0,
#  ('HO', 'Wind', 0, 21): 0.0,
#  ('HO', 'Wind', 0, 22): 0.0,
#  ('HO', 'Wind', 0, 23): 0.0}

# %% [markdown]
# Process flow on an hourly scale:

# %%
results_cost.output['P']
# Out:
# {('HO', 'ATR_CCS_OC', 0, 0): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 1): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 2): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 3): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 4): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 5): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 6): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 7): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 8): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 9): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 10): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 11): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 12): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 13): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 14): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 15): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 16): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 17): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 18): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 19): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 20): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 21): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 22): 0.0,
#  ('HO', 'ATR_CCS_OC', 0, 23): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 0): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 1): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 2): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 3): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 4): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 5): 20000.0,
#  ('HO', 'ATR_CCS_R', 0, 6): 19800.0,
#  ('HO', 'ATR_CCS_R', 0, 7): 17800.0,
#  ('HO', 'ATR_CCS_R', 0, 8): 15800.0,
#  ('HO', 'ATR_CCS_R', 0, 9): 13800.0,
#  ('HO', 'ATR_CCS_R', 0, 10): 11800.0,
#  ('HO', 'ATR_CCS_R', 0, 11): 9800.0,
#  ('HO', 'ATR_CCS_R', 0, 12): 7800.0,
#  ('HO', 'ATR_CCS_R', 0, 13): 5800.0,
#  ('HO', 'ATR_CCS_R', 0, 14): 3800.0,
#  ('HO', 'ATR_CCS_R', 0, 15): 1800.0,
#  ('HO', 'ATR_CCS_R', 0, 16): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 17): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 18): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 19): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 20): 0.0,
#  ('HO', 'ATR_CCS_R', 0, 21): 2000.0,
#  ('HO', 'ATR_CCS_R', 0, 22): 4000.0,
#  ('HO', 'ATR_CCS_R', 0, 23): 6000.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 0): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 1): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 2): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 3): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 4): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 5): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 6): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 7): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 8): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 9): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 10): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 11): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 12): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 13): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 14): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 15): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 16): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 17): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 18): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 19): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 20): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 21): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 22): 0.0,
#  ('HO', 'ATR_CCS_R_OC', 0, 23): 0.0,
#  ('HO', 'AWE', 0, 0): 0.0,
#  ('HO', 'AWE', 0, 1): 0.0,
#  ('HO', 'AWE', 0, 2): 0.0,
#  ('HO', 'AWE', 0, 3): 0.0,
#  ('HO', 'AWE', 0, 4): 0.0,
#  ('HO', 'AWE', 0, 5): 0.0,
#  ('HO', 'AWE', 0, 6): 0.0,
#  ('HO', 'AWE', 0, 7): 0.0,
#  ('HO', 'AWE', 0, 8): 0.0,
#  ('HO', 'AWE', 0, 9): 0.0,
#  ('HO', 'AWE', 0, 10): 0.0,
#  ('HO', 'AWE', 0, 11): 0.0,
#  ('HO', 'AWE', 0, 12): 0.0,
#  ('HO', 'AWE', 0, 13): 0.0,
#  ('HO', 'AWE', 0, 14): 0.0,
#  ('HO', 'AWE', 0, 15): 0.0,
#  ('HO', 'AWE', 0, 16): 0.0,
#  ('HO', 'AWE', 0, 17): 0.0,
#  ('HO', 'AWE', 0, 18): 0.0,
#  ('HO', 'AWE', 0, 19): 0.0,
#  ('HO', 'AWE', 0, 20): 0.0,
#  ('HO', 'AWE', 0, 21): 0.0,
#  ('HO', 'AWE', 0, 22): 0.0,
#  ('HO', 'AWE', 0, 23): 0.0,
#  ('HO', 'Grid', 0, 0): 35.0807452,
#  ('HO', 'Grid', 0, 1): 35.0807452,
#  ('HO', 'Grid', 0, 2): 35.0807452,
#  ('HO', 'Grid', 0, 3): 35.0807452,
#  ('HO', 'Grid', 0, 4): 35.0807452,
#  ('HO', 'Grid', 0, 5): 35.0807452,
#  ('HO', 'Grid', 0, 6): 34.729937748,
#  ('HO', 'Grid', 0, 7): 31.221863228,
#  ('HO', 'Grid', 0, 8): 27.713788708,
#  ('HO', 'Grid', 0, 9): 24.205714188,
#  ('HO', 'Grid', 0, 10): 20.697639668,
#  ('HO', 'Grid', 0, 11): 17.189565148,
#  ('HO', 'Grid', 0, 12): 13.681490628,
#  ('HO', 'Grid', 0, 13): 10.173416108,
#  ('HO', 'Grid', 0, 14): 6.665341588,
#  ('HO', 'Grid', 0, 15): 0.0,
#  ('HO', 'Grid', 0, 16): 0.0,
#  ('HO', 'Grid', 0, 17): 0.0,
#  ('HO', 'Grid', 0, 18): 0.0,
#  ('HO', 'Grid', 0, 19): 0.0,
#  ('HO', 'Grid', 0, 20): 0.0,
#  ('HO', 'Grid', 0, 21): 3.50807452,
#  ('HO', 'Grid', 0, 22): 7.01614904,
#  ('HO', 'Grid', 0, 23): 10.52422356,
#  ('HO', 'PEM', 0, 0): 0.0,
#  ('HO', 'PEM', 0, 1): 0.0,
#  ('HO', 'PEM', 0, 2): 0.0,
#  ('HO', 'PEM', 0, 3): 0.0,
#  ('HO', 'PEM', 0, 4): 0.0,
#  ('HO', 'PEM', 0, 5): 0.0,
#  ('HO', 'PEM', 0, 6): 0.0,
#  ('HO', 'PEM', 0, 7): 0.0,
#  ('HO', 'PEM', 0, 8): 0.0,
#  ('HO', 'PEM', 0, 9): 0.0,
#  ('HO', 'PEM', 0, 10): 0.0,
#  ('HO', 'PEM', 0, 11): 0.0,
#  ('HO', 'PEM', 0, 12): 0.0,
#  ('HO', 'PEM', 0, 13): 0.0,
#  ('HO', 'PEM', 0, 14): 0.0,
#  ('HO', 'PEM', 0, 15): 0.0,
#  ('HO', 'PEM', 0, 16): 0.0,
#  ('HO', 'PEM', 0, 17): 0.0,
#  ('HO', 'PEM', 0, 18): 0.0,
#  ('HO', 'PEM', 0, 19): 0.0,
#  ('HO', 'PEM', 0, 20): 0.0,
#  ('HO', 'PEM', 0, 21): 0.0,
#  ('HO', 'PEM', 0, 22): 0.0,
#  ('HO', 'PEM', 0, 23): 0.0,
#  ('HO', 'PV', 0, 0): 0.0,
#  ('HO', 'PV', 0, 1): 0.0,
#  ('HO', 'PV', 0, 2): 0.0,
#  ('HO', 'PV', 0, 3): 0.0,
#  ('HO', 'PV', 0, 4): 0.0,
#  ('HO', 'PV', 0, 5): 0.0,
#  ('HO', 'PV', 0, 6): 0.0,
#  ('HO', 'PV', 0, 7): 0.0,
#  ('HO', 'PV', 0, 8): 0.0,
#  ('HO', 'PV', 0, 9): 0.0,
#  ('HO', 'PV', 0, 10): 0.0,
#  ('HO', 'PV', 0, 11): 0.0,
#  ('HO', 'PV', 0, 12): 0.0,
#  ('HO', 'PV', 0, 13): 0.0,
#  ('HO', 'PV', 0, 14): 0.0,
#  ('HO', 'PV', 0, 15): 3.157267068,
#  ('HO', 'PV', 0, 16): 0.0,
#  ('HO', 'PV', 0, 17): 0.0,
#  ('HO', 'PV', 0, 18): 0.0,
#  ('HO', 'PV', 0, 19): 0.0,
#  ('HO', 'PV', 0, 20): 0.0,
#  ('HO', 'PV', 0, 21): 0.0,
#  ('HO', 'PV', 0, 22): 0.0,
#  ('HO', 'PV', 0, 23): 0.0,
#  ('HO', 'SMR', 0, 0): 0.0,
#  ('HO', 'SMR', 0, 1): 0.0,
#  ('HO', 'SMR', 0, 2): 0.0,
#  ('HO', 'SMR', 0, 3): 0.0,
#  ('HO', 'SMR', 0, 4): 0.0,
#  ('HO', 'SMR', 0, 5): 0.0,
#  ('HO', 'SMR', 0, 6): 0.0,
#  ('HO', 'SMR', 0, 7): 0.0,
#  ('HO', 'SMR', 0, 8): 0.0,
#  ('HO', 'SMR', 0, 9): 0.0,
#  ('HO', 'SMR', 0, 10): 0.0,
#  ('HO', 'SMR', 0, 11): 0.0,
#  ('HO', 'SMR', 0, 12): 0.0,
#  ('HO', 'SMR', 0, 13): 0.0,
#  ('HO', 'SMR', 0, 14): 0.0,
#  ('HO', 'SMR', 0, 15): 0.0,
#  ('HO', 'SMR', 0, 16): 0.0,
#  ('HO', 'SMR', 0, 17): 0.0,
#  ('HO', 'SMR', 0, 18): 0.0,
#  ('HO', 'SMR', 0, 19): 0.0,
#  ('HO', 'SMR', 0, 20): 0.0,
#  ('HO', 'SMR', 0, 21): 0.0,
#  ('HO', 'SMR', 0, 22): 0.0,
#  ('HO', 'SMR', 0, 23): 0.0,
#  ('HO', 'SMRCCS', 0, 0): 0.0,
#  ('HO', 'SMRCCS', 0, 1): 0.0,
#  ('HO', 'SMRCCS', 0, 2): 0.0,
#  ('HO', 'SMRCCS', 0, 3): 0.0,
#  ('HO', 'SMRCCS', 0, 4): 0.0,
#  ('HO', 'SMRCCS', 0, 5): 0.0,
#  ('HO', 'SMRCCS', 0, 6): 0.0,
#  ('HO', 'SMRCCS', 0, 7): 0.0,
#  ('HO', 'SMRCCS', 0, 8): 0.0,
#  ('HO', 'SMRCCS', 0, 9): 0.0,
#  ('HO', 'SMRCCS', 0, 10): 0.0,
#  ('HO', 'SMRCCS', 0, 11): 0.0,
#  ('HO', 'SMRCCS', 0, 12): 0.0,
#  ('HO', 'SMRCCS', 0, 13): 0.0,
#  ('HO', 'SMRCCS', 0, 14): 0.0,
#  ('HO', 'SMRCCS', 0, 15): 0.0,
#  ('HO', 'SMRCCS', 0, 16): 0.0,
#  ('HO', 'SMRCCS', 0, 17): 0.0,
#  ('HO', 'SMRCCS', 0, 18): 0.0,
#  ('HO', 'SMRCCS', 0, 19): 0.0,
#  ('HO', 'SMRCCS', 0, 20): 0.0,
#  ('HO', 'SMRCCS', 0, 21): 0.0,
#  ('HO', 'SMRCCS', 0, 22): 0.0,
#  ('HO', 'SMRCCS', 0, 23): 0.0,
#  ('HO', 'WF', 0, 0): 0.0,
#  ('HO', 'WF', 0, 1): 0.0,
#  ('HO', 'WF', 0, 2): 0.0,
#  ('HO', 'WF', 0, 3): 0.0,
#  ('HO', 'WF', 0, 4): 0.0,
#  ('HO', 'WF', 0, 5): 0.0,
#  ('HO', 'WF', 0, 6): 0.0,
#  ('HO', 'WF', 0, 7): 0.0,
#  ('HO', 'WF', 0, 8): 0.0,
#  ('HO', 'WF', 0, 9): 0.0,
#  ('HO', 'WF', 0, 10): 0.0,
#  ('HO', 'WF', 0, 11): 0.0,
#  ('HO', 'WF', 0, 12): 0.0,
#  ('HO', 'WF', 0, 13): 0.0,
#  ('HO', 'WF', 0, 14): 0.0,
#  ('HO', 'WF', 0, 15): 0.0,
#  ('HO', 'WF', 0, 16): 0.0,
#  ('HO', 'WF', 0, 17): 0.0,
#  ('HO', 'WF', 0, 18): 0.0,
#  ('HO', 'WF', 0, 19): 0.0,
#  ('HO', 'WF', 0, 20): 0.0,
#  ('HO', 'WF', 0, 21): 0.0,
#  ('HO', 'WF', 0, 22): 0.0,
#  ('HO', 'WF', 0, 23): 0.0}

# %% [markdown]
# ## How would the objective change as we enforce more strict environmental constraints?

# %%
from energiapy.model.constraints.emission import constraint_global_warming_potential_network_reduction

# %%
from pyomo.environ import Var, Binary

def modeler(gwp_pct: float):
    instance = formulate(scenario=scenario, constraints={Constraints.COST, Constraints.INVENTORY, Constraints.PRODUCTION,
                        Constraints.RESOURCE_BALANCE, Constraints.DEMAND, Constraints.EMISSION}, objective=Objective.COST, demand_sign = 'eq')

    constraint_global_warming_potential_network_reduction(instance= instance, network_scale_level = 0, gwp_reduction_pct = gwp_pct, gwp = results_cost.output['global_warming_potential_network'][0])

    ramping_limit = 1000

    instance.cons2 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons2.add(expr = instance.P['HO', 'SMR', *i] - instance.P['HO', 'SMR', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limit)

    instance.cons3 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons3.add(expr = instance.P['HO', 'SMR', *i] - instance.P['HO', 'SMR', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limit)

    ramping_limitz = 2000

    instance.cons4 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons4.add(expr = instance.P['HO', 'ATR_CCS_R', *i] - instance.P['HO', 'ATR_CCS_R', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitz)

    instance.cons5 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons5.add(expr = instance.P['HO', 'ATR_CCS_R', *i] - instance.P['HO', 'ATR_CCS_R', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitz)

    instance.cons6 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons6.add(expr = instance.P['HO', 'ATR_CCS_OC', *i] - instance.P['HO', 'ATR_CCS_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitz)

    instance.cons7 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons7.add(expr = instance.P['HO', 'ATR_CCS_OC', *i] - instance.P['HO', 'ATR_CCS_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitz)        

    instance.cons8 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons8.add(expr = instance.P['HO', 'ATR_CCS_R_OC', *i] - instance.P['HO', 'ATR_CCS_R_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] <= ramping_limitz)

    instance.cons9 = ConstraintList()
    for i in scales.scale_iter(1):
        if i != (0,0):
            instance.cons9.add(expr = instance.P['HO', 'ATR_CCS_R_OC', *i] - instance.P['HO', 'ATR_CCS_R_OC', *scales.scale_iter(2)[scales.scale_iter(1).index(i) - 1]] >= -ramping_limitz)  

    # Minimum production rate
    # milp_cost.cons1 = ConstraintList()
    # for i in scales.scale_iter(1):
    #  milp_cost.cons1.add(expr = milp_cost.P['HO', 'SMR', *i] >= 1000)

    # Add binary variables for on/off control
    instance.on_smr = Var(scales.scale_iter(1), domain=Binary)  # Binary variable for SMR system
    instance.on_atr_ccs_r = Var(scales.scale_iter(1), domain=Binary)  # Binary variable for ATR_CCS_R system
    instance.on_atr_ccs_oc = Var(scales.scale_iter(1), domain=Binary)  # Binary variable for ATR_CCS_OC system
    instance.on_atr_ccs_r_oc = Var(scales.scale_iter(1), domain=Binary)  # Binary variable for ATR_CCS_R_OC system

    instance.cons10 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0,0):
            instance.cons10.add(expr = instance.P['HO', 'SMR', *i] >= 6000 * instance.on_smr[i]) #30% of max production rate

    instance.cons11 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0,0):
            instance.cons11.add(expr = instance.P['HO', 'ATR_CCS_R', *i] >= 4000 * instance.on_atr_ccs_r[i]) #20% of max production rate
    
    instance.cons12 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0,0):
            instance.cons12.add(expr = instance.P['HO', 'ATR_CCS_OC', *i] >= 4000 * instance.on_atr_ccs_oc[i]) #20% of max production rate

    instance.cons13 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0,0):
            instance.cons13.add(expr = instance.P['HO', 'ATR_CCS_R_OC', *i] >= 4000 * instance.on_atr_ccs_r_oc[i]) #20% of max production rate

    # For SMR
    instance.cons14 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0, 0):
        # Force production to zero if the system is off (on_smr == 0)
            instance.cons14.add(expr = instance.P['HO', 'SMR', *i] <= 20000 * instance.on_smr[i])

# For ATR_CCS_R
    instance.cons15 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0, 0):
        # Force production to zero if the system is off (on_atr_ccs_r == 0)
            instance.cons15.add(expr = instance.P['HO', 'ATR_CCS_R', *i] <= 20000 * instance.on_atr_ccs_r[i])

# For ATR_CCS_OC
    instance.cons16 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0, 0):
        # Force production to zero if the system is off (on_atr_ccs_oc == 0)
            instance.cons16.add(expr = instance.P['HO', 'ATR_CCS_OC', *i] <= 20000 * instance.on_atr_ccs_oc[i])

# For ATR_CCS_R_OC
    instance.cons17 = ConstraintList()
    for i in scales.scale_iter(1):
        #if i != (0, 0):
        # Force production to zero if the system is off (on_atr_ccs_r_oc == 0)
            instance.cons17.add(expr = instance.P['HO', 'ATR_CCS_R_OC', *i] <= 20000 * instance.on_atr_ccs_r_oc[i])


    return instance

# %%
models = [modeler(i+1) for i in range(100)]
# Out:
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# ...
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction
# constraint process capex
# constraint process fopex
# constraint process vopex
# constraint storage capex
# constraint process incidental
# constraint location capex
# constraint storage cost
# constraint storage cost location
# constraint storage cost network
# constraint global warming potential resource
# constraint global warming potential resource consumption
# constraint global warming potential resource discharge
# constraint global warming potential location
# constraint global warming potential network
# constraint production mode
# constraint inventory balance
# constraint inventory network
# constraint demand
# objective cost
# constraint global warming potential network reduction

# %%
def solver(instance, i): 
    return solve(scenario=scenario, instance=instance,
                     solver='gurobi', name=f"res_red/res_red_{i}", print_solversteps=True, saveformat = '.pkl')

# %%
results = {i: solver(m,i) for i,m in enumerate(models)}
# Out:
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xa69b3958
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 524612.54882
# Found heuristic solution: objective 500087.09491
# Found heuristic solution: objective 347300.00883
#
# Root relaxation: objective 3.173901e+05, 109 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 317390.119    0    1 347300.009 317390.119  8.61%     -    0s
# H    0     0                    317423.15934 317390.119  0.01%     -    0s
#
# Explored 1 nodes (109 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 317423 347300 500087 524613
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.174231593439e+05, best bound 3.174081302742e+05, gap 0.0047%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x098e3743
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 525626.23328
# Found heuristic solution: objective 501101.20006
# Found heuristic solution: objective 348121.57542
#
# Root relaxation: objective 3.174253e+05, 111 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 317425.271    0    1 348121.575 317425.271  8.82%     -    0s
# H    0     0                    317447.75405 317425.271  0.01%     -    0s
#
# Explored 1 nodes (111 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 317448 348122 501101 525626
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.174477540453e+05, best bound 3.174252711899e+05, gap 0.0071%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xe0f22c87
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 526640.52182
# Found heuristic solution: objective 502115.48859
# Found heuristic solution: objective 348958.24639
#
# Root relaxation: objective 3.179360e+05, 113 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 317936.010    0    1 348958.246 317936.010  8.89%     -    0s
# H    0     0                    317937.36124 317936.010  0.00%     -    0s
#
# Explored 1 nodes (113 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 317937 348958 502115 526641
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.179373612411e+05, best bound 3.179360101018e+05, gap 0.0004%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x160e3dba
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 527654.81035
# Found heuristic solution: objective 503129.77712
# Found heuristic solution: objective 349825.12342
#
# Root relaxation: objective 3.186519e+05, 118 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    318651.87967 318651.880  0.00%     -    0s
#
# Explored 1 nodes (118 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 318652 349825 503130 527655
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.186518796680e+05, best bound 3.186518796680e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xe9344208
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 528669.09888
# Found heuristic solution: objective 504144.06566
# Found heuristic solution: objective 350697.72521
#
# Root relaxation: objective 3.194016e+05, 140 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    319401.55840 319401.558  0.00%     -    0s
#
# Explored 1 nodes (140 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 319402 350698 504144 528669
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.194015584002e+05, best bound 3.194015584002e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x303fb858
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.02s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 529683.38742
# Found heuristic solution: objective 505158.35419
# Found heuristic solution: objective 351574.04888
#
# Root relaxation: objective 3.202150e+05, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 320215.026    0    1 351574.049 320215.026  8.92%     -    0s
# H    0     0                    320217.95748 320215.026  0.00%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 320218 351574 505158 529683
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.202179574784e+05, best bound 3.202150255481e+05, gap 0.0009%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xfabb9356
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 530697.67595
# Found heuristic solution: objective 506172.64272
# Found heuristic solution: objective 352474.95895
#
# Root relaxation: objective 3.210396e+05, 151 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 321039.637    0    1 352474.959 321039.637  8.92%     -    0s
# H    0     0                    321045.79838 321039.637  0.00%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 321046 352475 506173 530698
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.210457983797e+05, best bound 3.210396371802e+05, gap 0.0019%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xde223fa7
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 531711.96448
# Found heuristic solution: objective 507191.25871
# Found heuristic solution: objective 353405.24486
#
# Root relaxation: objective 3.218816e+05, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 321881.611    0    1 353405.245 321881.611  8.92%     -    0s
# H    0     0                    321895.45647 321881.611  0.00%     -    0s
#
# Explored 1 nodes (145 simplex iterations) in 0.01 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 321895 353405 507191 531712
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.218954564743e+05, best bound 3.218816105367e+05, gap 0.0043%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x718804e3
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 532745.98611
# Found heuristic solution: objective 508233.29356
# Found heuristic solution: objective 354345.07195
#
# Root relaxation: objective 3.227438e+05, 166 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 322743.835    0    1 354345.072 322743.835  8.92%     -    0s
# H    0     0                    322758.09879 322743.835  0.00%     -    0s
#
# Explored 1 nodes (166 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 322758 354345 508233 532746
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.227580987884e+05, best bound 3.227438352348e+05, gap 0.0044%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x39b8c20c
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.02s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 533789.41843
# Found heuristic solution: objective 502053.74673
# Found heuristic solution: objective 355290.40059
#
# Root relaxation: objective 3.236160e+05, 164 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 323615.979    0    1 355290.401 323615.979  8.92%     -    0s
# H    0     0                    323629.37379 323615.979  0.00%     -    0s
#
# Explored 1 nodes (164 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 323629 355290 502054 533789
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.236293737894e+05, best bound 3.236159794553e+05, gap 0.0041%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x3e09e9ef
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 366901.65123
# Found heuristic solution: objective 356249.00763
#
# Root relaxation: objective 3.245023e+05, 140 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 324502.277    0    1 356249.008 324502.277  8.91%     -    0s
# H    0     0                    324509.22825 324502.277  0.00%     -    0s
#
# Explored 1 nodes (140 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 324509 356249 366902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.245092282544e+05, best bound 3.245022772364e+05, gap 0.0021%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x14dbc607
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 371144.54991
# Found heuristic solution: objective 357216.69199
#
# Root relaxation: objective 3.254132e+05, 165 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 325413.248    0    1 357216.692 325413.248  8.90%     -    0s
# H    0     0                    325413.28247 325413.248  0.00%     -    0s
#
# Explored 1 nodes (165 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 325413 357217 371145
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.254132824725e+05, best bound 3.254132478168e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xf43f6b8b
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 378048.32027
# Found heuristic solution: objective 358210.49668
#
# Root relaxation: objective 3.263430e+05, 153 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    326343.00880 326343.009  0.00%     -    0s
#
# Explored 1 nodes (153 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 326343 358210 378048
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.263430088028e+05, best bound 3.263430088028e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xd03703c2
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 359224.78091
#
# Root relaxation: objective 3.272892e+05, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    327289.15628 327289.156  0.00%     -    0s
#
# Explored 1 nodes (150 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 327289 359225
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272891562761e+05, best bound 3.272891562761e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x976abfd1
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 360267.04944
#
# Root relaxation: objective 3.282485e+05, 156 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    328248.50647 328248.506  0.00%     -    0s
#
# Explored 1 nodes (156 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 328249 360267
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.282485064743e+05, best bound 3.282485064743e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xabb876e8
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 366222.31349
#
# Root relaxation: objective 3.292267e+05, 207 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    329226.73644 329226.736  0.00%     -    0s
#
# Explored 1 nodes (207 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 329227 366222
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.292267364361e+05, best bound 3.292267364361e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x28cc3c6a
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 3.302569e+05, 231 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    330256.88156 330256.882  0.00%     -    0s
#
# Explored 1 nodes (231 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 330257
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.302568815559e+05, best bound 3.302568815559e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x19cfaa86
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 3.313205e+05, 202 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    331320.54808 331320.548  0.00%     -    0s
#
# Explored 1 nodes (202 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: 331321
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.313205480793e+05, best bound 3.313205480793e+05, gap 0.0000%
# WARNING: Cannot get duals for MIP.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x08b29ebd
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.00s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 3.530134e+05, 229 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 353013.382    0    2          - 353013.382      -     -    0s
#
# Cutting planes:
#   Implied bound: 3
#   MIR: 1
#   StrongCG: 1
#   Flow cover: 4
#
# Explored 1 nodes (229 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x23c6375d
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 17056 columns
# Presolve time: 0.02s
# Presolved: 594 rows, 257 columns, 1853 nonzeros
# Variable types: 253 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 4.136508e+05, 278 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 413650.792    0    2          - 413650.792      -     -    0s
#
# Cutting planes:
#   MIR: 1
#   RLT: 1
#
# Explored 1 nodes (278 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x743c8fab
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2853 rows and 16987 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xc12cddb6
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x61d9e4e4
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x49a3a5df
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x13ce1983
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2804 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x33b4f02e
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 3036 rows and 17107 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xb2093384
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xb9f0e2ad
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x494fdcd2
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xfb05cfa3
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xc3800e34
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xb7a33708
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x1a4e29c7
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x56e34533
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# ...
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xab68742d
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x4213d1f9
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x535c69bf
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xc3bbad8f
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xf1a40517
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xf8bdbfa7
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xdfb30f19
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x6da9c9cb
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16964 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x411b7434
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16965 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x8357e638
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16966 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x29384ba6
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2783 rows and 16966 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x9186caff
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2789 rows and 16987 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.01 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0x9bf3d87c
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2902 rows and 17109 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# QCPDual  1
#
# Optimize a model with 3398 rows, 17313 columns and 9142 nonzeros
# Model fingerprint: 0xa7e22bd8
# Variable types: 17217 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-03, 1e+08]
# Presolve removed 2684 rows and 16859 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Cannot get duals for MIP.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: <undefined>

# %%
for i in range(len(models)):
    print(results[i].output['termination'])
# Out:
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# optimal
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible
# infeasible

# %% [markdown]
# Visualization of different optimal points as a function of Carbon Intensity vs. Total Hydrogen Cost

# %%
cost = [None for i in range(len(results))]
gwp_study = [None for i in range(len(results))]
prod_study = [None for i in range(len(results))]


for gwp_red, result in results.items():

    if result.output['termination'] == 'optimal':
        cost[gwp_red] = result.output['objective']
        gwp_study[gwp_red] = result.output['global_warming_potential_location']['HO', 0]
        prod_study[gwp_red] = result.output['P']

print(type(gwp_study[0]))

plt.plot(gwp_study, cost, color='blue', linestyle='--', alpha=0.5)

plt.xlabel('Total Cost of Hydrogen Production [USD]')
plt.ylabel('Carbon Intensity [kg CO$_2$ eq.]')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))  # For x-axis
plt.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # For y-axis
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha = 0.5)
# gwp_study[0]
# Out:
# <class 'float'>

# %% [markdown]
# ### A maximum reduction of 17% has been observed, the energy consumption on an hourly rate is graphed below:

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Generate time labels
time_labels = [datetime(2024, 1, 1) + timedelta(hours=i) for i in range(24)]

# Plotting the data
plt.plot(time_labels, [prod_study[17]['HO', 'Grid', 0, hour] for hour in range(24)], color='blue', label="Grid")
plt.plot(time_labels, [prod_study[17]['HO', 'PV', 0, hour] for hour in range(24)], color='red', linestyle='--', label="PV")
plt.plot(time_labels, [prod_study[17]['HO', 'WF', 0, hour] for hour in range(24)], color='g', linestyle=':', label="WF")


# Labeling axes
plt.xlabel('Time')
plt.ylabel('Total Electricity Consumed [MWh]')

# Format the y-axis in scientific notation
plt.ticklabel_format(style='sci', axis='y')  

# Set limits for y and x axes
plt.ylim(bottom=0)
plt.xlim([time_labels[0], time_labels[-1]])

# Set custom time labels for the x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))  # Hour:Minute format
plt.xticks(time_labels[::3])  # Show every second hour for better spacing

# Add grid
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### The hourly energy consumption rate of the cost minimization (Base case) scenario is plotted to compare with the strict 17% case

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Generate time labels
#For an entire year of hour data point I should maybe just discretize it into only months??
'''Second discretization is months, do I do a : "for i in range(12), for i in range(24)" so how do I make two time periods talk with each other?'''
time_labels = [datetime(2024, 1, 1) + timedelta(hours=i) for i in range(24)]
#datetime(2024, i, j,k) for i in range(1), for j in range(12), for k in range(24)
'''month_labels = [datetime(2024,1,1) + timedelta(months=i) for i in range(12)]'''

# Plotting the data
'''Example -> plt.plot(time_labels, [prod_study[0]['HO', 'Grid', month, hour] for month in range(12), for hour in range(24)], label="Grid")'''
plt.plot(time_labels, [prod_study[0]['HO', 'Grid', 0, hour] for hour in range(24)], color='blue', label="Grid")
plt.plot(time_labels, [prod_study[0]['HO', 'PV', 0, hour] for hour in range(24)], color='red', linestyle='--', label="PV")
plt.plot(time_labels, [prod_study[0]['HO', 'WF', 0, hour] for hour in range(24)], color='g', linestyle=':', label="WF")


# Labeling axes
plt.xlabel('Time')
plt.ylabel('Total Electricity Consumed [MWh]')

# Format the y-axis in scientific notation
plt.ticklabel_format(style='sci', axis='y')  

# Set limits for y and x axes
plt.ylim(bottom=0)
plt.xlim([time_labels[0], time_labels[-1]])

# Set custom time labels for the x-axis
'''plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Mo?:%D:%H:%M))'''
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))  # Hour:Minute format
plt.xticks(time_labels[::3])  # Show every second hour for better spacing this will have to be extend to show every 6 hours or actually not showing hours at all
'''plt.xticks(month_labels[::2] to show every second month?'''
# Add grid
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### A spread of hydrogen production profiles are shown below as the emission reduction constraint is increased

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta
import numpy as np

# Generate time labels
time_labels = [datetime(2024, 1, 1) + timedelta(hours=i) for i in range(24)]

# Data for plotting
data_sets = [0, 5, 10, 17]  # Indices of the different datasets

# Create a colormap from red to yellowgreen
cmap = plt.cm.get_cmap('RdYlGn', len(data_sets))

# Plot each dataset with its corresponding color
for i, study in enumerate(data_sets):
    plt.plot(time_labels, 
             [prod_study[study]['HO', 'ATR_CCS_R', 0, hour] for hour in range(24)], 
             color=cmap(i), label=f'Study {study}')

# Labeling axes
plt.xlabel('Time')
plt.ylabel('Total Amount of Hydrogen Produced [kg/hr]')

# Format the y-axis in scientific notation
plt.ticklabel_format(style='sci', axis='y')

# Set limits for y and x axes
plt.ylim(bottom=3000)
plt.xlim([time_labels[0], time_labels[-1]])

# Set custom time labels for the x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))  # Hour:Minute format
plt.xticks(time_labels[::3])  # Show every second hour for better spacing

# Add grid
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

# Create a colorbar to represent the spectrum of the studies
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=len(data_sets) - 1))
sm.set_array([])  # Empty array for the colorbar
cbar = plt.colorbar(sm, ax=plt.gca(), ticks=np.linspace(0, len(data_sets) - 1, len(data_sets)))
cbar.set_label('Reduction in Carbon Dioxide Emissions')
cbar.set_ticks([0, 1, 2, 3])
cbar.set_ticklabels([f'{study}% reduction' for study in data_sets])

# Show the plot
plt.show()
# Out:
# C:\Users\marcopdsousa\AppData\Local\Temp\ipykernel_39080\3804237497.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('RdYlGn', len(data_sets))

# %% [markdown]
# ## End of small Demo

# %%
# def load_data(loc:str, index:list):
#     df = pandas.read_csv(f'data/{loc}_solar19.csv')
#     df['idx'] = index
#     df = df.set_index('idx')
#     return df
# idx = [(i,j,k) for i,j,k in product(range(1), range(365), range(24))]
# weather_ny = load_data('ny', idx)[['DNI', 'Wind Speed']]
# weather_ny = weather_ny.rename(columns= {'DNI': 'dni', 'Wind Speed': 'wind_speed'})
# weather_sd = load_data('sd', idx)[['dni', 'wind_speed']]
# weather_ho = load_data('ho', idx)[['dni', 'wind_speed']]""
# demand_sd = pandas.read_excel('data/HistoricalEMSHourlyLoad-2019.xlsx', index_col= 0)[['SDGE']]
# demand_ho = pandas.read_excel('data/Native_Load_2019.xlsx')[['COAST']]
# demand_ny = DataFrame(pandas.read_csv('data/NYC_load.csv')['Load']) #from Will and Doga
# ng_price = make_henry_price_df(
#     file_name='data/Henry_Hub_Natural_Gas_Spot_Price_Daily.csv', year=2020)
# ng_price = ng_price.drop(columns= 'scales')
# ng_price = remove_outliers(ng_price, sd_cuttoff = 3)
# ng_price = pandas.concat([ng_price])

# %%
from src.energiapy.analytical.decision import Decision
from src.energiapy.analytical.taskmaster import Chanakya

# %%
c = Chanakya('c')

# %%
c.transact.causes
# Out:
# [trade, build, operate]

# %%
c.transact.pos
# Out:
# transact[+]

# %%
# from energiapy.components import *
from energiapy.environ import *
from pandas import DataFrame
from dataclasses import fields, field, dataclass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # from energiapy.components import *
# ----> 2 from energiapy.environ import *
#       3 from pandas import DataFrame
#       4 from dataclasses import fields, field, dataclass
#
# ModuleNotFoundError: No module named 'energiapy'

# %%
from energiapy.components.analytical.player import Player
from energiapy.components.commodity.cash import Cash
from energiapy.components.commodity.emission import Emission
from energiapy.components.commodity.land import Land
from energiapy.components.commodity.resource import Resource
from energiapy.components.operation.process import Process
from energiapy.components.operation.storage import Storage
from energiapy.components.operation.transit import Transit
from energiapy.components.spatial.linkage import Linkage
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from energiapy.components.analytical.player import Player
#       2 from energiapy.components.commodity.cash import Cash
#       3 from energiapy.components.commodity.emission import Emission
#
# File ~/Desktop/repos/energiapy/src/energiapy/components/analytical/player.py:12
#       9 from dataclasses import dataclass, fields
#      11 from .._attrs._bounds import _Emit, _Setup, _Trade, _Transact, _Use
# ---> 12 from .._base._defined import _Defined
#      15 @dataclass
#      16 class Player(_Transact, _Emit, _Trade, _Use, _Setup, _Defined):
#      17     """Player represents a decision maker in the Scenario
#      18
#      19     A Player has ownership of some Commodities which they give
#    (...)
#      30         label (str): label of the component
#      31     """
#
# File ~/Desktop/repos/energiapy/src/energiapy/components/_base/_defined.py:7
#       4 from dataclasses import dataclass, field
#       6 from ...core._handy._printers import _EasyPrint
# ----> 7 from ._component import _Component
#       8 from ._consistent import _Consistent
#      11 @dataclass
#      12 class _Defined(_Component, _Consistent, _EasyPrint):
#
# File ~/Desktop/repos/energiapy/src/energiapy/components/_base/_component.py:10
#       7 from typing import TYPE_CHECKING
#       9 from ...core._handy._dunders import _Dunders
# ---> 10 from ...environ.program import Block
#      13 if TYPE_CHECKING:
#      14     from ...environ.model import Model
#
# File ~/Desktop/repos/energiapy/src/energiapy/environ/__init__.py:6
#       1 """environ init file
#       2 """
#       4 __all__ = ['Scenario']
# ----> 6 from .scenario import Scenario
#
# File ~/Desktop/repos/energiapy/src/energiapy/environ/scenario.py:37
#       1 """Scenario, is the core object
#       2
#       3     All Components defined as a scenario attribute.
#    (...)
#      32     The Matrix Model is just a matrix representation of the problem block
#      33 """
#      35 from dataclasses import dataclass, field
# ---> 37 from ..components._base._component import _Component
#      38 from ..components._base._defined import _Defined
#      39 from ..components.commodity.resource import ResourceStg, ResourceTrn
#
# ImportError: cannot import name '_Component' from partially initialized module 'energiapy.components._base._component' (most likely due to a circular import) (/Users/cacodcar/Desktop/repos/energiapy/src/energiapy/components/_base/_component.py)

# %%
s = Scenario(default=True)

# %%
s.birth_scales(scales=[2, 12])
s.birth_locations(locations=[1, 1, 1], names=['madgaon', 'ponje', 'cacoda'])

# %%
s.network.locations
# Out:
# [madgaon, ponje, cacoda]

# %%
s.alink = Linkage(source=s.madgaon, sink=s.ponje, bi=True, distance=50)
s.blink = Linkage(source=s.ponje, sink=s.cacoda, bi=False, distance=80)
s.clink = Linkage(source=s.cacoda, sink=s.madgaon, bi=True, distance=100)
s.dlink = Linkage(source=s.madgaon, sink=s.ponje, bi=False, distance=200)

# %%
a = DataFrame({'a': list(range(2))})
b = DataFrame({'b': list(range(24))})

# %%
s.program
# Out:
# :s:

# %%
s.taskmaster
# Out:
# TaskMaster|:s:|

# %%
s.csh = Cash(
    spend={
        s.madgaon: True,
        s.ponje: {s.t1: (2, a)},
        s.cacoda: a,
        s.network: {s.t1: [5, 7]},
    },
    # label='cash',
    basis='USD',
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s.csh = Cash(
#       2     spend={
#       3         s.madgaon: True,
#       4         s.ponje: {s.t1: (2, a)},
#       5         s.cacoda: a,
#       6         s.network: {s.t1: [5, 7]},
#       7     },
#       8     # label='cash',
#       9     basis='USD',
#      10 )
#
# File c:\Users\cacodcar\energiapy\src\energiapy\environ\scenario.py:152, in Scenario.__setattr__(self, name, value)
#     148     self.isok_nolabel(component=value)
#     149     # All defined components have constraints
#     150     # The data is handled first and made into internal formats and added to the Data Model
#     151     # The Program Model is then generated using information from the Data Model
# --> 152     self.update_model(name=name, component=value)
#     154 # find where all the Operation is located
#     155 # if nothing is provided, available throughout Network (all locations)
#     156 if isinstance(value, _Operation):
#
# File c:\Users\cacodcar\energiapy\src\energiapy\environ\_scenario\_update.py:119, in _Update.update_model(self, name, component)
#     107 """Updates the Data and System Model with the components
#     108
#     109 Args:
#     110     name (str): name of component
#     111     component (IsDfn): Component to be added
#     112 """
#     114 # Make the component inputs consistent
#     115 # i.e. of the form - {Spatial[Location, Linkage, Network]: Temporal[Scale]: Mode[X]: Value}
#     116 # Value can be numeric, DataFrame, True
#     117 # or a tuple of numeric or DataFrame
#     118 # or a list or numeric, DataFrame, True, or a tuple of numeric or DataFrame
# --> 119 component.make_consistent(getattr(self, 'ok_inconsistent'))
#     121 # make Small Blocks to be added to the larger Model Blocks
#     122 # where all the model elements go
#     123 programblock: Block = component.programblock
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:422, in _Consistent.make_consistent(self, ok_inconsistent)
#     419     if value is None:
#     420         continue
# --> 422     setattr(self, attr, make_any_consistent(value, attr, ok_inconsistent))
#     424 setattr(self, 'consistent', True)
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:410, in _Consistent.make_consistent.<locals>.make_any_consistent(value, attr, ok_inconsistent)
#     407     return make_exact_consistent(value, attr, ok_inconsistent)
#     409 if attr in self.bounds() + self.boundbounds():
# --> 410     return make_bound_consistent(value, attr, ok_inconsistent)
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:400, in _Consistent.make_consistent.<locals>.make_bound_consistent(value, attr, ok_inconsistent)
#     396 """Makes Bound inputs consistent"""
#     397 # Bounds are defined for the Component itself
#     398 # or can be declared at other components
# --> 400 return self.make_spttmpmde(value, attr, ok_inconsistent)
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:354, in _Consistent.make_spttmpmde(self, value, attr, ok_inconsistent)
#     350 spttmpmdeval = self.make_modes(
#     351     value=self.make_temporal(self.make_spatial(value)), attr=attr
#     352 )
#     353 # Then we fix the temporal disposition and warn if inconsistent
# --> 354 spttmpmdeval = self.fix_temporal(spttmpmdeval, attr, ok_inconsistent)
#     356 # The dummy values are replaced with actual values
#     357 spttmpmdeval = self.modize(
#     358     self.temporalize(self.spatialize(spttmpmdeval, attr))
#     359 )
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:239, in _Consistent.fix_temporal(self, spttmpmdeval, attr, ok_inconsistent)
#     237 for tmp, mdeval in tmpmdeval.items():
#     238     for val in mdeval.values():
# --> 239         scl_upd = self.match_scale(val, tmp, attr)
#     240         if is_not(scl_upd, tmp):
#     241             if ok_inconsistent:
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:216, in _Consistent.match_scale(self, val, tmp, attr)
#     212     return self.system.horizon.match_scale(val, self, attr)
#     213 elif isinstance(val, (list, tuple)) and any(
#     214     isinstance(v, DataFrame) for v in val
#     215 ):
# --> 216     return sorted(self.match_scale(v, self, attr) for v in val)[-1]
#     217 else:
#     218     return tmp
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:216, in <genexpr>(.0)
#     212     return self.system.horizon.match_scale(val, self, attr)
#     213 elif isinstance(val, (list, tuple)) and any(
#     214     isinstance(v, DataFrame) for v in val
#     215 ):
# --> 216     return sorted(self.match_scale(v, self, attr) for v in val)[-1]
#     217 else:
#     218     return tmp
#
# File c:\Users\cacodcar\energiapy\src\energiapy\components\_base\_consistent.py:212, in _Consistent.match_scale(self, val, tmp, attr)
#     210 # if value is a DataFrame, check if the scale is consistent
#     211 if isinstance(val, DataFrame):
# --> 212     return self.system.horizon.match_scale(val, self, attr)
#     213 elif isinstance(val, (list, tuple)) and any(
#     214     isinstance(v, DataFrame) for v in val
#     215 ):
#     216     return sorted(self.match_scale(v, self, attr) for v in val)[-1]
#
# AttributeError: 'System' object has no attribute 'horizon'

# %%
from operator import is_

is_(s.registrar.spend[0], s.registrar.spend[1])

# %%
s.H2 = Resource(
    # sell={s.t0: [0, 4], s.t1: [a, 34], s.t2: (a, b)},
    sell_price={
        s.madgaon: {s.t1: (2, a)},
        s.ponje: {s.t1: (2, b)},
        s.cacoda: 300,
    },
)

# %%
s.Solar = Resource(buy=True, basis='MW', label='Solar Power')


s.Wind = Resource(buy=a, basis='MW', label='Wind Power')


s.Power = Resource(basis='MW', label='Power generated')


s.Uranium = Resource(
    buy=DataFrame({'a': [i for i in range(24)]}),
    buy_price=42.70 / (250 / 2),
    basis='kg',
    label='Uranium',
)


# s.H2_L = Resource(sell=(0, 23), basis='tons', label='Hydrogen')


# s.CO2_AQoff = Resource(basis='tons', label='Carbon dioxide - sequestered')


s.H2O = Resource(buy=(20, 50), buy_price=b, basis='tons', label='Water')


s.CH4 = Resource(buy=[20, 40], buy_price=20, basis='tons', label='Natural gas')


s.CO2 = Resource(basis='tons', label='Carbon dioxide', block='Resource')


s.CO2_Vent = Resource(
    basis='tons',
    label='Carbon dioxide - Vented',
    sell_price=(2, 20),
    sell_emit={s.gwp: b},
)


s.O2 = Resource(sell=[20, True], basis='tons', label='Oxygen')


s.CO2_DAC = Resource(basis='tons', label='Carbon dioxide - captured')
s.Power = Resource(buy=[0, a], basis='MW', label='Power generated')

# %%
s.LiR = Resource(
    use_emit={s.gwp: {s.t1: 1.484}},
    use={s.ponje: 1.5},
    basis='kg',
    label='Lithium Reserves',
    citation='Nelson Bunyui Manjong (2021)',
)

# %%
s.WF = Process(
    conversion={s.Power: {X(0): {s.Wind: -1}, X(1): {s.Wind: -1}}},
    produce=[(0, 3), (3, 5)],
    capex={s.madgaon: {s.t1: {1462000, I(202233)}}},
    opex={4953, I(70)},
    setup=1000,
    setup_emit={s.gwp: 50, s.odp: 2900},
    setup_use={s.LiR: 1.5, s.land: 30},
    locations=[s.madgaon, s.ponje],
    label='Wind mill array',
    basis='MW',
)


s.PV = Process(
    conversion={s.Power: {X(1): {s.Solar: -1.2}, X(2): {s.Solar: -1.5}}},
    capex={X(0): 1333, X(1): 1444, X(2): 1555},
    opex=22623,
    setup={X(0): 3000, X(1): 4000, X(2): 5000},
    locations=s.cacoda,
    label='Solar PV',
    basis='MW',
)


s.SMRH = Process(
    setup_use={s.land: 50},
    conversion={
        s.H2: {
            s.Power: -1.11,
            s.CH4: -3.76,
            s.H2O: -23.7,
            s.CO2_Vent: 1.03,
            s.CO2: 9.332,
        }
    },
    capex={
        2520000,
    },
    opex={51.5, I(945000)},
    setup=[1000],
    label='Steam methane reforming + CCUS',
)

s.NGCC = Process(
    conversion={
        s.Power: {
            s.CH4: -0.108,
            s.H2O: -10,
            s.CO2_Vent: 0.297 * 0.05,
            s.CO2: 0.297 * 0.95,
        }
    },
    capex=2158928,
    opex={4090, I(53320)},
    setup=[1, 100],
    label='NGCC + 95% CC',
)
s.SMR = Process(
    capex=2400,
    opex={0.03, I(800)},
    conversion={s.H2: {s.Power: -1.11, s.CH4: -3.76, s.H2O: -23.7, s.CO2_Vent: 9.4979}},
    setup=1000,
    label='Steam methane reforming',
)
s.H2FC = Process(
    conversion={s.Power: {s.H2: -0.050}},
    capex=1.6 * 10**6,
    opex=3.5,
    setup=[1000, 2000],
    label='hydrogen fuel cell',
)
s.DAC = Process(
    capex=0.02536,
    opex=0.634,
    conversion={s.CO2_DAC: {s.Power: -0.193, s.H2O: -4.048}},
    setup=1000,
    label='Direct air capture',
)
# s.PSH = Process(conversion = {s.Power: 0.6}, capex = 3924781, fopex= 17820, vopex = 512.5, store = 10000, capacity=1000, label='Pumped storage hydropower', basis = 'MW')
s.ASMR = Process(
    conversion={s.Power: {s.Uranium: -4.17 * 10 ** (-5), s.H2O: -3.364}},
    capex=7988951,
    opex=I(0.04 * 0.730),
    setup=1000,
    label='Small modular reactors (SMRs)',
    locations=s.madgaon,
)
s.AWE = Process(
    setup_use={s.land: (0, 20)},
    conversion={s.H2: {s.Power: -1, s.O2: 0.7632, s.H2O: -0.1753}},
    capex={1.1 * 10**6, I(20)},
    opex=I(16918),
    setup=True,
    label='Alkaline water electrolysis (AWE)',
    citation='Demirhan et al. 2018 AIChE paper',
)

# %%
s.LiI = Storage(setup=[2000], inventory=s.Power, setup_in=[40], setup_out=[20])
s.LiI2 = Storage(setup=[2000], inventory={s.Power: 0.6})
s.H2Stg = Storage(
    setup=[2000], inventory={s.H2: {X(0): {s.Power: 0.8}, X(1): {s.Power: 0.9}}}
)

# %%
s.parameters[4].__dict__

# %%
s.program.variables

# %%
s.attr.buy.cns()

# %%
s.data.__dict__
s.data.H2.__dict__

# %%
s.registrar.__dict__

# %%
s.H2FC.pprint()

# %%
s.H2FC.constraints[-1].__dict__

# %%
s.WF.constraints[-1].__dict__

# %%
s.NGCC.pprint()

# %%
s.pprint()

# %%
[100 * (i + 1) / 14 for i in range(14)]

# %%
[100 * (i + 1) / 13 for i in range(13)]

# %%
print(len(s.variables))
print(len(set(s.variables)))
print(len(set([v.name for v in s.variables])))
print()
print(len(s.parameters))
print(len(set(s.parameters)))
print(len(set([v.name for v in s.parameters])))
print()
print(len(s.constraints))
print(len(set(s.constraints)))
print(len(set([v.name for v in s.constraints])))
print()
print(len(s.indices))
print(len(set(s.indices)))
print(len(set([v.name for v in s.indices])))

# %%
s.registrar.__dict__

# %%
s.registrar.mbounds

# %%
s.indices

# %%
s.parameters

# %%
sorted(s.indices)

# %%
s.indices[43].__dict__

# %%
s.indices[40].disposition == s.indices[43].disposition

# %%
s.SMRH.program.indices

# %%
s.indices[40].__dict__

# %%
s.train = Transit(
    freight=s.H2,
    setup=[5, 400],
    setup_use={s.land: 20},
    setup_emit={s.odp: 0.1},
    capex={s.alink: 200, s.blink: 300, s.clink: 400},
    opex=100,
    label='Train',
    basis='passengers',
    linkages=[s.alink],
)

# %%
s.train.pprint()

# %%
s.pprint()
